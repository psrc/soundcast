# %%
import os, sys, time, glob
import warnings
import re
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import pandana as pdna
pd.options.mode.chained_assignment = None
import h5py
sys.path.append(os.path.join(os.getcwd(),r'..\..\..'))
from input_configuration import base_year

# %matplotlib inline

from IPython.display import display, HTML

if (sys.version_info < (3, 0)):
    HTML('''<script>
    code_show=true; 
    function code_toggle() {
     if (code_show){
     $('div.input').hide();
     } else {
     $('div.input').show();
     }
     code_show = !code_show
    } 
    $( document ).ready(code_toggle);
    </script>
    <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))

# Relative path between notebooks and goruped output directories
relative_path = '../../../outputs'
survey_path = '../../../inputs/base_year/survey'

# Write out CSVs with a numeric value prefix to help organize outputs 
incr = 1

# %%
pd.options.display.float_format = '{:0,.0f}'.format

# %%
output_dir = r'..\..\..\outputs\compare\RTP\mode_share'

# %% [markdown]
# # Commute Tours to RGCs

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\tour_rgc_dest.csv')

# %%
pd.options.display.float_format = '{:0,.1%}'.format
_df = df[df['pdpurp'] == 'Work']
_df = _df.pivot_table(columns='tour_d_rgc', index='tmodetp', values='toexpfac', aggfunc='sum')
for col in _df:
    _df[col] = _df[col]/_df[col].sum()
_df = _df.T
_df.to_clipboard()
_df
# Out:
# tmodetp                                   Bike  HOV2  HOV3+  Park   SOV  TNC  \
# tour_d_rgc
# Auburn                                    1.2% 16.5%   8.0%  2.5% 64.2% 0.7%
# Ballard-Interbay                          1.8% 15.1%   7.2%  1.4% 62.2% 1.4%
# Bellevue                                  1.1% 15.0%   7.6%  4.7% 51.9% 0.8%
# Bothell Canyon Park                       0.9% 17.6%   9.3%  1.8% 67.5% 0.7%
# Bremerton                                 1.2% 17.4%   8.5%  2.0% 63.4% 0.7%
# Burien                                    1.1% 15.7%   8.8%  1.7% 64.2% 1.0%
# Cascade                                   1.6% 18.8%   9.6%  0.9% 67.2% 0.7%
# Duwamish                                  1.3% 16.4%   8.1%  1.6% 63.4% 1.2%
# Everett                                   1.4% 17.3%   9.5%  2.7% 59.5% 0.9%
# Federal Way                               1.0% 16.1%   7.7%  5.2% 60.2% 0.5%
# Frederickson                              1.3% 19.7%   9.3%   NaN 69.0% 0.6%
# Issaquah                                  0.5% 17.4%   8.4%  1.9% 67.7% 1.0%
# Kent                                      0.9% 17.1%   9.1%  2.3% 63.6% 0.9%
# Kent MIC                                  0.7% 17.6%   8.8%  1.7% 67.0% 0.7%
# Kirkland Totem Lake                       1.0% 17.3%   8.8%  1.6% 67.3% 0.9%
# Lakewood                                  1.5% 17.8%   9.7%  1.9% 64.4% 0.7%
# Lynnwood                                  1.4% 17.3%   8.5%  1.8% 66.3% 0.7%
# North Tukwila                             1.0% 16.4%   8.2%  1.2% 68.4% 0.5%
# Not in RGC                                1.1% 17.2%   8.6%  1.6% 65.6% 0.9%
# Paine Field / Boeing Everett              1.2% 17.6%   9.1%  1.2% 68.1% 0.5%
# Port of Tacoma                            0.9% 17.8%   9.5%  0.7% 69.2% 0.6%
# Puget Sound Industrial Center- Bremerton  0.4% 17.4%   8.3%   NaN 73.4% 0.4%
# Puyallup Downtown                         1.3% 16.9%   8.0%  3.4% 61.1% 0.8%
# Puyallup South Hill                       1.1% 18.3%  10.5%  2.2% 64.8% 0.7%
# Redmond Downtown                          1.1% 15.2%   7.7%  2.8% 60.0% 1.0%
# Redmond-Overlake                          0.9% 15.9%   8.2%  3.7% 62.3% 0.8%
# Renton                                    0.8% 17.2%   8.6%  2.4% 64.8% 0.6%
# SeaTac                                    0.9% 16.2%   8.2%  2.2% 63.3% 0.6%
# Seattle Downtown                          1.4% 10.5%   5.2%  5.7% 35.2% 1.8%
# Seattle First Hill/Capitol Hill           1.4% 12.5%   6.1%  3.5% 43.2% 2.5%
# Seattle Northgate                         2.1% 16.5%   7.8%  1.8% 61.3% 0.7%
# Seattle South Lake Union                  1.8% 11.7%   5.6%  4.8% 41.2% 1.7%
# Seattle University Community              1.6% 13.1%   6.7%  4.1% 46.6% 1.3%
# Seattle Uptown                            1.9% 13.1%   6.8%  2.0% 50.1% 1.8%
# Silverdale                                1.1% 16.9%   8.9%  1.9% 67.4% 0.8%
# Sumner Pacific                            0.9% 18.8%   9.4%  0.2% 69.5% 0.6%
# Tacoma Downtown                           1.3% 17.2%   9.1%  3.0% 60.1% 0.9%
# Tacoma Mall                               1.4% 17.6%   8.8%  2.9% 63.2% 0.8%
# Tukwila                                   0.8% 17.2%   8.7%  2.5% 64.3% 0.9%
# University Place                          1.6% 18.3%   9.4%  1.4% 63.7% 0.8%
#
# tmodetp                                   Transit  Walk
# tour_d_rgc
# Auburn                                       5.6%  1.3%
# Ballard-Interbay                             5.6%  5.2%
# Bellevue                                     8.9%  9.9%
# Bothell Canyon Park                          1.7%  0.5%
# Bremerton                                    2.6%  4.2%
# Burien                                       4.5%  3.1%
# Cascade                                      0.8%  0.5%
# Duwamish                                     7.4%  0.6%
# Everett                                      2.9%  5.7%
# Federal Way                                  7.0%  2.3%
# Frederickson                                  NaN  0.1%
# Issaquah                                     2.6%  0.4%
# Kent                                         5.3%  0.9%
# Kent MIC                                     3.3%  0.1%
# Kirkland Totem Lake                          2.1%  1.1%
# Lakewood                                     1.6%  2.4%
# Lynnwood                                     2.5%  1.5%
# North Tukwila                                4.1%  0.1%
# Not in RGC                                   3.1%  1.9%
# Paine Field / Boeing Everett                 1.7%  0.5%
# Port of Tacoma                               1.0%  0.2%
# Puget Sound Industrial Center- Bremerton      NaN   NaN
# Puyallup Downtown                            6.4%  2.2%
# Puyallup South Hill                          1.4%  1.0%
# Redmond Downtown                             4.8%  7.4%
# Redmond-Overlake                             6.4%  1.7%
# Renton                                       3.8%  1.7%
# SeaTac                                       7.6%  0.9%
# Seattle Downtown                            27.0% 13.3%
# Seattle First Hill/Capitol Hill             14.6% 16.4%
# Seattle Northgate                            4.8%  4.9%
# Seattle South Lake Union                    18.8% 14.3%
# Seattle University Community                21.2%  5.5%
# Seattle Uptown                               7.1% 17.2%
# Silverdale                                   0.9%  2.2%
# Sumner Pacific                               0.4%  0.3%
# Tacoma Downtown                              3.3%  5.1%
# Tacoma Mall                                  2.9%  2.4%
# Tukwila                                      5.5%  0.1%
# University Place                             2.0%  2.8%

# %% [markdown]
# # Commute Trips to RGCs
#
# ### All Work Destinations (regardless of origin)

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\trip_rgc_dest.csv')

# %%
pd.options.display.float_format = '{:0,.1%}'.format
_df = df[df['dpurp'] == 'Work']
_df = _df.pivot_table(columns='trip_d_rgc', index='mode', values='trexpfac', aggfunc='sum')
for col in _df:
    _df[col] = _df[col]/_df[col].sum()
_df = _df.T
_df.to_clipboard()
_df
# Out:
# mode                                      Bike  HOV2  HOV3+   SOV  School Bus  \
# trip_d_rgc
# Auburn                                    1.2% 11.1%   4.7% 70.1%         NaN
# Ballard-Interbay                          1.7% 10.1%   4.7% 64.8%         NaN
# Bellevue                                  1.2%  9.2%   4.4% 48.6%         NaN
# Bothell Canyon Park                       0.9% 11.2%   5.4% 75.4%        0.0%
# Bremerton                                 1.2% 10.6%   4.9% 66.6%         NaN
# Burien                                    1.1% 10.7%   5.4% 70.3%         NaN
# Cascade                                   1.5% 12.0%   5.7% 75.8%         NaN
# Duwamish                                  1.3% 11.1%   5.3% 67.3%        0.0%
# Everett                                   1.4% 10.2%   5.1% 62.5%        0.0%
# Federal Way                               0.8% 10.0%   4.0% 66.7%         NaN
# Frederickson                              1.2% 11.7%   6.2% 78.0%         NaN
# Issaquah                                  0.6% 10.9%   4.7% 73.9%         NaN
# Kent                                      0.9% 10.5%   4.9% 70.1%         NaN
# Kent MIC                                  0.8% 11.5%   5.3% 74.8%        0.0%
# Kirkland Totem Lake                       1.0% 11.0%   5.1% 73.5%         NaN
# Lakewood                                  1.3% 10.0%   5.0% 71.2%        0.0%
# Lynnwood                                  1.2% 10.4%   4.5% 72.7%        0.0%
# North Tukwila                             0.8% 11.8%   5.3% 74.6%         NaN
# Not in RGC                                1.1% 11.0%   5.1% 72.2%        0.0%
# Paine Field / Boeing Everett              1.2% 11.6%   5.5% 75.3%        0.0%
# Port of Tacoma                            1.1% 11.9%   5.9% 75.7%         NaN
# Puget Sound Industrial Center- Bremerton  1.0% 11.5%   4.9% 81.2%         NaN
# Puyallup Downtown                         1.3% 11.2%   4.4% 67.9%         NaN
# Puyallup South Hill                       1.0% 10.9%   5.6% 73.2%         NaN
# Redmond Downtown                          1.1%  8.9%   4.3% 64.6%        0.0%
# Redmond-Overlake                          0.9%  9.9%   4.4% 65.7%        0.0%
# Renton                                    0.8% 11.0%   4.8% 71.5%        0.0%
# SeaTac                                    1.0% 10.7%   5.0% 69.5%         NaN
# Seattle Downtown                          1.5%  7.0%   3.4% 32.1%         NaN
# Seattle First Hill/Capitol Hill           1.4%  8.1%   3.6% 40.7%         NaN
# Seattle Northgate                         1.8% 10.7%   4.7% 66.7%        0.0%
# Seattle South Lake Union                  1.9%  7.3%   3.5% 38.6%         NaN
# Seattle University Community              1.7% 10.2%   4.9% 49.1%        0.0%
# Seattle Uptown                            1.9%  8.2%   4.0% 47.4%        0.0%
# Silverdale                                1.0%  9.7%   4.7% 71.4%        0.0%
# Sumner Pacific                            0.9% 12.4%   5.6% 77.8%         NaN
# Tacoma Downtown                           1.4% 10.4%   5.0% 61.5%        0.0%
# Tacoma Mall                               1.3% 11.0%   4.9% 68.1%         NaN
# Tukwila                                   0.8% 11.0%   5.3% 70.6%         NaN
# University Place                          1.9% 10.6%   5.7% 70.9%         NaN
#
# mode                                      TNC  Transit  Walk
# trip_d_rgc
# Auburn                                   1.8%     4.9%  6.3%
# Ballard-Interbay                         3.7%     5.1%  9.9%
# Bellevue                                 4.1%     9.0% 23.6%
# Bothell Canyon Park                      1.6%     2.1%  3.4%
# Bremerton                                2.6%     3.4% 10.8%
# Burien                                   1.4%     5.0%  6.1%
# Cascade                                  1.2%     1.0%  2.8%
# Duwamish                                 3.2%     7.4%  4.4%
# Everett                                  2.7%     3.6% 14.4%
# Federal Way                              1.5%     8.2%  8.7%
# Frederickson                             0.8%      NaN  2.1%
# Issaquah                                 2.0%     2.8%  5.0%
# Kent                                     1.7%     5.1%  6.9%
# Kent MIC                                 1.8%     3.7%  2.1%
# Kirkland Totem Lake                      1.8%     2.5%  5.0%
# Lakewood                                 1.7%     2.4%  8.4%
# Lynnwood                                 1.8%     2.7%  6.7%
# North Tukwila                            1.1%     4.8%  1.6%
# Not in RGC                               1.9%     3.3%  5.3%
# Paine Field / Boeing Everett             1.5%     2.0%  2.9%
# Port of Tacoma                           1.7%     1.4%  2.3%
# Puget Sound Industrial Center- Bremerton 0.7%      NaN  0.7%
# Puyallup Downtown                        1.4%     6.2%  7.6%
# Puyallup South Hill                      1.4%     2.5%  5.3%
# Redmond Downtown                         2.0%     4.8% 14.2%
# Redmond-Overlake                         2.9%     6.7%  9.5%
# Renton                                   1.8%     4.3%  5.8%
# SeaTac                                   1.6%     7.1%  5.1%
# Seattle Downtown                         4.9%    21.4% 29.6%
# Seattle First Hill/Capitol Hill          5.4%    12.2% 28.5%
# Seattle Northgate                        1.9%     5.0%  9.2%
# Seattle South Lake Union                 5.1%    14.9% 28.7%
# Seattle University Community             4.2%    17.7% 12.1%
# Seattle Uptown                           5.2%     6.6% 26.8%
# Silverdale                               1.5%     1.8%  9.9%
# Sumner Pacific                           1.1%     0.4%  1.8%
# Tacoma Downtown                          2.8%     4.8% 14.1%
# Tacoma Mall                              2.0%     4.2%  8.6%
# Tukwila                                  2.3%     5.7%  4.3%
# University Place                         1.5%     2.4%  7.0%

# %% [markdown]
# ### Origin Home, Destination Work

# %%
pd.options.display.float_format = '{:0,.1%}'.format
_df = df[(df['opurp'] == 'None/Home') | (df['dpurp'] == 'Work')]
_df = _df.pivot_table(columns='trip_d_rgc', index='mode', values='trexpfac', aggfunc='sum')
for col in _df:
    _df[col] = _df[col]/_df[col].sum()
_df = _df.T
_df.to_clipboard()
_df
# Out:
# mode                                      Bike  HOV2  HOV3+   SOV  School Bus  \
# trip_d_rgc
# Auburn                                    1.0% 24.5%  16.7% 48.1%        0.4%
# Ballard-Interbay                          1.6% 18.6%  11.0% 51.2%        1.0%
# Bellevue                                  1.2% 16.5%  11.1% 38.1%        0.7%
# Bothell Canyon Park                       1.0% 22.0%  14.8% 54.0%        1.5%
# Bremerton                                 1.2% 18.6%  11.5% 50.5%        0.1%
# Burien                                    0.9% 22.7%  16.4% 47.4%        1.1%
# Cascade                                   1.2% 22.6%  15.6% 54.2%        1.0%
# Duwamish                                  1.3% 19.7%  12.2% 54.0%        0.4%
# Everett                                   1.3% 22.2%  16.2% 42.7%        0.7%
# Federal Way                               0.8% 20.8%  14.2% 54.1%        0.4%
# Frederickson                              1.2% 21.9%  16.0% 55.8%        0.5%
# Issaquah                                  0.6% 23.6%  14.8% 54.3%        0.1%
# Kent                                      0.8% 23.0%  15.8% 50.0%        0.8%
# Kent MIC                                  0.9% 19.9%  12.8% 59.7%        0.3%
# Kirkland Totem Lake                       1.4% 20.4%  13.3% 54.1%        1.1%
# Lakewood                                  1.0% 26.6%  17.9% 44.8%        0.9%
# Lynnwood                                  1.0% 24.0%  15.6% 50.1%        0.7%
# North Tukwila                             1.0% 19.8%  12.3% 60.0%        0.3%
# Not in RGC                                1.3% 23.2%  16.9% 42.6%        2.6%
# Paine Field / Boeing Everett              1.3% 15.4%   9.1% 67.0%        0.3%
# Port of Tacoma                            1.2% 21.5%  14.1% 58.1%        0.2%
# Puget Sound Industrial Center- Bremerton  1.1% 20.0%  13.6% 63.2%        0.6%
# Puyallup Downtown                         1.3% 26.4%  19.3% 41.4%        2.2%
# Puyallup South Hill                       0.8% 25.7%  17.6% 48.0%        0.8%
# Redmond Downtown                          1.0% 22.1%  14.8% 46.3%        1.0%
# Redmond-Overlake                          1.0% 15.6%   9.5% 54.8%        0.8%
# Renton                                    1.0% 21.6%  14.2% 51.2%        1.2%
# SeaTac                                    1.0% 17.9%  11.5% 56.4%        0.3%
# Seattle Downtown                          1.7% 12.5%   8.1% 26.8%        0.3%
# Seattle First Hill/Capitol Hill           2.0% 14.7%   9.6% 30.6%        0.6%
# Seattle Northgate                         1.3% 17.9%  10.2% 54.2%        0.9%
# Seattle South Lake Union                  1.9% 12.0%   7.0% 33.7%        0.3%
# Seattle University Community              4.3% 13.9%   9.3% 35.0%        0.6%
# Seattle Uptown                            2.1% 15.3%   9.3% 36.6%        0.6%
# Silverdale                                0.9% 24.6%  16.6% 48.1%        1.6%
# Sumner Pacific                            1.0% 19.1%  11.5% 64.7%        0.1%
# Tacoma Downtown                           1.8% 19.0%  13.2% 45.3%        0.8%
# Tacoma Mall                               1.1% 24.8%  16.2% 46.6%        0.8%
# Tukwila                                   0.7% 23.1%  15.2% 52.8%        0.6%
# University Place                          1.5% 23.9%  15.9% 44.5%        1.7%
#
# mode                                      TNC  Transit  Walk
# trip_d_rgc
# Auburn                                   0.7%     2.2%  6.5%
# Ballard-Interbay                         2.1%     3.7% 10.8%
# Bellevue                                 2.6%     6.7% 23.0%
# Bothell Canyon Park                      0.9%     1.1%  4.6%
# Bremerton                                1.5%     1.9% 14.6%
# Burien                                   0.5%     2.4%  8.7%
# Cascade                                  0.7%     0.5%  4.3%
# Duwamish                                 1.9%     6.1%  4.5%
# Everett                                  1.3%     1.5% 14.1%
# Federal Way                              0.5%     2.4%  6.8%
# Frederickson                             0.5%      NaN  4.0%
# Issaquah                                 0.8%     1.3%  4.6%
# Kent                                     0.7%     2.4%  6.6%
# Kent MIC                                 1.1%     2.6%  2.7%
# Kirkland Totem Lake                      1.0%     1.9%  6.9%
# Lakewood                                 0.6%     0.7%  7.5%
# Lynnwood                                 0.8%     1.2%  6.7%
# North Tukwila                            0.7%     3.5%  2.5%
# Not in RGC                               0.9%     1.5% 10.9%
# Paine Field / Boeing Everett             1.2%     1.7%  3.9%
# Port of Tacoma                           1.0%     0.9%  2.9%
# Puget Sound Industrial Center- Bremerton 0.4%      NaN  1.1%
# Puyallup Downtown                        0.7%     1.8%  7.0%
# Puyallup South Hill                      0.6%     0.8%  5.7%
# Redmond Downtown                         0.8%     2.1% 11.9%
# Redmond-Overlake                         2.1%     5.0% 11.1%
# Renton                                   1.0%     2.7%  7.2%
# SeaTac                                   1.0%     5.4%  6.5%
# Seattle Downtown                         3.5%    18.9% 28.3%
# Seattle First Hill/Capitol Hill          3.2%    10.4% 28.8%
# Seattle Northgate                        1.1%     3.2% 11.2%
# Seattle South Lake Union                 3.7%    13.0% 28.4%
# Seattle University Community             2.6%    15.8% 18.5%
# Seattle Uptown                           3.2%     5.6% 27.5%
# Silverdale                               0.6%     0.6%  6.9%
# Sumner Pacific                           0.8%     0.3%  2.6%
# Tacoma Downtown                          1.7%     3.6% 14.7%
# Tacoma Mall                              0.8%     1.4%  8.3%
# Tukwila                                  1.0%     3.4%  3.1%
# University Place                         0.7%     0.8% 11.0%

# %%
df
# Out:
#                               opurp   dpurp  mode  \
# 0                         None/Home    Work  Walk
# 1                         None/Home    Work  Walk
# 2                         None/Home    Work  Walk
# 3                         None/Home    Work  Walk
# 4                         None/Home    Work  Walk
# ...                             ...     ...   ...
# 16622  Change Mode Inserted Purpose  Social   SOV
# 16623  Change Mode Inserted Purpose  Social  HOV2
# 16624  Change Mode Inserted Purpose  Social  HOV2
# 16625  Change Mode Inserted Purpose  Social  HOV2
# 16626  Change Mode Inserted Purpose  Social  HOV2
#
#                             trip_d_rgc   trexpfac
# 0                               Auburn   4,900.0%
# 1                     Ballard-Interbay  71,200.0%
# 2                             Bellevue 388,300.0%
# 3                  Bothell Canyon Park   5,800.0%
# 4                            Bremerton  40,600.0%
# ...                                ...        ...
# 16622                 University Place     100.0%
# 16623                       Not in RGC     900.0%
# 16624  Seattle First Hill/Capitol Hill     100.0%
# 16625     Seattle University Community     100.0%
# 16626                   Seattle Uptown     100.0%
#
# [16627 rows x 5 columns]
