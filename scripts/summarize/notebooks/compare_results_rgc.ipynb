# %%
import pandas as pd
import os, sys
import toml
sys.path.append(os.path.join(os.getcwd(),r'..\..\..'))
sum_config = toml.load(os.path.join(os.getcwd(),r'../../../configuration/summary_configuration.toml'))
# from settings import comparison_dict

# %%
def load_data(fname, geog):
    df = pd.DataFrame()
    for scen_name, scen_path in sum_config['comparison_dict'].items():
        _df = pd.read_csv(os.path.join(scen_path,r'outputs\compare', geog ,fname))
        _df['source'] = scen_name
        df = df.append(_df)
    
    return df

# %%
geog = 'rgc'
geog_col = 'hh_rgc'

# %% [markdown]
# # Population

# %%
pd.options.display.float_format = '{:0,.0f}'.format
df = load_data('1_population.csv', geog)
df = df.pivot_table(index=geog_col, columns='source', aggfunc='sum', values='Persons')

# %%
df.plot(kind='barh', alpha=0.6).invert_yaxis()
df
# Out:
# source                               Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                              1,525       1,525       1,525
# Ballard-Interbay                      383         383         383
# Bellevue                           13,386      13,386      13,386
# Bothell Canyon Park                   487         487         487
# Bremerton                           2,525       2,525       2,525
# Burien                              3,383       3,383       3,383
# Cascade                             1,161       1,161       1,161
# Duwamish                            1,109       1,109       1,109
# Everett                             6,006       6,006       6,006
# Frederickson                          643         643         643
# Kent                                1,630       1,630       1,630
# Kent MIC                              251         251         251
# Kirkland Totem Lake                 5,104       5,104       5,104
# Lakewood                            2,707       2,707       2,707
# Lynnwood                            3,251       3,251       3,251
# North Tukwila                          16          16          16
# Not in RGC                      3,820,429   3,820,429   3,820,429
# Paine Field / Boeing Everett          555         555         555
# Port of Tacoma                          3           3           3
# Puyallup Downtown                   1,420       1,420       1,420
# Puyallup South Hill                 1,461       1,461       1,461
# Redmond Downtown                    6,406       6,406       6,406
# Redmond-Overlake                    2,198       2,198       2,198
# Renton                              5,439       5,439       5,439
# SeaTac                             10,440      10,440      10,440
# Seattle Downtown                   33,327      33,327      33,327
# Seattle First Hill/Capitol Hill    45,647      45,647      45,647
# Seattle Northgate                   8,216       8,216       8,216
# Seattle South Lake Union           12,379      12,379      12,379
# Seattle University Community       18,396      18,396      18,396
# Seattle Uptown                      9,885       9,885       9,885
# Silverdale                          1,949       1,949       1,949
# Sumner Pacific                         71          71          71
# Tacoma Downtown                    13,024      13,024      13,024
# Tacoma Mall                         5,046       5,046       5,046
# Tukwila                               155         155         155

# %% [markdown]
# # Employment

# %%
df = load_data('2_employment.csv', geog)
df['Workers'] = df['Paid Full-Time Worker']+df['Paid Part-Time Worker']
df = df.pivot_table(index=geog_col, columns='source', aggfunc='sum', values='Workers')
df
# Out:
# source                               Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                                657         657         657
# Ballard-Interbay                      276         276         276
# Bellevue                            8,665       8,665       8,665
# Bothell Canyon Park                   312         312         312
# Bremerton                           1,260       1,260       1,260
# Burien                              2,058       2,058       2,058
# Cascade                               530         530         530
# Duwamish                              692         692         692
# Everett                             3,049       3,049       3,049
# Frederickson                          287         287         287
# Kent                                  539         539         539
# Kent MIC                              115         115         115
# Kirkland Totem Lake                 3,297       3,297       3,297
# Lakewood                            1,161       1,161       1,161
# Lynnwood                            1,611       1,611       1,611
# North Tukwila                           9           9           9
# Not in RGC                      1,879,801   1,879,801   1,879,801
# Paine Field / Boeing Everett          271         271         271
# Port of Tacoma                          0           0           0
# Puyallup Downtown                     725         725         725
# Puyallup South Hill                   778         778         778
# Redmond Downtown                    4,144       4,144       4,144
# Redmond-Overlake                    1,273       1,273       1,273
# Renton                              3,075       3,075       3,075
# SeaTac                              5,197       5,197       5,197
# Seattle Downtown                   23,547      23,547      23,547
# Seattle First Hill/Capitol Hill    32,908      32,908      32,908
# Seattle Northgate                   4,279       4,279       4,279
# Seattle South Lake Union            9,499       9,499       9,499
# Seattle University Community       10,026      10,026      10,026
# Seattle Uptown                      8,040       8,040       8,040
# Silverdale                          1,020       1,020       1,020
# Sumner Pacific                         29          29          29
# Tacoma Downtown                     6,709       6,709       6,709
# Tacoma Mall                         2,647       2,647       2,647
# Tukwila                                95          95          95

# %% [markdown]
# # Transit Ridership

# %%
df = load_data('3_transit_trips.csv', geog)
df = df.pivot_table(index=geog_col, columns='source', aggfunc='sum', values='trexpfac')
df.plot(kind='barh', alpha=0.6).invert_yaxis()
df
# Out:
# source                             Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                              357         357         357
# Ballard-Interbay                     73          73          73
# Bellevue                          2,841       2,841       2,841
# Bothell Canyon Park                  28          28          28
# Bremerton                           273         273         273
# Burien                              909         909         909
# Cascade                              31          31          31
# Duwamish                            467         467         467
# Everett                             394         394         394
# Frederickson                         18          18          18
# Kent                                416         416         416
# Kent MIC                             53          53          53
# Kirkland Totem Lake                 826         826         826
# Lakewood                            142         142         142
# Lynnwood                            370         370         370
# North Tukwila                         3           3           3
# Not in RGC                      401,026     401,026     401,026
# Paine Field / Boeing Everett         29          29          29
# Port of Tacoma                        1           1           1
# Puyallup Downtown                   252         252         252
# Puyallup South Hill                 141         141         141
# Redmond Downtown                  1,138       1,138       1,138
# Redmond-Overlake                    372         372         372
# Renton                              991         991         991
# SeaTac                            3,471       3,471       3,471
# Seattle Downtown                 13,850      13,850      13,850
# Seattle First Hill/Capitol Hill  22,429      22,429      22,429
# Seattle Northgate                 2,408       2,408       2,408
# Seattle South Lake Union          4,109       4,109       4,109
# Seattle University Community      6,980       6,980       6,980
# Seattle Uptown                    3,548       3,548       3,548
# Silverdale                           82          82          82
# Sumner Pacific                        7           7           7
# Tacoma Downtown                   1,427       1,427       1,427
# Tacoma Mall                         650         650         650
# Tukwila                              47          47          47

# %% [markdown]
# ## Transit Commute Mode Share

# %%
pd.options.display.float_format = '{:0,.1%}'.format
df = load_data('4_transit_commute_share.csv', geog)
df = df.pivot_table(index=geog_col, columns='source', aggfunc='sum', values='mode_share')
df.plot(kind='barh', alpha=0.6).invert_yaxis()
df
# Out:
# source                           Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                          18.1%       18.1%       18.1%
# Ballard-Interbay                 4.5%        4.5%        4.5%
# Bellevue                         5.5%        5.5%        5.5%
# Bothell Canyon Park              3.3%        3.3%        3.3%
# Bremerton                        6.0%        6.0%        6.0%
# Burien                           8.7%        8.7%        8.7%
# Cascade                          1.9%        1.9%        1.9%
# Duwamish                        11.3%       11.3%       11.3%
# Everett                          4.1%        4.1%        4.1%
# Frederickson                     3.7%        3.7%        3.7%
# Kent                            16.4%       16.4%       16.4%
# Kent MIC                        13.3%       13.3%       13.3%
# Kirkland Totem Lake              5.7%        5.7%        5.7%
# Lakewood                         4.5%        4.5%        4.5%
# Lynnwood                         5.9%        5.9%        5.9%
# North Tukwila                    7.1%        7.1%        7.1%
# Not in RGC                       5.7%        5.7%        5.7%
# Paine Field / Boeing Everett     3.6%        3.6%        3.6%
# Port of Tacoma                  50.0%       50.0%       50.0%
# Puyallup Downtown               15.1%       15.1%       15.1%
# Puyallup South Hill              7.2%        7.2%        7.2%
# Redmond Downtown                 6.7%        6.7%        6.7%
# Redmond-Overlake                 5.7%        5.7%        5.7%
# Renton                           6.0%        6.0%        6.0%
# SeaTac                          14.7%       14.7%       14.7%
# Seattle Downtown                 6.5%        6.5%        6.5%
# Seattle First Hill/Capitol Hill 11.4%       11.4%       11.4%
# Seattle Northgate                9.0%        9.0%        9.0%
# Seattle South Lake Union         6.4%        6.4%        6.4%
# Seattle University Community    10.8%       10.8%       10.8%
# Seattle Uptown                   8.2%        8.2%        8.2%
# Silverdale                       2.4%        2.4%        2.4%
# Sumner Pacific                   6.7%        6.7%        6.7%
# Tacoma Downtown                  6.5%        6.5%        6.5%
# Tacoma Mall                      8.5%        8.5%        8.5%
# Tukwila                         13.2%       13.2%       13.2%

# %% [markdown]
# # VMT

# %%
pd.options.display.float_format = '{:0,.0f}'.format
df = load_data('5_vmt.csv', geog)
df = df.pivot_table(index=geog_col, columns='source', aggfunc='sum', values='VMT')
df.plot(kind='barh', alpha=0.6).invert_yaxis()
df.loc['Total'] = df.sum(axis=0)
df
# Out:
# source                                Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                              18,786      18,786      18,786
# Ballard-Interbay                     4,252       4,252       4,252
# Bellevue                            99,176      99,176      99,176
# Bothell Canyon Park                  9,928       9,928       9,928
# Bremerton                           13,942      13,942      13,942
# Burien                              41,843      41,843      41,843
# Cascade                             18,620      18,620      18,620
# Duwamish                            13,056      13,056      13,056
# Everett                             53,482      53,482      53,482
# Frederickson                        10,697      10,697      10,697
# Kent                                16,584      16,584      16,584
# Kent MIC                             2,962       2,962       2,962
# Kirkland Totem Lake                 75,219      75,219      75,219
# Lakewood                            24,884      24,884      24,884
# Lynnwood                            40,520      40,520      40,520
# North Tukwila                          369         369         369
# Not in RGC                      66,885,456  66,885,456  66,885,456
# Paine Field / Boeing Everett         9,390       9,390       9,390
# Puyallup Downtown                   16,572      16,572      16,572
# Puyallup South Hill                 21,512      21,512      21,512
# Redmond Downtown                    76,491      76,491      76,491
# Redmond-Overlake                    21,676      21,676      21,676
# Renton                              73,929      73,929      73,929
# SeaTac                             136,701     136,701     136,701
# Seattle Downtown                    90,410      90,410      90,410
# Seattle First Hill/Capitol Hill    205,502     205,502     205,502
# Seattle Northgate                   89,133      89,133      89,133
# Seattle South Lake Union            54,224      54,224      54,224
# Seattle University Community       134,093     134,093     134,093
# Seattle Uptown                      64,704      64,704      64,704
# Silverdale                          16,753      16,753      16,753
# Sumner Pacific                       1,228       1,228       1,228
# Tacoma Downtown                    108,553     108,553     108,553
# Tacoma Mall                         49,547      49,547      49,547
# Tukwila                              1,552       1,552       1,552
# Total                           68,501,744  68,501,744  68,501,744

# %%
pd.options.display.float_format = '{:0,.0f}'.format
df = load_data('5_vmt.csv', geog)
df = df.pivot_table(index=geog_col, columns='source', aggfunc='sum', values='VMT')
df.plot(kind='barh', alpha=0.6).invert_yaxis()
df.loc['Total'] = df.sum(axis=0)
df
# Out:
# source                                Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                              18,786      18,786      18,786
# Ballard-Interbay                     4,252       4,252       4,252
# Bellevue                            99,176      99,176      99,176
# Bothell Canyon Park                  9,928       9,928       9,928
# Bremerton                           13,942      13,942      13,942
# Burien                              41,843      41,843      41,843
# Cascade                             18,620      18,620      18,620
# Duwamish                            13,056      13,056      13,056
# Everett                             53,482      53,482      53,482
# Frederickson                        10,697      10,697      10,697
# Kent                                16,584      16,584      16,584
# Kent MIC                             2,962       2,962       2,962
# Kirkland Totem Lake                 75,219      75,219      75,219
# Lakewood                            24,884      24,884      24,884
# Lynnwood                            40,520      40,520      40,520
# North Tukwila                          369         369         369
# Not in RGC                      66,885,456  66,885,456  66,885,456
# Paine Field / Boeing Everett         9,390       9,390       9,390
# Puyallup Downtown                   16,572      16,572      16,572
# Puyallup South Hill                 21,512      21,512      21,512
# Redmond Downtown                    76,491      76,491      76,491
# Redmond-Overlake                    21,676      21,676      21,676
# Renton                              73,929      73,929      73,929
# SeaTac                             136,701     136,701     136,701
# Seattle Downtown                    90,410      90,410      90,410
# Seattle First Hill/Capitol Hill    205,502     205,502     205,502
# Seattle Northgate                   89,133      89,133      89,133
# Seattle South Lake Union            54,224      54,224      54,224
# Seattle University Community       134,093     134,093     134,093
# Seattle Uptown                      64,704      64,704      64,704
# Silverdale                          16,753      16,753      16,753
# Sumner Pacific                       1,228       1,228       1,228
# Tacoma Downtown                    108,553     108,553     108,553
# Tacoma Mall                         49,547      49,547      49,547
# Tukwila                              1,552       1,552       1,552
# Total                           68,501,744  68,501,744  68,501,744

# %% [markdown]
# # Delay
# **Total Delay Hours per Day**

# %%
pd.options.display.float_format = '{:0,.0f}'.format
df = load_data('7_delay.csv', geog)
df = df.pivot_table(index=geog_col, columns='source', aggfunc='sum', values='Total Delay Hours')
df = df.clip(lower=0)
df.plot(kind='barh', alpha=0.6).invert_yaxis()
df.loc['Total'] = df.sum(axis=0)
df
# Out:
# source                             Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                               83          83          83
# Ballard-Interbay                     23          23          23
# Bellevue                            527         527         527
# Bothell Canyon Park                  76          76          76
# Bremerton                             3           3           3
# Burien                              163         163         163
# Cascade                              69          69          69
# Duwamish                             61          61          61
# Everett                             213         213         213
# Frederickson                         55          55          55
# Kent                                 78          78          78
# Kent MIC                             14          14          14
# Kirkland Totem Lake                 557         557         557
# Lakewood                             96          96          96
# Lynnwood                            294         294         294
# North Tukwila                         1           1           1
# Not in RGC                      319,578     319,578     319,578
# Paine Field / Boeing Everett         57          57          57
# Puyallup Downtown                    82          82          82
# Puyallup South Hill                 115         115         115
# Redmond Downtown                    388         388         388
# Redmond-Overlake                    116         116         116
# Renton                              434         434         434
# SeaTac                              572         572         572
# Seattle Downtown                    189         189         189
# Seattle First Hill/Capitol Hill     856         856         856
# Seattle Northgate                   546         546         546
# Seattle South Lake Union            235         235         235
# Seattle University Community        840         840         840
# Seattle Uptown                      294         294         294
# Silverdale                            3           3           3
# Sumner Pacific                        4           4           4
# Tacoma Downtown                     442         442         442
# Tacoma Mall                         213         213         213
# Tukwila                               8           8           8
# Total                           327,285     327,285     327,285

# %% [markdown]
# **Delay Hours per Household**

# %%
pd.options.display.float_format = '{:0,.1f}'.format
df = load_data('7_delay.csv', geog)
df = df.pivot_table(index=geog_col, columns='source', 
                    aggfunc='sum', values='Avg. Minutes of Delay per Household')
df = df.clip(lower=0)
df.plot(kind='barh', alpha=0.6).invert_yaxis()
df.loc['Total'] = df.sum(axis=0)
df
# Out:
# source                           Base  Scenario 1  Scenario 2
# hh_rgc
# Auburn                            7.4         7.4         7.4
# Ballard-Interbay                  5.8         5.8         5.8
# Bellevue                          3.8         3.8         3.8
# Bothell Canyon Park              22.7        22.7        22.7
# Bremerton                         0.2         0.2         0.2
# Burien                            5.5         5.5         5.5
# Cascade                          10.2        10.2        10.2
# Duwamish                          5.9         5.9         5.9
# Everett                           3.7         3.7         3.7
# Frederickson                     16.6        16.6        16.6
# Kent                              6.5         6.5         6.5
# Kent MIC                          8.4         8.4         8.4
# Kirkland Totem Lake              11.9        11.9        11.9
# Lakewood                          4.8         4.8         4.8
# Lynnwood                         11.7        11.7        11.7
# North Tukwila                     7.6         7.6         7.6
# Not in RGC                       13.0        13.0        13.0
# Paine Field / Boeing Everett     16.3        16.3        16.3
# Puyallup Downtown                 7.1         7.1         7.1
# Puyallup South Hill               9.4         9.4         9.4
# Redmond Downtown                  6.8         6.8         6.8
# Redmond-Overlake                  6.5         6.5         6.5
# Renton                            8.5         8.5         8.5
# SeaTac                            8.0         8.0         8.0
# Seattle Downtown                  0.5         0.5         0.5
# Seattle First Hill/Capitol Hill   1.7         1.7         1.7
# Seattle Northgate                 7.2         7.2         7.2
# Seattle South Lake Union          1.6         1.6         1.6
# Seattle University Community      5.0         5.0         5.0
# Seattle Uptown                    2.5         2.5         2.5
# Silverdale                        0.1         0.1         0.1
# Sumner Pacific                    9.5         9.5         9.5
# Tacoma Downtown                   3.4         3.4         3.4
# Tacoma Mall                       5.9         5.9         5.9
# Tukwila                           7.2         7.2         7.2
# Total                           253.1       253.1       253.1
