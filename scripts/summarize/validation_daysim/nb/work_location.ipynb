# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": True, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination_choice", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "../../../../inputs/base_year/survey"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "base_year_2023_final", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/rtp_2026_2050", "abm_model": "daysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_daysim": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": True, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %% [raw]
# ---
# title: "Work Location"
# date: today
# ---

# %%
import plotly.express as px
import polars as pl
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
hh = util.get_hh_data(summary_config, quantile_groups=['hhincome', 'emptot_1', 'hh_1'])
person = util.get_person_data(summary_config)
parcel_geog = util.get_parcel_geog(input_config, summary_config)

# %%
# add group aliases matching the plot column names
hh = hh.with_columns([
    pl.col('hhincome_4group').alias('hhincome_group'),
    pl.col('hh_1_4group').alias('hh_density_group'),
    pl.col('emptot_1_4group').alias('emp_density_group'),
])

# %%
person = person.join(hh, on=['hhno', 'source'], how='left')

# %%
person = person.join(parcel_geog, left_on='pwpcl', right_on='ParcelID', how='left').rename({
    'CountyName': 'CountyName_work',
    'rg_proposed': 'rg_proposed_work',
    'District': 'District_work'
})
person = person.join(parcel_geog, left_on='hhparcel', right_on='ParcelID', how='left').rename({
    'CountyName': 'CountyName_home',
    'rg_proposed': 'rg_proposed_home',
    'District': 'District_home'
})

# %%
df_workers = person.filter(pl.col('pwtyp') > 0)

# %%
df = (
    df_workers.filter(pl.col('pwaudist') > 0)
    .with_columns((pl.col('pwaudist') * pl.col('psexpfac')).alias('wt_dist'))
    .group_by(['source'])
    .agg([
        pl.col('wt_dist').sum().alias('wt_dist'),
        pl.col('psexpfac').sum().alias('psexpfac')
    ])
    .with_columns((pl.col('wt_dist') / pl.col('psexpfac')).alias('Mean Distance to Work by Car (pwaudist)'))
)
df.select(['source', 'Mean Distance to Work by Car (pwaudist)'])
# Out:
# shape: (2, 2)
# ┌────────┬─────────────────────────────────┐
# │ source ┆ Mean Distance to Work by Car (… │
# │ ---    ┆ ---                             │
# │ str    ┆ f64                             │
# ╞════════╪═════════════════════════════════╡
# │ survey ┆ 11.319597                       │
# │ model  ┆ 11.258345                       │
# └────────┴─────────────────────────────────┘

# %%
def plot_work_location(df: pl.DataFrame, var: str, title_cat: str, sub_name: str):
    df_plot = (
        df.filter(pl.col('pwaudist') > 0)
        .with_columns((pl.col('pwaudist') * pl.col('psexpfac')).alias('wt_dist'))
        .group_by(['source', var])
        .agg([
            pl.col('wt_dist').sum().alias('wt_dist'),
            pl.col('psexpfac').sum().alias('psexpfac'),
            pl.col('psexpfac').count().alias('sample count')
        ])
        .with_columns((pl.col('wt_dist') / pl.col('psexpfac')).alias('average_wt_pwaudist'))
    )

    fig = px.bar(df_plot.to_pandas(), x=var, y='average_wt_pwaudist', color="source",
                 barmode="group", hover_data=['sample count'],
                 title="Work Distance by " + title_cat)
    fig.for_each_annotation(lambda a: a.update(text=sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text=sub_name)
    fig.update_layout(height=400, width=800, font=dict(size=11),
                      yaxis=dict(tickformat=".2f"))
    fig.for_each_yaxis(lambda a: a.update(tickformat=".2f"))
    fig.show()

# %% [markdown]
# ## Work Location by Workplace Geography

# %% [raw]
# ::: {.panel-tabset}
#
# ### County

# %%
plot_work_location(df_workers, 'CountyName_work', 'Work County', 'County')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="
')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="0fe6020f-e762-4bb1-a110-7e1b13a4b9bd" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0fe6020f-e762-4bb1-a110-7e1b13a4b9bd")) {                    Plotly.newPlot(                        "0fe6020f-e762-4bb1-a110-7e1b13a4b9bd",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"dUEbAF6qBgA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003epwtyp=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQI="},"xaxis":"x","y":{"dtype":"f8","bdata":"LbsGzMNSKECjgFK5N0IeQA=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"6AEAAB8JAAA=","shape":"2, 1"},"hovertemplate":"source=survey\u003cbr\u003epwtyp=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AgE="},"xaxis":"x","y":{"dtype":"f8","bdata":"Nhl6ksmbGkBjeYPFpAMpQA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"} ...

# %% [raw]
# ### Income

# %%
plot_work_location(df_workers, 'hhincome_group', 'Income', 'Income Group')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="bbdaa25c-933b-468a-842e-b1b009a86d1f" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bbdaa25c-933b-468a-842e-b1b009a86d1f")) {                    Plotly.newPlot(                        "bbdaa25c-933b-468a-842e-b1b009a86d1f",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"XQIAAJgDAAByAgAAqAAAALsAAAA9AQAA","shape":"6, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhincome_group=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["high","medium-high","medium","very low","low",null],"xaxis":"x","y":{"dtype":"f8","bdata":"QBbN2SdJKUB3bYCFchYnQBsgqe\u002fK5iRAzCo90yR5FkDCHAsvp70nQNIhXgN32ydA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"itUMAAI5BwAmdgIAvDkBAIgqCgDdAgAA","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003ehhincome_group=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["high","medium","low","very low","medium-high",null],"xaxis":"x","y":{"dtype":"f8","bdata":"URRULFNsJkBV1m1PUDcnQOITywZMFSRAzU8gxJJ0HkDlnDGnPpsnQATI\u002fhMO9SVA"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7 ...

# %% [raw]
# ### Household Density

# %%
plot_work_location(df_workers, 'hh_density_group', 'Household Density', 'Household Density Group')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="456f8cd9-b78c-4d6e-a1f1-e95cd01aa2be" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("456f8cd9-b78c-4d6e-a1f1-e95cd01aa2be")) {                    Plotly.newPlot(                        "456f8cd9-b78c-4d6e-a1f1-e95cd01aa2be",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"\u002fQEAACgCAAAOAwAANAIAAKABAAA=","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehh_density_group=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["low","very low","medium","medium-high","high"],"xaxis":"x","y":{"dtype":"f8","bdata":"2Gdg8T+eJkAn6XQUwUQsQADXE8G80yZAA3JmwDziIkD+L4NIvpAjQA=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"MkYEALl\u002fBADG9wgATkkIANTkBwA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh_density_group=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["very low","low","medium","medium-high","high"],"xaxis":"x","y":{"dtype":"f8","bdata":"VPF\u002f7\u002fdHL0CtSo58YAAqQEjdHG2mTChA3ry4fCHWJUAH\u002fa+MmfIcQA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778 ...

# %% [raw]
# ### Employment Density

# %%
plot_work_location(df_workers, 'emp_density_group', 'Employment Density', 'Employment Density Group')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="3d2334d8-095d-4922-87e3-44b7ff9abcdc" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3d2334d8-095d-4922-87e3-44b7ff9abcdc")) {                    Plotly.newPlot(                        "3d2334d8-095d-4922-87e3-44b7ff9abcdc",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"qwMAAKgBAAAZAwAAmwIAAA==","shape":"4, 1"},"hovertemplate":"source=survey\u003cbr\u003eemp_density_group=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["low","high","medium","medium-high"],"xaxis":"x","y":{"dtype":"f8","bdata":"QyBgHBVVK0CpoxrIbaMjQE1bWkGuSyVAsqA21s8OI0A="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"Z28IANvrCAAR2wgAgLUHAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eemp_density_group=%{x}\u003cbr\u003eaverage_wt_pwaudist=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["medium-high","medium","low","high"],"xaxis":"x","y":{"dtype":"f8","bdata":"nx7SeahSJUAehQZjk54oQCvc2aGxHCxAxXhoxG\u002fsHUA="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"hist ...

# %% [raw]
# :::

# %%
# distance to school bins from workplace_location.csv
df_workers = df_workers.with_columns([
    pl.when(pl.col('pwaudist') < 1).then(pl.lit('0-1'))
      .when(pl.col('pwaudist') < 2).then(pl.lit('1-2'))
      .when(pl.col('pwaudist') < 5).then(pl.lit('2-5'))
      .when(pl.col('pwaudist') < 15).then(pl.lit('5-15'))
      .otherwise(pl.lit('15+')).alias('distance_to_work_bin')
])
max_bin = 60
bin_size = 2
df_workers = df_workers.with_columns(
    pl.when((pl.col('pwaudist') >= 0) & (pl.col('pwaudist') <= max_bin))
      .then(pl.col('pwaudist').truediv(bin_size).floor().mul(bin_size).cast(pl.Int64).cast(pl.Utf8))
      .otherwise(None)
      .alias('d_work_bin_60mi')
)

# %% [markdown]
# ## Distance Bins

# %% [raw]
# ::: {.panel-tabset}
#
# ### All Workers

# %%
def plot_distance(df: pl.DataFrame, group: str, title_name: str):

    df_group = df.filter(pl.col(group).is_not_null())

    df_plot = (
        df_group.filter(pl.col('distance_to_work_bin').is_not_null())
        .group_by(['source', 'distance_to_work_bin'])
        .agg([
            pl.col('psexpfac').sum().alias('psexpfac'),
            pl.col('psexpfac').count().alias('sample count')
        ])
        .with_columns((100 * pl.col('psexpfac') / pl.col('psexpfac').sum().over(['source'])).alias('percentage'))
    )

    fig1 = px.bar(df_plot.to_pandas(), x='distance_to_work_bin', y="percentage", color="source", barmode="group", hover_data=['sample count'],
                  title=title_name)
    fig1.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
    fig1.update_layout(height=400, width=700, font=dict(size=11))
    fig1.show()

    df_plot = (
        df_group.filter(pl.col('d_work_bin_60mi').is_not_null())
        .group_by(['source', 'd_work_bin_60mi'])
        .agg(pl.col('psexpfac').sum().alias('psexpfac'))
        .with_columns((100 * pl.col('psexpfac') / pl.col('psexpfac').sum().over(['source'])).alias('percentage'))
    )

    fig2 = px.line(df_plot.to_pandas(), x='d_work_bin_60mi', y="percentage", color="source",
                   title=title_name)
    fig2.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
    fig2.update_layout(height=400, width=700, font=dict(size=11))
    fig2.show()

# distance to work
plot_distance(df_workers, 'pwtyp', "worker: distance to work (miles)")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="9605b1bb-6264-473d-a7bb-59c3ecc8e868" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9605b1bb-6264-473d-a7bb-59c3ecc8e868")) {                    Plotly.newPlot(                        "9605b1bb-6264-473d-a7bb-59c3ecc8e868",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"NQIAAAkBAAD1AwAAZgQAAFYCAAA=","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003edistance_to_work_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["15+","1-2","5-15","0-1","2-5"],"xaxis":"x","y":{"dtype":"f8","bdata":"kMEuw+jnN0DAa45xMsEdQAQKh5wUwEBAlQD5bup3NEDCHc3wbV8tQA=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"CG4FABLJAgCC4Q0AGioJAPaLAwA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003edistance_to_work_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["2-5","0-1","5-15","15+","1-2"],"xaxis":"x","y":{"dtype":"f8","bdata":"f4jA1AEzL0DS\u002fsKNPgEgQDAmFsmK8ENAl5\u002fVQkFUOkDBoHjzEWEkQA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725" ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1dbf68b7-b713-41bb-9213-78ac54f85c9e" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1dbf68b7-b713-41bb-9213-78ac54f85c9e")) {                    Plotly.newPlot(                        "1dbf68b7-b713-41bb-9213-78ac54f85c9e",                        [{"hovertemplate":"source=model\u003cbr\u003ed_work_bin_60mi=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","line":{"color":"#91268F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"model","orientation":"v","showlegend":true,"x":["6","24","4","52","60","28","40","0","18","38","56","10","42","36","54","22","30","20","26","50","32","58","12","48","34","14","46","8","44","16","2"],"xaxis":"x","y":{"dtype":"f8","bdata":"eLSnt4X4IkALl\u002fxKAJH\u002fP8LmpRpPtSRAzeKYYwGuuz\u002fOeLrcqZQnP+NcGwsDzPM\u002fA5pw3tio2z+laZ4rEzowQI3\u002fs3bu\u002fg1ARgdUlO3e3z9jHeHsmoCvP9y5aCHZeh9A+NUfTxqH2D+9kdr9\u002fJDiP+xB6ejkoLg\u002fRoqfB\u002fbjA0BPTdQnzI3uP6PoaT9qBwlAWgOkSw2f+D\u002fdVfCGEfa+P9EFiqfxeug\u002fUo0Jj6W0pj9VXOkwKmobQIz4PDjxpsU\u002f005N1CfM5T8XY9VqKc4WQLDCYdYOas4\u002fHGcv7dREIUCNPKvKBCfUP\u002fIg5Mi5QRJAnHkVx35\u002fJUA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=survey\u003cbr\u003ed_work_bin_60mi=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","line":{"color":"#8CC63E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"survey","orientation":"v","showlegend":true,"x":["4","54","30","52","46","2","0","22","26","24","42","48","58","16","40","18","10","20","14","8","28","12","32","38","44","36","6","56","50","34"],"xaxis":"x","y":{"dtype":"f8","bdata":"imT9iUZmJkCSG\u002fZkcYGzP3PnTD+q7PE\u002f9Dxv67J6zj\u002fkUuf8PITZP9XbwAGeDCdA2DBMzjDMMEAIz91ut5YDQCrh56iHveY\u002fOgFVtEAi8j8v5WvMTWWJPwtHvAGe9bk\u002f3Q9JakAufT85JZp\u002fWlsSQPHbQx0\u002fQ+A\u002f0nIzrWkTFUCl9nF+IJgeQAlF54bVCwNAPx3vsl70FUDGu7Bb7rwgQOLd5FTj5vU\u002fsAh\u002fC8jtFkC6P\u002fGrmMzVP3jFYdV7JfQ\u002fkk7j0RCNsD9j7cH4d3GmP5pnWb3eOyJAdv97oabskD8fQxypgxnUP\u002fTW9vUKifs\u002f"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#3168 ...

# %% [raw]
# ### Worker Type

# %%
def plot_group(df: pl.DataFrame, group: str, title_name: str, height: int = 900):
    df_plot = (
        df.group_by(['source', group, 'distance_to_work_bin'])
        .agg([
            pl.col('psexpfac').sum().alias('psexpfac'),
            pl.col('psexpfac').count().alias('sample count')
        ])
        .with_columns((pl.col('psexpfac') / pl.col('psexpfac').sum().over(['source', group])).alias('percentage'))
    )

    fig = px.bar(df_plot.to_pandas(), x="distance_to_work_bin", y="percentage", color="source", barmode="group",
                 facet_col=group, facet_col_wrap=2, hover_data=['sample count'],
                 title="Distance to work by " + title_name)
    fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
    fig.update_layout(height=height, width=700, font=dict(size=11),
                      yaxis=dict(tickformat=".0%"))
    fig.show()

def plot_group_line(df: pl.DataFrame, group: str, title_name: str, height: int = 400):
    df_plot = (
        df.group_by(['source', group, 'd_work_bin_60mi'])
        .agg(pl.col('psexpfac').sum().alias('psexpfac'))
        .with_columns((pl.col('psexpfac') / pl.col('psexpfac').sum().over(['source', group])).alias('percentage'))
    )

    fig2 = px.line(df_plot.to_pandas(), x='d_work_bin_60mi', y="percentage", color="source",
                   facet_col=group, facet_col_wrap=2,
                   title="Distance to work by " + title_name)
    fig2.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
    fig2.update_layout(height=height, width=700, font=dict(size=11),
                       yaxis=dict(tickformat=".0%"))
    fig2.show()

# %%
df_workers = df_workers.with_columns(
    pl.col('pwtyp').replace_strict({1: 'full-time', 2: 'part-time'}, default=None).alias('worker_type')
)
plot_group(df_workers, 'worker_type', 'worker type', height=400)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="84305872-9615-4a9f-b8e8-74593f295a12" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("84305872-9615-4a9f-b8e8-74593f295a12")) {                    Plotly.newPlot(                        "84305872-9615-4a9f-b8e8-74593f295a12",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":
type":"scatter"},{"hovertemplate":"source=model\u003cbr\u003erg_proposed_work=Urban Unincorporated Areas\u003cbr\u003ed_work_bin_60mi=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","line":{"color":"#91268F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"model","orientation":"v","showlegend":false,"x":["28","0","22","50","20","48","12","52","10","30","4","32","44","40","54","36","56","24","42","26","16","18","6",null,"58","46","8","34","2","38","14"],"xaxis":"x5","y":{"dtype":"f8","bdata":"kHXd8Z94fj+thJ4FuPPPP8OOhRQetpI\u002f7vBIv1AZSD+ChhlzUZCWP7O0do\u002f8ElI\u002fJpxkyqKHrT80he23CCxHP6tH78xrwbE\u002f7FoUzTfWeT\u002fenlVQOkO8P20g0pZEAHM\u002f7vBIv1AZSD9Afq3RhGpaP9b+yItYnFE\u002fV88\u002ftGS1Zj8bk22EEK9AP8jFp1dPK4s\u002fnGPkrBzIVT8IIyoN1siBP6ixutpSfqM\u002fHjRb1Sjhmj9Fqha2tvC2P8JOJPqQg18\u002fBULboTBkND\u002fu8Ei\u002fUBlIP39F+5TyxLI\u002ftUqrgRVWcD9XRySeWejBPy24loK+c2A\u002fZ6lOOYZYpz8="},"yaxis":"y5","type":"scatter"},{"hovertemplate":"source=model\u003cbr\u003erg_proposed_work=Rural Areas\u003cbr\u003ed_work_bin_60mi=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","line":{"color":"#91268F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"model","orientation":"v","showlegend":false,"x":["28","40","54","10","0","2","42","16","24","34","50","8","38", ...

# %% [raw]
# :::

# %% [markdown]
# ## Origin-Destination Flows

# %%
# Get District lookup from parcel geographies

df_lehd = util.read_sqlite_db(input_config, summary_config, "SELECT * FROM observed_lehd_district_flows")


df_lehd = df_lehd.filter(pl.col('model_year').cast(pl.Int64) == int(input_config['base_year']))
df_lehd = df_lehd.with_columns(pl.lit('LEHD').alias('source'))

# %%
dist_name = {1: '1: Suburban Snohomish',
              2: '2: Everett-Lynwood-Edmonds',
              3: '3: North Seattle-Shoreline',
              4: '4: Seattle CBD',
              5: '5: West-South Seattle',
              6: '6: East Side',
              7: '7: Renton-FedWay-Kent',
              8: '8: Tacoma',
              9: '9: Kitsap',
              10: '10: South Pierce'}

df_lehd = df_lehd.with_columns([
    pl.col('home_dist').replace_strict(dist_name, default=None).alias('home_dist_name'),
    pl.col('work_dist').replace_strict(dist_name, default=None).alias('work_dist_name')
])

# %%
df_model = (
    person.filter(pl.col('source') == 'model')
    .group_by(['District_home', 'District_work'])
    .agg(pl.col('psexpfac').sum().alias('workers_total'))
    .with_columns([
        pl.lit('model').alias('source'),
        pl.col('District_home').cast(pl.Int64),
        pl.col('District_work').cast(pl.Int64)
    ])
    .with_columns([
        pl.col('District_home').replace_strict(dist_name, default=None).alias('home_dist_name'),
        pl.col('District_work').replace_strict(dist_name, default=None).alias('work_dist_name')
    ])
    .select(['source', 'home_dist_name', 'work_dist_name', 'workers_total'])
)

df_lehd = (
    df_lehd.rename({'S000': 'workers_total'})
    .filter((pl.col('home_dist') > 0) & (pl.col('work_dist') > 0))
    .select(['source', 'home_dist_name', 'work_dist_name', pl.col('workers_total').cast(pl.Float64)])
)

# %%
_df_model = df_model.pivot(values='workers_total', index='home_dist_name', on='work_dist_name', aggregate_function='sum').to_pandas().set_index('home_dist_name')
_df_lehd = df_lehd.pivot(values='workers_total', index='home_dist_name', on='work_dist_name', aggregate_function='sum').to_pandas().set_index('home_dist_name')

# %% [raw]
# ::: {.panel-tabset}
#
# ### Work District

# %%
df = pl.concat([df_lehd, df_model], how='diagonal')
df.head()

var = 'work_dist_name'
df_plot = df.group_by(['source', var]).agg(pl.col('workers_total').sum().alias('workers_total'))
df_plot

fig = px.bar(df_plot.sort('source', descending=True).to_pandas(), x=var, y='workers_total', color="source",
             barmode="group",
             title="Work District Location")
fig.update_layout(height=400, width=800, font=dict(size=11),
                  xaxis=dict(categoryarray=list(dist_name.values())),
                  yaxis=dict(tickformat=".0f"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="8fbf63b2-5d95-472a-b4e3-5ffaab98f64e" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8fbf63b2-5d95-472a-b4e3-5ffaab98f64e")) {                    Plotly.newPlot(                        "8fbf63b2-5d95-472a-b4e3-5ffaab98f64e",                        [{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003ework_dist_name=%{x}\u003cbr\u003eworkers_total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["9: Kitsap","4: Seattle CBD","10: South Pierce","7: Renton-FedWay-Kent","8: Tacoma","3: North Seattle-Shoreline","6: East Side",null,"5: West-South Seattle","1: Suburban Snohomish","2: Everett-Lynwood-Edmonds"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAALDt+EAAAAAAyEkWQQAAAACwOAVBAAAAAHisFUEAAAAAYDMDQQAAAADIbgNBAAAAAATlGUEAAAAAH2pAQQAAAABwEgFBAAAAAJDGAkEAAAAAcDoFQQ=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=LEHD\u003cbr\u003ework_dist_name=%{x}\u003cbr\u003eworkers_total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LEHD","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"LEHD","offsetgroup":"LEHD","orientation":"v","showlegend":true,"textposition":"auto","x":["9: Kitsap","1: Suburban Snohomish","10: South Pierce","2: Everett-Lynwood-Edmonds","8: Tacoma","4: Seattle CBD","3: North Seattle-Shoreline","5: West-South Seattle","6: East Side",null,"7: Renton-FedWay-Kent"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAOA860AAAAAAQO\u002f3QAAAAAAg2f5AAAAAABBvAEEAAAAA4Ob7QAAAAADkuRFBAAAAAPCd\u002fEAAAAAA0DgDQQAAAAB4GxdBAAAAAAB6zEAAAAAAZJ4QQQ=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.222222 ...

# %% [raw]
# ### Home District

# %%
df = pl.concat([df_model, df_lehd], how='diagonal')
df.head()

var = 'home_dist_name'
df_plot = df.group_by(['source', var]).agg(pl.col('workers_total').sum().alias('workers_total'))
df_plot

fig = px.bar(df_plot.sort('source', descending=True).to_pandas(), x=var, y='workers_total', color="source",
             barmode="group",
             title="Home District")
fig.update_layout(height=400, width=800, font=dict(size=11),
                  xaxis=dict(categoryarray=list(dist_name.values())),
                  yaxis=dict(tickformat=".0f"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="862bf6fd-8a12-425f-b1c0-107e9666b83a" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("862bf6fd-8a12-425f-b1c0-107e9666b83a")) {                    Plotly.newPlot(                        "862bf6fd-8a12-425f-b1c0-107e9666b83a",                        [{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003ehome_dist_name=%{x}\u003cbr\u003eworkers_total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["9: Kitsap","6: East Side","2: Everett-Lynwood-Edmonds","1: Suburban Snohomish","5: West-South Seattle","8: Tacoma","10: South Pierce",null,"3: North Seattle-Shoreline","7: Renton-FedWay-Kent","4: Seattle CBD"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAKzKEEEAAAAACmomQQAAAAAkQRNBAAAAAFhcIEEAAAAAWPUQQQAAAAAQ6g9BAAAAACgLIkEAAAAA4MnxQAAAAAAg1RZBAAAAAMJ+JEEAAAAA2AAOQQ=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=LEHD\u003cbr\u003ehome_dist_name=%{x}\u003cbr\u003eworkers_total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LEHD","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"LEHD","offsetgroup":"LEHD","orientation":"v","showlegend":true,"textposition":"auto","x":["5: West-South Seattle","7: Renton-FedWay-Kent","1: Suburban Snohomish","8: Tacoma","2: Everett-Lynwood-Edmonds","3: North Seattle-Shoreline",null,"9: Kitsap","4: Seattle CBD","6: East Side","10: South Pierce"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAIAc\u002fUAAAAAAjLcQQQAAAAAQFQtBAAAAAKA++UAAAAAAkL3+QAAAAAAY8ANBAAAAAADA10AAAAAAgAX0QAAAAABAA\u002fxAAAAAAOhtE0EAAAAACPQJQQ=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.222222 ...

# %% [raw]
# :::

# %%
# _df_model/_df_model['workers_total'].sum()
# df_model_dist = _df_model/_df_model.sum().sum()
# df_lehd_dist = _df_lehd/_df_lehd.sum().sum()

# %% [markdown]
# #### District Distribution: Model - LEHD

# %%
import numpy as np
import matplotlib
import matplotlib.cm as cm

df = (_df_model - _df_lehd) / _df_lehd

# Build a symmetric color range around zero, with a safe fallback when all values
# are 0/NaN/inf so TwoSlopeNorm still has a strictly increasing range.
finite_values = df.to_numpy(dtype=float)
finite_values = finite_values[np.isfinite(finite_values)]
abs_max = float(np.max(np.abs(finite_values))) if finite_values.size else 1.0
if abs_max == 0:
    abs_max = 1.0
abs_min = -abs_max

def make_pretty(styler):

    def background_with_norm(s):
        cmap = cm.get_cmap('RdBu_r', 9)
        norm = matplotlib.colors.TwoSlopeNorm(vmin=abs_min, vcenter=0, vmax=abs_max)
        return [
            '' if not np.isfinite(v) else 'background-color: {:s}'.format(matplotlib.colors.to_hex(cmap(norm(v))))
            for v in s.values
        ]

    styler.set_caption("District distribution")
    styler.format("{:.2%}")
    styler.apply(background_with_norm)
    styler.set_properties(**{'color': 'black'})
    return styler

df[list(dist_name.values())].reindex(list(dist_name.values())).style.pipe(make_pretty)
# Out:
# C:\Users\modeller\AppData\Local\Temp\ipykernel_36088\1891300503.py:19: MatplotlibDeprecationWarning:
#
# The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
# <style type="text/css">
# #T_365d4_row0_col0, #T_365d4_row1_col1, #T_365d4_row2_col2, #T_365d4_row4_col4, #T_365d4_row8_col8 {
#   background-color: #e58268;
#   color: black;
# }
# #T_365d4_row0_col1, #T_365d4_row0_col2, #T_365d4_row0_col3, #T_365d4_row0_col5, #T_365d4_row1_col2, #T_365d4_row1_col3, #T_365d4_row1_col5, #T_365d4_row2_col0, #T_365d4_row2_col4, #T_365d4_row2_col5, #T_365d4_row2_col6, #T_365d4_row3_col1, #T_365d4_row3_col2, #T_365d4_row3_col6, #T_365d4_row4_col2, #T_365d4_row4_col3, #T_365d4_row4_col5, #T_365d4_row4_col7, #T_365d4_row4_col9, #T_365d4_row5_col0, #T_365d4_row5_col1, #T_365d4_row5_col2, #T_365d4_row5_col3, #T_365d4_row5_col6, #T_365d4_row6_col2, #T_365d4_row6_col3, #T_365d4_row6_col4, #T_365d4_row6_col5, #T_365d4_row6_col9, #T_365d4_row7_col6, #T_365d4_row7_col9, #T_365d4_row8_col3, #T_365d4_row8_col7, #T_365d4_row9_col3, #T_365d4_row9_col6 {
#   background-color: #f7f7f7;
#   color: black;
# }
# #T_365d4_row0_col4, #T_365d4_row0_col6, #T_365d4_row0_col7, #T_365d4_row0_col8, #T_365d4_row1_col4, #T_365d4_row1_col6, #T_365d4_row1_col7, #T_365d4_row1_col8, #T_365d4_row2_col7, #T_365d4_row2_col8, #T_365d4_row2_col9, #T_365d4_row3_col0, #T_365d4_row3_col4, #T_365d4_row3_col5, #T_365d4_row3_col7, #T_365d4_row3_col8, #T_365d4_row3_col9, #T_365d4_row4_col0, #T_365d4_row4_col1, #T_365d4_row4_col8, #T_365d4_row5_col4, #T_365d4_row5_col7, #T_365d4_row5_col8, #T_365d4_row5_col9, #T_365d4_row6_col0, #T_365d4_row6_col1, #T_365d4_row6_col8, #T_365d4_row7_col2, #T_365d4_row7_col3, #T_365d4_row7_col4, #T_365d4_row7_col5, #T_365d4_row8_col0, #T_365d4_row8_col1, #T_365d4_row8_col2, #T_365d4_row8_col4, #T_365d4_row8_col5, #T_365d4_row8_col6, #T_365d4_row8_col9, #T_365d4_row9_col2, #T_365d4_row9_col4, #T_365d4_row9_col5, #T_365d4_row9_col8 {
#   background-color: #c1ddec;
#   color: black;
# }
# #T_365d4_row0_col9, #T_365d4_row1_col9, #T_365d4_row7_col0, #T_365d4_row7_col1, #T_365d4_row7_col8, #T_365d4_row9_col0, #T_365d4_row9_col1 {
#   background-color: #6bacd0;
#   color: black;
# }
# #T_365d4_row1_col0, #T_365d4_row2_col1, #T_365d4_row2_col3, #T_365d4_row4_col6, #T_365d4_row5_col5, #T_365d4_row6_col6, #T_365d4_row6_col7, #T_365d4_row7_col7, #T_365d4_row9_col7, #T_365d4_row9_col9 {
#   background-color: #fbcdb6;
#   color: black;
# }
# #T_365d4_row3_col3 {
#   background-color: #bb2a34;
#   color: black;
# }
# </style>
# <table id="T_365d4">
#   <caption>District distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_365d4_level0_col0" class="col_heading level0 col0" >1: Suburban Snohomish</th>
#       <th id="T_365d4_level0_col1" class="col_heading level0 col1" >2: Everett-Lynwood-Edmonds</th>
#       <th id="T_365d4_level0_col2" class="col_heading level0 col2" >3: North Seattle-Shoreline</th>
#       <th id="T_365d4_level0_col3" class="col_heading level0 col3" >4: Seattle CBD</th>
#       <th id="T_365d4_level0_col4" class="col_heading level0 col4" >5: West-South Seattle</th>
#       <th id="T_365d4_level0_col5" class="col_heading level0 col5" >6: East Side</th>
#       <th id="T_365d4_level0_col6" class="col_heading level0 col6" >7: Renton-FedWay-Kent</th>
#       <th id="T_365d4_level0_col7" class="col_heading level0 col7" >8: Tacoma</th>
#       <th id="T_365d4_level0_col8" class="col_heading level0 col8" >9: Kitsap</th>
#       <th id="T_365d4_level0_col9" class="col_heading level0 col9" >10: South Pierce</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >home_dist_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_365d4_level0_row0" class="row_heading level0 row0" >1: Suburban Snohomish</th>
#       <td id="T_365d4_row0_col0" class="data row0 col0" >103.87%</td>
#       <td id="T_365d4_row0_col1" class="data row0 col1" >23.27%</td>
#       <td id="T_365d4_row0_col2" class="data row0 col2" >9.84%</td>
#       <td id="T_365d4_row0_col3" class="data row0 col3" >-18.72%</td>
#       <td id="T_365d4_row0_col4" class="data row0 col4" >-61.57%</td>
#       <td id="T_365d4_row0_col5" class="data row0 col5" >2.36%</td>
#       <td id="T_365d4_row0_col6" class="data row0 col6" >-65.24%</td>
#       <td id="T_365d4_row0_col7" class="data row0 col7" >-85.12%</td>
#       <td id="T_365d4_row0_col8" class="data row0 col8" >-86.23%</td>
#       <td id="T_365d4_row0_col9" class="data row0 col9" >-91.76%</td>
#     </tr>
#     <tr>
#       <th id="T_365d4_level0_row1" class="row_heading level0 row1" >2: Everett-Lynwood-Edmonds</th>
#       <td id="T_365d4_row1_col0" class="data row1 col0" >33.39%</td>
#       <td id="T_365d4_row1_col1" class="data row1 col1" >90.50%</td>
#       <td id="T_365d4_row1_col2" class="data row1 col2" >19.83%</td>
#       <td id="T_365d4_row1_col3" class="data row1 col3" >0.01%</td>
#       <td id="T_365d4_row1_col4" class="data row1 col4" >-33.68%</td>
#       <td id="T_365d4_row1_col5" class="data row1 col5" >13.19%</td>
#       <td id="T_365d4_row1_col6" class="data row1 col6" >-54.03%</td>
#       <td id="T_365d4_row1_col7" class="data row1 col7" >-83.80%</td>
#       <td id="T_365d4_row1_col8" class="data row1 col8" >-73.93%</td>
#       <td id="T_365d4_row1_col9" class="data row1 col9" >-89.74%</td>
#     </tr>
#     <tr>
#       <th id="T_365d4_level0_row2" class="row_heading level0 row2" >3: North Seattle-Shoreline</th>
#       <td id="T_365d4_row2_col0" class="data row2 col0" >19.56%</td>
#       <td id="T_365d4_row2_col1" class="data row2 col1" >49.08%</td>
#       <td id="T_365d4_row2_col2" class="data row2 col2" >110.95%</td>
#       <td id="T_365d4_row2_col3" class="data row2 col3" >33.95%</td>
#       <td id="T_365d4_row2_col4" class="data row2 col4" >-7.90%</td>
#       <td id="T_365d4_row2_col5" class="data row2 col5" >-7.75%</td>
#       <td id="T_365d4_row2_col6" class="data row2 col6" >10.17%</td>
#       <td id="T_365d4_row2_col7" class="data row2 col7" >-60.30%</td>
#       <td id="T_365d4_row2_col8" class="data row2 col8" >-76.43%</td>
#       <td id="T_365d4_row2_col9" class="data row2 col9" >-70.43%</td>
#     </tr>
#     <tr>
#       <th id="T_365d4_level0_row3" class="row_heading level0 row3" >4: Seattle CBD</th>
#       <td id="T_365d4_row3_col0" class="data row3 col0" >-34.08%</td>
#       <td id="T_365d4_row3_col1" class="data row3 col1" >12.94%</td>
#       <td id="T_365d4_row3_col2" class="data row3 col2" >20.28%</td>
#       <td id="T_365d4_row3_col3" class="data row3 col3" >151.73%</td>
#       <td id="T_365d4_row3_col4" class="data row3 col4" >-41.89%</td>
#       <td id="T_365d4_row3_col5" class="data row3 col5" >-43.03%</td>
#       <td id="T_365d4_row3_col6" class="data row3 col6" >2.10%</td>
#       <td id="T_365d4_row3_col7" class="data row3 col7" >-57.96%</td>
#       <td id="T_365d4_row3_col8" class="data row3 col8" >-74.05%</td>
#       <td id="T_365d4_row3_col9" class="data row3 col9" >-73.54%</td>
#     </tr>
#     <tr>
#       <th id="T_365d4_level0_row4" class="row_heading level0 row4" >5: West-South Seattle</th>
#       <td id="T_365d4_row4_col0" class="data row4 col0" >-55.93%</td>
#       <td id="T_365d4_row4_col1" class="data row4 col1" >-37.21%</td>
#       <td id="T_365d4_row4_col2" class="data row4 col2" >7.32%</td>
#       <td id="T_365d4_row4_col3" class="data row4 col3" >10.12%</td>
#       <td id="T_365d4_row4_col4" class="data row4 col4" >97.60%</td>
#       <td id="T_365d4_row4_col5" class="data row4 col5" >-9.47%</td>
#       <td id="T_365d4_row4_col6" class="data row4 col6" >58.37%</td>
#       <td id="T_365d4_row4_col7" class="data row4 col7" >-10.90%</td>
#       <td id="T_365d4_row4_col8" class="data row4 col8" >-74.86%</td>
#       <td id="T_365d4_row4_col9" class="data row4 col9" >-22.06%</td>
#     </tr>
#     <tr>
#       <th id="T_365d4_level0_row5" class="row_heading l
