# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": True, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination_choice", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["intermediate_stop_generation", "other_home_based_tour_mode", "other_home_based_trip_mode", "persons", "school_location", "school_tour_mode", "school_trip_mode", "telecommute", "time_choice", "tours", "tour_destination", "transit_pass_ownership", "trips", "trip_destination", "workbased_subtour_generation", "workbased_subtour_mode", "work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "../../../../inputs/base_year/survey"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "base_year_2023_final", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/rtp_2026_2050", "abm_model": "daysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_daysim": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": True, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %% [raw]
# ---
# title: "Intermediate Stop Generation"
# date: today
# ---

# %%
import plotly.express as px
import polars as pl
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
df_tour = util.get_tour_data(summary_config)

# %%
# ptype_cat = {1: "1: full time worker",
#              2: "2: part time worker",
#              3: "3: non-worker age 65+",
#              4: "4: other non-working adult",
#              5: "5: university student",
#              6: "6: grade school student/child age 16+",
#              7: "7: child age 5-15",
#              8: "8: child age 0-4"}
pdpurp_cat = {1: "Work",
              2: "School",
              3: "Escort",
              4: "Personal Business",
              5: "Shop",
              6: "Meal",
              7: "Social",
              8: "Social",
              9: "Personal Business"}
# df_person = df_person.with_columns(
#     pl.col('pptyp').replace_strict(ptype_cat, default=None).alias('pptyp_label')
# )
# df_person = df_person.with_columns(pl.col('pptyp_label').cast(pl.Categorical))

df_tour = df_tour.with_columns(
    pl.col('pdpurp').replace_strict(pdpurp_cat, default=None).alias('pdpurp_label')
)
df_tour = df_tour.with_columns(pl.col('pdpurp_label').cast(pl.Categorical))

df_tour = df_tour.with_columns(
    (pl.col('tripsh1') + pl.col('tripsh2')).alias('all_stops')
)
df_tour = df_tour.sort(['source'])
# df_tour = df_tour.join(df_person, how='left', on=['pno','hhno','source'])

# %% [raw]
# :::{.panel-tabset}
# ### outbound: first half tour

# %%
df_plot = (
    df_tour.group_by(['tripsh1', 'source'])
    .agg(pl.col('toexpfac').sum())
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['source'])).alias('percentage')
    )
    .filter(pl.col('percentage') > 0.001)
)

df_plot_pd = df_plot.sort(['source']).to_pandas()

fig = px.bar(df_plot_pd, x="tripsh1", y="percentage", color="source",
             barmode="group",title="outbound: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="73c1e2b6-33c9-425a-a18f-ff204bab1d87" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("73c1e2b6-33c9-425a-a18f-ff204bab1d87")) {                    Plotly.newPlot(                        "73c1e2b6-33c9-425a-a18f-ff204bab1d87",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAwGhBUUEAAAAAaLAMQQAAAABA0NJAAAAAAOBT60AAAAAAgMQtQQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQMFBAI="},"xaxis":"x","y":{"dtype":"f8","bdata":"UcnX+GXg6D+Xn2SxEK6kP+m9Sw5kH2s\u002frwEyZdWygz+PaFHtFHXFPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"8fbyuKEJIEH7AMdszTXDQCZA0FtTiMVA\u002fVa90zbYAkGmg07Ks2lKQU18SegXauZA","shape":"6, 1"},"hovertemplate":"source=survey\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AgUGAwEE"},"xaxis":"x","y":{"dtype":"f8","bdata":"j0pMpjn1vz\u002fwAkPvzyNjP27p6RkpdGU\u002fJuVL+5DGoj8NYOd\u002f91DqPyy3SjgaVYY\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777 ...

# %% [raw]
# ### inbound: second half tour

# %%
df_plot = (
    df_tour.group_by(['tripsh2', 'source'])
    .agg(pl.col('toexpfac').sum())
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['source'])).alias('percentage')
    )
    .filter(pl.col('percentage') > 0.001)
)

df_plot_pd = df_plot.sort(['source']).to_pandas()

fig = px.bar(df_plot_pd, x="tripsh2", y="percentage", color="source",
             barmode="group",title="inbound: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fda95694-e0c2-4943-a36e-1d5a71cf8478" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fda95694-e0c2-4943-a36e-1d5a71cf8478")) {                    Plotly.newPlot(                        "fda95694-e0c2-4943-a36e-1d5a71cf8478",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAEA330AAAACAubNMQQAAAACVVzZBAAAAACCs+EAAAAAABAMbQQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"BQECBAM="},"xaxis":"x","y":{"dtype":"f8","bdata":"2CmjTVSAdj+rO6QJdbDkP+PnWQfYGtA\u002f7bpDhNnIkT\u002f+5iE5jHizPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"A9LqZjQbDkE6MUAYlDO\u002fQMVTasagR8tAfqc6rTB1KEGto3X376lGQdfHq9dYGvpAz4H7K1h30kCypzPmlZTkQA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AwAHAgEEBgU="},"xaxis":"x","y":{"dtype":"f8","bdata":"opuMpwL\u002frT\u002fptmjHWxZfPx+vBKcULms\u002fitXJHEleyD\u002fYr1t9tpTmP\u002fv4Fd7mAZo\u002fDPhRCw1mcj8z5B7nT4GEPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.55555555 ...

# %% [raw]
# ### all stops

# %%
df_plot = (
    df_tour.group_by(['all_stops', 'source'])
    .agg(pl.col('toexpfac').sum())
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['source'])).alias('percentage')
    )
    .filter(pl.col('percentage') > 0.001)
)

df_plot_pd = df_plot.sort(['source']).to_pandas()

fig = px.bar(df_plot_pd, x="all_stops", y="percentage", color="source",
             barmode="group",title="all stops: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="8728d2db-ccdb-4cce-9a91-2241fcb4215b" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8728d2db-ccdb-4cce-9a91-2241fcb4215b")) {                    Plotly.newPlot(                        "8728d2db-ccdb-4cce-9a91-2241fcb4215b",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAACIu0AAAAAAtJklQQAAAABL7kdBAAAAAIASzUAAAAAAxOEQQQAAAAACJDdBAAAAAOA0+kAAAAAAIBDjQA==","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"CQQCCAUDBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"oaQkJWjYUz\u002fSxLxy8iO\u002fP2emq1wDQOE\u002fE\u002fNFKsb0ZD+Q4vBOg1aoPzha4TMzrtA\u002ffJDkmvTjkj+LNu4Qent7Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"FYI7Ffc2wkBBkvDI5hjgQNiM9ruQRc9A21XEK32CGkHgOx1LP4vDQNJhK\u002fsnRvFAUKMHqDpoQ0Gm4VVdFq8rQb44eX2HcQZB","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"CgcJBAgGAgMF"},"xaxis":"x","y":{"dtype":"f8","bdata":"YvMAP+glYj8G7lOW0wmAP9j555JHKG8\u002fcrb0qqlpuj+amNzI8XhjP\u002fvmDan6NZE\u002f4yca8Q1W4z8mwVpaKZXLP\u002foLydaCXKY\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.222 ...

# %% [raw]
# :::

# %% [markdown]
# ## number of stops by purpose

# %% [raw]
# :::{.panel-tabset}
# ### outbound

# %%
df_plot = (
    df_tour.group_by(['tripsh1', 'pdpurp_label', 'source'])
    .agg(pl.col('toexpfac').sum())
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['pdpurp_label', 'source'])).alias('percentage')
    )
)
df_plot2 = df_plot.filter(
    (pl.col('percentage') > 0.001) & (pl.col('tripsh1') <= 10)
)

df_plot2_pd = df_plot2.sort(['source', 'pdpurp_label']).to_pandas()

fig = px.bar(df_plot2_pd,
             x="tripsh1", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2,
             hover_data=['toexpfac'],
             title="outbound: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="3ed6da41-6813-4a11-ad58-80d30c02a1b6" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3ed6da41-6813-4a11-ad58-80d30c02a1b6")) {                    Plotly.newPlot(                        "3ed6da41-6813-4a11-ad58-80d30c02a1b6",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAJBP+UAAAAAAPCQeQQAAAAAASJVAAAAAAABc1kAAAAAAALayQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AgEFAwQ="},"xaxis":"x7","y":{"dtype":"f8","bdata":"3JKNkdQqxT8TZonBDTXpPyE9spgjzGE\u002fyFYL6PSyoj\u002fsGRyDtkt\u002fPw=="},"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAITxEkEAAAAAAPCmQAAAAAAAMIhAAAAAAACW60AAAAAAgBrKQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQQFAgM="},"xaxis":"x8","y":{"dtype":"f8","bdata":"aZ18CCza6T9MUcV\u002fkE1\u002fP20Kyq4igWA\u002fRBxPjMjSwj\u002fo5\u002ft\u002f1M+hPw=="},"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAIDdwEAAAAAAQMfqQAAAAAAA7JFAAAAAAMAyFEE=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Personal Business\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AwIEAQ=="},"xaxis":"x5","y":{"dtype":"f8","bdata":"QUelyjZXlj\u002fNSQXwbrzBP+W2O8KIvWc\u002fQQI6pXrB6j8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAEDV+kAAAAAAAG63QAAAAAAA1JlAAAAAACgoHEEAAAAAQB3aQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgQFAQM="},"xaxis":"x6","y":{"dtype":"f8","bdata":"Ccc6cWI2xz9AxXImsUSEP1NydF7YV2Y\u002fpVpE8o9b6D+66hMrNpemPw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAACN3UAAAAAAENT+QAAAAAAAZJpAAAAAAAAbuUAAAAAAREMhQQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AwIFBAE="},"xaxis":"x3","y":{"dtype":"f8","bdata":"zSTtO7szpT9AkaFYZB7GP6tWVmNK72I\u002fpwz5Zz0Dgj+IXNy5dsXoPw=="},"yaxis":"y3","typ ...

# %% [markdown]
# - outliers

# %%
df_plot.filter((pl.col('percentage') > 0.001) & (pl.col('tripsh1') > 10))
# Out:
# shape: (0, 5)
# ┌─────────┬──────────────┬────────┬──────────┬────────────┐
# │ tripsh1 ┆ pdpurp_label ┆ source ┆ toexpfac ┆ percentage │
# │ ---     ┆ ---          ┆ ---    ┆ ---      ┆ ---        │
# │ i64     ┆ cat          ┆ str    ┆ f64      ┆ f64        │
# ╞═════════╪══════════════╪════════╪══════════╪════════════╡
# └─────────┴──────────────┴────────┴──────────┴────────────┘

# %% [raw]
# ### inbound

# %%
df_plot = (
    df_tour.group_by(['tripsh2', 'pdpurp_label', 'source'])
    .agg(pl.col('toexpfac').sum())
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['pdpurp_label', 'source'])).alias('percentage')
    )
)
df_plot2 = df_plot.filter(pl.col('percentage') > 0.001)

df_plot2_pd = df_plot2.sort(['source', 'pdpurp_label']).to_pandas()

fig = px.bar(df_plot2_pd,
             x="tripsh2", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2,
             hover_data=['toexpfac'],
             title="inbound: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="eda40e44-0810-4d60-a396-4ac70b72d77b" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eda40e44-0810-4d60-a396-4ac70b72d77b")) {                    Plotly.newPlot(                        "eda40e44-0810-4d60-a396-4ac70b72d77b",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAECO4UAAAAAA0AYDQQAAAAB4LhpBAAAAAAA5tEAAAAAAAOCIQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AwIBBAU="},"xaxis":"x7","y":{"dtype":"f8","bdata":"65wdRQtdrT8H42YV4dLPPyhCevI+5eU\u002f+Um6voDpgD\u002f454X2h81UPw=="},"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAEDA8kAAAAAAkK4RQQAAAAAAqM1AAAAAAABkoEA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgEDBA=="},"xaxis":"x8","y":{"dtype":"f8","bdata":"IQV9VvCWyT\u002fGB5VybyHoPzZW\u002flNuPKQ\u002fqcpAaVBedj8="},"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAIDp9EAAAAAAgI3MQAAAAAAAPJVAAAAAAMDxEUE=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Personal Business\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgMEAQ=="},"xaxis":"x5","y":{"dtype":"f8","bdata":"AT+ieo+zyz9gX+\u002fkS+miP2uYb0XYIGw\u002fvk8HqCbF5z8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAAD2pUAAAAAAgFcEQQAAAACAWMdAAAAAAOBL7EAAAAAAwFIWQQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"BQIEAwE="},"xaxis":"x6","y":{"dtype":"f8","bdata":"GVwj8Gz\u002fcj9e0auX2pjRP9A6js0XMpQ\u002f2OVRJnZ6uD\u002fN8iYrqU\u002fjPw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAODf4kAAAAAAAHC0QAAAAAAIMB9BAAAAAACwiEAAAAAAsFsFQQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AwQBBQI="},"xaxis":"x3","y":{"dtype":"f8","bdata":"x\u002fXfi4oVqz\u002fVDBk9tFN9P50JK65gYOY\u002fIvYfNni2UT\u002f4IYzo56XOPw=="},"yaxis":"y3","type":"bar"},{"al ...

# %% [raw]
# ### all stops

# %%
df_plot = (
    df_tour.group_by(['all_stops', 'pdpurp_label', 'source'])
    .agg(pl.col('toexpfac').sum())
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['pdpurp_label', 'source'])).alias('percentage')
    )
)
df_plot2 = df_plot.filter(
    (pl.col('percentage') > 0.001) & (pl.col('all_stops') <= 10)
)

df_plot2_pd = df_plot2.sort(['source', 'pdpurp_label']).to_pandas()

fig = px.bar(df_plot2_pd,
             x="all_stops", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2,
             hover_data=['toexpfac'],
             title="all stops: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c12a9953-88e1-4dc1-b08a-fd77cf3a7287" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c12a9953-88e1-4dc1-b08a-fd77cf3a7287")) {                    Plotly.newPlot(                        "c12a9953-88e1-4dc1-b08a-fd77cf3a7287",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAEB01UAAAAAAQFzxQAAAAACg5gRBAAAAAACEmkAAAAAAAJK5QAAAAAAIlhVB","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"BQQDBwYC"},"xaxis":"x7","y":{"dtype":"f8","bdata":"MziBJyXxoT8Lm4YZagm9PxEJu2q0etE\u002fcYlmesYsZj+\u002fqDtJZGKFP6zKjHBlDeI\u002f"},"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAMBP9kAAAAAAABbFQAAAAAAABqlAAAAAAABQikAAAAAAILvgQAAAAACItA1B","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AwUGBwQC"},"xaxis":"x8","y":{"dtype":"f8","bdata":"xF9+ud5yzj8GpgRkscacP55gjsIoE4E\u002fdP3sBFb0YT+B\u002fNfaNtW2PwRZyVH7ROQ\u002f"},"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAEDN30AAAAAAmJcOQQAAAAAAOJRAAAAAAABwukAAAAAAMHj5QA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Personal Business\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"BAIGBQM="},"xaxis":"x5","y":{"dtype":"f8","bdata":"PqpCXDAQtT\u002fEnPMvGEPkP7nbmvxuyGo\u002fDJAjJqWCkT8gLm75gt7QPw=="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAABOyUAAAAAAAGyQQAAAAADg1OFAAAAAAGj7AkEAAAAARL4SQQAAAAAAVK9AAAAAAMB+9UA=","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"BggFAwIHBA=="},"xaxis":"x6","y":{"dtype":"f8","bdata":"XCXY\u002fuzjlT95wu\u002f0gmlcP0ExuEbg2a4\u002fBU1kcbpr0D9WY5pc1jbgP4TQnT\u002fdGXs\u002fniz6EUSYwj8="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAJAsGUEAAAAAoG30QAAAAAAAD71AAAAAAIA92UAAAAAAABidQAAAAABYRQhB","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgQGBQcD" ...

# %% [markdown]
# - outliers

# %%
df_plot.filter((pl.col('percentage') > 0.001) & (pl.col('all_stops') > 10))
# Out:
# shape: (3, 5)
# ┌───────────┬───────────────────┬────────┬────────────┬────────────┐
# │ all_stops ┆ pdpurp_label      ┆ source ┆ toexpfac   ┆ percentage │
# │ ---       ┆ ---               ┆ ---    ┆ ---        ┆ ---        │
# │ i64       ┆ cat               ┆ str    ┆ f64        ┆ f64        │
# ╞═══════════╪═══════════════════╪════════╪════════════╪════════════╡
# │ 11        ┆ Personal Business ┆ survey ┆ 519.044046 ┆ 0.001725   │
# │ 11        ┆ Work              ┆ model  ┆ 2408.0     ┆ 0.001498   │
# │ 12        ┆ Work              ┆ model  ┆ 1734.0     ┆ 0.001079   │
# └───────────┴───────────────────┴────────┴────────────┴────────────┘

# %% [raw]
# :::
