# %% [raw]
# ---
# title: "All Tours"
# date: today
# ---

# %%
import polars as pl
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

config = util.summary_settings
input_config = util.input_settings

# %%
tour = util.get_tour_data()
parcel_geog = util.get_parcel_geog()

df_tour = tour.join(parcel_geog, left_on='tdpcl', right_on='ParcelID', how='left')

# %%
mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: walk to transit",
            7: "7: park-and-ride",
            8: "8: school bus",
            9: "9:tnc"}
pdpurp_cat = {1: "1: Work",
              2: "2: School",
              3: "3: Escort",
              4: "4: other home-based",
              5: "4: other home-based",
              6: "4: other home-based",
              7: "4: other home-based",
              8: "4: other home-based",
              9: "4: other home-based",
              10: "4: other home-based"}
df_tour = df_tour.with_columns(
    tmodetp_label=pl.col("tmodetp").replace_strict(mode_cat, default=None),
    pdpurp_label=pl.col("pdpurp").replace_strict(pdpurp_cat, default=None))

# %%
def plot_mode_choice(df: pl.DataFrame, grp: str, title_name: str):
    df_plot = (
        df.group_by(['source', grp, 'tmodetp_label'])
        .agg(
            toexpfac_sum=pl.col('toexpfac').sum(),
            sample_count=pl.col('toexpfac').count()
        )
        .with_columns(
            (pl.col('toexpfac_sum') / pl.col('toexpfac_sum').sum().over(['source', grp])).alias('percentage')
        )
    )

    fig = px.bar(
        df_plot.sort(by=[grp, 'source']),
        x="tmodetp_label",
        y="percentage",
        color="source",
        facet_col=grp,
        facet_col_wrap=2,
        barmode="group",
        hover_data=['sample_count'],
        title=title_name
    )
    fig.update_layout(
        height=500,
        width=900,
        font=dict(size=11),
        xaxis=dict(dtick=1, categoryorder='category ascending')
    )
    fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
    fig.for_each_yaxis(lambda a: a.update(tickformat=".1%"))
    fig.show()

# %%
# plot mode choice by purpose
all_tour = df_tour.filter(pl.col('parent') == 0)
plot_mode_choice(all_tour,'pdpurp_label', "tour mode choice by purpose")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e9de3b69-7232-499f-91af-7c724388faf5" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e9de3b69-7232-499f-91af-7c724388faf5")) {                    Plotly.newPlot(                        "e9de3b69-7232-499f-91af-7c724388faf5",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"yqwAAFimAwCqIgAAfwEDAALMDgAuQgAADFcAAJ3+AAAoAAAA","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=1: Work\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["6: walk to transit","4: hov 2","7: park-and-ride","5: hov 3+","3: sov","9:tnc","2: bike","1: walk",null],"xaxis":"x3","y":{"dtype":"f8","bdata":"l2N9k6P4nD9Z9tQ0HZXDP6J5MLGNP3c\u002fYaBelqQgwD\u002fdW6q8B9njP3gTZ69FMYY\u002fWBWh4qMwjT\u002fYDPitZFilPyfxeWix0\u002fo+"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"BAAAAC96AAAbTgEAAwAAAGuSAAAHAwMAS0gCAI8xAACeaAEA","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=2: School\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["9:tnc","1: walk","4: hov 2",null,"6: walk to transit","5: hov 3+","8: school bus","2: bike","3: sov"],"xaxis":"x4","y":{"dtype":"f8","bdata":"HSKEkkis2z4IvUtuXmqqPznsZ+3YDsI\u002flhnjbTbB1D5eMcnLpKevPxf9zxEo1tQ\u002fRC3Ag5CUzz9aiVSCvG2VP8MeajGtfcM\u002f"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"1T4EAF0IAADTJgQAEgAAANTPAADTUQAA","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=3: Escort\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["5: hov 3+","2: bike","4: hov 2",null,"1: walk","3: sov"],"xaxis":"x","y":{"dtype":"f8","bdata":"IzvXF7pq3D93flqBaP1rP6hNX78Hyts\u002fNfmmAu4e\u002fj6yaMYrZ7y1P4Lr6IiIHaE\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"tpcBAOVuCADa8A8AByYAAIO8BgDKTAoA3aEAAFgAAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=4: other home-based\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["6: walk to transit","1: walk","3: sov","9:tnc","5: hov 3+","4: hov 2","2: bike",null],"xaxis":"x2","y":{"dtype":"f8","bdata":"gB3MG46foj\u002f6bgvPPafIP4ubue3pTNc\u002fOPfDsb7Kaz9BRMuHYbHDPxHpZnlNHM4\u002fYOt1D\u002fmSjT8auGrbGRQAPw=="},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line": ...

# %%
all_tour = df_tour.filter(pl.col('CountyName').is_in(["King", "Kitsap", "Pierce", "Snohomish"]))
plot_mode_choice(all_tour,'CountyName', "tour mode choice by destination county")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="13785ff6-41d0-49d9-a519-fa89016f97ab" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("13785ff6-41d0-49d9-a519-fa89016f97ab")) {                    Plotly.newPlot(                        "13785ff6-41d0-49d9-a519-fa89016f97ab",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"JIcKAApLEwC5\u002fwgA3x4AAFa+AABTSwAADx0HAP6AAgDIKAEA","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003eCountyName=King\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["4: hov 2","3: sov","5: hov 3+","7: park-and-ride","2: bike","9:tnc","1: walk","6: walk to transit","8: school bus"],"xaxis":"x3","y":{"dtype":"f8","bdata":"278YFu+Myj9L6YFn71PYP+5idPTOscY\u002feYGo4K92Yz96JpeYMgCOP0TRdPzGvnc\u002fQ+Z5QJHwwT9tvKvzIEKpP13S00CsY5c\u002f"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"hv4BAHQ5AQAOBwAAKSAAAJmyAAA8DgAAYwEAAPQFAQAjBAAA","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003eCountyName=Kitsap\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["3: sov","4: hov 2","6: walk to transit","8: school bus","1: walk","2: bike","7: park-and-ride","5: hov 3+","9:tnc"],"xaxis":"x4","y":{"dtype":"f8","bdata":"VVo24uuv2D8AMv2qqFDOP5\u002fzf7NA1XU\u002f2cC6E+zhmD\u002fTS5C000XBP9wPBBrFBoY\u002fU8pMiqYqUT\u002fQWjNbl1XJP04akILWmmk\u002f"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"v\u002fQBAFyLAAAYKwAAaTMEAHU3AABzAQAAvcYDAK4NAACfdQYA","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003eCountyName=Pierce\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["1: walk","8: school bus","6: walk to transit","4: hov 2","2: bike","7: park-and-ride","5: hov 3+","9:tnc","3: sov"],"xaxis":"x","y":{"dtype":"f8","bdata":"aiujSFLPvD\u002fQ0+SyJwmgP8YU7Ay11YM\u002fxWr7i63vzj\u002fdv5bYdoaJP7phvq1VWDU\u002fAn1g0WHPyz\u002fz1M0aeS9pP+GE\u002f2HoyNc\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"GAsAAJi1AwCtvAEA\u002fnMAAIcvAAA7UQMAZDAAAA7aBQD1AAAA","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003eCountyName=Snohomish\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["9:tnc","4: hov 2","1: walk","8: school bus","2: bike","5: hov 3+","6: walk to transit","3: sov","7: park-and-ride"],"xaxis":"x2","y":{"dtype":"f8","bdata":"aamRKubqZj9FazkkuKbOPxXXlHvstLw\u002f0SDLv8TznT\u002fo3OcYrYuIP4xmgcNkacs\u002fzqZK6M\u002f9iD+++bstZC3YP1u38C\u002f5oS8\u002f"},"yaxis":"y2","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color": ...
