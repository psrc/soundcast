# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": True, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination_choice", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["all_tour_mode", "all_trip_mode", "auto_ownership", "day_pattern", "escort_tour_mode", "escort_trip_mode", "households", "intermediate_stop_generation", "other_home_based_tour_mode", "other_home_based_trip_mode", "persons", "school_location", "school_tour_mode", "school_trip_mode", "telecommute", "time_choice", "tours", "tour_destination", "transit_pass_ownership", "trips", "trip_destination", "workbased_subtour_generation", "workbased_subtour_mode", "work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "../../../../inputs/base_year/survey"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to6": 5, "6to7": 6, "7to8": 7, "8to9": 8, "9to10": 9, "10to14": 10, "14to15": 14, "15to16": 15, "16to17": 16, "17to18": 17, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "base_year_2023_final", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/rtp_2026_2050", "abm_model": "daysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_daysim": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": True, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %% [raw]
# ---
# title: "Other Home-Based Tour Mode"
# date: today
# ---

# %%
import plotly.express as px
import polars as pl
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
hh = util.get_hh_data(summary_config)

df_hh = hh.\
    join(util.get_parcel_landuse_data(summary_config), how="left", left_on='hhno', right_on='parcelid').\
    join(util.get_parcel_geog(input_config, summary_config), how="left", left_on='hhparcel', right_on='ParcelID')

df_person = util.get_person_data(summary_config)
df_tour = util.get_tour_data(summary_config)

# %%
# auto_ownership with 4+
df_hh = df_hh.with_columns(
    pl.when(pl.col('hhvehs') >= 4.0).then(pl.lit("4+")).otherwise(pl.col('hhvehs').cast(pl.Utf8)).alias('auto_ownership_4+')
)
# hhsize with 4+
df_hh = df_hh.with_columns(
    pl.when(pl.col('hhsize') >= 4.0).then(pl.lit("4+")).otherwise(pl.col('hhsize').cast(pl.Utf8)).alias('hhsize_4+')
)
# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh = df_hh.with_columns((
    pl.col('hhsize') - pl.col('hh515') - pl.col('hhcu5')
).alias('drivers'))
# auto availability
df_hh = df_hh.with_columns((pl.col('hhvehs') - pl.col('drivers')).alias('auto_count_driver'))
df_hh = df_hh.with_columns(
    pl.when(pl.col('drivers') <= 0).then(pl.lit("no driver")).
    when(pl.col('hhvehs') <= 0).then(pl.lit("no car")).
    when(pl.col('auto_count_driver') < 0).then(pl.lit("cars fewer than drivers")).
    otherwise(pl.lit("enough cars")).alias('auto_available_driver')
)

# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person = df_person.with_columns(
    pl.col('pptyp').replace_strict(ptype_cat, default=None).alias('pptyp_label')
)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: walk to transit",
            7: "7: park-and-ride",
            8: "8: school bus",
            9: "9: tnc"}
df_tour = df_tour.with_columns(
    pl.col('tmodetp').replace_strict(mode_cat, default=None).alias('tmodetp_label')
)

pdpurp_cat = {1: "Work",
              2: "School",
              3: "Escort",
              4: "Personal Business",
              5: "Shop",
              6: "Meal",
              7: "Social"}
df_tour = df_tour.with_columns(
    pl.col('pdpurp').replace_strict(pdpurp_cat, default=None).alias('pdpurp_label')
)

df_person = df_person.join(df_hh, how='left', on=['hhno', 'source']) # get auto ownership from hh data
df_tour = df_tour.join(df_person, how='left', on=['pno', 'hhno', 'source'])

# %%
hb_tour = df_tour.filter((pl.col('parent') == 0) & (~pl.col('pdpurp').is_in([1, 2, 3])))

# %%
df_plot = (
    hb_tour.group_by(['source', 'tmodetp_label'])
    .agg([
        pl.col('toexpfac').sum().alias('toexpfac'),
        pl.col('toexpfac').count().alias('sample count')
    ])
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['source'])).alias('percentage')
    )
)

df_plot_pd = df_plot.sort(['source']).to_pandas()

fig = px.bar(df_plot_pd, x="tmodetp_label", y="percentage", color="source",
             barmode="group",hover_data=['sample count'],title="other home-based tour mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e5d622d0-7477-4980-bb54-b5bcc7b86104" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e5d622d0-7477-4980-bb54-b5bcc7b86104")) {                    Plotly.newPlot(                        "e5d622d0-7477-4980-bb54-b5bcc7b86104",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"oiYAAFQAAADATAoAY6EAAAWTAQCNcggA4PAPAGy8BgA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["9: tnc",null,"4: hov 2","2: bike","6: walk to transit","1: walk","3: sov","5: hov 3+"],"xaxis":"x","y":{"dtype":"f8","bdata":"ffUXG7A8bD8rI7w1u7L+PsiG4B3lHM4\u002f\u002f0vpx199jT\u002f3\u002fJHWIGmiP3DCa22Cssg\u002fe38\u002fq35N1z8dlsuVlLHDPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"bAAAAAUAAAATAAAAEAAAACsCAAB0BQAAxAMAAGgDAADOAAAAGAAAAA==","shape":"10, 1"},"hovertemplate":"source=survey\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["2: bike","8: school bus",null,"7: park-and-ride","5: hov 3+","3: sov","1: walk","4: hov 2","6: walk to transit","9: tnc"],"xaxis":"x","y":{"dtype":"f8","bdata":"e6lJj7qziD8VQSAA9RpJP+eCYg95zoA\u002fc+dU1f1XcD\u002f0UAMe+XHGP\u002fp2tj7OT9Y\u002fqWi2M3ySwT8WT76n90HQP7IRVAnngKw\u002fkHJFLuB4cD8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","tic ...

# %%
df_plot = (
    hb_tour.group_by(['source', 'pdpurp_label', 'tmodetp_label'])
    .agg([
        pl.col('toexpfac').sum().alias('toexpfac'),
        pl.col('toexpfac').count().alias('sample count')
    ])
    .with_columns(
        (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['source', 'pdpurp_label'])).alias('percentage')
    )
)

df_plot_pd = df_plot.sort(['source', 'tmodetp_label']).to_pandas()

fig = px.bar(df_plot_pd,
             x="percentage", y="tmodetp_label", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=1, orientation='h',
             hover_data=['sample count'],
             category_orders={"tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                               "7: park-and-ride","8: school bus","9: otherâ€“survey only"]},
             title="other home-based tour mode choice")
fig.update_layout(height=1000, width=650)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1a49ad99-8a51-4330-b479-d8d0e182f1f3" class="plotly-graph-div" style="height:1000px; width:650px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1a49ad99-8a51-4330-b479-d8d0e182f1f3")) {                    Plotly.newPlot(                        "1a49ad99-8a51-4330-b479-d8d0e182f1f3",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"OQAAAA3GBQDzdwAAEskGAO7rBAAoUQMAdIUAALYQAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Social\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"USj+S7XdBD9OVHeFkujQP2Ox3KR49JU\u002f9a1Q8SDf0z\u002fl5nZqlNPMP4HqqLCfbcM\u002fnkMemjltmD9V5AIHNXhoPw=="},"xaxis":"x4","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"BgAAAGegAACFDAAA9McCAI9RAQCyzgAAZVwAAIoLAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Personal Business\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"COtXHckH8D5iA1qL18i6P8vOB710uYA\u002ftsN0\u002fZm43T8D1koh8C7MP67d7qnhQcE\u002fz0AW2lHbrj9YahlyTtR+Pw=="},"xaxis":"x3","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"DAAAAJFKAQAAGAAAAxcFAJZqAgCzlQEAFXcAAC4GAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"5VYBfGqC8T4HSY0tYCW+P+VWAXxqgoE\u002fbmwjLAC13T9emCpRujTMP\u002fCMbMS1f8I\u002fAXRXhii4pT9\u002ftmKspwhiPw=="},"xaxis":"x2","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"CQAAAIjBAADrBAAA10gBAK2kAQDfBgEAFzoAADQEAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"jIQL7GL0\u002fD4LaOVcAHXDPxVBv\u002f\u002fcpG8\u002fVePk\u002fr+H0D\u002fGLvDAjyXVP\u002fLNVOOhbco\u002f5srbpFZcpz+xbJXzXwtrPw=="},"xaxis":"x","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"CQAAAFcCAABMAAAATAIAAIcBAAA9AQAARgAAAAoAAAADAAAACwAAAA==","shape":"10, 1"},"hovertemplate":"source=survey\u003cbr\u003epdpurp_label=Social\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\ ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### home county

# %%
def plot_mode_choice(df: pl.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = (
        df.group_by(['source', grp_var, 'tmodetp_label'])
        .agg([
            pl.col('toexpfac').sum().alias('toexpfac'),
            pl.col('toexpfac').count().alias('sample count')
        ])
        .with_columns(
            (pl.col('toexpfac') / pl.col('toexpfac').sum().over(['source', grp_var])).alias('percentage')
        )
    )

    df_plot_pd = df_plot.sort(['tmodetp_label']).to_pandas()

    fig = px.bar(df_plot_pd,
                 x="percentage", y="tmodetp_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 hover_data=['sample count'],
                 category_orders=order_list,
                 title="other home-based tour mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
incl_county = ["King", "Kitsap", "Pierce", "Snohomish"]

plot_mode_choice(hb_tour.filter(pl.col("CountyName").is_in(incl_county)),"CountyName",
                 {"CountyName":["King", "Kitsap", "Pierce", "Snohomish"],
                  "tmodetp_label":list(mode_cat.values())},
                 "home county",
                 2,600)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4df57144-519e-4377-85e9-b7562a95f906" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4df57144-519e-4377-85e9-b7562a95f906")) {                    Plotly.newPlot(                        "4df57144-519e-4377-85e9-b7562a95f906",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"DQAAAEMDAABhAAAAkwMAAC8CAABeAQAAtgAAAAsAAAADAAAAEwAAAA==","shape":"10, 1"},"hovertemplate":"source=survey\u003cbr\u003eCountyName=King\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"0Y1wHoUQjj8ihyePXh\u002fFP93FyhyuuIk\u002fZJtnxCi91T+mARXumVzQP1lGzwCIVMM\u002fWoWdwBWNqT9F0Pip3x59P2AiCDKauyE\u002fRioTa7BqcT8="},"xaxis":"x3","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","8: school bus","9: tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"NQAAAHPvBABMXAAAxxgIANwmBQB0UgMAu1sBACAVAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eCountyName=King\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"YiZ8B+cwAj81W39dZRrLP5No3dXDrY8\u002f3yehoHY71j9ymfIjsErMP2Hr5cVfPsI\u002fxFFDvG3WrT8BX6shrwBtPw=="},"xaxis":"x3","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"AgAAAAoAAABfAAAAMgAAACcAAAACAAAABQAAAA==","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003eCountyName=Kitsap\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"9WYY7SUOJT\u002f+Avf\u002fvce0PxxFg8dmVuA\u002ffbX6gHRrzj\u002fctRlI34rBP40nlQ7f9J4\u002fd+tEZasUaj8="},"xaxis":"x4","y":[null,"1: walk","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"CAAAAFeSAABkCQAASigBAF62AAD5cgAA8wIAAMMCAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eCountyName=Kitsap\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"5Cj6UJ+yBT+sYKYgfc7IP\u002f+kjQIseIk\u002fl6eu180c2T\u002faKSO06enOPw5TCl5LfcM\u002fTOPo7eX+bz93b1H+JvZtPw=="},"xaxis":"x4","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"TgAAAAUAAADFAAAAigAAAFAAAAATAAAAAgAAAAIAAAA=","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eCountyName=Pierce\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{ ...

# %% [raw]
# ### person type

# %%
plot_mode_choice(hb_tour,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "tmodetp_label":list(mode_cat.values())},
                 "person type",2,1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="005c5274-b285-4d1f-ba89-8e14380e67fd" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("005c5274-b285-4d1f-ba89-8e14380e67fd")) {                    Plotly.newPlot(                        "005c5274-b285-4d1f-ba89-8e14380e67fd",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"JgAAAFQRAwDgPwAAyKcFAB+rAgAurAEAhXIAADUIAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"lGWVCAoKBj8AZKDrlXfMPw8\u002fX0bphZI\u002f+QdkRnc92j93KK5cI8PIP02HSW+7Cr8\u002f6I43T9CaoD9wv5KCJQpjPw=="},"xaxis":"x7","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"AgAAAMsBAAA0AAAAwAEAAAYBAACRAAAALAAAAAIAAAANAAAA","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"rReef\u002fF0Qz9h8\u002fQswPzHP\u002f5DR8vwJ5g\u002fgBK7lXbA1j9\u002fiYghtjnRP7WqMOGDE8M\u002f+EBS5f9hhD8Mq4o\u002fCg01P0I+t54eSXI\u002f"},"xaxis":"x7","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9: tnc"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"
y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","8: school bus","9: tnc"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"DAAAAE6PAQAYDwAAtR8AAKsNAABqyAAAVRkAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"T6mncYLsET\u002f7S5eUY6PiP\u002fbi9BJ8i5Y\u002fzrWRKgCupz+YjJ7oTGqUP0O6EsmXtdI\u002f1SxhhC3roj8="},"xaxis":"x5","y":[null,"1: walk","2: bike","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"BwAAAMwBAAA2AAAASwIAADkBAACxAAAANwAAAAYAAAACAAAABgAAAA==","shape":"10, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"MSW696F9Uj+89LjTcuTLPz6Jp\u002f1xJ40\u002fMokcjwjm0z+to22KZ2fRP6S582eyErQ\u002ffRZh20f0tj+YV+3dEJGKP2fcUtlarAU\u002fxHt8DGjUZj8="},"xaxis":"x6","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","8: school bus","9: tnc"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"FgAAAGBhAgDIMwAARDkEAIljAgBRDQEAhHIAAOYFAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Lrskg9JrAD+WlsKdkW3MPxk6bQNBU5M\u002fPPrLYpo42T9KWKnqXYfMP8\u002fEO7y3ILk\u002ffUw0FH5epT9gZNNOXJxhPw=="},"xaxis":"x6","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"AwAAAMsAAAAUAAAADwIAAIwBAAAkAQAADgAAAAUAAAABAAAABQAAAA==","shape":"10, 1"},"hovertemplate":"source=su ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(hb_tour.filter(pl.col('auto_available_driver') != "no dirver"), "auto_available_driver",
                 {"auto_available_driver": ["no car", "cars fewer than drivers", "enough cars"],
                  "tmodetp_label": list(mode_cat.values())},
                 "auto availability (driver, showing only households with at least one driver)", 3, 500, 1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e6a722b7-2948-49fa-95e9-3547c9cf066a" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e6a722b7-2948-49fa-95e9-3547c9cf066a")) {                    Plotly.newPlot(                        "e6a722b7-2948-49fa-95e9-3547c9cf066a",                        [{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"DAAAAE6PAQAYDwAAtR8AAKsNAABqyAAAVRkAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"T6mncYLsET\u002f7S5eUY6PiP\u002fbi9BJ8i5Y\u002fzrWRKgCupz+YjJ7oTGqUP0O6EsmXtdI\u002f1SxhhC3roj8="},"xaxis":"x","y":[null,"1: walk","2: bike","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"BgAAAPcAAAAcAAAACgAAABMAAAANAAAAhAAAAAUAAAABAAAADQAAAA==","shape":"10, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"3DFOsx2kej9R06I8ZG3bP7wTQcZMtps\u002fi70KvHrogj9NUBlV\u002fhe5P9EjSGKXJnM\u002f4xZDPSRV2D+6PGGgZXJ5P+3avm73fic\u002fXSNNJlgnpD8="},"xaxis":"x","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","8: school bus","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"EAAAAF1AAgDxNQAAVIwCALbHAwDL2wIAfaoAAMgFAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"xt3mzNG\u002f9D5ucR\u002fekFvHPwPFtg\u002f8fJE\u002fSpxZo6xvyj\u002f27gh31JvTPytbuhcYqM0\u002f\u002f7cE9wWjqz+IrCU6Pf1dPw=="},"xaxis":"x2","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","9: tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"BQAAABsBAAAjAAAA\u002fAAAABcBAADZAAAAJAAAAAkAAAACAAAABAAAAA==","shape":"10, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"wc8ZjL7WRz+Sy1MP2B3DPznKHPNLTpk\u002flaEVwuzFyT8oZbuAQCfVP2mtV+au88o\u002f0v27zjxtsT+M9ELwVoaJPxhuJKRCJwQ\u002fReP90i8JYj8="},"xaxis":"x2","y":[null,"1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","8: school bus","9: tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"u4","bdata":"OAAAAOKiBABaXAAAjGQNAFVl ...

# %% [raw]
# :::
