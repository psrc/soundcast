# %% [raw]
# ---
# title: "Auto Ownership"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import toml
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-58f83f37b7bc> in <module>
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import validation_data_input
#       5 import plotly.express as px
#       6 import toml
#
# ModuleNotFoundError: No module named 'validation_data_input'

# %%
hh = validation_data_input.get_data('household',config['survey_dir'])

# %%
# ACS auto ownership validation dataset
df_acs = pd.read_csv(config['p_acs_auto_ownership'])
# add lookup for maz and block groups
df_acs = df_acs.merge(pd.read_csv(config['p_maz_bg_lookup']), on='block_group_id')
# df_acs.columns

# parcel land use data
df_parcel = pd.read_csv(os.path.join(config['model_dir'],r'outputs\landuse\buffered_parcels.txt'),
                        delim_whitespace=True,
                        usecols=['parcelid','emptot_1','hh_1'])

# %%
hh = hh.merge(df_parcel, left_on='hhparcel', right_on='parcelid', how='left')
hh = hh.merge(df_acs, how='left', left_on='hhtaz', right_on='TAZ')
# hh.columns

# %% [markdown]
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# Group income, hh density, and employment density into 4 groups
var_group = hh.loc[hh['source'] == 'model',['hhincome','emptot_1','hh_1']].quantile([.125, .25, .50, .75])

var_group
# Out:
#        hhincome    emptot_1        hh_1
# 0.125   33179.0    0.000000   62.807899
# 0.250   58854.0    7.368156  139.187484
# 0.500  109520.0   88.065913  297.598054
# 0.750  182534.0  379.369208  588.501729

# %%
# data manipulation
# hhwkrs is not always accurate; recalculate from part and full time workers
hh['hhwkrs'] = hh['hhftw']+hh['hhptw']
hh['hhwkrs']
# Add column for adults (4/23/24 adults = all members 16 and above)
hh['adults'] = hh['hhsize']-hh['hh515']-hh['hhcu5']#-hh['hhhsc']

# add income group
hh['hhincome_group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + var_group['hhincome'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add hh density groups
hh['hh_density_group'] = pd.cut(hh['hh_1'],bins=[-9999999.0] + var_group['hh_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add employment density groups
hh['emp_density_group'] = pd.cut(hh['emptot_1'],bins=[-9999999.0] + var_group['emptot_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])

# add auto_ownership with 4+
hh['auto_ownership_simple'] = np.where(hh['hhvehs']>=4, "4+", hh['hhvehs'])
# add auto_ownership with 2+
hh['auto_ownership_2'] = np.where(hh['hhvehs']<2, hh['hhvehs'], "2+")
# add hhsize with 4+
hh['hhsize_simple'] = np.where(hh['hhsize']>=4, "4+", hh['hhsize'])
# add num_workers with 4+
hh['num_workers_simple'] = np.where(hh['hhwkrs']>=4, "4+", hh['hhwkrs'])
# add num_adults with 4+
hh['num_adults_simple'] = np.where(hh['adults']>=4, "4+",hh['adults'])

# %%
df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))
df_plot['source'] = df_plot['source'].astype(pd.CategoricalDtype(['model', 'survey']))

df_plot_ct = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
    rename(columns={'hhexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','auto_ownership_simple'])

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             hover_data=['sample count'],
             barmode="group",title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4a6158e4-51aa-4e0b-b361-d6439bf11097" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a6158e4-51aa-4e0b-b361-d6439bf11097")) {                    Plotly.newPlot(                        "4a6158e4-51aa-4e0b-b361-d6439bf11097",                        [{"alignmentgroup":"True","customdata":[[210586],[850055],[1175241],[674668],[346015]],"hovertemplate":"source=model<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.06466506886857779,0.26102810783755276,0.36088363045110416,0.20717166707865498,0.10625152576411034],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[10],[5945],[23898],[19679],[5787],[2362]],"hovertemplate":"source=survey<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.00025424778999155555,0.06396851388213094,0.23969146157186672,0.3965176426283396,0.20197004852550768,0.09759808560216346],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333 ...

# %% [markdown]
# ## Auto ownership by segments

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str, sub_name:str):
    df_plot = df.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = hh.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
        rename(columns={'hhexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',var,'auto_ownership_simple'])

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 hover_data=['sample count'],
                 title="Auto ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=800, font=dict(size=11),
                      yaxis=dict(tickformat=".2%"))
    fig.for_each_yaxis(lambda a: a.update(tickformat = ".2%"))
    fig.show()

# %% [raw]
# :::{.panel-tabset}
#
# ### income

# %%
plot_auto(hh,'hhincome_group','income level', 'Income')
# Out:
# <div>                            <div id="cc533245-cfa0-4b7a-a6d1-0e1e1534f5f7" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc533245-cfa0-4b7a-a6d1-0e1e1534f5f7")) {                    Plotly.newPlot(                        "cc533245-cfa0-4b7a-a6d1-0e1e1534f5f7",                        [{"alignmentgroup":"True","customdata":[[0],[108511],[165060],[81727],[34895],[16972]],"hovertemplate":"source=model<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.2665037515503543,0.4053884788722017,0.20072206599290213,0.08570235653850404,0.04168334704603785],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[37808],[164088],[119337],[57636],[28228]],"hovertemplate":"source=model<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x2","y":[0.0,0.09287221473015031,0.4030685561426392,0.29314143803565246,0.1415780514226339,0.06933973966892411],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[34457],[257815],[298835],[149169],[76832]],"hovertemplate":"source=model<br>hhincome_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x3","y":[0.0,0.04216945617959927,0.31552132643420455,0.36572276859362535,0.182557262932195,0.09402918586037587],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[18047],[155709],[334798],[198525],[105950]],"hovertemplate":"source=model<br>hhincome_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x4","y":[0.0,0.02219724019684415,0.1915171537546631,0.4117909693258174,0.2441794819126993,0.13031515480997602],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[11763],[107383],[340544],[234443],[118033]],"hovertemplate":"source=model<br>hhincome_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x5","y":[0.0,0.014483492290984848,0.13221804409443388,0.4193034428922166,0.2886638938345117,0.14533112688785296],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[2793],[6320],[4191],[1047],[627]],"hovertemplate":"source=survey<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.17328866645493457,0.3240632424545602,0.2725387140162578,0. ...

# %% [raw]
# ### household size

# %%
plot_auto(hh,'hhsize_simple','household size', 'HH size')
# Out:
# <div>                            <div id="5f85378c-6d94-4c5e-b201-ad736d5900f7" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f85378c-6d94-4c5e-b201-ad736d5900f7")) {                    Plotly.newPlot(                        "5f85378c-6d94-4c5e-b201-ad736d5900f7",                        [{"alignmentgroup":"True","customdata":[[166416],[520927],[82078],[26833],[16458]],"hovertemplate":"source=model<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.20476626406402268,0.6409736782525667,0.10099272559036904,0.033016615972201714,0.020250716120839854],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[28262],[170030],[556277],[241717],[112957]],"hovertemplate":"source=model<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.02547863723277947,0.15328471759569365,0.5014924592717737,0.2179116748990077,0.10183251100074556],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[7759],[65346],[215261],[186823],[53704]],"hovertemplate":"source=model<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.014670264117694884,0.12355240095822785,0.40700292875874705,0.35323401897926426,0.10154038718606599],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[8149],[93752],[321625],[219295],[162896]],"hovertemplate":"source=model<br>hhsize_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.010113973020303655,0.11635847326046242,0.3991786197883376,0.2721737284927586,0.20217520543813772],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[5071],[14118],[2144],[582],[254]],"hovertemplate":"source=survey<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.22491614053479947,0.619296099940466,0.09728077320579695,0.03596866538189444,0.022538320937043065],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[774],[6994],[10948],[2610],[1081]],"hovertemplate":"source=survey<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.016248647878962394,0.13505195235596634,0.589211726771596,0.18213044810126278,0.07735722489221249],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[10],[57],[ ...

# %% [raw]
# ### number of adults

# %%
plot_auto(hh.loc[hh['num_adults_simple']!="0"],'num_adults_simple','number of adults','num adults')
# Out:
# <div>                            <div id="5e697d0e-f2a4-49ad-aa63-e52467e58d42" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e697d0e-f2a4-49ad-aa63-e52467e58d42")) {                    Plotly.newPlot(                        "5e697d0e-f2a4-49ad-aa63-e52467e58d42",                        [{"alignmentgroup":"True","customdata":[[177793],[567286],[89937],[29111],[17965]],"hovertemplate":"source=model<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.20155834085333502,0.6431143236759884,0.10195875260176943,0.03300222652512436,0.020366356343782734],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[27629],[212136],[876998],[369133],[153408]],"hovertemplate":"source=model<br>num_adults_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.016854103936792687,0.12940613821475455,0.5349819191559345,0.22517666033877792,0.09358117835374037],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[2803],[36290],[133640],[216630],[52955]],"hovertemplate":"source=model<br>num_adults_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.006337069710027627,0.08204504451548433,0.30213556762329363,0.48976076035793253,0.11972155779326187],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[2361],[34343],[74666],[59794],[121687]],"hovertemplate":"source=model<br>num_adults_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.00806212032740199,0.11727124032357752,0.2549624211629805,0.20417891692362328,0.4155253012624167],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[5175],[14777],[2334],[613],[331]],"hovertemplate":"source=survey<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.21961478551185892,0.6102634642079877,0.1107943455489466,0.03576423998507839,0.023563164746128438],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[751],[8490],[15829],[3495],[1070]],"hovertemplate":"source=survey<br>num_adults_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.012527880247287022,0.11940645608713472,0.6011583431753675,0.20378118630254233,0.0631261341876685],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","cu ...

# %% [raw]
# ### number of workers

# %%
plot_auto(hh,'num_workers_simple','number of workers','num workers')
# Out:
# <div>                            <div id="2549bf4f-f6ff-4473-985f-ac0ade63ca68" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2549bf4f-f6ff-4473-985f-ac0ade63ca68")) {                    Plotly.newPlot(                        "2549bf4f-f6ff-4473-985f-ac0ade63ca68",                        [{"alignmentgroup":"True","customdata":[[122767],[258164],[193034],[110275],[44272]],"hovertemplate":"source=model<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.16851747122902574,0.35437165070719495,0.26497024070983044,0.15137019019590617,0.060770447158042695],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[79350],[460495],[418228],[209350],[96401]],"hovertemplate":"source=model<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.06278564103862563,0.36436639911886465,0.33092266011723154,0.16564806492043196,0.07627723480484624],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[7895],[113178],[516242],[295203],[137709]],"hovertemplate":"source=model<br>num_workers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.007376939658595793,0.10575139666631472,0.4823668249819898,0.2758321365467326,0.12867270214636709],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[435],[11338],[32663],[48426],[42374]],"hovertemplate":"source=model<br>num_workers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.0032165991304090626,0.08383862285190334,0.241525925049543,0.3580851252625041,0.3133337277056405],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[139],[6880],[15074],[11414],[25259]],"hovertemplate":"source=model<br>num_workers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[0.002365313276384304,0.11707449885988497,0.25650886567062586,0.19422795493993125,0.4298233672531736],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[2243],[6820],[4749],[1631],[496]],"hovertemplate":"source=survey<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.19483823818223894,0.4315250409751528,0.2474614491849211,0.09174411398166227,0.034431157676024914],"yaxis":"y","type":"bar"},{"alignmentgroup":"True ...

# %% [raw]
# ### household density

# %%
plot_auto(hh.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# <div>                            <div id="8717d506-1a84-49a0-b170-70cca3a1d059" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8717d506-1a84-49a0-b170-70cca3a1d059")) {                    Plotly.newPlot(                        "8717d506-1a84-49a0-b170-70cca3a1d059",                        [{"alignmentgroup":"True","customdata":[[0],[4004],[53922],[132363],[138120],[78673]],"hovertemplate":"source=model<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.009835856166570863,0.1324597992542043,0.3251507067372176,0.3392928206110808,0.19326081723092645],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[7325],[69973],[156376],[113733],[59670]],"hovertemplate":"source=model<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x2","y":[0.0,0.017994138701031993,0.17189131294570806,0.3841435404112735,0.27938940298764114,0.14658160495434525],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[25317],[172446],[322517],[195127],[98753]],"hovertemplate":"source=model<br>hh_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x3","y":[0.0,0.03109585339491009,0.21180848973174807,0.3961346664046379,0.2396666502898693,0.12129434017883463],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[47121],[237532],[315474],[142260],[71725]],"hovertemplate":"source=model<br>hh_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x4","y":[0.0,0.05788024252191345,0.291768208796824,0.38750687866043,0.1747425415667623,0.0881021284540702],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[126819],[316182],[248511],[85428],[37194]],"hovertemplate":"source=model<br>hh_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x5","y":[0.0,0.15577165429769546,0.3883660429364208,0.3052458194842618,0.1049311292735594,0.045685354008062555],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[10],[132],[1915],[2386],[1365],[718]],"hovertemplate":"source=survey<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0016750616214191462,0.02828015623902285,0.202900980158384 ...

# %% [raw]
# ### employment density

# %%
plot_auto(hh.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# <div>                            <div id="c974cc96-ad59-44a1-ad3b-ddce9adf6be5" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c974cc96-ad59-44a1-ad3b-ddce9adf6be5")) {                    Plotly.newPlot(                        "c974cc96-ad59-44a1-ad3b-ddce9adf6be5",                        [{"alignmentgroup":"True","customdata":[[0],[6912],[78621],[228144],[166321],[88613]],"hovertemplate":"source=model<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.01215593789075484,0.13826851749262678,0.4012303666302622,0.29250401416785815,0.15584116381849805],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[4024],[40084],[90494],[71237],[39793]],"hovertemplate":"source=model<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x2","y":[0.0,0.01638223032829599,0.1631872068785826,0.36841291036998436,0.2900151446065659,0.16200250781657113],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[22758],[176823],[316641],[198120],[99711]],"hovertemplate":"source=model<br>emp_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x3","y":[0.0,0.027956410700531783,0.21721312985763827,0.3889685315329592,0.2433748171187871,0.12248711079008369],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[50205],[237781],[302021],[148487],[75657]],"hovertemplate":"source=model<br>emp_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x4","y":[0.0,0.06166546500587729,0.292060072394433,0.3709643542782604,0.18238262926656112,0.0929274790548682],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[126687],[316746],[237941],[90503],[42241]],"hovertemplate":"source=model<br>emp_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x5","y":[0.0,0.15561257704657064,0.3890664498266836,0.2922684426581896,0.11116693157502966,0.051885598893526494],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[10],[90],[1978],[3391],[1312],[434]],"hovertemplate":"source=survey<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0017167785238825025,0.016827494234756202,0.1250565 ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data

# %%
df = hh.groupby(['source','block_group_id','auto_ownership_2'])['hhexpfac'].sum().reset_index()

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hhexpfac'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_csv(config['p_acs_auto_ownership'], usecols=['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id'])

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2', height=400, width=1000,
                 title="Auto ownership model results validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=400, width=950, font=dict(size=11))
fig.show()
# Out:
# <div>                            <div id="a1fa6e55-e825-4bfc-a3af-f5656d34e643" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1fa6e55-e825-4bfc-a3af-f5656d34e643")) {                    Plotly.newPlot(                        "a1fa6e55-e825-4bfc-a3af-f5656d34e643",                        [{"hovertemplate":"auto_ownership_2=0<br>acs data=%{x}<br>model=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":[18.081180811808117,18.181818181818183,18.170580964153277,18.206278026905828,18.093699515347335,6.292134831460674,6.172839506172839,6.292134831460674,6.216696269982238,6.301369863013699,6.25,6.118546845124283,6.109324758842444,25.75835475578406,25.869262865090402,25.720384204909283,18.317757009345794,18.313253012048193,18.076285240464344,18.226002430133658,1.937984496124031,1.9337016574585635,2.0361990950226243,8.81294964028777,8.814102564102564,8.734939759036145,8.827586206896552,8.709677419354838,8.848080133555927,12.251941328731665,12.162162162162161,12.171837708830548,12.280701754385966,1.6842105263157894,1.9031141868512111,2.3706896551724137,2.4630541871921183,5.277044854881266,4.926108374384237,6.509945750452079,6.410256410256411,21.26865671641791,21.296296296296298,21.220723917672107,21.221374045801525,21.25,13.583138173302109,13.612565445026178,13.607188703465981,7.751937984496124,7.581227436823105,7.6923076923076925,7.73286467486819,3.5714285714285716,3.6713286713286712,4.585537918871252,4.6263345195729535,4.704301075268817,18.418079096045197,18.403908794788272,18.315018315018314,13.836477987421384,13.84297520661157,13.855421686746988,13.612565445026178,5.327245053272451,5.180722891566265,5.2439024390243905,12.997658079625293,12.947189097103918,13.102119460500964,8.131067961165048,7.982261640798226,8.108108108108109,3.8461538461538463,3.7914691943127963,3.9244186046511627,4.355108877721943,4.370629370629371,4.120443740095087,4.08997955010225,2.763819095477387,2.7848101265822787,2.6970954356846475,6.6115702479338845,6.5349544072948325,6.11353711790393,6.214689265536723,6.175771971496437,6.265664160401003,2.2257551669316373,2.3465703971119134,2.1782178217821784,2.304147465437788,7.885304659498208,8.045977011494253,7.9245283018867925,7.861635220125786,5.007153075822604,5.007824726134586,5.040650406504065,2.8368794326241136,2.848575712143928,2.9535864978902953,2.8776978417266186,3.476482617586912,3.522504892367906,3.5587188612099645,3.5335689045936394,3.5398230088495577,11.041666666666666,11.006711409395972,11.052166224580018,10.943912448700411,11.075949367088608,11.02661596958175,10.944206008583691,7.6923076923076925,7.763401109057301,7.769423558897243,7.741935483870968,7.829181494661921,5.166051660516605,5.009633911368016,5.208333333333333,10.714285714285714,10.703363914373089,10.606060606060606,15.46644844517185,15.491803278688524,15.492957746478874,15.52,7.957957957957958,7.94044665012407,6.901217861975643,6.651376146788991,10.194174757281553,10.303030303030303,2.7656477438136826,2.735562310030395,2.766798418972332,2.610441767068273,2.816901408450704,2.7439024390243905,3.5190615835777126,3.5114503816793894,3.498542274052478,3.5058430717863107,3.4111310592459607,13.278008298755188,13.333333333333334,13.406593406593407,48.33997343957503,48.405466970387245,30.87649402390438,30.794341675734493,30.72289156626506,30.837359098228664,10.53864168618267,10.476190476190476,2.484472049689441,2.6101141924959217,2.5280898876404496,16.844919786096256,16.813048933500628,16.852589641434264,16.877637130801688,4.536082474226804,4.7913446676970635,4.741379310344827,4.690431519699812,12.948517940717629,12.934631432545201,12.914691943127963,12.837837837837839,12.884834663625998,13.35149863760218,13.271028037383177, ...
