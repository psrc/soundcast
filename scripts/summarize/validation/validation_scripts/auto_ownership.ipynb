# %% [raw]
# ---
# title: "Auto Ownership"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import toml
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

config = toml.load(os.path.join(os.getcwd(), '..\\..\\..\\..\\configuration', 'validation_configuration.toml'))
input_config = toml.load(os.path.join(os.getcwd(), '..\\..\\..\\..\\configuration', 'input_configuration.toml'))
# model_dir = os.path.join(os.getcwd(), '..\\..\\..\\..\\')

# %%
hh = validation_data_input.get_data('household')

# %%
# parcel land use data
df_parcel = pd.read_csv(os.path.join(config['model_dir'],r'outputs\landuse\buffered_parcels.txt'),
                        delim_whitespace=True,
                        usecols=['parcelid','emptot_1','hh_1'])

# %%
hh = hh.merge(df_parcel, left_on='hhparcel', right_on='parcelid', how='left')

# %% [markdown]
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# Group income, hh density, and employment density into 4 groups
var_group = hh.loc[hh['source'] == 'model',['hhincome','emptot_1','hh_1']].quantile([.125, .25, .50, .75])
var_group['labels']=['very low','low','medium','high']
var_group[['labels','emptot_1','hh_1']]
# Out:
#          labels    emptot_1        hh_1
# 0.125  very low    0.000000   83.067380
# 0.250       low   18.274732  170.372186
# 0.500    medium  139.851056  366.912211
# 0.750      high  583.735169  764.969046

# %%
income_4group = hh.loc[hh['source'] == 'model',['hhincome']].quantile([.25, .50, .75])
income_4group['labels']=['low','medium','high']
income_4group[['labels','hhincome']]
# Out:
#       labels  hhincome
# 0.25     low   56275.0
# 0.50  medium  105870.0
# 0.75    high  180100.0

# %%
# data manipulation
# hhwkrs is not always accurate; recalculate from part and full time workers
hh['hhwkrs'] = hh['hhftw']+hh['hhptw']
hh['hhwkrs']
# Add column for (potential) drivers adults (all hh members 16 and above)
hh['drivers'] = hh['hhsize']-hh['hh515']-hh['hhcu5']#-hh['hhhsc']

# add income group
hh['hhincome_group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + var_group['hhincome'].tolist() + [9999999.0], labels=var_group['labels'])
hh['hhincome_4group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + income_4group['hhincome'].tolist() + [9999999.0], labels=income_4group['labels'])
# add hh density groups
hh['hh_density_group'] = pd.cut(hh['hh_1'],bins=[-9999999.0] + var_group['hh_1'].tolist() + [9999999.0], labels=var_group['labels'])
# add employment density groups
hh['emp_density_group'] = pd.cut(hh['emptot_1'],bins=[-9999999.0] + var_group['emptot_1'].tolist() + [9999999.0], labels=var_group['labels'])

# add auto_ownership with 4+
hh['auto_ownership_simple'] = np.where(hh['hhvehs']>=4, "4+", hh['hhvehs'])
# add auto_ownership with 2+
hh['auto_ownership_2'] = np.where(hh['hhvehs']<2, hh['hhvehs'], "2+")
# add hhsize with 4+
hh['hhsize_simple'] = np.where(hh['hhsize']>=4, "4+", hh['hhsize'])
# add num_workers with 4+
hh['num_workers_simple'] = np.where(hh['hhwkrs']>=4, "4+", hh['hhwkrs'])
# add num_drivers with 4+
hh['num_drivers_simple'] = np.where(hh['drivers']>=4, "4+",hh['drivers'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 9>()
#       6 hh['drivers'] = hh['hhsize']-hh['hh515']-hh['hhcu5']#-hh['hhhsc']
#       8 # add income group
# ----> 9 hh['hhincome_group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + var_group['hhincome'].tolist() + [9999999.0], labels=var_group['labels'])
#      10 hh['hhincome_4group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + income_4group['hhincome'].tolist() + [9999999.0], labels=income_4group['labels'])
#      11 # add hh density groups
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\pandas\core\reshape\tile.py:273, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     270     if (np.diff(bins.astype("float64")) < 0).any():
#     271         raise ValueError("bins must increase monotonically.")
# --> 273 fac, bins = _bins_to_cuts(
#     274     x,
#     275     bins,
#     276     right=right,
#     277     labels=labels,
#     278     precision=precision,
#     279     include_lowest=include_lowest,
#     280     dtype=dtype,
#     281     duplicates=duplicates,
#     282     ordered=ordered,
#     283 )
#     285 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\pandas\core\reshape\tile.py:432, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     430 else:
#     431     if len(labels) != len(bins) - 1:
# --> 432         raise ValueError(
#     433             "Bin labels must be one fewer than the number of bin edges"
#     434         )
#     435 if not is_categorical_dtype(labels):
#     436     labels = Categorical(
#     437         labels,
#     438         categories=labels if len(set(labels)) == len(labels) else None,
#     439         ordered=ordered,
#     440     )
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
# Load ACS data
df_acs = pd.read_sql_table('observed_acs_vehicles_drivers', 'sqlite:///../../../../inputs/db/'+input_config['db_name'])
df_acs = df_acs.groupby('vehicles').sum()[['households']].reset_index()
df_acs.rename(columns={'households': 'hhexpfac'}, inplace=True)
df_acs['source'] = 'ACS'
df_acs.replace(4, '4+', inplace=True)
df_acs.rename(columns={'vehicles':'auto_ownership_simple'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\base.py:3208, in Engine._wrap_pool_connect(self, fn, connection)
#    3207 try:
# -> 3208     return fn()
#    3209 except dialect.dbapi.Error as e:
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:301, in Pool.connect(self)
#     294 """Return a DBAPI connection from the pool.
#     295
#     296 The connection is instrumented such that when its
#    (...)
#     299
#     300 """
# --> 301 return _ConnectionFairy._checkout(self)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:761, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     760 if not fairy:
# --> 761     fairy = _ConnectionRecord.checkout(pool)
#     763     fairy._pool = pool
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:419, in _ConnectionRecord.checkout(cls, pool)
#     417 @classmethod
#     418 def checkout(cls, pool):
# --> 419     rec = pool._do_get()
#     420     try:
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\impl.py:259, in NullPool._do_get(self)
#     258 def _do_get(self):
# --> 259     return self._create_connection()
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:247, in Pool._create_connection(self)
#     245 """Called by subclasses to create a new ConnectionRecord."""
# --> 247 return _ConnectionRecord(self)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:362, in _ConnectionRecord.__init__(self, pool, connect)
#     361 if connect:
# --> 362     self.__connect()
#     363 self.finalize_callback = deque()
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:605, in _ConnectionRecord.__connect(self)
#     604     with util.safe_reraise():
# --> 605         pool.logger.debug("Error on connect(): %s", e)
#     606 else:
#     607     # in SQLAlchemy 1.4 the first_connect event is not used by
#     608     # the engine, so this will usually not be set
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:599, in _ConnectionRecord.__connect(self)
#     598 self.starttime = time.time()
# --> 599 connection = pool._invoke_creator(self)
#     600 pool.logger.debug("Created new connection %r", connection)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\create.py:578, in create_engine.<locals>.connect(connection_record)
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\default.py:584, in DefaultDialect.connect(self, *cargs, **cparams)
#     582 def connect(self, *cargs, **cparams):
#     583     # inherits the docstring from interfaces.Dialect.connect
# --> 584     return self.dbapi.connect(*cargs, **cparams)
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 # Load ACS data
# ----> 2 df_acs = pd.read_sql_table('observed_acs_vehicles_drivers', 'sqlite:///../../../../inputs/db/'+input_config['db_name'])
#       3 df_acs = df_acs.groupby('vehicles').sum()[['households']].reset_index()
#       4 df_acs.rename(columns={'households': 'hhexpfac'}, inplace=True)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\pandas\io\sql.py:269, in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     267 meta = MetaData(con, schema=schema)
#     268 try:
# --> 269     meta.reflect(only=[table_name], views=True)
#     270 except sqlalchemy.exc.InvalidRequestError as err:
#     271     raise ValueError(f"Table {table_name} not found") from err
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\sql\schema.py:4656, in MetaData.reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4653 if bind is None:
#    4654     bind = _bind_or_error(self)
# -> 4656 with inspection.inspect(bind)._inspection_context() as insp:
#    4657     reflect_opts = {
#    4658         "autoload_with": insp,
#    4659         "extend_existing": extend_existing,
#    (...)
#    4662         "_extend_on": set(),
#    4663     }
#    4665     reflect_opts.update(dialect_kwargs)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\inspection.py:64, in inspect(subject, raiseerr)
#      62 if reg is True:
#      63     return subject
# ---> 64 ret = reg(subject)
#      65 if ret is not None:
#      66     break
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\reflection.py:182, in Inspector._engine_insp(bind)
#     180 @inspection._inspects(Engine)
#     181 def _engine_insp(bind):
# --> 182     return Inspector._construct(Inspector._init_engine, bind)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\reflection.py:117, in Inspector._construct(cls, init, bind)
#     114     cls = bind.dialect.inspector
#     116 self = cls.__new__(cls)
# --> 117 init(self, bind)
#     118 return self
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\reflection.py:128, in Inspector._init_engine(self, engine)
#     126 def _init_engine(self, engine):
#     127     self.bind = self.engine = engine
# --> 128     engine.connect().close()
#     129     self._op_context_requires_connect = True
#     130     self.dialect = self.engine.dialect
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\base.py:3162, in Engine.connect(self, close_with_result)
#    3147 def connect(self, close_with_result=False):
#    3148     """Return a new :class:`_engine.Connection` object.
#    3149
#    3150     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3159
#    3160     """
# -> 3162     return self._connection_cls(self, close_with_result=close_with_result)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\base.py:92, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      87     self._has_events = _branch_from._has_events
#      88 else:
#      89     self._dbapi_connection = (
#      90         connection
#      91         if connection is not None
# ---> 92         else engine.raw_connection()
#      93     )
#      95     self._transaction = self._nested_transaction = None
#      96     self.__savepoint_seq = 0
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\base.py:3241, in Engine.raw_connection(self, _connection)
#    3219 def raw_connection(self, _connection=None):
#    3220     """Return a "raw" DBAPI connection from the connection pool.
#    3221
#    3222     The returned object is a proxied version of the DBAPI
#    (...)
#    3239
#    3240     """
# -> 3241     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\base.py:3211, in Engine._wrap_pool_connect(self, fn, connection)
#    3209 except dialect.dbapi.Error as e:
#    3210     if connection is None:
# -> 3211         Connection._handle_dbapi_exception_noconnection(
#    3212             e, dialect, self
#    3213         )
#    3214     else:
#    3215         util.raise_(
#    3216             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3217         )
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\base.py:2061, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2059     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2060 elif should_wrap:
# -> 2061     util.raise_(
#    2062         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2063     )
#    2064 else:
#    2065     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\base.py:3208, in Engine._wrap_pool_connect(self, fn, connection)
#    3206 dialect = self.dialect
#    3207 try:
# -> 3208     return fn()
#    3209 except dialect.dbapi.Error as e:
#    3210     if connection is None:
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:301, in Pool.connect(self)
#     293 def connect(self):
#     294     """Return a DBAPI connection from the pool.
#     295
#     296     The connection is instrumented such that when its
#    (...)
#     299
#     300     """
# --> 301     return _ConnectionFairy._checkout(self)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:761, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     758 @classmethod
#     759 def _checkout(cls, pool, threadconns=None, fairy=None):
#     760     if not fairy:
# --> 761         fairy = _ConnectionRecord.checkout(pool)
#     763         fairy._pool = pool
#     764         fairy._counter = 0
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:419, in _ConnectionRecord.checkout(cls, pool)
#     417 @classmethod
#     418 def checkout(cls, pool):
# --> 419     rec = pool._do_get()
#     420     try:
#     421         dbapi_connection = rec.get_connection()
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\impl.py:259, in NullPool._do_get(self)
#     258 def _do_get(self):
# --> 259     return self._create_connection()
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:247, in Pool._create_connection(self)
#     244 def _create_connection(self):
#     245     """Called by subclasses to create a new ConnectionRecord."""
# --> 247     return _ConnectionRecord(self)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:362, in _ConnectionRecord.__init__(self, pool, connect)
#     360 self.__pool = pool
#     361 if connect:
# --> 362     self.__connect()
#     363 self.finalize_callback = deque()
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:605, in _ConnectionRecord.__connect(self)
#     603 except Exception as e:
#     604     with util.safe_reraise():
# --> 605         pool.logger.debug("Error on connect(): %s", e)
#     606 else:
#     607     # in SQLAlchemy 1.4 the first_connect event is not used by
#     608     # the engine, so this will usually not be set
#     609     if pool.dispatch.first_connect:
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\pool\base.py:599, in _ConnectionRecord.__connect(self)
#     597 try:
#     598     self.starttime = time.time()
# --> 599     connection = pool._invoke_creator(self)
#     600     pool.logger.debug("Created new connection %r", connection)
#     601     self.connection = connection
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\create.py:578, in create_engine.<locals>.connect(connection_record)
#     576         if connection is not None:
#     577             return connection
# --> 578 return dialect.connect(*cargs, **cparams)
#
# File C:\ProgramData\Anaconda3\envs\joanne\lib\site-packages\sqlalchemy\engine\default.py:584, in DefaultDialect.connect(self, *cargs, **cparams)
#     582 def connect(self, *cargs, **cparams):
#     583     # inherits the docstring from interfaces.Dialect.connect
# --> 584     return self.dbapi.connect(*cargs, **cparams)
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
# df_plot = pd.concat([df_plot,df_acs])
# df_plot = df_plot.reset_index(drop=True)
# df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
#         apply(lambda x: x / float(x.sum()))

# %%
df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
df_plot = pd.concat([df_plot,df_acs])
df_plot = df_plot.reset_index(drop=True)
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

df_plot_ct = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
    rename(columns={'hhexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','auto_ownership_simple'], how='left')
df_plot = df_plot[df_plot['auto_ownership_simple'] != '-1']

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             hover_data=['sample count'],
             barmode="group",title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
# ----> 2 df_plot = pd.concat([df_plot,df_acs])
#       3 df_plot = df_plot.reset_index(drop=True)
#       4 df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
#       5         apply(lambda x: x / float(x.sum()))
#
# NameError: name 'df_acs' is not defined

# %% [markdown]
# ## Auto ownership by segments

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str, sub_name:str):
    df2 = df.loc[df['auto_ownership_simple'] != '-1'].copy()
    df_plot = df2.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df2.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
        rename(columns={'hhexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',var,'auto_ownership_simple'])

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 hover_data=['sample count'],
                 title="Auto ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=800, font=dict(size=11),
                      yaxis=dict(tickformat=".2%"))
    fig.for_each_yaxis(lambda a: a.update(tickformat = ".2%"))
    fig.show()

# %% [raw]
# :::{.panel-tabset}
#
# ### income

# %%
plot_auto(hh,'hhincome_4group','income level', 'Income')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="38537176-791d-42ae-8ecf-a3cf9cb22076" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38537176-791d-42ae-8ecf-a3cf9cb22076")) {                    Plotly.newPlot(                        "38537176-791d-42ae-8ecf-a3cf9cb22076",                        [{"alignmentgroup":"True","customdata":[[87824],[204371],[100787],[29810],[12174]],"hovertemplate":"source=model<br>hhincome_4group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.20191003434751223,0.46985511511244554,0.2317123637249808,0.06853409231985948,0.027988394495201924],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[24551],[175704],[155703],[52184],[25016]],"hovertemplate":"source=model<br>hhincome_4group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.056679087076771065,0.40563489534996466,0.3594600584544208,0.12047336075981513,0.057752598359028344],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[17126],[116475],[184605],[75077],[40780]],"hovertemplate":"source=model<br>hhincome_4group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.03945510213955117,0.2683366239462935,0.4252954064271776,0.17296337167646172,0.09394949581051598],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[14183],[87639],[182859],[96781],[52480]],"hovertemplate":"source=model<br>hhincome_4group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.03268409142235598,0.20196016979227638,0.4213904162307405,0.223027501371151,0.12093782118347614],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[334],[531],[245],[64],[32]],"hovertemplate":"source=survey<br>hhincome_4group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2196525575713663,0.3633801215936281,0.23241046586083616,0.10814018826804965,0.07641666670611982],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[112],[435],[216],[49],[22]],"hovertemplate":"source=survey<br>hhincome_4group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.04508072169299935,0.43582883498601543,0.35112229122987515,0.12384977790454876,0.04411837418656125],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","cust ...

# %% [raw]
# ### household size

# %%
plot_auto(hh,'hhsize_simple','household size', 'HH size')
# Out:
# <div>                            <div id="8840840d-45b7-4693-b323-82604f9bb10e" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8840840d-45b7-4693-b323-82604f9bb10e")) {                    Plotly.newPlot(                        "8840840d-45b7-4693-b323-82604f9bb10e",                        [{"alignmentgroup":"True","customdata":[[95011],[321389],[51473],[10899],[3955]],"hovertemplate":"source=model<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.19682139180116298,0.6657779655996039,0.10662962709771776,0.022577978857615175,0.008193036643900175],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[29796],[153959],[299350],[77371],[22358]],"hovertemplate":"source=model<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.051122618103954125,0.26415583167763035,0.5136110796556138,0.13274963368643558,0.03836083687636617],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[8973],[51866],[117013],[68462],[26190]],"hovertemplate":"source=model<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.03292795702081437,0.19033115110236914,0.4293992014796113,0.2512330094237149,0.0961086809734903],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[9904],[56975],[156118],[97120],[77947]],"hovertemplate":"source=model<br>hhsize_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.02488042123879577,0.14313025041199406,0.39219321516138106,0.24398086739820732,0.19581524578962176],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[486],[910],[110],[23],[13]],"hovertemplate":"source=survey<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2687938511842041,0.6005710316628838,0.08504764216309818,0.026625608984241603,0.0189618660055722],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[76],[480],[573],[126],[52]],"hovertemplate":"source=survey<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.031471596736617126,0.18587184377513574,0.578619960259244,0.13548961436014545,0.06854698486885764],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[6],[109],[162],[55],[19]],"hover ...

# %% [raw]
# ### number of drivers

# %%
plot_auto(hh.loc[hh['num_drivers_simple']!="0"],'num_drivers_simple','number of (poential) drivers age 16+','num drivers')
# Out:
# <div>                            <div id="c779b918-ebef-4008-87b8-f7cdfaf3c9ef" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c779b918-ebef-4008-87b8-f7cdfaf3c9ef")) {                    Plotly.newPlot(                        "c779b918-ebef-4008-87b8-f7cdfaf3c9ef",                        [{"alignmentgroup":"True","customdata":[[100606],[350596],[57002],[11861],[4303]],"hovertemplate":"source=model<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.19186144082018736,0.6686067799713179,0.10870609953315229,0.022619610655112442,0.008206069020230067],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[33865],[200374],[471569],[118796],[30467]],"hovertemplate":"source=model<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.03960489830669032,0.23433609606687633,0.5514968932404444,0.13893115308553325,0.035630959300455754],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[5359],[22820],[66260],[81459],[31975]],"hovertemplate":"source=model<br>num_drivers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.025780163850043055,0.10977856672102677,0.3187523151154792,0.391869073905702,0.15381988040774897],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[3854],[10399],[29123],[41736],[63705]],"hovertemplate":"source=model<br>num_drivers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.02589757890563578,0.06987776934086831,0.1956967281963754,0.28045183010005575,0.4280760934570647],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[493],[952],[119],[24],[14]],"hovertemplate":"source=survey<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2653237232075296,0.6001355099542031,0.08914986290668014,0.026493453337588055,0.018897450593999374],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[77],[580],[823],[157],[56]],"hovertemplate":"source=survey<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.024992258639501472,0.1670497862275846,0.6004011815594862,0.15089011666702598,0.0566666569064018],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[2] ...

# %% [raw]
# ### number of workers

# %%
plot_auto(hh,'num_workers_simple','number of workers','num workers')
# Out:
# <div>                            <div id="1e59d61b-523d-4a56-9b44-3f54ae30106f" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e59d61b-523d-4a56-9b44-3f54ae30106f")) {                    Plotly.newPlot(                        "1e59d61b-523d-4a56-9b44-3f54ae30106f",                        [{"alignmentgroup":"True","customdata":[[70229],[166766],[100791],[37737],[11673]],"hovertemplate":"source=model<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.18137842333081952,0.4307017634479695,0.2603100238638829,0.09746226717218152,0.03014752218514654],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[58942],[307721],[224164],[76112],[30370]],"hovertemplate":"source=model<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.0845278061806172,0.44129790379874634,0.32147010866057946,0.10915103634113428,0.04355314501892275],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[13363],[101949],[276946],[107599],[47466]],"hovertemplate":"source=model<br>num_workers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.024415199068922738,0.18626843746745522,0.5060010268159753,0.19659140946022732,0.08672392718741949],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[748],[4606],[12664],[18793],[18890]],"hovertemplate":"source=model<br>num_workers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.013428843288271305,0.08269151361734978,0.22735677995009065,0.33739071111829233,0.33913215202599595],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[402],[3147],[9389],[13611],[22051]],"hovertemplate":"source=model<br>num_workers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[0.008271604938271605,0.06475308641975308,0.19318930041152263,0.2800617283950617,0.45372427983539093],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[219],[407],[227],[75],[27]],"hovertemplate":"source=survey<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.27830038846743504,0.42938734376181753,0.18059654088328006,0.07073643897887645,0.040979287908590796],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","custom ...

# %% [raw]
# ### household density

# %%
plot_auto(hh.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# <div>                            <div id="2fc4b426-6dbe-423f-a783-b18c9377d24a" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fc4b426-6dbe-423f-a783-b18c9377d24a")) {                    Plotly.newPlot(                        "2fc4b426-6dbe-423f-a783-b18c9377d24a",                        [{"alignmentgroup":"True","customdata":[[1717],[35067],[89002],[60387],[30858]],"hovertemplate":"source=model<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.007911312208854956,0.16157599605586298,0.4100888813118863,0.2782413572254655,0.14218245319793024],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4008],[47442],[93832],[47431],[24313]],"hovertemplate":"source=model<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.018467833347156563,0.21860053634126786,0.43235372720319226,0.2185498511699059,0.11202805193847742],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[15959],[123753],[180743],[74305],[39262]],"hovertemplate":"source=model<br>hh_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.036770025482579224,0.2851307076599804,0.4164374156148767,0.17120099902769906,0.09046085221486469],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[31539],[170789],[157131],[49198],[25378]],"hovertemplate":"source=model<br>hh_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.07266464686027624,0.3934913083046298,0.36202379992396927,0.11335030585091065,0.05846993906021404],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[90461],[207138],[103246],[22531],[10639]],"hovertemplate":"source=model<br>hh_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[0.20842828012856698,0.4772600025344746,0.23788578735757981,0.05191295231731622,0.024512977662062372],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[9],[86],[137],[66],[37]],"hovertemplate":"source=survey<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.035729854692504184,0.2012539774011063,0.3039145977272905,0.2525710222295298,0.2065305479495692],"yaxis":"y","type":"bar"},{"alignmentgrou ...

# %% [raw]
# ### employment density

# %%
plot_auto(hh.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# <div>                            <div id="cc9b2b9d-ff71-43de-b6c1-52f22a793147" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc9b2b9d-ff71-43de-b6c1-52f22a793147")) {                    Plotly.newPlot(                        "cc9b2b9d-ff71-43de-b6c1-52f22a793147",                        [{"alignmentgroup":"True","customdata":[[2592],[38698],[113142],[59487],[29446]],"hovertemplate":"source=model<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.010650668748587513,0.15901218334600292,0.46490662174100633,0.2444353132126641,0.12099521295173915],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2816],[38667],[82231],[43948],[23015]],"hovertemplate":"source=model<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.014768430382269493,0.2027879607923347,0.4312580961521316,0.23048401223010642,0.1207015004431578],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[15720],[128328],[176875],[73852],[39276]],"hovertemplate":"source=model<br>emp_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.03621694224872193,0.2956518934410933,0.40749819721645614,0.1701459045135249,0.09048706258020371],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[31588],[170652],[152955],[52141],[26668]],"hovertemplate":"source=model<br>emp_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.07278273932959144,0.39320374927420026,0.3524276273951392,0.12013944571939429,0.06144643828167482],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[90968],[207844],[98751],[24424],[12045]],"hovertemplate":"source=model<br>emp_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[0.20958823312566816,0.47886791757289787,0.2275200906845578,0.05627234858259299,0.027751410034283188],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[6],[86],[156],[53],[23]],"hovertemplate":"source=survey<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.02524045514314636,0.11166234484687279,0.46821486965896564,0.238977405765487,0.15590492458552824],"yaxis":"y","type":"bar"},{"alignmen ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data

# %%
# ACS auto ownership validation dataset
df_acs = pd.read_csv(config['p_acs_auto_ownership'])
# add lookup for maz and block groups
df_acs = df_acs.merge(pd.read_csv(config['p_maz_bg_lookup']), on='block_group_id')
df_acs_taz = df_acs[['TAZ','block_group_id','cars_none_control', 'cars_one_control','cars_two_or_more_control']].drop_duplicates()

hh_taz = hh.merge(df_acs_taz, how='left', left_on='hhtaz', right_on='TAZ')

# %%
df = hh_taz.groupby(['source','block_group_id','auto_ownership_2'])['hhexpfac'].sum().reset_index()

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hhexpfac'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_csv(config['p_acs_auto_ownership'], usecols=['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id'])

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2', height=400, width=1000,
                 title="Auto ownership model results validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=400, width=950, font=dict(size=11))
fig.show()
# Out:
# <div>                            <div id="591f0928-6401-4b29-a509-032db27b9bbd" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("591f0928-6401-4b29-a509-032db27b9bbd")) {                    Plotly.newPlot(                        "591f0928-6401-4b29-a509-032db27b9bbd",                        [{"hovertemplate":"auto_ownership_2=0\u003cbr\u003eacs data=%{x}\u003cbr\u003emodel=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":[18.081180811808117,18.181818181818183,18.170580964153277,18.206278026905828,18.093699515347335,6.292134831460674,6.172839506172839,6.292134831460674,6.216696269982238,6.301369863013699,6.25,6.118546845124283,6.109324758842444,25.75835475578406,25.869262865090402,25.720384204909283,18.317757009345794,18.313253012048193,18.076285240464344,18.226002430133658,1.937984496124031,1.9337016574585635,2.0361990950226243,8.81294964028777,8.814102564102564,8.734939759036145,8.827586206896552,8.709677419354838,8.848080133555927,12.251941328731665,12.162162162162161,12.171837708830548,12.280701754385966,1.6842105263157894,1.9031141868512111,2.3706896551724137,2.4630541871921183,5.277044854881266,4.926108374384237,6.509945750452079,6.410256410256411,21.26865671641791,21.296296296296298,21.220723917672107,21.221374045801525,21.25,13.583138173302109,13.612565445026178,13.607188703465981,7.751937984496124,7.581227436823105,7.6923076923076925,7.73286467486819,3.5714285714285716,3.6713286713286712,4.585537918871252,4.6263345195729535,4.704301075268817,18.418079096045197,18.403908794788272,18.315018315018314,13.836477987421384,13.84297520661157,13.855421686746988,13.612565445026178,5.327245053272451,5.180722891566265,5.2439024390243905,12.997658079625293,12.947189097103918,13.102119460500964,8.131067961165048,7.982261640798226,8.108108108108109,3.8461538461538463,3.7914691943127963,3.9244186046511627,4.355108877721943,4.370629370629371,4.120443740095087,4.08997955010225,2.763819095477387,2.7848101265822787,2.6970954356846475,6.6115702479338845,6.5349544072948325,6.11353711790393,6.214689265536723,6.175771971496437,6.265664160401003,2.2257551669316373,2.3465703971119134,2.1782178217821784,2.304147465437788,7.885304659498208,8.045977011494253,7.9245283018867925,7.861635220125786,5.007153075822604,5.007824726134586,5.040650406504065,2.8368794326241136,2.848575712143928,2.9535864978902953,2.8776978417266186,3.476482617586912,3.522504892367906,3.5587188612099645,3.5335689045936394,3.5398230088495577,11.041666666666666,11.006711409395972,11.052166224580018,10.943912448700411,11.075949367088608,11.02661596958175,10.944206008583691,7.6923076923076925,7.763401109057301,7.769423558897243,7.741935483870968,7.829181494661921,5.166051660516605,5.009633911368016,5.208333333333333,10.714285714285714,10.703363914373089,10.606060606060606,15.46644844517185,15.491803278688524,15.492957746478874,15.52,7.957957957957958,7.94044665012407,6.901217861975643,6.651376146788991,10.194174757281553,10.303030303030303,2.7656477438136826,2.735562310030395,2.766798418972332,2.610441767068273,2.816901408450704,2.7439024390243905,3.5190615835777126,3.5114503816793894,3.498542274052478,3.5058430717863107,3.4111310592459607,13.278008298755188,13.333333333333334,13.406593406593407,48.33997343957503,48.405466970387245,30.87649402390438,30.794341675734493,30.72289156626506,30.837359098228664,10.53864168618267,10.476190476190476,2.484472049689441,2.6101141924959217,2.5280898876404496,16.844919786096256,16.813048933500628,16.852589641434264,16.877637130801688,4.536082474226804,4.7913446676970635,4.741379310344827,4.690431519699812,12.948517940717629,12.934631432545201,12.914691943127963,12.837837837837839,12.88483466 ...
