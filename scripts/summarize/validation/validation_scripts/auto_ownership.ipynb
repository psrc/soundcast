# %% [raw]
# ---
# title: "Auto Ownership"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine,text
# import validation_data_input
import plotly.express as px
import toml
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio

pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

# %%
# %store -r validation_data

config = validation_data.config.copy()
input_config = validation_data.input_config.copy()
hh = validation_data.hh.copy()
df_parcel = validation_data.land_use.copy()

hh = hh.merge(df_parcel, left_on='hhparcel', right_on='parcelid', how='left')

# %% [markdown]
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# Group income, hh density, and employment density into 4 groups
var_group = hh.loc[hh['source'] == 'model',['hhincome','emptot_1','hh_1']].quantile([.125, .25, .50, .75])
var_group['labels']=['very low','low','medium','high']
var_group[['labels','emptot_1','hh_1']]
# Out:
#          labels     emptot_1         hh_1
# 0.125  very low     2.000000   128.659489
# 0.250       low    41.769303   237.838325
# 0.500    medium   314.334884   559.410036
# 0.750      high  1151.094055  1376.642062

# %%
income_4group = hh.loc[hh['source'] == 'model',['hhincome']].quantile([.25, .50, .75])
income_4group['labels']=['low','medium','high']
income_4group[['labels','hhincome']]
# Out:
#       labels  hhincome
# 0.25     low   55243.0
# 0.50  medium  107893.0
# 0.75    high  186756.0

# %%
# data manipulation
# hhwkrs is not always accurate; recalculate from part and full time workers
hh['hhwkrs'] = hh['hhftw']+hh['hhptw']
hh['hhwkrs']
# Add column for (potential) drivers adults (all hh members 16 and above)
hh['drivers'] = hh['hhsize']-hh['hh515']-hh['hhcu5']#-hh['hhhsc']

# add income group
hh['hhincome_group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + var_group['hhincome'].tolist(), labels=var_group['labels'])
hh['hhincome_4group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + income_4group['hhincome'].tolist(), labels=income_4group['labels'])
# add hh density groups
hh['hh_density_group'] = pd.cut(hh['hh_1'],bins=[-9999999.0] + var_group['hh_1'].tolist(), labels=var_group['labels'])
# add employment density groups
hh['emp_density_group'] = pd.cut(hh['emptot_1'],bins=[-9999999.0] + var_group['emptot_1'].tolist(), labels=var_group['labels'])

# add auto_ownership with 4+
hh['auto_ownership_simple'] = np.where(hh['hhvehs']>=4, "4+", hh['hhvehs'])
# add auto_ownership with 2+
hh['auto_ownership_2'] = np.where(hh['hhvehs']<2, hh['hhvehs'], "2+")
# add hhsize with 4+
hh['hhsize_simple'] = np.where(hh['hhsize']>=4, "4+", hh['hhsize'])
# add num_workers with 4+
hh['num_workers_simple'] = np.where(hh['hhwkrs']>=4, "4+", hh['hhwkrs'])
# add num_drivers with 4+
hh['num_drivers_simple'] = np.where(hh['drivers']>=4, "4+",hh['drivers'])

# %%
# Load ACS data
conn = create_engine('sqlite:///../../../../inputs/db/'+input_config['db_name'])
df_acs = pd.read_sql(text("SELECT * FROM observed_acs_vehicles_drivers"), con=conn.connect())
df_acs = df_acs.groupby('vehicles').sum()[['households']].reset_index()
df_acs.rename(columns={'households': 'hhexpfac'}, inplace=True)
df_acs['source'] = 'ACS'
df_acs.replace(4, '4+', inplace=True)
df_acs.rename(columns={'vehicles':'auto_ownership_simple'}, inplace=True)
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_18956\1033767512.py:4: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
# df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
# df_plot = pd.concat([df_plot,df_acs])
# df_plot = df_plot.reset_index(drop=True)
# df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
#         apply(lambda x: x / float(x.sum()))

# %%
df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
df_plot = pd.concat([df_plot,df_acs])
df_plot = df_plot.reset_index(drop=True)
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

df_plot_ct = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
    rename(columns={'hhexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','auto_ownership_simple'], how='left')
df_plot = df_plot[df_plot['auto_ownership_simple'] != '-1']

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             hover_data=['sample count'],
             barmode="group",title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0a1c528a-e2bf-4ed6-a2d4-ff2ecf65f52b" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a1c528a-e2bf-4ed6-a2d4-ff2ecf65f52b")) {                    Plotly.newPlot(                        "0a1c528a-e2bf-4ed6-a2d4-ff2ecf65f52b",                        [{"alignmentgroup":"True","customdata":[[null],[null],[null],[null],[null]],"hovertemplate":"source=ACS\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ACS","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"ACS","offsetgroup":"ACS","orientation":"v","showlegend":true,"textposition":"auto","x":["4+",2,1,0,3],"xaxis":"x","y":[0.07446127240013051,0.3619077947716689,0.3363774353518135,0.08278407778714399,0.1444694196892431],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[102770.0],[336749.0],[306181.0],[56737.0],[112268.0]],"hovertemplate":"source=model\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","4+","3"],"xaxis":"x","y":[0.11235316304163638,0.36815038728333177,0.33473196276395123,0.0620276482581816,0.12273683865289903],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1641.0],[1086.0],[283.0],[131.0],[623.0]],"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4+","0"],"xaxis":"x","y":[0.3216022438123581,0.3802748011645925,0.13305563611455756,0.08011217392085788,0.08447562602106247],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1034.0],[268.0],[1576.0],[572.0],[118.0]],"hovertemplate":"source=survey (2017\u002f2019)\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey (2017\u002f2019)","marker":{"color":"#F05A28","pattern":{"shape":""}},"name":"survey (2017\u002f2019)","offsetgroup":"survey (2017\u002f2019)","orientation":"v","showlegend":true,"textposition":"auto","x":["2","3","1","0","4+"],"xaxis":"x","y":[0.36644633844044494,0.15615264928526182,0.2951293847124539,0.09999010213004896,0.08190440443850651],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2960.0],[1662.0],[347.0],[141.0],[1077.0]],"hovertemplate":"source=survey (old weights)\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey (old weights)","marker":{"color":"#4C4C4C","pattern":{"shape":""}},"name":"survey (old weights)","offsetgroup":"survey (old weights)","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4+","0"],"xaxis":"x","y":[0.32547078412317665,0.3691143611215752,0.14911010548168657,0.08196642706642096,0.07236731694466522],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"f ...

# %% [markdown]
# ## Auto ownership by segments

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str, sub_name:str):
    df2 = df.loc[df['auto_ownership_simple'] != '-1'].copy()
    df_plot = df2.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df2.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
        rename(columns={'hhexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',var,'auto_ownership_simple'])

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 hover_data=['sample count'],
                 title="Auto ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=800, font=dict(size=11),
                      yaxis=dict(tickformat=".2%"))
    fig.for_each_yaxis(lambda a: a.update(tickformat = ".2%"))
    fig.show()

# %% [raw]
# :::{.panel-tabset}
#
# ### income

# %%
plot_auto(hh,'hhincome_4group','income level', 'Income')
# Out:
# <div>                            <div id="11b02754-fd74-472d-bbd0-a5d73890e097" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11b02754-fd74-472d-bbd0-a5d73890e097")) {                    Plotly.newPlot(                        "11b02754-fd74-472d-bbd0-a5d73890e097",                        [{"alignmentgroup":"True","customdata":[[57703],[105655],[46978],[12996],[5469]],"hovertemplate":"source=model\u003cbr\u003ehhincome_4group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2521973243123937,0.46177682789847946,0.20532252918475008,0.05680045104697969,0.02390286755739704],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[18351],[99611],[75777],[23549],[11345]],"hovertemplate":"source=model\u003cbr\u003ehhincome_4group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.08026400388395376,0.4356807634943337,0.3314350946713729,0.10299912960946145,0.049621008340878174],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[14692],[72883],[89156],[33851],[18126]],"hovertemplate":"source=model\u003cbr\u003ehhincome_4group=high\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.06423911712751632,0.31867271805096453,0.3898245798135614,0.1480096892106966,0.07925389579726114],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[369],[564],[263],[71],[36]],"hovertemplate":"source=survey\u003cbr\u003ehhincome_4group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.19358754174279638,0.3987833374118388,0.27589609554953237,0.07887906081298547,0.052853964482847],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[123],[453],[230],[52],[24]],"hovertemplate":"source=survey\u003cbr\u003ehhincome_4group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.04190416208419456,0.4102124774567785,0.36909853850577384,0.11396281993712248,0.06482200201613048],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[84],[403],[371],[98],[48]],"hovertemplate":"source=survey\u003cbr\u003ehhincome_4group=high\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgrou ...

# %% [raw]
# ### household size

# %%
plot_auto(hh,'hhsize_simple','household size', 'HH size')
# Out:
# <div>                            <div id="ebb9a661-60ed-4528-8fa3-ef658cf4391e" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebb9a661-60ed-4528-8fa3-ef658cf4391e")) {                    Plotly.newPlot(                        "ebb9a661-60ed-4528-8fa3-ef658cf4391e",                        [{"alignmentgroup":"True","customdata":[[70419],[189690],[25872],[4862],[1780]],"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2406475225802483,0.6482402271865164,0.08841410278754575,0.016615235302761575,0.006082912142927931],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[21730],[92204],[152758],[35113],[9936]],"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.06970530023320641,0.29577116901530437,0.49001575025421745,0.11263516829675917,0.03187261220051261],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[5406],[27255],[56909],[31402],[11758]],"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=3\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.04072930008287501,0.20534167106155354,0.4287576282679123,0.23658554961199427,0.08858585097566489],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[5215],[27600],[70642],[40891],[33263]],"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=4+\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.029361920151341977,0.15539578066673798,0.3977343745601342,0.23022785750882546,0.18728006711296036],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[490],[912],[110],[22],[13]],"hovertemplate":"source=survey\u003cbr\u003ehhsize_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2229499924759339,0.6515717896924654,0.08246062016816785,0.02919836513672624,0.013819232526706585],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[111],[515],[598],[128],[52]],"hovertemplate":"source=survey\u003cbr\u003ehhsize_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marke ...

# %% [raw]
# ### number of drivers

# %%
plot_auto(hh.loc[hh['num_drivers_simple']!="0"],'num_drivers_simple','number of (poential) drivers age 16+','num drivers')
# Out:
# <div>                            <div id="a8a39d58-5327-4319-b2e0-e016023232ff" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8a39d58-5327-4319-b2e0-e016023232ff")) {                    Plotly.newPlot(                        "a8a39d58-5327-4319-b2e0-e016023232ff",                        [{"alignmentgroup":"True","customdata":[[72976],[203595],[28330],[5306],[1930]],"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.23379477601181534,0.6522616671525644,0.09076142847531693,0.01699894597564531,0.006183182384658019],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[23914],[115899],[235591],[53429],[13454]],"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.05406896426980671,0.262044780877575,0.5326654412180326,0.120801651416388,0.030419162218197685],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[3519],[12029],[29838],[37325],[14380]],"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=3\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.0362443480858164,0.1238940787508626,0.3073199369663512,0.384433160643108,0.14810847555386183],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[2361],[5226],[12422],[16208],[26973]],"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=4+\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.037363506884000634,0.08270295932900776,0.1965817376167115,0.2564962810571293,0.42685551511315084],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[497],[954],[119],[23],[14]],"hovertemplate":"source=survey\u003cbr\u003enum_drivers_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.22005488280568178,0.644757445405664,0.08702484587564029,0.035135565050128124,0.013027260862885767],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[112],[616],[850],[159],[56]],"hovertemplate":"source=survey\u003cbr\u003enum_drivers_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legen ...

# %% [raw]
# ### number of workers

# %%
plot_auto(hh,'num_workers_simple','number of workers','num workers')
# Out:
# <div>                            <div id="97f95dec-cec3-4cbb-b8dd-9418b735692d" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97f95dec-cec3-4cbb-b8dd-9418b735692d")) {                    Plotly.newPlot(                        "97f95dec-cec3-4cbb-b8dd-9418b735692d",                        [{"alignmentgroup":"True","customdata":[[47197],[87615],[45999],[16311],[5141]],"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=0\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.23334470466669632,0.43317364026045296,0.2274217232019697,0.08064252977558921,0.025417402095291773],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[44658],[183651],[110127],[34005],[13220]],"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.11579599700254888,0.4761980080951924,0.28555389318598456,0.08817329208812921,0.034278809628144925],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[10139],[61350],[140183],[48315],[20759]],"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.03611449495273308,0.21852493000790751,0.49932323167560716,0.17209506101600736,0.07394228234774494],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[518],[2577],[6111],[8684],[8921]],"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=3\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.01932042818246242,0.09611726530155533,0.22792883517959048,0.32389690798552834,0.33273656335086343],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[258],[1556],[3761],[4953],[8696]],"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=4+\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[0.013420724094881398,0.0809404910528506,0.1956408655846858,0.25764669163545567,0.4523512276321265],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[226],[412],[235],[76],[27]],"hovertemplate":"source=survey\u003cbr\u003enum_workers_simple=0\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u00 ...

# %% [raw]
# ### household density

# %%
plot_auto(hh.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# <div>                            <div id="630874ec-6bed-44e3-b1bd-668333de207c" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("630874ec-6bed-44e3-b1bd-668333de207c")) {                    Plotly.newPlot(                        "630874ec-6bed-44e3-b1bd-668333de207c",                        [{"alignmentgroup":"True","customdata":[[1118],[20725],[47851],[29333],[15321]],"hovertemplate":"source=model\u003cbr\u003ehh_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.009777171441564347,0.18124497149053767,0.4184681848392626,0.2565239444502746,0.1339857277783608],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2527],[27847],[49426],[22703],[11835]],"hovertemplate":"source=model\u003cbr\u003ehh_density_group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.022101138729031466,0.24354982595462576,0.43227973202259967,0.1985604086130595,0.10350889468068358],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[10852],[76233],[91648],[33015],[16922]],"hovertemplate":"source=model\u003cbr\u003ehh_density_group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.047457034154021076,0.3333756067695806,0.4007871605370184,0.1443783618314602,0.07400183670791971],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[22024],[100005],[76951],[20206],[9503]],"hovertemplate":"source=model\u003cbr\u003ehh_density_group=high\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.09630546287753237,0.4372969403862888,0.3364875442194421,0.0883558019843543,0.0415542505323824],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[151],[466],[315],[105],[43]],"hovertemplate":"source=survey\u003cbr\u003ehh_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.08258592521995095,0.32617757395148245,0.3628873761121726,0.1681255525132733,0.06022357220312066],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[165],[321],[244],[53],[27]],"hovertemplate":"source=survey\u003cbr\u003ehh_density_group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\ ...

# %% [raw]
# ### employment density

# %%
plot_auto(hh.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# <div>                            <div id="a8fe91e6-2645-48bc-ba69-15666e384e75" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8fe91e6-2645-48bc-ba69-15666e384e75")) {                    Plotly.newPlot(                        "a8fe91e6-2645-48bc-ba69-15666e384e75",                        [{"alignmentgroup":"True","customdata":[[1334],[19498],[54081],[26509],[13146]],"hovertemplate":"source=model\u003cbr\u003eemp_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.011643739962293136,0.1701871377697088,0.4720428042734446,0.23138223587738285,0.11474408211717059],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2012],[26128],[49467],[23831],[12671]],"hovertemplate":"source=model\u003cbr\u003eemp_density_group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.017632263888036875,0.22897405112655445,0.43350655951765416,0.208844175306067,0.11104295016168751],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[11086],[77835],[89482],[33221],[17063]],"hovertemplate":"source=model\u003cbr\u003eemp_density_group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.048476738948868975,0.34035603248107676,0.3912859060637465,0.14526842365329032,0.07461289885301745],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[23157],[101175],[73094],[20874],[10364]],"hovertemplate":"source=model\u003cbr\u003eemp_density_group=high\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.10127086030157786,0.44246142812161077,0.3196567890004548,0.0912867788545639,0.04532414372179267],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[176],[446],[309],[73],[43]],"hovertemplate":"source=survey\u003cbr\u003eemp_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.09045052347602256,0.2810738091515251,0.40594118287949593,0.11785489292238024,0.1046795915705762],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[105],[249],[206],[68],[31]],"hovertemplate":"source=survey\u003cbr\u003eemp_density_group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data

# %%
# ACS auto ownership validation dataset
df_acs = pd.read_csv(config['p_acs_auto_ownership'])
# add lookup for maz and block groups
df_acs = df_acs.merge(pd.read_csv(config['p_maz_bg_lookup']), on='block_group_id')
df_acs_taz = df_acs[['TAZ','block_group_id','cars_none_control', 'cars_one_control','cars_two_or_more_control']].drop_duplicates()

hh_taz = hh.merge(df_acs_taz, how='left', left_on='hhtaz', right_on='TAZ')

# %%
df = hh_taz.groupby(['source','block_group_id','auto_ownership_2'])['hhexpfac'].sum().reset_index()

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hhexpfac'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read