# %% [raw]
# ---
# title: "Auto Ownership"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import toml
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))
# Out:
# C:\Workspace\travel-modeling\estimation

# %%
hh = validation_data_input.get_data('household',config['survey_dir'])

# %%
# parcel land use data
df_parcel = pd.read_csv(os.path.join(config['model_dir'],r'outputs\landuse\buffered_parcels.txt'),
                        delim_whitespace=True,
                        usecols=['parcelid','emptot_1','hh_1'])

# %%
hh = hh.merge(df_parcel, left_on='hhparcel', right_on='parcelid', how='left')

# %% [markdown]
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# Group income, hh density, and employment density into 4 groups
var_group = hh.loc[hh['source'] == 'model',['hhincome','emptot_1','hh_1']].quantile([.125, .25, .50, .75])

var_group
# Out:
#        hhincome    emptot_1        hh_1
# 0.125   30957.0    0.000000   83.119769
# 0.250   56275.0   18.312550  170.311965
# 0.500  105870.0  140.996951  367.217505
# 0.750  180012.0  582.620361  766.455845

# %%
# data manipulation
# hhwkrs is not always accurate; recalculate from part and full time workers
hh['hhwkrs'] = hh['hhftw']+hh['hhptw']
hh['hhwkrs']
# Add column for adults (4/23/24 adults = all members 16 and above)
hh['adults'] = hh['hhsize']-hh['hh515']-hh['hhcu5']#-hh['hhhsc']

# add income group
hh['hhincome_group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + var_group['hhincome'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add hh density groups
hh['hh_density_group'] = pd.cut(hh['hh_1'],bins=[-9999999.0] + var_group['hh_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add employment density groups
hh['emp_density_group'] = pd.cut(hh['emptot_1'],bins=[-9999999.0] + var_group['emptot_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])

# add auto_ownership with 4+
hh['auto_ownership_simple'] = np.where(hh['hhvehs']>=4, "4+", hh['hhvehs'])
# add auto_ownership with 2+
hh['auto_ownership_2'] = np.where(hh['hhvehs']<2, hh['hhvehs'], "2+")
# add hhsize with 4+
hh['hhsize_simple'] = np.where(hh['hhsize']>=4, "4+", hh['hhsize'])
# add num_workers with 4+
hh['num_workers_simple'] = np.where(hh['hhwkrs']>=4, "4+", hh['hhwkrs'])
# add num_adults with 4+
hh['num_adults_simple'] = np.where(hh['adults']>=4, "4+",hh['adults'])

# %%
df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))
df_plot['source'] = df_plot['source'].astype(pd.CategoricalDtype(['model', 'survey']))

df_plot_ct = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
    rename(columns={'hhexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','auto_ownership_simple'])

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             hover_data=['sample count'],
             barmode="group",title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="afd855ea-70a5-4fc7-bb31-6fd62d152cd5" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afd855ea-70a5-4fc7-bb31-6fd62d152cd5")) {                    Plotly.newPlot(                        "afd855ea-70a5-4fc7-bb31-6fd62d152cd5",                        [{"alignmentgroup":"True","customdata":[[162339],[487533],[605396],[321367],[159494]],"hovertemplate":"source=model<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.09350630051107954,0.2808161144707565,0.3487045029488016,0.18510548467308593,0.09186759739627642],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1],[572],[1575],[1034],[268],[118]],"hovertemplate":"source=survey<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.00047515471510152805,0.09344805062807443,0.26811175796904835,0.37597470069638117,0.1668663427726972,0.09512399321869736],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333 ...

# %% [markdown]
# ## Auto ownership by segments

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str, sub_name:str):
    df_plot = df.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = hh.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
        rename(columns={'hhexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',var,'auto_ownership_simple'])

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 hover_data=['sample count'],
                 title="Auto ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=800, font=dict(size=11),
                      yaxis=dict(tickformat=".2%"))
    fig.for_each_yaxis(lambda a: a.update(tickformat = ".2%"))
    fig.show()

# %% [raw]
# :::{.panel-tabset}
#
# ### income

# %%
plot_auto(hh,'hhincome_group','income level', 'Income')
# Out:
# <div>                            <div id="2a41adcf-9a8c-46c9-8423-239f69dd4f19" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a41adcf-9a8c-46c9-8423-239f69dd4f19")) {                    Plotly.newPlot(                        "2a41adcf-9a8c-46c9-8423-239f69dd4f19",                        [{"alignmentgroup":"True","customdata":[[0],[74029],[82260],[38837],[15381],[7158]],"hovertemplate":"source=model<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.3401052075437025,0.3779201984701261,0.1784255622171686,0.07066363448418442,0.032885397284818416],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[29128],[91749],[59604],[25114],[11653]],"hovertemplate":"source=model<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x2","y":[0.0,0.13407718367948152,0.4223237958462218,0.2743592576226248,0.11560060391810281,0.053639158933569006],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[27856],[148789],[152566],[69237],[34769]],"hovertemplate":"source=model<br>hhincome_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x3","y":[0.0,0.0643003390910329,0.3434514342696616,0.3521699286962423,0.1598205979913069,0.08025769995175627],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[18124],[95245],[176393],[94941],[49350]],"hovertemplate":"source=model<br>hhincome_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x4","y":[0.0,0.041755269517777784,0.2194317283834002,0.40638585610513,0.2187313530836096,0.11369579291008242],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[13202],[69490],[177996],[116694],[56564]],"hovertemplate":"source=model<br>hhincome_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x5","y":[0.0,0.030423140206385126,0.16013513202103488,0.4101800684877842,0.2689136436330788,0.13034801565171703],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[268],[385],[205],[55],[29]],"hovertemplate":"source=survey<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.22952149381052767,0.30287302776476593,0.24988462283200955,0.12898028386073201 ...

# %% [raw]
# ### household size

# %%
plot_auto(hh,'hhsize_simple','household size', 'HH size')
# Out:
# <div>                            <div id="90b74df9-4ec2-4165-a997-52648ee82a80" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90b74df9-4ec2-4165-a997-52648ee82a80")) {                    Plotly.newPlot(                        "90b74df9-4ec2-4165-a997-52648ee82a80",                        [{"alignmentgroup":"True","customdata":[[127143],[294749],[41183],[12603],[7119]],"hovertemplate":"source=model<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2633467067939527,0.6105029650142814,0.08530086143865849,0.026104139006663255,0.014745327746444157],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[23244],[102929],[288122],[116475],[52098]],"hovertemplate":"source=model<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.03987866892675528,0.176590583116589,0.4943177529046028,0.19983083648441843,0.08938215856763453],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[5939],[38271],[114282],[88626],[25251]],"hovertemplate":"source=model<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.021804977805844276,0.14051158538600209,0.4195851950846095,0.3253894532784568,0.09270878844508736],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[6013],[51584],[161809],[103663],[75026]],"hovertemplate":"source=model<br>hhsize_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.015104434871073488,0.1295771109910951,0.4064582574511109,0.26039764377849506,0.18846255290822542],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[486],[909],[110],[23],[13]],"hovertemplate":"source=survey<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2809443770492259,0.5907773186871075,0.07900302633634847,0.028957580120606917,0.020317697806711114],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[76],[480],[573],[126],[52]],"hovertemplate":"source=survey<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.02880613663988219,0.17138414934079013,0.5665145755841402,0.15364410649004043,0.07965103194514687],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[1],[6],[109],[162],[55],[19]], ...

# %% [raw]
# ### number of adults

# %%
plot_auto(hh.loc[hh['num_adults_simple']!="0"],'num_adults_simple','number of adults','num adults')
# Out:
# <div>                            <div id="f6e53fbf-34da-40ef-babe-12da76900ca1" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6e53fbf-34da-40ef-babe-12da76900ca1")) {                    Plotly.newPlot(                        "f6e53fbf-34da-40ef-babe-12da76900ca1",                        [{"alignmentgroup":"True","customdata":[[134352],[319454],[45210],[13611],[7641]],"hovertemplate":"source=model<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.25823613983562316,0.6140181598714509,0.08689752204632997,0.026161516756748444,0.01468666148984754],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[23628],[126962],[448158],[176567],[70574]],"hovertemplate":"source=model<br>num_adults_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.027932742948542894,0.15009297910245906,0.5298071023503084,0.20873542509714632,0.08343175050154335],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[2506],[21178],[73177],[101654],[24373]],"hovertemplate":"source=model<br>num_adults_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.011243315028175585,0.09501633107210797,0.32831287462761566,0.4560765945228097,0.10935088474929112],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[1853],[19939],[38851],[29535],[56906]],"hovertemplate":"source=model<br>num_adults_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.012598243180767453,0.13556199178700606,0.2641415789616818,0.20080362241984173,0.386894563650703],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[493],[951],[119],[24],[14]],"hovertemplate":"source=survey<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2766203484355516,0.5891283756510662,0.08513523761375777,0.028836767833937717,0.02027927046568643],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[77],[580],[823],[157],[56]],"hovertemplate":"source=survey<br>num_adults_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.022748581731060657,0.14937543729298106,0.6037139973233124,0.1590469965101242,0.06511498714252156],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[1],[2] ...

# %% [raw]
# ### number of workers

# %%
plot_auto(hh,'num_workers_simple','number of workers','num workers')
# Out:
# <div>                            <div id="59c01917-0521-41da-ab48-c63b900fa806" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59c01917-0521-41da-ab48-c63b900fa806")) {                    Plotly.newPlot(                        "59c01917-0521-41da-ab48-c63b900fa806",                        [{"alignmentgroup":"True","customdata":[[83265],[137586],[94132],[51424],[20048]],"hovertemplate":"source=model<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.21545846217541498,0.3560207527396463,0.24357816563377366,0.13306594558227997,0.05187667386888512],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[69948],[267515],[216424],[100054],[43698]],"hovertemplate":"source=model<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.10026389006348556,0.383457633532529,0.3102234823454537,0.1434180141878536,0.06263697987067811],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[8663],[71227],[268453],[139794],[63946]],"hovertemplate":"source=model<br>num_workers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.015691481172215048,0.12901502129208833,0.48625478415383194,0.25321192646757823,0.11582678691428644],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[345],[7210],[18473],[24108],[19585]],"hovertemplate":"source=model<br>num_workers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[0.00494829391431563,0.10341217136874113,0.2649560390700076,0.34577817300382957,0.2809053226431061],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[118],[3995],[7914],[5987],[12217]],"hovertemplate":"source=model<br>num_workers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[0.003903278092024743,0.1321491184545665,0.2617842611888459,0.19804174522840792,0.40412159703615497],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[219],[407],[227],[75],[27]],"hovertemplate":"source=survey<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2797446166879498,0.4229408345419412,0.18208277026613737,0.07024309077369802,0.044988687730273744],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[31 ...

# %% [raw]
# ### household density

# %%
plot_auto(hh.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# <div>                            <div id="e62a5b76-ccee-4b42-9cb9-a6a78a8733ec" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e62a5b76-ccee-4b42-9cb9-a6a78a8733ec")) {                    Plotly.newPlot(                        "e62a5b76-ccee-4b42-9cb9-a6a78a8733ec",                        [{"alignmentgroup":"True","customdata":[[0],[2223],[29004],[74691],[72543],[38570]],"hovertemplate":"source=model<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.010242776377568182,0.13363989476157784,0.3441489925402362,0.3342517889149476,0.17771654740567017],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[4954],[39498],[85355],[57864],[29334]],"hovertemplate":"source=model<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x2","y":[0.0,0.02282896707449137,0.18201423930324187,0.3933319508767079,0.26664823391166104,0.13517660883389784],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[18429],[102548],[172398],[93729],[46928]],"hovertemplate":"source=model<br>hh_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x3","y":[0.0,0.04246000294909131,0.23626829358204005,0.3972011280274266,0.2159495152431157,0.10812106019832639],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[36057],[143436],[158809],[64774],[30958]],"hovertemplate":"source=model<br>hh_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x4","y":[0.0,0.08307413704917126,0.33047180635618406,0.36589069059105966,0.1492371565361239,0.07132620946746107],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[100676],[173047],[114143],[32457],[13704]],"hovertemplate":"source=model<br>hh_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x5","y":[0.0,0.23195791966859206,0.3987010024721964,0.2629859432708103,0.07478106200766312,0.03157407258073806],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[1],[9],[86],[137],[67],[38]],"hovertemplate":"source=survey<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0028451796767302814,0.030952034602368225,0.1980501451697654,0.2964 ...

# %% [raw]
# ### employment density

# %%
plot_auto(hh.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# <div>                            <div id="9d21b449-3319-4318-b9b7-c4f6f44cffaa" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d21b449-3319-4318-b9b7-c4f6f44cffaa")) {                    Plotly.newPlot(                        "9d21b449-3319-4318-b9b7-c4f6f44cffaa",                        [{"alignmentgroup":"True","customdata":[[0],[3220],[32550],[99654],[71824],[36682]],"hovertemplate":"source=model<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.0,0.013200508342557291,0.13343992128889434,0.40853523551838644,0.29444512770056985,0.1503792071495921],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[3499],[32359],[73176],[53619],[27455]],"hovertemplate":"source=model<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x2","y":[0.0,0.018405327498053736,0.17021377322364128,0.38491804658404694,0.28204494287457654,0.14441790981968144],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[18373],[106601],[168302],[93416],[47339]],"hovertemplate":"source=model<br>emp_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x3","y":[0.0,0.042331077734078904,0.24560688061451832,0.38776492923316536,0.21522886614089776,0.10906824627733963],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[35704],[142430],[155767],[67533],[32600]],"hovertemplate":"source=model<br>emp_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x4","y":[0.0,0.08226083670864494,0.32815401558403257,0.3588820230673173,0.15559380140726303,0.07510932323274214],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[0],[101543],[173593],[108497],[34975],[15418]],"hovertemplate":"source=model<br>emp_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x5","y":[0.0,0.23395603028390005,0.3999599102357923,0.24997811191034638,0.08058273006686235,0.03552321750309889],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[1],[6],[86],[158],[55],[23]],"hovertemplate":"source=survey<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["-1","0","1","2","3","4+"],"xaxis":"x","y":[0.003546936552338671,0.018595793939984145,0.11033133169 ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data

# %%
# ACS auto ownership validation dataset
df_acs = pd.read_csv(config['p_acs_auto_ownership'])
# add lookup for maz and block groups
df_acs = df_acs.merge(pd.read_csv(config['p_maz_bg_lookup']), on='block_group_id')
df_acs_taz = df_acs[['TAZ','block_group_id','cars_none_control', 'cars_one_control','cars_two_or_more_control']].drop_duplicates()

hh_taz = hh.merge(df_acs_taz, how='left', left_on='hhtaz', right_on='TAZ')

# %%
df = hh_taz.groupby(['source','block_group_id','auto_ownership_2'])['hhexpfac'].sum().reset_index()

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hhexpfac'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_csv(config['p_acs_auto_ownership'], usecols=['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id'])

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2', height=400, width=1000,
                 title="Auto ownership model results validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=400, width=950, font=dict(size=11))
fig.show()
# Out:
# <div>                            <div id="1d9aebd6-0854-4658-85b0-290e83d6e711" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d9aebd6-0854-4658-85b0-290e83d6e711")) {                    Plotly.newPlot(                        "1d9aebd6-0854-4658-85b0-290e83d6e711",                        [{"hovertemplate":"auto_ownership_2=0<br>acs data=%{x}<br>model=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":[18.081180811808117,18.181818181818183,18.170580964153277,18.206278026905828,18.093699515347335,6.292134831460674,6.172839506172839,6.292134831460674,6.216696269982238,6.301369863013699,6.25,6.118546845124283,6.109324758842444,25.75835475578406,25.869262865090402,25.720384204909283,18.317757009345794,18.313253012048193,18.076285240464344,18.226002430133658,1.937984496124031,1.9337016574585635,2.0361990950226243,8.81294964028777,8.814102564102564,8.734939759036145,8.827586206896552,8.709677419354838,8.848080133555927,12.251941328731665,12.162162162162161,12.171837708830548,12.280701754385966,1.6842105263157894,1.9031141868512111,2.3706896551724137,2.4630541871921183,5.277044854881266,4.926108374384237,6.509945750452079,6.410256410256411,21.26865671641791,21.296296296296298,21.220723917672107,21.221374045801525,21.25,13.583138173302109,13.612565445026178,13.607188703465981,7.751937984496124,7.581227436823105,7.6923076923076925,7.73286467486819,3.5714285714285716,3.6713286713286712,4.585537918871252,4.6263345195729535,4.704301075268817,18.418079096045197,18.403908794788272,18.315018315018314,13.836477987421384,13.84297520661157,13.855421686746988,13.612565445026178,5.327245053272451,5.180722891566265,5.2439024390243905,12.997658079625293,12.947189097103918,13.102119460500964,8.131067961165048,7.982261640798226,8.108108108108109,3.8461538461538463,3.7914691943127963,3.9244186046511627,4.355108877721943,4.370629370629371,4.120443740095087,4.08997955010225,2.763819095477387,2.7848101265822787,2.6970954356846475,6.6115702479338845,6.5349544072948325,6.11353711790393,6.214689265536723,6.175771971496437,6.265664160401003,2.2257551669316373,2.3465703971119134,2.1782178217821784,2.304147465437788,7.885304659498208,8.045977011494253,7.9245283018867925,7.861635220125786,5.007153075822604,5.007824726134586,5.040650406504065,2.8368794326241136,2.848575712143928,2.9535864978902953,2.8776978417266186,3.476482617586912,3.522504892367906,3.5587188612099645,3.5335689045936394,3.5398230088495577,11.041666666666666,11.006711409395972,11.052166224580018,10.943912448700411,11.075949367088608,11.02661596958175,10.944206008583691,7.6923076923076925,7.763401109057301,7.769423558897243,7.741935483870968,7.829181494661921,5.166051660516605,5.009633911368016,5.208333333333333,10.714285714285714,10.703363914373089,10.606060606060606,15.46644844517185,15.491803278688524,15.492957746478874,15.52,7.957957957957958,7.94044665012407,6.901217861975643,6.651376146788991,10.194174757281553,10.303030303030303,2.7656477438136826,2.735562310030395,2.766798418972332,2.610441767068273,2.816901408450704,2.7439024390243905,3.5190615835777126,3.5114503816793894,3.498542274052478,3.5058430717863107,3.4111310592459607,13.278008298755188,13.333333333333334,13.406593406593407,48.33997343957503,48.405466970387245,30.87649402390438,30.794341675734493,30.72289156626506,30.837359098228664,10.53864168618267,10.476190476190476,2.484472049689441,2.6101141924959217,2.5280898876404496,16.844919786096256,16.813048933500628,16.852589641434264,16.877637130801688,4.536082474226804,4.7913446676970635,4.741379310344827,4.690431519699812,12.948517940717629,12.934631432545201,12.914691943127963,12.837837837837839,12.884834663625998,13.35149863760218,13.271028037383177, ...
