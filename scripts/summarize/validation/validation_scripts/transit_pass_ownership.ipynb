# %% [raw]
# ---
# title: "Transit Pass Ownership"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import toml
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

config = toml.load(os.path.join(os.getcwd(), '..\\..\\..\\..\\configuration', 'validation_configuration.toml'))

# %%
person = validation_data_input.get_data('person',config['survey_dir'])
hh = validation_data_input.get_data('household',config['survey_dir'])

# %%
# parcel land use data
df_parcel = pd.read_csv(os.path.join(config['model_dir'],r'outputs\landuse\buffered_parcels.txt'),
                        delim_whitespace=True,
                        usecols=['parcelid','emptot_1','hh_1'])

# %%
# Load parcel geography lookups
parcel_geog = pd.read_sql_table(
    'parcel_'+config['base_year']+'_geography',
    'sqlite:///'+config['model_dir']+'/inputs/db/soundcast_inputs.db',
    columns=['ParcelID','CountyName','rg_proposed']
    )

# %%
hh = hh.merge(df_parcel, left_on='hhparcel', right_on='parcelid', how='left')

# %%
# Group income, hh density, and employment density into 4 groups
var_group = hh.loc[hh['source'] == 'model',['hhincome','emptot_1','hh_1']].quantile([.125, .25, .50, .75])

# var_group

# %%
# Group ages
survey_ages = person.loc[person['source'] == 'survey', 'pagey'].unique()
survey_ages.sort()
survey_ages = np.insert(survey_ages, 0, 0)
survey_ages = np.append(survey_ages, 999)
# Create labels

person['age'] = pd.cut(person['pagey'], bins=survey_ages)

# %%
hh['hhincome_group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + var_group['hhincome'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add hh density groups
hh['hh_density_group'] = pd.cut(hh['hh_1'],bins=[-9999999.0] + var_group['hh_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add employment density groups
hh['emp_density_group'] = pd.cut(hh['emptot_1'],bins=[-9999999.0] + var_group['emptot_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])

# %%
person = person.merge(hh, on=['hhno'], how='left')

# %%
person = person.merge(parcel_geog, left_on='hhparcel', right_on='ParcelID', how='left')

# %%
person.drop('source_x', axis=1, inplace=True)
person.rename(columns={'source_y': 'source'}, inplace=True)

# %%
df = person.pivot_table(index='source', columns='ptpass', aggfunc='sum', values='psexpfac')
df_tot = person.groupby('source').sum()[['psexpfac']].reset_index()
df = df.merge(df_tot, on='source')
df['no pass'] = df[0]/df['psexpfac']
df['% owns transit pass'] = df[1]/df['psexpfac']
df[['source','% owns transit pass']]
# Out:
#    source  % owns transit pass
# 0   model             0.176595
# 1  survey             0.237584

# %%
# auto ownership in Income groups
def plot_transit_pass(df:pd.DataFrame, var:str, title_cat:str, sub_name:str):
    df_plot = df.groupby(['source',var,'ptpass'])['psexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['psexpfac'].\
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',var,'ptpass'])['psexpfac'].count().reset_index(). \
        rename(columns={'psexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',var,'ptpass'])

    # Only show the share with a pass (ptpass==1)
    df_plot = df_plot[df_plot['ptpass'] == 1]

    fig = px.bar(df_plot, x="ptpass", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 hover_data=['sample count'],
                 title="Transit Pass Ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="ptpass")
    fig.update_layout(height=400, width=800, font=dict(size=11),
                      yaxis=dict(tickformat=".2%"))
    fig.for_each_yaxis(lambda a: a.update(tickformat = ".2%"))
    fig.show()

# %% [markdown]
# ## Pass Ownership by Home Location

# %% [raw]
# ::: {.panel-tabset}
#
# ### County

# %%
plot_transit_pass(person, 'CountyName', 'Home County', 'County')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e6c9cc94-dd75-4f6f-8111-2d9dbe695485" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6c9cc94-dd75-4f6f-8111-2d9dbe695485")) {                    Plotly.newPlot(                        "e6c9cc94-dd75-4f6f-8111-2d9dbe695485",                        [{"alignmentgroup":"True","customdata":[[503098]],"hovertemplate":"source=model<br>CountyName=King<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.2183602128836076],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[29754]],"hovertemplate":"source=model<br>CountyName=Kitsap<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.10814799198903763],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[120409]],"hovertemplate":"source=model<br>CountyName=Pierce<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.13010929876978103],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[116009]],"hovertemplate":"source=model<br>CountyName=Snohomish<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x4","y":[0.13622715289724455],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[2238]],"hovertemplate":"source=survey<br>CountyName=King<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.32079715064125963],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[106]],"hovertemplate":"source=survey<br>CountyName=Kitsap<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.21962915463413568],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[116]],"hovertemplate":"source=survey<br>CountyName=Pierce<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.09441413237875462],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[192]],"hovertemplate":"source=survey<br>CountyName=Snohomish<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x4","y":[0.1696004161811417],"yaxis":"y4","type":"bar"}],                        {"template":{"data":{"barpola ...

# %% [raw]
# ### Regional Geography

# %%
plot_transit_pass(person, 'rg_proposed', 'Regional Geography', 'Geog')
# Out:
# <div>                            <div id="566111cc-4253-43ea-859e-50c4796c5e72" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("566111cc-4253-43ea-859e-50c4796c5e72")) {                    Plotly.newPlot(                        "566111cc-4253-43ea-859e-50c4796c5e72",                        [{"alignmentgroup":"True","customdata":[[42851]],"hovertemplate":"source=model<br>rg_proposed=CitiesTowns<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.11251411316791388],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[163033]],"hovertemplate":"source=model<br>rg_proposed=Core<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.16291032852262247],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[138542]],"hovertemplate":"source=model<br>rg_proposed=HCT<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.14465044358202536],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[351815]],"hovertemplate":"source=model<br>rg_proposed=Metro<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x4","y":[0.2747196113172158],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[51614]],"hovertemplate":"source=model<br>rg_proposed=Rural<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x5","y":[0.09459957295112764],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[21415]],"hovertemplate":"source=model<br>rg_proposed=UU<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x6","y":[0.11240112742293581],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[41]],"hovertemplate":"source=survey<br>rg_proposed=CitiesTowns<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.12332023808350748],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[208]],"hovertemplate":"source=survey<br>rg_proposed=Core<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.20425010195406165],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[274]],"hovertemp ...

# %% [raw]
# :::

# %% [markdown]
# ## Pass Ownership by Person/Household Characteristics

# %% [raw]
# ::: {.panel-tabset}
#
# ### Person Type

# %%
plot_transit_pass(person, 'pptyp', 'Person Type', 'student type')
# Out:
# <div>                            <div id="2b58631c-be72-4329-83ad-e0978c78de8b" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b58631c-be72-4329-83ad-e0978c78de8b")) {                    Plotly.newPlot(                        "2b58631c-be72-4329-83ad-e0978c78de8b",                        [{"alignmentgroup":"True","customdata":[[523907]],"hovertemplate":"source=model<br>pptyp=1<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.28965333840500945],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[43743]],"hovertemplate":"source=model<br>pptyp=2<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.1302014501553738],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[271]],"hovertemplate":"source=model<br>pptyp=3<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.0005177219470166034],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[17010]],"hovertemplate":"source=model<br>pptyp=4<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x4","y":[0.02879848846028822],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[80723]],"hovertemplate":"source=model<br>pptyp=5<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x5","y":[0.49082772416896203],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[101546]],"hovertemplate":"source=model<br>pptyp=6<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x6","y":[0.7766483873681634],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[2070]],"hovertemplate":"source=model<br>pptyp=7<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x7","y":[0.00371332419652275],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":[[1524]],"hovertemplate":"source=survey<br>pptyp=1<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.3131819027200478],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[280]],"hovertemplate":"source=survey<br>pptyp=2<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{custo ...

# %% [raw]
# ### Age

# %%
plot_transit_pass(person, 'age', 'Age', 'Age')
# Out:
# <div>                            <div id="8a55f3eb-7579-4ae3-a602-6b434c4d91f7" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a55f3eb-7579-4ae3-a602-6b434c4d91f7")) {                    Plotly.newPlot(                        "8a55f3eb-7579-4ae3-a602-6b434c4d91f7",                        [{"alignmentgroup":"True","customdata":[[0]],"hovertemplate":"source=model<br>age=(0, 2]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[747]],"hovertemplate":"source=model<br>age=(2, 8]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.002439717423893554],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[1129]],"hovertemplate":"source=model<br>age=(8, 14]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.0037417806766359106],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[71709]],"hovertemplate":"source=model<br>age=(14, 17]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x4","y":[0.4867302888792355],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[78346]],"hovertemplate":"source=model<br>age=(17, 21]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x5","y":[0.4177985398968649],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[179481]],"hovertemplate":"source=model<br>age=(21, 30]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x6","y":[0.29672264489698746],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":[[170892]],"hovertemplate":"source=model<br>age=(30, 40]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x7","y":[0.2425014722472524],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":[[118657]],"hovertemplate":"source=model<br>age=(40, 50]<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x8","y":[0.20698563658501698],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":[[97071]],"hovertemplate":"source=model<br>age=(50, 60]<br>ptpass=%{x}<br>percentage=%{y}< ...

# %% [raw]
# ### Household Density

# %%
plot_transit_pass(person, 'hh_density_group', 'Household Density', 'HH Density at Home')
# Out:
# <div>                            <div id="ff7e51d6-a024-44bc-8ef9-27c5f40ebbb8" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff7e51d6-a024-44bc-8ef9-27c5f40ebbb8")) {                    Plotly.newPlot(                        "ff7e51d6-a024-44bc-8ef9-27c5f40ebbb8",                        [{"alignmentgroup":"True","customdata":[[60702]],"hovertemplate":"source=model<br>hh_density_group=very low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.10107296994884911],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[74718]],"hovertemplate":"source=model<br>hh_density_group=low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.12191731200375944],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[166427]],"hovertemplate":"source=model<br>hh_density_group=medium<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.13848190541489572],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[189827]],"hovertemplate":"source=model<br>hh_density_group=medium-high<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x4","y":[0.17549713262941072],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[277596]],"hovertemplate":"source=model<br>hh_density_group=high<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x5","y":[0.32306703970430095],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[113]],"hovertemplate":"source=survey<br>hh_density_group=very low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.1030650262183194],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[184]],"hovertemplate":"source=survey<br>hh_density_group=low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.1512308313403071],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[339]],"hovertemplate":"source=survey<br>hh_density_group=medium<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.1928006571538723],"yaxis":"y3","type":"bar"},{"alignment ...

# %% [raw]
# ### Employment Density

# %%
plot_transit_pass(person, 'emp_density_group', 'Employment Density', 'Emp Density at Home')
# Out:
# <div>                            <div id="e80e7176-09c1-4e9c-94a5-85bf80eadb5a" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e80e7176-09c1-4e9c-94a5-85bf80eadb5a")) {                    Plotly.newPlot(                        "e80e7176-09c1-4e9c-94a5-85bf80eadb5a",                        [{"alignmentgroup":"True","customdata":[[81366]],"hovertemplate":"source=model<br>emp_density_group=very low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.11669291203070277],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[56663]],"hovertemplate":"source=model<br>emp_density_group=low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.1069938877360076],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[163394]],"hovertemplate":"source=model<br>emp_density_group=medium<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.13777919440902867],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":[[198404]],"hovertemplate":"source=model<br>emp_density_group=medium-high<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x4","y":[0.18235913178950078],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":[[269443]],"hovertemplate":"source=model<br>emp_density_group=high<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x5","y":[0.31499764432457583],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":[[166]],"hovertemplate":"source=survey<br>emp_density_group=very low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":[0.16328023888603418],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[110]],"hovertemplate":"source=survey<br>emp_density_group=low<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x2","y":[0.12157260645208563],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":[[370]],"hovertemplate":"source=survey<br>emp_density_group=medium<br>ptpass=%{x}<br>percentage=%{y}<br>sample count=%{customdata[0]}<extra></extra>","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":[1],"xaxis":"x3","y":[0.2114732672438223],"yaxis":"y3","type":"bar"},{" ...

# %% [raw]
# :::
