# %% [raw]
# ---
# title: "Person"
# date: today
# ---

# %%
import pandas as pd
import toml
from pathlib import Path

config = toml.load(Path.cwd() / '../../../../configuration/input_configuration.toml')
summary_config = toml.load(Path.cwd() / '../../../../configuration/summary_configuration.toml')

pd.set_option('display.float_format', '{:,.1f}'.format)

# %%
# Relative path between notebooks and goruped output directories
output_path = Path(summary_config['sc_run_path']) / summary_config["output_folder"]
survey_path = Path(summary_config['sc_run_path']) / summary_config["survey_folder"]

# %%
# trip data
trip = pd.read_csv(output_path / 'agg\dash\person_trips.csv')
# person data
person = pd.read_csv(output_path / 'agg\dash\person_geog.csv')
# vmt data
vmt = pd.read_csv(output_path / 'agg/dash/person_vmt.csv')

# list of equity geographies
equity_geogs = summary_config['hh_equity_geogs']
# not_equity_geogs = ["NOT in " + item for item in equity_geogs]

# %%
# TRIPS
df_trip = trip.copy()
# add home RGC
df_trip['is_rgc'] = 'Not in RGC'
df_trip.loc[df_trip['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'
# add trip type
df_trip.loc[df_trip['dpurp'] != 'Work', 'trip_type'] = 'Non-Work'
df_trip.loc[df_trip['dpurp'] == 'Work', 'trip_type'] = 'Work'

# PERSONS
df_person = person.copy()
# add home RGC
df_person['is_rgc'] = 'Not in RGC'
df_person.loc[df_person['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'

# VMT
df_vmt = vmt.copy()
# add home RGC
df_vmt['is_rgc'] = 'Not in RGC'
df_vmt.loc[df_vmt['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'

# Select only walk and bike trips
df_vmt_bp = df_vmt[df_vmt['mode'].isin(['Walk','Bike'])].copy()
# Select only drivers (dorp = 1) and auto trips
df_vmt = df_vmt[df_vmt['mode'].isin(['SOV','HOV2','HOV3+']) & (df_vmt['dorp'] == 1)].copy()

# # not in equity geography
# df_person[not_equity_geogs] = 1 - df_person[equity_geogs]
# df_trip[not_equity_geogs] = 1 - df_trip[equity_geogs]
# df_vmt[not_equity_geogs] = 1 - df_vmt[equity_geogs]
# df_vmt_bp[not_equity_geogs] = 1 - df_vmt_bp[equity_geogs]

# total population by equity geography
equity_geogs_population = df_person[equity_geogs].apply(lambda x: x * df_person['psexpfac']).sum().reset_index()
equity_geogs_population.columns = ['Equity Group', 'psexpfac']

# total population by "NOT in" equity geography
# not_equity_geogs_population = df_person[not_equity_geogs].apply(lambda x: x * df_person['psexpfac']).sum().reset_index()
# not_equity_geogs_population.columns = ['Equity Group', 'psexpfac']

# %% [markdown]
# ## Trips per Day by Resident

# %%
def trips_per_day(geog, map=False): 
    """
    Calculate trips per day by geography
    """

    # total population by geography
    df1 = df_person.groupby([geog], as_index=False)['psexpfac'].sum().set_index(geog)

    # total trips by geography
    df2 = df_trip.groupby([geog], as_index=False)['trexpfac'].sum().set_index(geog)

    # total trips by trip type and geography
    df3 = df_trip.groupby([geog, 'trip_type'], as_index=False)['trexpfac'].sum().set_index(geog)
    df3 = df3.pivot(columns='trip_type', values='trexpfac')

    # Merge the dataframes
    df = df1.merge(df2, left_index=True, right_index=True)
    df = df.merge(df3, left_index=True, right_index=True)

    if map:
        df.index = df.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population',
                                })

    # regional totals
    df.loc['Region', ['Work','Non-Work','psexpfac','trexpfac']] = df[['Work','Non-Work','psexpfac','trexpfac']].sum()

    df['Total Trips per Day'] = df['trexpfac']/df['psexpfac']
    df['Work Trips per Day'] = df['Work']/df['psexpfac']
    df['Non-Work Trips per Day'] = df['Non-Work']/df['psexpfac']


    
    return df[['Work Trips per Day', 'Non-Work Trips per Day','Total Trips per Day']]

# %% [raw]
# :::{.panel-tabset}
#
# ### County and Region

# %%
trips_per_day('hh_county')
# Out:
#                 Work Trips per Day  Non-Work Trips per Day  \
# hh_county
# King                           0.5                     3.3
# Kitsap                         0.4                     3.3
# Outside Region                 0.1                     2.6
# Pierce                         0.4                     3.1
# Snohomish                      0.5                     3.2
# Region                         0.5                     3.2
#
#                 Total Trips per Day
# hh_county
# King                            3.8
# Kitsap                          3.7
# Outside Region                  2.8
# Pierce                          3.6
# Snohomish                       3.7
# Region                          3.7

# %% [raw]
# ### Regional Growth Centers

# %%
trips_per_day('is_rgc')
# Out:
#             Work Trips per Day  Non-Work Trips per Day  Total Trips per Day
# is_rgc
# In RGC                     0.7                     3.3                  4.0
# Not in RGC                 0.5                     3.2                  3.7
# Region                     0.5                     3.2                  3.7

# %%
trips_per_day('hh_rgc')
# Out:
#                                  Work Trips per Day  Non-Work Trips per Day  \
# hh_rgc
# Auburn                                          0.4                     3.5
# Bellevue                                        0.7                     3.4
# Bothell Canyon Park                             0.6                     3.4
# Bremerton                                       0.5                     3.5
# Burien                                          0.6                     3.3
# Everett                                         0.5                     3.4
# Federal Way                                     0.4                     3.5
# Greater Downtown Kirkland                       0.6                     3.3
# Kent                                            0.5                     3.4
# Kirkland Totem Lake                             0.6                     3.3
# Lakewood                                        0.4                     3.2
# Lynnwood                                        0.6                     3.4
# Not in RGC                                      0.5                     3.2
# Puyallup Downtown                               0.4                     3.0
# Puyallup South Hill                             0.5                     3.1
# Redmond Downtown                                0.7                     3.3
# Redmond-Overlake                                0.6                     3.2
# Renton                                          0.6                     3.3
# SeaTac                                          0.5                     3.3
# Seattle Downtown                                0.9                     3.4
# Seattle First Hill/Capitol Hill                 0.8                     3.4
# Seattle Northgate                               0.6                     3.3
# Seattle South Lake Union                        0.9                     3.3
# Seattle University Community                    0.6                     3.0
# Seattle Uptown                                  0.8                     3.3
# Silverdale                                      0.5                     3.3
# Tacoma Downtown                                 0.5                     3.4
# Tacoma Mall                                     0.4                     3.1
# Tukwila                                         0.7                     3.1
# University Place                                0.5                     3.2
# Region                                          0.5                     3.2
#
#                                  Total Trips per Day
# hh_rgc
# Auburn                                           3.9
# Bellevue                                         4.0
# Bothell Canyon Park                              4.0
# Bremerton                                        4.0
# Burien                                           3.8
# Everett                                          3.9
# Federal Way                                      3.9
# Greater Downtown Kirkland                        3.9
# Kent                                             3.9
# Kirkland Totem Lake                              3.9
# Lakewood                                         3.6
# Lynnwood                                         3.9
# Not in RGC                                       3.7
# Puyallup Downtown                                3.4
# Puyallup South Hill                              3.6
# Redmond Downtown                                 3.9
# Redmond-Overlake                                 3.8
# Renton                                           3.9
# SeaTac                                           3.8
# Seattle Downtown                                 4.3
# Seattle First Hill/Capitol Hill                  4.2
# Seattle Northgate                                3.9
# Seattle South Lake Union                         4.2
# Seattle University Community                     3.6
# Seattle Uptown                                   4.1
# Silverdale                                       3.8
# Tacoma Downtown                                  3.9
# Tacoma Mall                                      3.5
# Tukwila                                          3.8
# University Place                                 3.7
# Region                                           3.7

# %% [raw]
# ### Regional Geographies

# %%
trips_per_day('hh_rg_proposed')
# Out:
#                       Work Trips per Day  Non-Work Trips per Day  \
# hh_rg_proposed
# Cities and Towns                     0.5                     3.2
# Core                                 0.5                     3.3
# HCT                                  0.5                     3.2
# Metro                                0.6                     3.3
# Rural                                0.4                     3.1
# Urban Unincorporated                 0.4                     3.2
# Region                               0.5                     3.2
#
#                       Total Trips per Day
# hh_rg_proposed
# Cities and Towns                      3.7
# Core                                  3.8
# HCT                                   3.7
# Metro                                 3.9
# Rural                                 3.5
# Urban Unincorporated                  3.6
# Region                                3.7

# %% [raw]
# :::

# %% [markdown]
# ### Equity Focus Areas

# %% [raw]
# :::{.panel-tabset}
#
# ### People of Color

# %%
trips_per_day('hh_efa_poc', map=True)
# Out:
#                                    Work Trips per Day  Non-Work Trips per Day  \
# hh_efa_poc
# Below Regional Average                            0.5                     3.2
# Above Regional Average                            0.5                     3.3
# Higher Share of Equity Population                 0.5                     3.3
# Region                                            0.5                     3.2
#
#                                    Total Trips per Day
# hh_efa_poc
# Below Regional Average                             3.7
# Above Regional Average                             3.8
# Higher Share of Equity Population                  3.8
# Region                                             3.7

# %% [raw]
# ### Income

# %%
trips_per_day('hh_efa_pov200', map=True)
# Out:
#                                    Work Trips per Day  Non-Work Trips per Day  \
# hh_efa_pov200
# Below Regional Average                            0.5                     3.3
# Above Regional Average                            0.5                     3.2
# Higher Share of Equity Population                 0.5                     3.2
# Region                                            0.5                     3.2
#
#                                    Total Trips per Day
# hh_efa_pov200
# Below Regional Average                             3.8
# Above Regional Average                             3.7
# Higher Share of Equity Population                  3.7
# Region                                             3.7

# %% [raw]
# ### English Proficiency

# %%
trips_per_day('hh_efa_lep', map=True)
# Out:
#                                    Work Trips per Day  Non-Work Trips per Day  \
# hh_efa_lep
# Below Regional Average                            0.5                     3.2
# Above Regional Average                            0.5                     3.3
# Higher Share of Equity Population                 0.5                     3.3
# Region                                            0.5                     3.2
#
#                                    Total Trips per Day
# hh_efa_lep
# Below Regional Average                             3.7
# Above Regional Average                             3.8
# Higher Share of Equity Population                  3.8
# Region                                             3.7

# %% [raw]
# ### Disability

# %%
trips_per_day('hh_efa_dis', map=True)
# Out:
#                                    Work Trips per Day  Non-Work Trips per Day  \
# hh_efa_dis
# Below Regional Average                            0.5                     3.3
# Above Regional Average                            0.5                     3.2
# Higher Share of Equity Population                 0.4                     3.2
# Region                                            0.5                     3.2
#
#                                    Total Trips per Day
# hh_efa_dis
# Below Regional Average                             3.8
# Above Regional Average                             3.7
# Higher Share of Equity Population                  3.7
# Region                                             3.7

# %% [raw]
# ### Older Adults

# %%
trips_per_day('hh_efa_older', map=True)
# Out:
#                                    Work Trips per Day  Non-Work Trips per Day  \
# hh_efa_older
# Below Regional Average                            0.5                     3.2
# Above Regional Average                            0.5                     3.3
# Higher Share of Equity Population                 0.4                     3.2
# Region                                            0.5                     3.2
#
#                                    Total Trips per Day
# hh_efa_older
# Below Regional Average                             3.8
# Above Regional Average                             3.7
# Higher Share of Equity Population                  3.7
# Region                                             3.7

# %% [raw]
# ### Youth

# %%
trips_per_day('hh_efa_youth', map=True)
# Out:
#                                    Work Trips per Day  Non-Work Trips per Day  \
# hh_efa_youth
# Below Regional Average                            0.5                     3.3
# Above Regional Average                            0.5                     3.2
# Higher Share of Equity Population                 0.4                     3.2
# Region                                            0.5                     3.2
#
#                                    Total Trips per Day
# hh_efa_youth
# Below Regional Average                             3.8
# Above Regional Average                             3.7
# Higher Share of Equity Population                  3.7
# Region                                             3.7

# %% [raw]
# :::

# %% [markdown]
# ## Miles Driven per Day by Resident

# %%
# pd.options.display.float_format = '{:0,.1f}'.format
df_vmt = pd.read_csv(output_path / 'agg/dash/person_vmt.csv')
df_person = person.copy()

df_vmt['is_rgc'] = 0
df_vmt.loc[df_vmt['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 1
df_person['is_rgc'] = 0
df_person.loc[df_person['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 1

# Select only drivers (dorp = 1) and auto trips
df_vmt = df_vmt[df_vmt['mode'].isin(['SOV','HOV2','HOV3+']) & (df_vmt['dorp'] == 1)]

def vmt_per_person(df_vmt, df_person, geog):
    _df_vmt = df_vmt.groupby(geog).sum()[['travdist_wt']]
    _df_person = df_person.groupby(geog).sum()[['psexpfac']]

    df = _df_vmt.merge(_df_person, left_index=True, right_index=True)
    df.loc['Region',:] = df.sum(axis=0)
    df['Average Miles per Person'] = df['travdist_wt']/df['psexpfac']
    
    return df[['Average Miles per Person']]

# %%
def miles_per_day(geog, map=False): 
    """
    Calculate trips per day by geography
    """

    # total population by geography
    df1 = df_person.groupby([geog], as_index=False)['psexpfac'].sum().set_index(geog)

    # total miles by geography
    df2 = df_vmt.groupby([geog], as_index=False)['travdist_wt'].sum().set_index(geog)

    # Merge the dataframes
    df = df1.merge(df2, left_index=True, right_index=True)

    if map:
        df.index = df.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population',
                                })

    # regional totals
    df.loc['Region', ['psexpfac','travdist_wt']] = df[['psexpfac','travdist_wt']].sum()

    df['Average Miles per Person'] = df['travdist_wt']/df['psexpfac']
    
    return df[['Average Miles per Person']]

# %% [raw]
# :::{.panel-tabset}
#
# ### County

# %%
miles_per_day('hh_county')
# Out:
#                 Average Miles per Person
# hh_county
# King                                13.4
# Kitsap                              13.8
# Outside Region                      25.8
# Pierce                              15.1
# Snohomish                           16.4
# Region                              14.4

# %% [raw]
# ### Regional Growth Centers

# %%
miles_per_day('is_rgc')
# Out:
#         Average Miles per Person
# is_rgc
# 0                           14.9
# 1                            6.2
# Region                      14.4

# %%
miles_per_day('hh_rgc')
# Out:
#                                  Average Miles per Person
# hh_rgc
# Auburn                                               11.4
# Bellevue                                              6.9
# Bothell Canyon Park                                  15.1
# Bremerton                                             7.1
# Burien                                               12.6
# Everett                                               8.8
# Federal Way                                          10.9
# Greater Downtown Kirkland                            11.8
# Kent                                                 10.0
# Kirkland Totem Lake                                  12.5
# Lakewood                                              9.7
# Lynnwood                                             11.8
# Not in RGC                                           14.9
# Puyallup Downtown                                     9.0
# Puyallup South Hill                                  12.6
# Redmond Downtown                                     10.3
# Redmond-Overlake                                      8.3
# Renton                                               11.8
# SeaTac                                               10.8
# Seattle Downtown                                      1.8
# Seattle First Hill/Capitol Hill                       3.0
# Seattle Northgate                                     9.3
# Seattle South Lake Union                              3.1
# Seattle University Community                          5.0
# Seattle Uptown                                        4.9
# Silverdale                                            7.4
# Tacoma Downtown                                       7.4
# Tacoma Mall                                           7.7
# Tukwila                                              11.1
# University Place                                     10.9
# Region                                               14.4

# %% [raw]
# ### Regional Geography

# %%
miles_per_day('hh_rg_proposed')
# Out:
#                       Average Miles per Person
# hh_rg_proposed
# Cities and Towns                          17.6
# Core                                      13.9
# HCT                                       14.7
# Metro                                      9.9
# Rural                                     22.1
# Urban Unincorporated                      16.0
# Region                                    14.4

# %% [raw]
# ### Equity Focus Areas

# %%
df = pd.DataFrame()
for name, col in {
    "People of Color": "hh_efa_poc",
    "Income": "hh_efa_pov200",
    "LEP": "hh_efa_lep",
    "Disability": "hh_efa_dis",
    "Older Adults": "hh_efa_older",
    "Youth": "hh_efa_youth"
}.items():
    df[name] = miles_per_day(col, map=True)
df
# Out:
#                                    People of Color  Income  LEP  Disability  \
# hh_efa_poc
# Below Regional Average                        15.5    15.3 14.8        14.5
# Above Regional Average                        13.2    13.7 14.1        14.5
# Higher Share of Equity Population             12.7    11.7 13.1        13.3
# Region                                        14.4    14.4 14.4        14.4
#
#                                    Older Adults  Youth
# hh_efa_poc
# Below Regional Average                     13.6   12.9
# Above Regional Average                     15.0   15.7
# Higher Share of Equity Population          15.5   16.2
# Region                                     14.4   14.4

# %% [raw]
# :::

# %% [markdown]
# # Delay

# %% [raw]
# :::{.panel-tabset}
#
# ### County

# %%
pd.options.display.float_format = '{:0,.1f}'.format

def delay_per_person(geog):

    df_person = pd.read_csv(output_path / 'agg/dash/person_geog.csv')
    df_person['is_rgc'] = 'Not in RGC'
    df_person.loc[df_person['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'

    df = pd.read_csv(output_path / 'agg/dash/trip_time_total.csv')
    df['is_rgc'] = 'Not in RGC'
    df.loc[df['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'
    df = df[(df['mode'].isin(['SOV','HOV2','HOV3+'])&(df['dorp']==1))]
    df = df.groupby(geog).sum()[['travtime_wt']]

    df2 = pd.read_csv(output_path / 'agg/dash/trip_sov_ff_time.csv')
    df2['is_rgc'] = 'Not in RGC'
    df2.loc[df2['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'
    df2 = df2[(df2['mode'].isin(['SOV','HOV2','HOV3+'])&(df2['dorp']==1))]
    df2 = df2.groupby(geog).sum()[['sov_ff_time_wt']]
    df = df2.merge(df, on=geog)

    # Hours of delay from travel time (in min)
    df['Total Delay Hours'] = (df['travtime_wt'] - df['sov_ff_time_wt'])/60
    # Set any negative delay to 0
    df.loc[df['Total Delay Hours'] < 0, 'Total Delay Hours'] = 0

    df_person = df_person.groupby(geog).sum()[['psexpfac']]

    df = df.merge(df_person, left_index=True, right_index=True)
    df.loc['Region',:] = df.sum(axis=0)
    df['Average Minutes of Delay per Person'] = df['Total Delay Hours']/df['psexpfac']*60

    df['Annual Hours of Delay per Person'] = df['Average Minutes of Delay per Person']*summary_config['weekday_to_annual']/60

    df[['Total Delay Hours',
        'Annual Hours of Delay per Person']] = df[['Total Delay Hours', 'Annual Hours of Delay per Person']].astype(int).map('{:,}'.format)


    return df[['Total Delay Hours','Average Minutes of Delay per Person','Annual Hours of Delay per Person']]

delay_per_person('hh_county')
# Out:
#                Total Delay Hours  Average Minutes of Delay per Person  \
# hh_county
# King                     101,538                                  2.6
# Kitsap                     4,985                                  1.1
# Outside Region                 0                                  1.2
# Pierce                    35,124                                  2.3
# Snohomish                 45,348                                  3.2
# Region                   186,997                                  2.6
#
#                Annual Hours of Delay per Person
# hh_county
# King                                         14
# Kitsap                                        5
# Outside Region                                6
# Pierce                                       12
# Snohomish                                    17
# Region                                       13

# %% [raw]
# ### Regional Growth Center

# %%
delay_per_person('is_rgc')
# Out:
#            Total Delay Hours  Average Minutes of Delay per Person  \
# is_rgc
# In RGC                 5,022                                  1.1
# Not in RGC           181,974                                  2.7
# Region               186,997                                  2.6
#
#            Annual Hours of Delay per Person
# is_rgc
# In RGC                                    5
# Not in RGC                               14
# Region                                   13

# %%
df = delay_per_person('hh_rgc')

df
# Out:
#                                 Total Delay Hours  \
# hh_rgc
# Auburn                                         61
# Bellevue                                      425
# Bothell Canyon Park                            57
# Bremerton                                      62
# Burien                                        134
# Everett                                       132
# Federal Way                                    10
# Greater Downtown Kirkland                     440
# Kent                                           68
# Kirkland Totem Lake                           503
# Lakewood                                        9
# Lynnwood                                      239
# Not in RGC                                181,974
# Puyallup Downtown                              21
# Puyallup South Hill                            88
# Redmond Downtown                              306
# Redmond-Overlake                              148
# Renton                                        256
# SeaTac                                        363
# Seattle Downtown                                0
# Seattle First Hill/Capitol Hill               273
# Seattle Northgate                             314
# Seattle South Lake Union                       76
# Seattle University Community                  498
# Seattle Uptown                                114
# Silverdale                                      0
# Tacoma Downtown                               190
# Tacoma Mall                                   113
# Tukwila                                        21
# University Place                              193
# Region                                    187,103
#
#                                  Average Minutes of Delay per Person  \
# hh_rgc
# Auburn                                                           1.7
# Bellevue                                                         1.5
# Bothell Canyon Park                                              5.2
# Bremerton                                                        1.2
# Burien                                                           2.1
# Everett                                                          1.2
# Federal Way                                                      1.1
# Greater Downtown Kirkland                                        3.2
# Kent                                                             1.9
# Kirkland Totem Lake                                              3.7
# Lakewood                                                         1.0
# Lynnwood                                                         2.9
# Not in RGC                                                       2.7
# Puyallup Downtown                                                1.1
# Puyallup South Hill                                              2.0
# Redmond Downtown                                                 1.9
# Redmond-Overlake                                                 1.8
# Renton                                                           2.8
# SeaTac                                                           1.9
# Seattle Downtown                                                 0.0
# Seattle First Hill/Capitol Hill                                  0.3
# Seattle Northgate                                                2.2
# Seattle South Lake Union                                         0.3
# Seattle University Community                                     1.3
# Seattle Uptown                                                   0.6
# Silverdale                                                       0.0
# Tacoma Downtown                                                  0.7
# Tacoma Mall                                                      1.1
# Tukwila                                                          2.0
# University Place                                                 1.7
# Region                                                           2.6
#
#                                 Annual Hours of Delay per Person
# hh_rgc
# Auburn                                                         8
# Bellevue                                                       8
# Bothell Canyon Park                                           27
# Bremerton                                                      6
# Burien                                                        10
# Everett                                                        6
# Federal Way                                                    5
# Greater Downtown Kirkland                                     17
# Kent                                                          10
# Kirkland Totem Lake                                           19
# Lakewood                                                       5
# Lynnwood                                                      15
# Not in RGC                                                    14
# Puyallup Downtown                                              6
# Puyallup South Hill                                           10
# Redmond Downtown                                              10
# Redmond-Overlake                                               9
# Renton                                                        14
# SeaTac                                                        10
# Seattle Downtown                                               0
# Seattle First Hill/Capitol Hill                                1
# Seattle Northgate                                             11
# Seattle South Lake Union                                       1
# Seattle University Community                                   7
# Seattle Uptown                                                 3
# Silverdale                                                     0
# Tacoma Downtown                                                3
# Tacoma Mall                                                    5
# Tukwila                                                       10
# University Place                                               8
# Region                                                        13

# %% [raw]
# ### Regional Geography

# %%
delay_per_person('hh_rg_proposed')
# Out:
#                      Total Delay Hours  Average Minutes of Delay per Person  \
# hh_rg_proposed
# Cities and Towns                18,080                                  2.8
# Core                            47,073                                  2.8
# HCT                             49,724                                  3.1
# Metro                           39,866                                  1.9
# Rural                           23,690                                  2.6
# Urban Unincorporated             8,561                                  2.9
# Region                         186,997                                  2.6
#
#                      Annual Hours of Delay per Person
# hh_rg_proposed
# Cities and Towns                                   14
# Core                                               15
# HCT                                                16
# Metro                                               9
# Rural                                              13
# Urban Unincorporated                               15
# Region                                             13

# %% [raw]
# :::

# %% [markdown]
# ## Miles Walking and Biking per Day by Resident

# %%
df_vmt_bp2 = df_vmt_bp.copy()
df_vmt_bp2['mode'] = 'Walk and Bike'
# add walk and bike
df_vmt_bp2 = pd.concat([df_vmt_bp, df_vmt_bp2])

def walk_bike_per_person(geog, map=False):
    
    # miles by mode and geography
    df1 = df_vmt_bp2.groupby([geog, 'mode'], as_index=False)['travdist_wt'].sum().set_index(geog)

    if map:
        df1.index = df1.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population',
                                })

    # add total miles in region
    df1_region = df_vmt_bp2.groupby(['mode'])['travdist_wt'].sum().reset_index()
    df1_region[geog] = 'Region'
    df1_region = df1_region.set_index(geog)
    df1 = pd.concat([df1, df1_region])

    # population by geography
    df3 = df_person.groupby(geog, as_index=False)['psexpfac'].sum().set_index(geog)
    if map:
        df3.index = df3.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population',
                                })
    df3.loc['Region',:] = df3.sum(axis=0)

    # calculate average miles per person
    df = df1.merge(df3, on=geog)
    df['Average Miles per Person'] = df['travdist_wt']/df['psexpfac']

    return df.pivot(columns='mode', values='Average Miles per Person')

# %%
walk_bike_per_person("hh_efa_poc", map=True)
# Out:
# mode                               Bike  Walk  Walk and Bike
# hh_efa_poc
# Above Regional Average              0.2   0.6            0.8
# Below Regional Average              0.2   0.5            0.7
# Higher Share of Equity Population   0.2   0.6            0.8
# Region                              0.2   0.5            0.7

# %% [raw]
# :::{.panel-tabset}
#
# ### County and Region

# %%
walk_bike_per_person('hh_county')
# Out:
# mode       Bike  Walk  Walk and Bike
# hh_county
# King        0.2   0.6            0.8
# Kitsap      0.1   0.5            0.7
# Pierce      0.2   0.5            0.6
# Region      0.2   0.5            0.7
# Snohomish   0.2   0.5            0.6

# %% [raw]
# ### Regional Growth Center

# %%
walk_bike_per_person('is_rgc')
# Out:
# mode    Bike  Walk  Walk and Bike
# is_rgc
# Region   0.2   0.5            0.7

# %%
walk_bike_per_person('hh_rgc')
# Out:
# mode                             Bike  Walk  Walk and Bike
# hh_rgc
# Auburn                            0.4   0.6            1.0
# Bellevue                          0.3   0.9            1.2
# Bothell Canyon Park               0.3   0.5            0.8
# Bremerton                         0.2   1.0            1.2
# Burien                            0.3   0.6            0.9
# Everett                           0.2   0.7            0.9
# Federal Way                       0.3   0.7            1.0
# Greater Downtown Kirkland         0.3   0.6            0.9
# Kent                              0.3   0.6            1.0
# Kirkland Totem Lake               0.3   0.6            0.8
# Lakewood                          0.3   0.7            0.9
# Lynnwood                          0.2   0.7            0.9
# Not in RGC                        0.2   0.5            0.7
# Puyallup Downtown                 0.1   0.6            0.7
# Puyallup South Hill               0.2   0.6            0.8
# Redmond Downtown                  0.3   0.7            1.0
# Redmond-Overlake                  0.2   0.7            1.0
# Region                            0.2   0.5            0.7
# Renton                            0.4   0.7            1.0
# SeaTac                            0.3   0.6            0.9
# Seattle Downtown                  0.2   1.4            1.6
# Seattle First Hill/Capitol Hill   0.3   1.5            1.7
# Seattle Northgate                 0.3   0.8            1.1
# Seattle South Lake Union          0.2   1.3            1.5
# Seattle University Community      0.4   1.0            1.4
# Seattle Uptown                    0.3   1.3            1.5
# Silverdale                        0.1   0.7            0.8
# Tacoma Downtown                   0.2   1.0            1.2
# Tacoma Mall                       0.3   0.8            1.1
# Tukwila                           0.2   0.6            0.8
# University Place                  0.2   0.6            0.8

# %% [raw]
# ### Regional Geography

# %%
walk_bike_per_person('hh_rg_proposed')
# Out:
# mode                  Bike  Walk  Walk and Bike
# hh_rg_proposed
# Cities and Towns       0.1   0.4            0.6
# Core                   0.2   0.5            0.7
# HCT                    0.2   0.5            0.7
# Metro                  0.2   0.7            1.0
# Region                 0.2   0.5            0.7
# Rural                  0.2   0.3            0.5
# Urban Unincorporated   0.2   0.4            0.6

# %% [raw]
# ### EFA: People of Color

# %%
walk_bike_per_person('hh_efa_poc', map=True)
# Out:
# mode                               Bike  Walk  Walk and Bike
# hh_efa_poc
# Above Regional Average              0.2   0.6            0.8
# Below Regional Average              0.2   0.5            0.7
# Higher Share of Equity Population   0.2   0.6            0.8
# Region                              0.2   0.5            0.7

# %% [raw]
# ### EFA: Income

# %%
walk_bike_per_person('hh_efa_pov200', map=True)
# Out:
# mode                               Bike  Walk  Walk and Bike
# hh_efa_pov200
# Above Regional Average              0.2   0.6            0.7
# Below Regional Average              0.2   0.5            0.7
# Higher Share of Equity Population   0.2   0.6            0.8
# Region                              0.2   0.5            0.7

# %% [raw]
# ### EFA: English Proficiency

# %%
walk_bike_per_person('hh_efa_lep', map=True)
# Out:
# mode                               Bike  Walk  Walk and Bike
# hh_efa_lep
# Above Regional Average              0.2   0.5            0.7
# Below Regional Average              0.2   0.5            0.7
# Higher Share of Equity Population   0.2   0.5            0.7
# Region                              0.2   0.5            0.7

# %% [raw]
# ### EFA: Disability

# %%
walk_bike_per_person('hh_efa_dis', map=True)
# Out:
# mode                               Bike  Walk  Walk and Bike
# hh_efa_dis
# Above Regional Average              0.2   0.5            0.7
# Below Regional Average              0.2   0.5            0.7
# Higher Share of Equity Population   0.2   0.6            0.8
# Region                              0.2   0.5            0.7

# %% [raw]
# ### EFA: Older Adults

# %%
walk_bike_per_person('hh_efa_older', map=True)
# Out:
# mode                               Bike  Walk  Walk and Bike
# hh_efa_older
# Above Regional Average              0.2   0.5            0.7
# Below Regional Average              0.2   0.6            0.8
# Higher Share of Equity Population   0.2   0.5            0.7
# Region                              0.2   0.5            0.7

# %% [raw]
# ### EFA: Youth

# %%
walk_bike_per_person('hh_efa_youth', map=True)
# Out:
# mode                               Bike  Walk  Walk and Bike
# hh_efa_youth
# Above Regional Average              0.2   0.5            0.6
# Below Regional Average              0.2   0.6            0.8
# Higher Share of Equity Population   0.2   0.4            0.6
# Region                              0.2   0.5            0.7

# %% [raw]
# :::
