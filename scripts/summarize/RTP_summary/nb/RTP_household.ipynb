# %% [raw]
# ---
# title: "Household"
# date: today
# ---

# %%
import pandas as pd
from pathlib import Path
import util

pd.set_option('display.float_format', '{:,.0%}'.format)

# %%
# list of equity geographies
equity_geogs = util.summary_config['hh_equity_geogs']
# not_equity_geogs = ["NOT in " + item for item in equity_geogs]

# %% [markdown]
# ## Household VMT

# %%
# vmt data
df_vmt = pd.read_csv(util.output_path / 'agg/dash/person_vmt.csv')

# add home RGC
df_vmt['is_rgc'] = 'Not in RGC'
df_vmt.loc[df_vmt['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'

# Select only drivers (dorp = 1) and auto trips
df_vmt = df_vmt[df_vmt['mode'].isin(['SOV','HOV2','HOV3+']) & (df_vmt['dorp'] == 1)].copy()

df_hh = pd.read_csv(util.output_path / 'agg/dash/hh_geog.csv')
df_hh['is_rgc'] = 'Not in RGC'
df_hh.loc[df_hh['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'

def vmt_per_hh(df_vmt, df_hh, geog, map=False):
    _df_vmt = df_vmt.groupby(geog).sum()[['travdist_wt']]
    df_hh = df_hh.groupby(geog).sum()[['hhexpfac']]

    df = _df_vmt.merge(df_hh, left_index=True, right_index=True)

    if map:
        df.index = df.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population',
                                })
    
    
    df.loc['Region',:] = df.sum(axis=0)
    df['Average Miles per Household'] = df['travdist_wt']/df['hhexpfac']

    
    return df[['Average Miles per Household']]

# %% [raw]
# :::{.panel-tabset}
#
# ### County

# %%
pd.set_option('display.float_format', '{:,.1f}'.format)
vmt_per_hh(df_vmt, df_hh, "hh_county")
# Out:
#                 Average Miles per Household
# hh_county
# King                                   26.6
# Kitsap                                 31.0
# Outside Region                         79.0
# Pierce                                 34.3
# Snohomish                              36.0
# Region                                 30.3

# %% [raw]
# ### Regional Growth Center

# %%
vmt_per_hh(df_vmt, df_hh, "is_rgc")
# Out:
#             Average Miles per Household
# is_rgc
# In RGC                              9.3
# Not in RGC                         35.1
# Region                             30.3

# %%
vmt_per_hh(df_vmt, df_hh, "hh_rgc")
# Out:
#                                  Average Miles per Household
# hh_rgc
# Auburn                                                  18.1
# Bellevue                                                 5.2
# Bothell Canyon Park                                     30.4
# Bremerton                                                7.6
# Burien                                                  19.7
# Everett                                                  7.6
# Federal Way                                             19.3
# Greater Downtown Kirkland                               19.2
# Issaquah                                                19.5
# Kent                                                    12.4
# Kirkland Totem Lake                                     19.2
# Lakewood                                                16.8
# Lynnwood                                                15.5
# Not in RGC                                              35.1
# Puyallup Downtown                                       18.3
# Puyallup South Hill                                     24.1
# Redmond Downtown                                        13.7
# Redmond-Overlake                                        12.1
# Renton                                                  17.9
# SeaTac                                                  22.9
# Seattle Downtown                                         1.9
# Seattle First Hill/Capitol Hill                          3.4
# Seattle Northgate                                       14.4
# Seattle South Lake Union                                 3.1
# Seattle University Community                             7.8
# Seattle Uptown                                           5.3
# Silverdale                                              11.0
# Tacoma Downtown                                          6.3
# Tacoma Mall                                             14.5
# Tukwila                                                 20.9
# University Place                                        20.6
# Region                                                  30.3

# %% [raw]
# ### Regional Geography

# %%
pd.set_option('display.float_format', '{:,.1f}'.format)
vmt_per_hh(df_vmt, df_hh, "hh_rg_proposed")
# Out:
#                                    Average Miles per Household
# hh_rg_proposed
# Cities and Towns                                          46.7
# Core Cities                                               29.6
# High Capacity Transit Communities                         34.1
# Metropolitan Cities                                       16.2
# Rural Areas                                               58.6
# Urban Unincorporated Areas                                44.4
# Region                                                    30.3

# %% [raw]
# ### Equity Focus Area

# %%
efa_names = {
    "People of Color": "hh_efa_poc",
    "Income": "hh_efa_pov200",
    "LEP": "hh_efa_lep",
    "Disability": "hh_efa_dis",
    "Older Adults": "hh_efa_older",
    "Youth": "hh_efa_youth"
}

df = pd.DataFrame()
for name, col in efa_names.items():
    df[name] = vmt_per_hh(df_vmt, df_hh, col, map=True)
df
# Out:
#                                    People of Color  Income  LEP  Disability  \
# hh_efa_poc
# Below Regional Average                        34.7    33.9 31.8        32.1
# Above Regional Average                        25.9    28.7 28.9        31.2
# Higher Share of Equity Population             25.7    21.6 27.1        24.1
# Region                                        30.3    30.3 30.3        30.3
#
#                                    Older Adults  Youth
# hh_efa_poc
# Below Regional Average                     28.3   24.0
# Above Regional Average                     33.2   37.6
# Higher Share of Equity Population          32.0   43.4
# Region                                     30.3   30.3

# %% [raw]
# :::

# %% [markdown]
# ## Delay

# %% [raw]
# :::{.panel-tabset}
# ### County

# %%
df = pd.read_csv(util.output_path / 'agg/dash/trip_time_total.csv')
df = df[(df['mode'].isin(['SOV','HOV2','HOV3+'])&(df['dorp']==1))]

# %%
pd.options.display.float_format = '{:0,.1f}'.format
# Hours of delay for households in these locations
# df[['Total Delay Hours']]

def delay_per_hh(geog, map=False):

    df_hh = pd.read_csv(util.output_path / 'agg/dash/hh_geog.csv')
    df_hh['is_rgc'] = 'Not in RGC'
    df_hh.loc[df_hh['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'

    df = pd.read_csv(util.output_path / 'agg/dash/trip_time_total.csv')
    df['is_rgc'] = 'Not in RGC'
    df.loc[df['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'
    df = df[(df['mode'].isin(['SOV','HOV2','HOV3+'])&(df['dorp']==1))]
    df = df.groupby(geog).sum()[['travtime_wt']]

    df2 = pd.read_csv(util.output_path / 'agg/dash/trip_sov_ff_time.csv')
    df2['is_rgc'] = 'Not in RGC'
    df2.loc[df2['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'
    df2 = df2[(df2['mode'].isin(['SOV','HOV2','HOV3+'])&(df2['dorp']==1))]
    df2 = df2.groupby(geog).sum()[['sov_ff_time_wt']]
    df = df2.merge(df, on=geog)

    # Hours of delay from travel time
    df['Total Delay Hours'] = (df['travtime_wt'] - df['sov_ff_time_wt'])/60
    # Set any negative delay to 0
    df.loc[df['Total Delay Hours'] < 0, 'Total Delay Hours'] = 0

    df_hh = df_hh.groupby(geog).sum()[['hhexpfac']]
    
    
    # df.loc['Region',:] = df.sum(axis=0)
    # df['Average Miles per Household'] = df['travdist_wt']/df['hhexpfac']


    df = df.merge(df_hh, left_index=True, right_index=True)
    
    df['Average Minutes of Delay per HH'] = df['Total Delay Hours']/df['hhexpfac']*60

    if map:
        df.index = df.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population',
                                })

    df['Annual Hours of Delay per HH'] = df['Average Minutes of Delay per HH']*util.summary_config['weekday_to_annual']/60

    df[['Total Delay Hours',
        'Annual Hours of Delay per HH']] = df[['Total Delay Hours', 'Annual Hours of Delay per HH']].astype(int).map('{:,}'.format)


    return df[['Total Delay Hours','Average Minutes of Delay per HH','Annual Hours of Delay per HH']]

df = delay_per_hh('hh_county')
df
# Out:
#                Total Delay Hours  Average Minutes of Delay per HH  \
# hh_county
# King                     123,825                              5.8
# Kitsap                     8,025                              3.2
# Outside Region                 0                              7.2
# Pierce                    62,382                              7.5
# Snohomish                 69,039                              8.6
#
#                Annual Hours of Delay per HH
# hh_county
# King                                     30
# Kitsap                                   17
# Outside Region                           38
# Pierce                                   39
# Snohomish                                45

# %% [raw]
# ### Regional Growth Center

# %%
delay_per_hh('is_rgc')
# Out:
#            Total Delay Hours  Average Minutes of Delay per HH  \
# is_rgc
# In RGC                13,838                              1.9
# Not in RGC           249,434                              7.6
#
#            Annual Hours of Delay per HH
# is_rgc
# In RGC                                9
# Not in RGC                           40

# %%
delay_per_hh('hh_rgc')
# Out:
#                                 Total Delay Hours  \
# hh_rgc
# Auburn                                        285
# Bellevue                                      607
# Bothell Canyon Park                           894
# Bremerton                                      63
# Burien                                        655
# Everett                                       469
# Federal Way                                   382
# Greater Downtown Kirkland                     607
# Issaquah                                      178
# Kent                                          178
# Kirkland Totem Lake                           844
# Lakewood                                      299
# Lynnwood                                      926
# Not in RGC                                249,434
# Puyallup Downtown                             246
# Puyallup South Hill                           460
# Redmond Downtown                              567
# Redmond-Overlake                              345
# Renton                                      1,103
# SeaTac                                        748
# Seattle Downtown                                0
# Seattle First Hill/Capitol Hill               143
# Seattle Northgate                             669
# Seattle South Lake Union                        0
# Seattle University Community                  668
# Seattle Uptown                                  0
# Silverdale                                     28
# Tacoma Downtown                               903
# Tacoma Mall                                   656
# Tukwila                                       441
# University Place                              589
#
#                                  Average Minutes of Delay per HH  \
# hh_rgc
# Auburn                                                       3.4
# Bellevue                                                     1.1
# Bothell Canyon Park                                         10.1
# Bremerton                                                    0.7
# Burien                                                       4.5
# Everett                                                      1.3
# Federal Way                                                  3.7
# Greater Downtown Kirkland                                    5.9
# Issaquah                                                     4.1
# Kent                                                         2.8
# Kirkland Totem Lake                                          6.5
# Lakewood                                                     2.8
# Lynnwood                                                     4.2
# Not in RGC                                                   7.6
# Puyallup Downtown                                            4.4
# Puyallup South Hill                                          5.7
# Redmond Downtown                                             2.8
# Redmond-Overlake                                             2.1
# Renton                                                       4.6
# SeaTac                                                       4.7
# Seattle Downtown                                             0.0
# Seattle First Hill/Capitol Hill                              0.1
# Seattle Northgate                                            3.9
# Seattle South Lake Union                                     0.0
# Seattle University Community                                 1.8
# Seattle Uptown                                               0.0
# Silverdale                                                   0.6
# Tacoma Downtown                                              1.1
# Tacoma Mall                                                  3.0
# Tukwila                                                      4.6
# University Place                                             4.7
#
#                                 Annual Hours of Delay per HH
# hh_rgc
# Auburn                                                    18
# Bellevue                                                   5
# Bothell Canyon Park                                       53
# Bremerton                                                  3
# Burien                                                    23
# Everett                                                    6
# Federal Way                                               19
# Greater Downtown Kirkland                                 31
# Issaquah                                                  21
# Kent                                                      14
# Kirkland Totem Lake                                       34
# Lakewood                                                  15
# Lynnwood                                                  22
# Not in RGC                                                40
# Puyallup Downtown                                         23
# Puyallup South Hill                                       30
# Redmond Downtown                                          15
# Redmond-Overlake                                          11
# Renton                                                    24
# SeaTac                                                    25
# Seattle Downtown                                           0
# Seattle First Hill/Capitol Hill                            0
# Seattle Northgate                                         20
# Seattle South Lake Union                                   0
# Seattle University Community                               9
# Seattle Uptown                                             0
# Silverdale                                                 3
# Tacoma Downtown                                            6
# Tacoma Mall                                               16
# Tukwila                                                   24
# University Place                                          24

# %% [raw]
# ### Regional Geography

# %%
delay_per_hh('hh_rg_proposed')
# Out:
#                                   Total Delay Hours  \
# hh_rg_proposed
# Cities and Towns                             28,364
# Core Cities                                  68,309
# High Capacity Transit Communities            73,224
# Metropolitan Cities                          43,865
# Rural Areas                                  33,965
# Urban Unincorporated Areas                   15,543
#
#                                    Average Minutes of Delay per HH  \
# hh_rg_proposed
# Cities and Towns                                               9.7
# Core Cities                                                    7.3
# High Capacity Transit Communities                              8.5
# Metropolitan Cities                                            3.1
# Rural Areas                                                    8.9
# Urban Unincorporated Areas                                    11.2
#
#                                   Annual Hours of Delay per HH
# hh_rg_proposed
# Cities and Towns                                            51
# Core Cities                                                 38
# High Capacity Transit Communities                           45
# Metropolitan Cities                                         16
# Rural Areas                                                 47
# Urban Unincorporated Areas                                  59

# %% [raw]
# ### Equity Focus Areas

# %%
df = pd.DataFrame()
for name, col in efa_names.items():
    _df = delay_per_hh(col, map=True)
    _df['Group'] = name
    df = pd.concat([df, _df])

df = df.reset_index()
df.rename(columns={'index':'EFA Type'}, inplace=True)

df[['Group', 'EFA Type', 'Total Delay Hours', 'Average Minutes of Delay per HH', 'Annual Hours of Delay per HH']]
# Out:
#               Group                           EFA Type Total Delay Hours  \
# 0   People of Color             Below Regional Average           142,169
# 1   People of Color             Above Regional Average            78,543
# 2   People of Color  Higher Share of Equity Population            42,548
# 3            Income             Below Regional Average           165,079
# 4            Income             Above Regional Average            64,981
# 5            Income  Higher Share of Equity Population            33,200
# 6               LEP             Below Regional Average           151,410
# 7               LEP             Above Regional Average            66,212
# 8               LEP  Higher Share of Equity Population            45,639
# 9        Disability             Below Regional Average           149,247
# 10       Disability             Above Regional Average            79,383
# 11       Disability  Higher Share of Equity Population            34,630
# 12     Older Adults             Below Regional Average           145,790
# 13     Older Adults             Above Regional Average            85,683
# 14     Older Adults  Higher Share of Equity Population            31,787
# 15            Youth             Below Regional Average           118,633
# 16            Youth             Above Regional Average            98,786
# 17            Youth  Higher Share of Equity Population            45,841
#
#     Average Minutes of Delay per HH Annual Hours of Delay per HH
# 0                               6.9                           36
# 1                               6.2                           33
# 2                               5.9                           31
# 3                               7.3                           39
# 4                               6.1                           32
# 5                               4.6                           24
# 6                               6.2                           33
# 7                               7.3                           38
# 8                               6.6                           34
# 9                               7.3                           38
# 10                              6.5                           34
# 11                              4.5                           24
# 12                              6.7                           35
# 13                              6.7                           35
# 14                              5.7                           30
# 15                              5.1                           27
# 16                              8.0                           42
# 17                             10.0                           53

# %% [raw]
# :::

# %% [markdown]
# ## Vehicle Ownership Distribution
#
# percentage of households by number of vehicles available, by geography

# %%
pd.set_option('display.float_format', '{:,.0%}'.format)

hh = pd.read_csv(util.output_path / 'agg/dash/auto_ownership_efa.csv')
df_hh = hh.copy()
df_hh = df_hh[df_hh['hh_county']!="Outside Region"].copy()
# add home RGC
df_hh['is_rgc'] = 'Not in RGC'
df_hh.loc[df_hh['hh_rgc'] != 'Not in RGC', 'is_rgc'] = 'In RGC'

equity_geogs = ['hh_efa_dis', 'hh_efa_older', 'hh_efa_lep', 'hh_efa_pov200', 'hh_efa_poc', 'hh_efa_youth']
df_hh[equity_geogs] = df_hh[equity_geogs].apply(lambda x: x.\
        map({0: 'Below Regional Average', 
             1: 'Above Regional Average', 
             2: 'Higher Share of Equity Population'}))

df_hh['hhvehs'] = df_hh['hhvehs'].map({0:"0 vehicle",
                                       1:"1 vehicle",
                                       2:"2 vehicles",
                                       3:"3 vehicles",
                                       4:"4 or more vehicles"})

# %%
def stat_by_geog(df, geog):
    """
    Function to calculate statistics by geography and vehicle ownership.
    """
    
    # Group by equity geography and vehicle ownership
    df_grouped = df.groupby([geog, 'hhvehs'], as_index=False)['hhexpfac'].sum()
    
    # Calculate total households in each equity geography
    total_hh = df.groupby([geog], as_index=False)['hhexpfac'].sum().rename(columns={'hhexpfac': 'total_hh'})
    
    # Merge the grouped data with total households
    df_merged = df_grouped.merge(total_hh, on=geog)
    
    # Calculate percentage of households with the specified vehicle ownership
    df_merged['percentage'] = df_merged['hhexpfac'] / df_merged['total_hh']
    
    return df_merged.pivot(index=geog, columns='hhvehs', values='percentage')

# %% [raw]
# :::{.panel-tabset}
#
# ### County

# %%
df_region = df_hh.groupby(['hhvehs'], as_index=False)['hhexpfac'].sum()
df_region['percentage'] = df_region['hhexpfac'] / df_hh['hhexpfac'].sum()
df_region['hh_county'] = 'Region'

# %%
df = stat_by_geog(df_hh, 'hh_county')
pd.concat([df_region.pivot(index='hh_county', columns='hhvehs', values='percentage'),df])
# Out:
# hhvehs     0 vehicle  1 vehicle  2 vehicles  3 vehicles  4 or more vehicles
# hh_county
# Region           14%        35%         33%         12%                  6%
# King             17%        37%         30%         10%                  5%
# Kitsap            6%        30%         38%         17%                  8%
# Pierce           11%        33%         35%         14%                  7%
# Snohomish         9%        34%         36%         14%                  8%

# %% [raw]
# ### Regional Geography

# %%
df = stat_by_geog(df_hh, 'hh_rg_proposed')
df
# Out:
# hhvehs                             0 vehicle  1 vehicle  2 vehicles  \
# hh_rg_proposed
# Cities and Towns                          3%        28%         42%
# Core Cities                              11%        38%         33%
# High Capacity Transit Communities         7%        34%         38%
# Metropolitan Cities                      26%        41%         24%
# Rural Areas                               1%        18%         43%
# Urban Unincorporated Areas                3%        25%         44%
#
# hhvehs                             3 vehicles  4 or more vehicles
# hh_rg_proposed
# Cities and Towns                          17%                  9%
# Core Cities                               11%                  6%
# High Capacity Transit Communities         14%                  7%
# Metropolitan Cities                        6%                  3%
# Rural Areas                               25%                 13%
# Urban Unincorporated Areas                18%                 10%

# %% [raw]
# ### Regional Growth Center

# %%
df = stat_by_geog(df_hh, 'is_rgc')
df
# Out:
# hhvehs      0 vehicle  1 vehicle  2 vehicles  3 vehicles  4 or more vehicles
# is_rgc
# In RGC            41%        41%         14%          3%                  1%
# Not in RGC         7%        34%         37%         14%                  7%

# %%
df = stat_by_geog(df_hh, 'hh_rgc')
df
# Out:
# hhvehs                           0 vehicle  1 vehicle  2 vehicles  3 vehicles  \
# hh_rgc
# Auburn                                 28%        47%         18%          4%
# Bellevue                               48%        38%         11%          2%
# Bothell Canyon Park                    11%        43%         32%          9%
# Bremerton                              34%        46%         15%          3%
# Burien                                 26%        46%         20%          5%
# Everett                                38%        44%         14%          3%
# Federal Way                            28%        44%         20%          5%
# Greater Downtown Kirkland              17%        53%         23%          5%
# Issaquah                               22%        46%         25%          5%
# Kent                                   31%        45%         16%          5%
# Kirkland Totem Lake                    18%        49%         24%          6%
# Lakewood                               25%        46%         21%          5%
# Lynnwood                               34%        43%         18%          4%
# Not in RGC                              7%        34%         37%         14%
# Puyallup Downtown                      26%        48%         19%          4%
# Puyallup South Hill                    17%        46%         26%          7%
# Redmond Downtown                       30%        49%         17%          3%
# Redmond-Overlake                       31%        48%         17%          3%
# Renton                                 27%        47%         19%          4%
# SeaTac                                 18%        49%         23%          6%
# Seattle Downtown                       59%        33%          7%          1%
# Seattle First Hill/Capitol Hill        51%        39%          9%          1%
# Seattle Northgate                      31%        45%         19%          4%
# Seattle South Lake Union               50%        39%          9%          1%
# Seattle University Community           45%        40%         12%          2%
# Seattle Uptown                         44%        42%         12%          2%
# Silverdale                             17%        51%         22%          6%
# Tacoma Downtown                        46%        40%         12%          2%
# Tacoma Mall                            28%        45%         20%          4%
# Tukwila                                24%        44%         21%          6%
# University Place                       16%        47%         27%          7%
#
# hhvehs                           4 or more vehicles
# hh_rgc
# Auburn                                           3%
# Bellevue                                         1%
# Bothell Canyon Park                              5%
# Bremerton                                        2%
# Burien                                           3%
# Everett                                          1%
# Federal Way                                      2%
# Greater Downtown Kirkland                        2%
# Issaquah                                         2%
# Kent                                             2%
# Kirkland Totem Lake                              3%
# Lakewood                                         3%
# Lynnwood                                         2%
# Not in RGC                                       7%
# Puyallup Downtown                                3%
# Puyallup South Hill                              4%
# Redmond Downtown                                 1%
# Redmond-Overlake                                 1%
# Renton                                           2%
# SeaTac                                           3%
# Seattle Downtown                                 0%
# Seattle First Hill/Capitol Hill                  0%
# Seattle Northgate                                2%
# Seattle South Lake Union                         1%
# Seattle University Community                     1%
# Seattle Uptown                                   1%
# Silverdale                                       3%
# Tacoma Downtown                                  1%
# Tacoma Mall                                      2%
# Tukwila                                          5%
# University Place                                 3%

# %% [raw]
# ### Equity Focus Areas

# %%
df = pd.DataFrame()
for name, col in efa_names.items():
    _df = stat_by_geog(df_hh,col).reset_index()
    _df['Group'] = name
    _df.rename(columns={col: 'EFA Type'}, inplace=True)
    df = pd.concat([df, _df])

df.set_index(['Group','EFA Type'])
# Out:
# hhvehs                                             0 vehicle  1 vehicle  \
# Group           EFA Type
# People of Color Above Regional Average                   18%        36%
#                 Below Regional Average                   10%        33%
#                 Higher Share of Equity Population        17%        39%
# Income          Above Regional Average                   14%        37%
#                 Below Regional Average                   11%        33%
#                 Higher Share of Equity Population        21%        41%
# LEP             Above Regional Average                   16%        36%
#                 Below Regional Average                   13%        34%
#                 Higher Share of Equity Population        14%        40%
# Disability      Above Regional Average                   12%        36%
#                 Below Regional Average                   12%        34%
#                 Higher Share of Equity Population        20%        38%
# Older Adults    Above Regional Average                   11%        34%
#                 Below Regional Average                   16%        37%
#                 Higher Share of Equity Population        12%        34%
# Youth           Above Regional Average                    6%        32%
#                 Below Regional Average                   19%        38%
#                 Higher Share of Equity Population         5%        29%
#
# hhvehs                                             2 vehicles  3 vehicles  \
# Group           EFA Type
# People of Color Above Regional Average                    30%         10%
#                 Below Regional Average                    36%         14%
#                 Higher Share of Equity Population         29%          9%
# Income          Above Regional Average                    32%         11%
#                 Below Regional Average                    36%         14%
#                 Higher Share of Equity Population         26%          8%
# LEP             Above Regional Average                    32%         11%
#                 Below Regional Average                    34%         13%
#                 Higher Share of Equity Population         31%         10%
# Disability      Above Regional Average                    33%         12%
#                 Below Regional Average                    35%         13%
#                 Higher Share of Equity Population         27%         10%
# Older Adults    Above Regional Average                    35%         14%
#                 Below Regional Average                    31%         11%
#                 Higher Share of Equity Population         34%         14%
# Youth           Above Regional Average                    38%         15%
#                 Below Regional Average                    28%          9%
#                 Higher Share of Equity Population         41%         17%
#
# hhvehs                                             4 or more vehicles
# Group           EFA Type
# People of Color Above Regional Average                             5%
#                 Below Regional Average                             7%
#                 Higher Share of Equity Population                  5%
# Income          Above Regional Average                             6%
#                 Below Regional Average                             7%
#                 Higher Share of Equity Population                  4%
# LEP             Above Regional Average                             6%
#                 Below Regional Average                             7%
#                 Higher Share of Equity Population                  5%
# Disability      Above Regional Average                             6%
#                 Below Regional Average                             6%
#                 Higher Share of Equity Population                  5%
# Older Adults    Above Regional Average                             7%
#                 Below Regional Average                             6%
#                 Higher Share of Equity Population                  7%
# Youth           Above Regional Average                             8%
#                 Below Regional Average                             5%
#                 Higher Share of Equity Population                  9%

# %% [raw]
# :::
