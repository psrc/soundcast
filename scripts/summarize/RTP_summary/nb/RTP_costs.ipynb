# %% [raw]
# ---
# title: "Household Transportation Costs"
# date: today
# ---

# %% [markdown]
# - Average Annual Household Transportation Costs: Out-of-pocket expenses including tolls, parking, and transit fares
#
#     - These costs do not include other vehicle operating and purchase costs.
#
#     - Costs are annualized using factor of 320

# %%
import pandas as pd
import polars as pl
from pathlib import Path
import util

pd.set_option('display.float_format', '${:0,.0f}'.format)

# %%
# person data
person = pd.read_csv(util.output_path / 'agg/dash/person_cost.csv')
# household data
hh = pd.read_csv(util.output_path / 'agg/dash/hh_geog.csv')

annual_factor = util.summary_config['weekday_to_annual']
# list of equity geographies
equity_geogs = util.summary_config['equity_geogs']
not_equity_geogs = ["NOT in " + item for item in equity_geogs]

# %%
df_person = person.copy()
df_person['is_rgc'] = "In RGC"
df_person.loc[df_person['hh_rgc'] == 'Not in RGC', 'is_rgc'] = "Not in RGC"
# included modes
# TODO: ask what this means
df_person = df_person[(df_person['mode'].isin(['SOV','HOV2','HOV3+']) & (df_person['dorp'] == 1)) 
                      | (~df_person['mode'].isin(['SOV','HOV2','HOV3+']))]

df_hh = hh.copy()
df_hh['is_rgc'] = "In RGC"
df_hh.loc[df_hh['hh_rgc'] == 'Not in RGC', 'is_rgc'] = "Not in RGC"

# %%
def annual_costs(geog, map=False):
    df = df_person.groupby(geog, as_index=False)['travcost_wt'].sum().set_index(geog)
    df['hhexpfac'] = df_hh.groupby(geog)['hhexpfac'].sum()

    if map:
        df.index = df.index.astype('int').map({
                                0: 'Below Regional Average', 
                                1: 'Above Regional Average', 
                                2: 'Higher Share of Equity Population'}
                                )

    df.loc['Region'] = [df_person['travcost_wt'].sum(), df_hh['hhexpfac'].sum()]
    df['Average Annual Costs'] = (df['travcost_wt'] / df['hhexpfac']) * annual_factor




    return df[['Average Annual Costs']]

# %% [raw]
# :::{.panel-tabset}
# ### County

# %%
df = annual_costs('hh_county')
df = df[df.index!='Outside Region']
df
# Out:
#            Average Annual Costs
# hh_county
# King                     $2,351
# Kitsap                   $2,908
# Pierce                   $2,633
# Snohomish                $2,809
# Region                   $2,531

# %% [raw]
# ### Regional Growth Center

# %%
annual_costs('is_rgc')
# Out:
#             Average Annual Costs
# is_rgc
# In RGC                    $1,017
# Not in RGC                $2,786
# Region                    $2,531

# %%
annual_costs('hh_rgc')
# Out:
#                                  Average Annual Costs
# hh_rgc
# Auburn                                         $1,648
# Bellevue                                         $857
# Bothell Canyon Park                            $2,297
# Bremerton                                        $949
# Burien                                         $1,818
# Everett                                          $847
# Federal Way                                    $1,758
# Greater Downtown Kirkland                      $1,944
# Issaquah                                       $1,671
# Kent                                           $1,210
# Kirkland Totem Lake                            $1,762
# Lakewood                                       $1,135
# Lynnwood                                       $1,840
# Not in RGC                                     $2,786
# Puyallup Downtown                              $1,569
# Puyallup South Hill                            $1,697
# Redmond Downtown                               $1,501
# Redmond-Overlake                               $1,491
# Renton                                         $1,493
# SeaTac                                         $2,037
# Seattle Downtown                                 $412
# Seattle First Hill/Capitol Hill                  $677
# Seattle Northgate                              $1,720
# Seattle South Lake Union                         $521
# Seattle University Community                   $1,208
# Seattle Uptown                                   $761
# Silverdale                                       $908
# Tacoma Downtown                                  $917
# Tacoma Mall                                    $1,158
# Tukwila                                        $1,840
# University Place                               $1,531
# Region                                         $2,531

# %% [raw]
# ### Regional Geography

# %%
annual_costs('hh_rg_proposed')
# Out:
#                                    Average Annual Costs
# hh_rg_proposed
# Cities and Towns                                 $3,339
# Core Cities                                      $2,436
# High Capacity Transit Communities                $2,727
# Metropolitan Cities                              $1,660
# Rural Areas                                      $4,438
# Urban Unincorporated Areas                       $3,165
# Region                                           $2,531

# %% [raw]
# ### Equity Focus Areas

# %%
df = pd.DataFrame()
for name, col in {
    "People of Color": "hh_efa_poc",
    "Income": "hh_efa_pov200",
    "LEP": "hh_efa_lep",
    "Disability": "hh_efa_dis",
    "Older Adults": "hh_efa_older",
    "Youth": "hh_efa_youth"
}.items():
    _df = annual_costs(col, map=True)
    _df['Group'] = name
    df = pd.concat([df, _df])

df = df.reset_index()
df
df.rename(columns={'index':'EFA Type'}, inplace=True)

df[['Group', 'EFA Type', 'Average Annual Costs']]
# Out:
#               Group                           EFA Type  Average Annual Costs
# 0   People of Color             Below Regional Average                $2,804
# 1   People of Color             Above Regional Average                $2,219
# 2   People of Color  Higher Share of Equity Population                $2,245
# 3   People of Color                             Region                $2,531
# 4            Income             Below Regional Average                $2,792
# 5            Income             Above Regional Average                $2,344
# 6            Income  Higher Share of Equity Population                $1,904
# 7            Income                             Region                $2,531
# 8               LEP             Below Regional Average                $2,609
# 9               LEP             Above Regional Average                $2,434
# 10              LEP  Higher Share of Equity Population                $2,368
# 11              LEP                             Region                $2,531
# 12       Disability             Below Regional Average                $2,670
# 13       Disability             Above Regional Average                $2,560
# 14       Disability  Higher Share of Equity Population                $2,056
# 15       Disability                             Region                $2,531
# 16     Older Adults             Below Regional Average                $2,378
# 17     Older Adults             Above Regional Average                $2,629
# 18     Older Adults  Higher Share of Equity Population                $2,893
# 19     Older Adults                             Region                $2,531
# 20            Youth             Below Regional Average                $2,162
# 21            Youth             Above Regional Average                $2,942
# 22            Youth  Higher Share of Equity Population                $3,198
# 23            Youth                             Region                $2,531

# %% [raw]
# :::
