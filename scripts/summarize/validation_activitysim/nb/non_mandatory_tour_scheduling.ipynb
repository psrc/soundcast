# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation4/c$/workspace/sc_asim_040112/output", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached", "survey 2025": "R:/e2projects_two/2023_base_year/2025_survey/activitysim_format/cleaned"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": True, "run_setup_emme_project_folders": True, "run_setup_emme_bank_folders": True, "run_copy_scenario_inputs": True, "run_import_networks": True, "run_skims_and_paths_free_flow": True, "run_skims_and_paths": True, "run_truck_model": True, "run_supplemental_trips": True, "run_abm": True, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Non-mandatory tour scheduling
# date: today
# ---

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
# read data
tour_data = util.get_tour_data(summary_config)

non_m_tour_data = tour_data.loc[tour_data['tour_category']=="non_mandatory"]

# %% [markdown]
# ## non-mandatory tour start time

# %%
df_plot = non_m_tour_data.groupby(['source','start'])[['tour_weight']].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot, x="start", y="percentage", color="source",barmode="group",
             title="non-mandatory tour start time")
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.update_layout(height=400, width=700, yaxis=dict(tickformat=".0%"), xaxis=dict(dtick="1"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f3014e7b-1519-4b87-aa63-302547e52cc5" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f3014e7b-1519-4b87-aa63-302547e52cc5")) {                    Plotly.newPlot(                        "f3014e7b-1519-4b87-aa63-302547e52cc5",                        [{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003estart=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAFEAAAAAAAAAYQAAAAAAAABxAAAAAAAAAIEAAAAAAAAAiQAAAAAAAACRAAAAAAAAAJkAAAAAAAAAoQAAAAAAAACpAAAAAAAAALEAAAAAAAAAuQAAAAAAAADBAAAAAAAAAMUAAAAAAAAAyQAAAAAAAADNAAAAAAAAANEAAAAAAAAA1QAAAAAAAADZAAAAAAAAAN0A="},"xaxis":"x","y":{"dtype":"f8","bdata":"9lzpIMiwhT8TfjMktFmSP4Wt1hhHd60\u002fplplcEjluT+NEkSd9JKyP\u002fQcSkcIQrQ\u002fe7lfU92jtD\u002f9k60G5eW1P9UWHWOZv7A\u002fusuTzzwZsj8O1YRONTa1P4Aj3maCGq0\u002frRo4CnyZsT8RJP6Sxj23P1zEWHyQIpE\u002fy73ykpcxlD+bhU3r4duVPxPnTFPj1kU\u002fn6h4EMgjUj8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey\u003cbr\u003estart=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAFEAAAAAAAAAYQAAAAAAAABxAAAAAAAAAIEAAAAAAAAAiQAAAAAAAACRAAAAAAAAAJkAAAAAAAAAoQAAAAAAAACpAAAAAAAAALEAAAAAAAAAuQAAAAAAAADBAAAAAAAAAMUAAAAAAAAAyQAAAAAAAADNAAAAAAAAANEAAAAAAAAA1QAAAAAAAADZAAAAAAAAAN0A="},"xaxis":"x","y":{"dtype":"f8","bdata":"WFsdPR2ylT\u002fWbz1zrQedP7csU8Jb2LM\u002f28yk0qGrtz8cWr2Zsw61P1WGAOi8H68\u002fPFmm5SjEsD8nz0VCJlusP3MmPLyUhKs\u002fAQUs2Z3HtD8gJry+bO+7P53ZwCZiobA\u002fkiGvJp2ttD97u4WJfbmsP+XrTZDiwqQ\u002fAvb2pEUsjz\u002fokCwgwrllPwi\u002fO0jfKoY\u002fkkmr2KqCVz8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey 2025\u003cbr\u003estart=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey 2025","offsetgroup":"survey 2025","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAFEAAAAAAAAAYQAAAAAAAABxAAAAAAAAAIEAAAAAAAAAiQAAAAAAAACRAAAAAAAAAJkAAAAAAAAAoQAAAAAAAACpAAAAAAAAALEAAAAAAAAAuQAAAAAAAADBAAAAAAAAAMUAAAAAAAAAyQAAAAAAAADNAAAAAAAAANEAAAAAAAAA1QAAAAAAAADZA"},"xaxis":"x","y":{"dtype":"f8","bdata":"Ty3Ah\u002fsslT9pInrAtVKhP9aSGTVGtbA\u002fKPf2vJf4vj\u002fbJanGw36vPw7vHIuCW5U\u002f\u002fA2JFOXdtT\u002fjEmj+raukP8ZPNOHTAqo\u002f9wl7rJ+zsz+J23mtxkvAP+vDUYIRzas\u002fm\u002fe7P25IsT9uZ50hggi6PzppgDqC1q4\u002fiL\u002f1fKmXhD\u002fcidBlYVdDP5\u002fz7uwhpVo\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tic ...

# %%
df_plot = non_m_tour_data.groupby(['source','tour_type','start'], observed=True)[['tour_weight']].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source','tour_type'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot, x="start", y="percentage", color="source",barmode="group",
             facet_row='tour_type',
             title="non-mandatory tour start time by tour purpose")
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.update_layout(height=1000, width=700, yaxis=dict(tickformat=".0%"), xaxis=dict(dtick="1"))
fig.show()
# Out:
# C:\Users\JLin\AppData\Local\Temp\ipykernel_30792\1221153050.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="070d7861-e164-4746-9110-5a183f9b856d" class="plotly-graph-div" style="height:1000px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("070d7861-e164-4746-9110-5a183f9b856d")) {                    Plotly.newPlot(                        "070d7861-e164-4746-9110-5a183f9b856d",                        [{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=othmaint\u003cbr\u003estart=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAFEAAAAAAAAAYQAAAAAAAABxAAAAAAAAAIEAAAAAAAAAiQAAAAAAAACRAAAAAAAAAJkAAAAAAAAAoQAAAAAAAACpAAAAAAAAALEAAAAAAAAAuQAAAAAAAADBAAAAAAAAAMUAAAAAAAAAyQAAAAAAAADNAAAAAAAAANEAAAAAAAAA1QAAAAAAAADZAAAAAAAAAN0A="},"xaxis":"x6","y":{"dtype":"f8","bdata":"kI0dp35+hz94xlaulJmSP\u002fWG5BQzDLI\u002fyIfGgXxovD\u002fsCUhnRCa6P+wJSGdEJro\u002fwdrVXPeouD+9yflJFBW4PwfkXsuaSLA\u002fofpOXPU6sD\u002fAJaiX8hixP0jKhYGkXKg\u002f7kKFtAEnqz9NM55ny3mwP\u002fjkNTYEE4g\u002fqMoaGEFDiD9Qke+InICGPwC1l1uq1TM\u002fgLw7H+bZQT8="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=shopping\u003cbr\u003estart=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAFEAAAAAAAAAYQAAAAAAAABxAAAAAAAAAIEAAAAAAAAAiQAAAAAAAACRAAAAAAAAAJkAAAAAAAAAoQAAAAAAAACpAAAAAAAAALEAAAAAAAAAuQAAAAAAAADBAAAAAAAAAMUAAAAAAAAAyQAAAAAAAADNAAAAAAAAANEAAAAAAAAA1QAAAAAAAADZAAAAAAAAAN0A="},"xaxis":"x5","y":{"dtype":"f8","bdata":"1dmGLQRvfD8n1\u002fGdexWHPyQVh+0ErpA\u002fH1Tcbpsrsz9ULpv9hQe1PydzmJrSULg\u002fz8aVZ9+puD\u002f2Uko9gCO7PwV6Ad+NobM\u002fNv4eySlctD+jlcSos1K2P+Wc0N6pua8\u002fd8BSblIHsT+Grx6zk2i1P5b\u002fePj+B5E\u002fg0zeiWaTkz8H4CD4+GuTP7zgDUrpHTo\u002frs9OOLw3QD8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=escort\u003cbr\u003estart=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAFEAAAAAAAAAYQAAAAAAAABxAAAAAAAAAIEAAAAAAAAAiQAAAAAAAACRAAAAAAAAAJkAAAAAAAAAoQAAAAAAAACpAAAAAAAAALEAAAAAAAAAuQAAAAAAAADBAAAAAAAAAMUAAAAAAAAAyQAAAAAAAADNAAAAAAAAANEAAAAAAAAA1QAAAAAAAADZAAAAAAAAAN0A="},"xaxis":"x4","y":{"dtype":"f8","bdata":"tIxPH7v+lD\u002faiAj+NnKeP1CPr2iaxsE\u002fD5mQHMkbyD\u002faqadACFimP0WAhD7ovqw\u002fB0lwmsqkrT+qk3l+EryuP+J3ms7\u002fZbA\u002fDq8kj1hdsj\u002fpmUNVoSu3PyfEf0AzeqI\u002fIyWMxHT2qT87GIEzHNiwPyymtyp8m3c\u002fBcvcd1eKgT8MKdubyZ6EP3LJCKA8qUQ\u002fAyInWa2+TT8="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=social\u003cbr\u003estart=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAFEAAAAAAAAAYQAAAAAAAABxAAAAAAAAAIEAAAAAAAAAiQAAAAAAAACRAAAAAAAAAJkAAAAAAAAAoQAAAAAAAACpAAAAAAAAALEAAAAAAAAAuQAAAAAAAADBAAAAAAAAAMUAAAAAAAAAyQAAAAAAAADNAAAAAAAAANEAAAAAAAAA1QAAAAAAAADZAAAAAAAAAN0A="},"xaxis":"x3","y":{"dtype":"f8","bdata":"jr4arY+Gez\u002fT0VR0RbGPP08J ...

# %% [markdown]
# ## non-mantatory tour duration

# %%
non_m_tour_data['duration_cal'] = non_m_tour_data['end'] - non_m_tour_data['start']

df_plot = non_m_tour_data.groupby(['source','duration_cal'])[['tour_weight']].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot, x="duration_cal", y="percentage", color="source",barmode="group",
             title="non-mandatory tour duration")
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.update_layout(height=400, width=700, yaxis=dict(tickformat=".0%"), xaxis=dict(dtick="1"))
fig.show()
# Out:
# C:\Users\JLin\AppData\Local\Temp\ipykernel_30792\3214436017.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="0c9d12b7-ed71-4164-99df-9f98dada863e" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0c9d12b7-ed71-4164-99df-9f98dada863e")) {                    Plotly.newPlot(                        "0c9d12b7-ed71-4164-99df-9f98dada863e",                        [{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003eduration_cal=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAqQAAAAAAAACxAAAAAAAAALkAAAAAAAAAwQAAAAAAAADFAAAAAAAAAMkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"i\u002fAnLnYL0D8i7DRhcUzNP0lJKBg1McM\u002f6tbbod\u002fuwD\u002fKqN1dHWOtP57faWzKcKk\u002fk7fGNwVDnT\u002fWG2HSNviXP\u002fk7ASte2JU\u002fASDOV+mLkT+SrUlM1mmLP94AVFDqX4M\u002fGevmF7xGfj\u002fTI5FbeZl1P1xccJGV8Wk\u002fAePFNE8oWD9MR2JPuHw8P3UYQ91jtgk\u002f8ZCk3Mu3xD4="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey\u003cbr\u003eduration_cal=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAqQAAAAAAAACxAAAAAAAAALkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"KpvU\u002fcQixj9nhnXU1b\u002fVP7nGmvD2Tck\u002f1cAffOiatj9xlzkr3yKuP6EMB3PCEJ8\u002fZ4oDp6G9lD9V3VAFseiaP11ELCMI8JU\u002fHYkaEx7rgz9iYwixxu2QP\u002fL0HViovX8\u002fkAhiX0V9eT8ZTzHmChxJPyfdfCOic2g\u002fwkLSm\u002fffGj8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey 2025\u003cbr\u003eduration_cal=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey 2025","offsetgroup":"survey 2025","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAsQA=="},"xaxis":"x","y":{"dtype":"f8","bdata":"lATHHGGAyz8tS7RASYbWP9WXlbHeb8c\u002fueG4yy5PvD+AsTaYCfysP0GxAtpHn5k\u002fQAV0A8LcWz\u002fpgGbHwZ1IP\u002f+SdCmg6o0\u002f9H2fPTcrkT8dmZMBysKLP9YBJC75VGA\u002fIjoDR6KDTz9RscA70ud+Pw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ti ...

# %%
df_plot = non_m_tour_data.groupby(['source','tour_type','duration_cal'], observed=True)[['tour_weight']].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source','tour_type'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot, x="duration_cal", y="percentage", color="source",barmode="group",
             facet_row='tour_type',
             title="non-mandatory tour duration by tour type")
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.update_layout(height=1000, width=700, yaxis=dict(tickformat=".0%"), xaxis=dict(dtick="1"))
fig.show()
# Out:
# C:\Users\JLin\AppData\Local\Temp\ipykernel_30792\744512889.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="a0a38a92-9ec2-405c-adb6-14b9a88d83b5" class="plotly-graph-div" style="height:1000px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a0a38a92-9ec2-405c-adb6-14b9a88d83b5")) {                    Plotly.newPlot(                        "a0a38a92-9ec2-405c-adb6-14b9a88d83b5",                        [{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=othmaint\u003cbr\u003eduration_cal=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAqQAAAAAAAACxAAAAAAAAALkAAAAAAAAAwQAAAAAAAADFA"},"xaxis":"x6","y":{"dtype":"f8","bdata":"MSKD8wQUyj8UOV8jc9XHP16FHI4KfcY\u002fZcvp9ltCxD+an7Q3kOCxP3jLoTZs0a4\u002fah9q7EHtoT9Qrnq2mV+cP5wk+Buk3Jk\u002fsM9HEAqMkz+oHxnNRd2MPyC5\u002ftNkvoI\u002f8HgaTdryfD8Qae61RZtzPwAZ3pcmeGQ\u002fQItCLuFVUT8AE44uXQ42PwCg\u002f2ppY+k+"},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=shopping\u003cbr\u003eduration_cal=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAqQAAAAAAAACxAAAAAAAAALkAAAAAAAAAwQAAAAAAAADFA"},"xaxis":"x5","y":{"dtype":"f8","bdata":"l+4XeQHc0T8iCD4VxJTQP0a37aDeg8I\u002fJJ2F5pyOvz9BZNJDX02rP076MeHSBqc\u002fs\u002feTRu7NmD9JSLsuGRGUP1xXcGbM9ZA\u002fq+\u002fxeIZ\u002fiT9f+oF+5TGCP\u002frEvjJdhXc\u002fTfVbDeLecD+FidCIFAVlPxk3oZ12cFE\u002fFS6hOuOWNz\u002fHyMcb14gSP1zS48dEkeU+"},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=escort\u003cbr\u003eduration_cal=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAqQAAAAAAAACxAAAAAAAAALkAAAAAAAAAwQAAAAAAAADFAAAAAAAAAMkA="},"xaxis":"x4","y":{"dtype":"f8","bdata":"jvcN2kaL2z\u002fxK+FFyOrYP3Ma7Ma0Z6Y\u002fu4BCwXmWpD\u002fYTblJTvWOPxKzAaVaNow\u002fZSGU+Bcehz8f6bT5r6CEP8tPAKq7B4I\u002fjbXPVKS\u002ffz8ZWJ8fZbp8PzdvCv73iHg\u002fQ8abfqRVdD+d5BUGNOJwP0unjpZ\u002fKHE\u002fV8HEkHPUYz\u002fP8MAOxLJIPx4fIa+ucg0\u002fYSgBnN1l3j4="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model\u003cbr\u003etour_type=social\u003cbr\u003eduration_cal=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAqQAAAAAAAACxAAAAAAAAALkAAAAAAAAAwQAAAAAAAADFA"},"xaxis":"x3","y":{"dtype":"f8","bdata":"3LQOwEHkxD+wXBz9RDnEP1GQS4NpvsQ\u002fiaavGj6Gwz8d4uhyNSmyP7HjB5vI3 ...
