# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtour_frequency", "atwork_subtour_destination", "atwork_subtour_scheduling", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["all_tour_mode", "all_trip_mode", "auto_ownership", "day_pattern", "escort_tour_mode", "escort_trip_mode", "households", "intermediate_stop_generation", "other_home_based_tour_mode", "other_home_based_trip_mode", "persons", "school_location", "school_tour_mode", "school_trip_mode", "telecommute", "time_choice", "tours", "tour_destination", "transit_pass_ownership", "trips", "trip_destination", "workbased_subtour_generation", "workbased_subtour_mode", "work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}, "output_dir": "C:/workspace/sc_6_22_26_asim_output", "data_dir": "C:/workspace/sc_6_22_26_asim_data"}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "uv_directory": "C:/workspace/uv_envs/activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# Parameters
# summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["mandatory_tour_frequency"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation3/c$/Workspace/sc_20251118/outputs", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 7, "9to15": 12, "15to18": 17, "18to20": 19, "20to5": 22}, "summer_list": [87], "pollutant_map": {"1": "Total Gaseous HCs", "2": "CO", "3": "NOx", "5": "Methane", "6": "N20", "79": "Non-methane HCs", "87": "VOCs", "90": "Atmospheric CO2", "91": "Total Energy", "98": "CO2 Equivalent", "PM10": "PM10 Total", "PM25": "PM25 Total", "100": "PM10 Exhaust", "106": "PM10 Brakewear", "107": "PM10 Tirewear", "110": "PM25 Exhaust", "112": "Elemental Carbon", "115": "Sulfate Particulate", "116": "PM25 Brakewear", "117": "PM25 Tirewear", "118": "Composite NonECPM", "119": "H20 Aerosol"}, "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
# input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_asim", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Joint Tour Composition
# date: today
# ---

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
# read data
hh = util.get_hh_data(summary_config, uncloned=True)
person = util.get_person_data(summary_config, uncloned=True)
tour = util.get_tour_data(summary_config)

# %% [markdown]
# This model predicts the makeup of the travel party (adults, children, or mixed).

# %%
# all joint tours
num_hh_joint_tours = tour.loc[tour['tour_category'] == "joint"].groupby(['source','household_id']).size().to_frame(). \
    rename(columns={0: 'num_hh_joint_tours'})

# all households with joint tours
hh_data = pd.merge(hh, num_hh_joint_tours, on=['source','household_id'], how='left')
hh_data['num_hh_joint_tours'] = hh_data['num_hh_joint_tours'].fillna(0)
joint_hh_data = hh_data.loc[hh_data['num_hh_joint_tours']>0]

per_data = person.\
    merge(hh_data[['household_id','income_group','num_drivers','auto_ownership_4+','auto_available_driver','hhsize_4+','num_hh_joint_tours','hh_weight','source']],
            how='left', on=['household_id','source'])

tour_data = tour.merge(per_data, how='left', on=['person_id','household_id','source'])
joint_tour_data = tour_data.loc[tour_data['tour_category'] == "joint"].copy()

# %% [markdown]
# - joint tour count

# %%
# total number of joint tours by source
df_1 = joint_tour_data.groupby('source')['tour_weight'].sum().reset_index()
df_1 = df_1.rename(columns={"tour_weight": "joint tour count"})
# total number of tours by source
df_2 = tour.groupby('source')['tour_weight'].sum().reset_index()
df_2 = df_2.rename(columns={"tour_weight": "tour count"})

df_joint_tour_count = df_1.merge(df_2, how="left", on='source')
df_joint_tour_count['joint_percent'] = df_joint_tour_count['joint tour count']/df_joint_tour_count['tour count']
df_joint_tour_count['tour count'] = df_joint_tour_count['tour count'].astype(float).map(lambda n: '{:.2f}'.format(n))
df_joint_tour_count['joint tour count'] = df_joint_tour_count['joint tour count'].astype(float).map(lambda n: '{:.2f}'.format(n))
df_joint_tour_count['joint_percent'] = df_joint_tour_count['joint_percent'].astype(float).map(lambda n: '{:.2%}'.format(n))
df_joint_tour_count
# Out:
#    source joint tour count  tour count joint_percent
# 0   model         96754.00  5089114.00         1.90%
# 1  survey        525347.70  4633302.91        11.34%

# %%
util.plot_share_barchart(joint_tour_data, 'tour_weight', 'composition', title="Joint tour composition")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="824751a1-ffa4-4e20-a85a-fca8f723f7a1" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("824751a1-ffa4-4e20-a85a-fca8f723f7a1")) {                    Plotly.newPlot(                        "824751a1-ffa4-4e20-a85a-fca8f723f7a1",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"H7gAAFifAAB7IgAA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x","y":{"dtype":"f8","bdata":"TOlREa8t3z9eF8DUlPvaP1X9t2fwWrc\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"FQKOAVMA","shape":"3, 1"},"hovertemplate":"source=survey\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x","y":{"dtype":"f8","bdata":"LyWfi2hW2T93b\u002fn7T5PfP2utneEdWbw\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36, ...

# %% [markdown]
# # joint tour composition by segment

# %%
def plot_joint_tour_segment(joint_tour_data, segment, title, height=350, facet_col_wrap=4):
    util.plot_share_facetbar(joint_tour_data, 'tour_weight', 'composition', title, 
                        segment, facet_col_wrap=facet_col_wrap,
                        height=height, orientation='v')

# %% [raw]
# :::{.panel-tabset}
#
# ### tour purpose

# %%
plot_joint_tour_segment(joint_tour_data, 'tour_type', "Household joint tour composition by tour purpose", height=550, facet_col_wrap=3)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="768bed82-71c7-401d-a325-1113544067ea" class="plotly-graph-div" style="height:550px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("768bed82-71c7-401d-a325-1113544067ea")) {                    Plotly.newPlot(                        "768bed82-71c7-401d-a325-1113544067ea",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"NiN5JdAI","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=othmaint\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x7","y":{"dtype":"f8","bdata":"IB4XXNGm2z9VnRazg23dPywSScOrrrs\u002f"},"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"UyyOGNoE","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=shopping\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x8","y":{"dtype":"f8","bdata":"D0sGkL884z\u002fszMEdalDVP9tzxghb2LA\u002f"},"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"RRewEDgD","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=social\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x9","y":{"dtype":"f8","bdata":"kBsCWRE\u002f4T9EjLhgcLzYP3PyDLWzFbM\u002f"},"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"syLmEdcC","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=eatout\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x4","y":{"dtype":"f8","bdata":"DveYAoEH5D\u002fk5iBitKnUPwdYacVMOqo\u002f"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"ni67PsIO","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=othdiscr\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x5","y":{"dtype":"f8","bdata":"NZwy1T8K2D8qg95zvCzgP+B1QQwdcb4\u002f"},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"MSM=","shape":"2, 1"},"hovertemplate":"source=survey\u003cbr\u003etour_type=othmaint\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"s ...

# %% [raw]
# ### income group

# %%
plot_joint_tour_segment(joint_tour_data, 'income_group', "Household joint tour composition by income group")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="308281db-e5ff-4d36-85c7-84303f7a94e7" class="plotly-graph-div" style="height:350px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("308281db-e5ff-4d36-85c7-84303f7a94e7")) {                    Plotly.newPlot(                        "308281db-e5ff-4d36-85c7-84303f7a94e7",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"rhyRFVoF","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=low\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x","y":{"dtype":"f8","bdata":"gloYJsqB4D8QBoc1YNPYP7ITIfktpLg\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"zi8VIL8H","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=medium\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x2","y":{"dtype":"f8","bdata":"NTwSEdR04T\u002f89ppaHm7XP2pCAg3moLY\u002f"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"6zXTLncJ","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=medium-high\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x3","y":{"dtype":"f8","bdata":"h62c+b9P3z8OIVEnJzHbP6rFSHxj\u002fLU\u002f"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"uDXfOusL","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=high\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x4","y":{"dtype":"f8","bdata":"Mdlvjduc2z9vcizx2kLeP3\u002fRjgUmgbg\u002f"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"IiAD","shape":"3, 1"},"hovertemplate":"source=survey\u003cbr\u003eincome_group=low\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x","y":{"dtype":"f8","bdata":"Ls3Ls0s62T+uNpApLUvjP9e74on8rGc\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"QzQN","shape":"3, 1"},"hovertemplate":"source=survey\u003cbr\u003eincome_group=medium\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{ ...

# %% [raw]
# ### auto deficiency

# %%
plot_joint_tour_segment(joint_tour_data, 'auto_available_driver', "Household joint tour composition by auto deficiency")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1618cafd-f5cb-4743-a55e-a63d6f6ab93b" class="plotly-graph-div" style="height:350px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1618cafd-f5cb-4743-a55e-a63d6f6ab93b")) {                    Plotly.newPlot(                        "1618cafd-f5cb-4743-a55e-a63d6f6ab93b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"x0pcPAwO","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x","y":{"dtype":"f8","bdata":"1PNnVDAK4D9pxyXE7uTZP7xDKUzCGrg\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"lmhvYfgT","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x2","y":{"dtype":"f8","bdata":"yVe1wAkn3j8KjCWFJxfcP7VwlOg6B7c\u002f"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"wgSNAXcA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x3","y":{"dtype":"f8","bdata":"TYnFAT565j8DEiEwP07NP5KRkZGRkbE\u002f"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"rgBYABQA","shape":"3, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZD1nOe3n4D+ZAaW7tmzbP\u002fAcZIx2G6Y\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"1ACpAC8A","shape":"3, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["adults","mixed","children"],"xaxis":"x2","y":{"dtype":"f8","bdata":"j9+Ze7sv1T9OIqR6yZTgP6u3Ox5jTcM\u002f"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"Cgc=","shape":"2, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003ecomposition=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003 ...

# %% [raw]
# :::
