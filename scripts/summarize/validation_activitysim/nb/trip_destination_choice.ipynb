# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["trip_destination_choice", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation4/c$/workspace/sc_asim_040112/output", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached", "survey 2025": "R:/e2projects_two/2023_base_year/2025_survey/activitysim_format/cleaned"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": True, "run_setup_emme_project_folders": True, "run_setup_emme_bank_folders": True, "run_copy_scenario_inputs": True, "run_import_networks": True, "run_skims_and_paths_free_flow": True, "run_skims_and_paths": True, "run_truck_model": True, "run_supplemental_trips": True, "run_abm": True, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# Parameters
# summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["mandatory_tour_frequency"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation3/c$/Workspace/sc_20251118/outputs", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 7, "9to15": 12, "15to18": 17, "18to20": 19, "20to5": 22}, "summer_list": [87], "pollutant_map": {"1": "Total Gaseous HCs", "2": "CO", "3": "NOx", "5": "Methane", "6": "N20", "79": "Non-methane HCs", "87": "VOCs", "90": "Atmospheric CO2", "91": "Total Energy", "98": "CO2 Equivalent", "PM10": "PM10 Total", "PM25": "PM25 Total", "100": "PM10 Exhaust", "106": "PM10 Brakewear", "107": "PM10 Tirewear", "110": "PM25 Exhaust", "112": "Elemental Carbon", "115": "Sulfate Particulate", "116": "PM25 Brakewear", "117": "PM25 Tirewear", "118": "Composite NonECPM", "119": "H20 Aerosol"}, "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
# input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_asim", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Trip destination choice
# date: today
# ---

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
# read data
trip_data = util.get_trip_data(summary_config)

# %% [markdown]
# ## trip distance

# %% [raw]
# :::{.panel-tabset}
#
# ### distance bins

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_distance_bin', title="share of trip by distance bin")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="10b02f63-8d5f-408e-bc6b-097f99beeb82" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("10b02f63-8d5f-408e-bc6b-097f99beeb82")) {                    Plotly.newPlot(                        "10b02f63-8d5f-408e-bc6b-097f99beeb82",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"+PYdADbaKQC9HzYAuTM8AKRlGAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15","dist_15_up"],"xaxis":"x","y":{"dtype":"f8","bdata":"a59dbaQ3wj\u002fLrn7Wz3HJPyETtRDec9A\u002f0EiyB9tM0j\u002fT86kWM6q9Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"\u002fixEG3gjrR7ZDA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15","dist_15_up"],"xaxis":"x","y":{"dtype":"f8","bdata":"8CNWc7AEyz9y7IjwttLIP\u002fWHy3sMls0\u002fjjVfvr6Hzz82ZOzDmhW+Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"QwAsALoAlgOcBg==","shape":"5, 1"},"hovertemplate":"source=survey 2025\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey 2025","offsetgroup":"survey 2025","orientation":"v","showlegend":true,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15","dist_15_up"],"xaxis":"x","y":{"dtype":"f8","bdata":"uMnlxneUlz9Km0PBLkOQP0XmRD\u002fuba0\u002fhuHe7iaS0T+x9VpwUCHkPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks ...

# %% [raw]
# ### 0 to 60-mile bins

# %%
df_plot = trip_data.loc[trip_data['trip_distance_bin_60mi'].notna()].groupby(['source','trip_distance_bin_60mi'])['trip_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['trip_weight']. \
    apply(lambda x: x / float(x.sum()))

fig2 = px.line(df_plot, x='trip_distance_bin_60mi', y="percentage", color="source", title="trip distance")
fig2.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig2.update_layout(height=400, width=700, font=dict(size=11), yaxis=dict(tickformat=".1%"))
fig2.show()
# Out:
# C:\Users\JLin\AppData\Local\Temp\ipykernel_9132\4263737271.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b22c06d4-a841-4d24-940a-58c09b13c5e5" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b22c06d4-a841-4d24-940a-58c09b13c5e5")) {                    Plotly.newPlot(                        "b22c06d4-a841-4d24-940a-58c09b13c5e5",                        [{"hovertemplate":"source=model\u003cbr\u003etrip_distance_bin_60mi=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","line":{"color":"#91268F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"model","orientation":"v","showlegend":true,"x":["8","2","0","4","6","12","16","56","10","24","58","18","14","26","20","38","22","34","42","52","40","28","36","30","32","48","46","50","54","44"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpdqslaKrT929oEU+mvJPxsn7iG61NU\u002fG6xvkGz8uz9Md+m5MuuzP3I5742LFqM\u002fOsx\u002fPsXWlj\u002f0dKXmRpAlP74h5AuevKc\u002fYO3ZImWRgD86MelN9GRSP1sd\u002fq1iB5I\u002f7zrI8IYbnj+s8bkamUx5P98q\u002f6A\u002f4os\u002fdpzCycycWj8dsUm1VCmGP9bpB9Ue+2I\u002fRh2uzincUT9rxOpyUy0yPyJ6V0KlelY\u002faZdcccqNcz+KNnaFrshePxPeJQzsSW4\u002frmrbh\u002fQXZz8JfXyW+y1BP29D5YMmYEc\u002flovGiChVOD9cqH9uW8cqP7zODxyc7Us\u002f"},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=survey\u003cbr\u003etrip_distance_bin_60mi=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","line":{"color":"#8CC63E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"survey","orientation":"v","showlegend":true,"x":["8","2","0","4","6","12","16","56","10","24","58","18","14","26","20","38","22","34","42","52","40","28","36","30","32","48","46","50","54","44"],"xaxis":"x","y":{"dtype":"f8","bdata":"es2k2UBQqj\u002f+mD43yNfFP6Y5cvK2Fto\u002fVa2RpJo3vD+VTE+EggawP5W\u002f7gAEkKE\u002ffVF6XqSJkD8dE+2R\u002f5E+P3I5C+11e6E\u002f3U9yYmfubT8lWOY8rlmKPziiSsdce5M\u002fCCIiTt9blj82P0Im8wN1P64L+gSPFYo\u002f\u002fX+K81kDWj86M9aJARN4Py64DkYikWo\u002fNeOLBo7KXz91stprXz0jP5LNt1bQ9Hw\u002fvvt3pZuicz9zbQOdC7dWP6KH41wSYHI\u002faMd9xHsXaD+3Yapoj\u002flCP0aHyhqp70M\u002fhyxpsaYAVj\u002fuVMT\u002filE5P+uOOLSCN0o\u002f"},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=survey 2025\u003cbr\u003etrip_distance_bin_60mi=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","line":{"color":"#00A7A0","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"survey 2025","orientation":"v","showlegend":true,"x":["8","2","0","4","6","12","16","56","10","24","58","18","14","26","20","38","22","34","42","52","40","28","36","30","32","48","46","50","54","44"],"xaxis":"x","y":{"dtype":"f8","bdata":"cGXpi8UspT+DN1d\u002fUe+bP1nTvj65L6Q\u002fA1LfWOmHrj+MCEuYOEqsP8pALPMyfqU\u002fVX\u002fGCixosD8MuB7g9AV5P6lCdqvxZ7A\u002fgYtwUUG2sD\u002f0PUtpPoWhP8SfvpsJMKs\u002fRR3yZCbDsj\u002fxrPwNm\u002fimP2CbktSmJac\u002fl63SGE69jz\u002f8iyzNaJqmPyBTWxbkjp8\u002fFoSBut5Pfj+xJtPNfFlnP3xn95HmDnc\u002fmDqSL\u002fX1pz+Yfmtn\u002fPuLP6tw+jwps5g\u002fcBaYXxUYqj+888nT4h2IP5z2SilprYY\u002fsv5jSCwIej8FUMWbB2xfPzT7MEvpLog\u002f"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb ...

# %% [raw]
# :::

# %% [markdown]
# ## trip destination by mode

# %%
util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_distance_bin", title="share of trip by distance bin and trip mode", 
                            facet_col="trip_mode", facet_col_wrap=2, height=1400, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="812f3d24-99cf-4d29-8a0f-de7504219636" class="plotly-graph-div" style="height:1400px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("812f3d24-99cf-4d29-8a0f-de7504219636")) {                    Plotly.newPlot(                        "812f3d24-99cf-4d29-8a0f-de7504219636",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ogUGAEFUEACVOhsAkasiANKUDgA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode=DRIVEALONEFREE\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15","dist_15_up"],"xaxis":"x13","y":{"dtype":"f8","bdata":"\u002fqmiF3wyrz980rhA\u002fSXFP5xHYk3rodE\u002fZtFVNIZz1j8AUe61gOLCPw=="},"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"miIQAKczBwCJFQIAQgAAAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode=WALK\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15"],"xaxis":"x14","y":{"dtype":"f8","bdata":"tfGdZWRP5D\u002fZlFR7ZCHSP+wWG0ey\u002fLQ\u002fL09AGPXEBD8="},"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"r4sCALSkBQBcUAgACwoJAO9bAwA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode=SHARED3FREE\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15","dist_15_up"],"xaxis":"x11","y":{"dtype":"f8","bdata":"Z6PBfHKMtj\u002f2apz0Z\u002f7IP0HFu8IdadI\u002f7qxz\u002fUwE1D\u002fyvUeZEsG9Pw=="},"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"FKwAAIvrAAAiRAEAEWEBACNOAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode=SCH_BUS\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15","dist_15_up"],"xaxis":"x12","y":{"dtype":"f8","bdata":"yy9384zwwj+j2Ka5w+zJP4X3CrZ01tE\u002flsUOMRRu0z+3+lwJOzOxPw=="},"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"C+YCAMdaCADrcgwAFiUNACaDBQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode=SHARED2FREE\u003cbr\u003etrip_distance_bin=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["dist_0_1","dist_1_2","dist_2_5","dist_5_15","dist_15_up"],"xaxis":"x9","y":{"dtype":"f8","bdata":"fEujS5GEsT\u002fu3roa5T7JPw ...
