# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtour_frequency", "atwork_subtour_destination", "atwork_subtour_scheduling", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["all_tour_mode", "all_trip_mode", "auto_ownership", "day_pattern", "escort_tour_mode", "escort_trip_mode", "households", "intermediate_stop_generation", "other_home_based_tour_mode", "other_home_based_trip_mode", "persons", "school_location", "school_tour_mode", "school_trip_mode", "telecommute", "time_choice", "tours", "tour_destination", "transit_pass_ownership", "trips", "trip_destination", "workbased_subtour_generation", "workbased_subtour_mode", "work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}, "output_dir": "C:/workspace/sc_6_22_26_asim_output", "data_dir": "C:/workspace/sc_6_22_26_asim_data"}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "uv_directory": "C:/workspace/uv_envs/activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Trip Mode Choice
# date: today
# ---

# %% [markdown]
# The trip mode choice models explanatory variables include household and person variables, level-of-service between the trip origin and destination according to the time period for the tour leg, urban form variables, and alternative-specific constants segmented by tour mode.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
# read data
person = util.get_person_data(summary_config)
hh = util.get_hh_data(summary_config)
trip = util.get_trip_data(summary_config)
tour = util.get_tour_data(summary_config)

# %%
per_data = person.merge(hh[['household_id','auto_ownership','auto_ownership_4+','log_hh_1','log_hh_1_group','source']],
                          how='left', on=['household_id','source']) # get auto ownership from hh data

trip_data = trip.\
    merge(tour[['tour_id', 'tour_mode', 'tour_mode_transit_agg', 'tour_type','source']], how = 'left', on=['tour_id', 'source']).\
    merge(per_data, how = 'left', on=['person_id', 'household_id', 'source'])

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_mode_transit_agg', title="Trip mode choice: all modes")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="8dcbcb38-801d-4b4a-b8f6-d0d89d4767d0" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8dcbcb38-801d-4b4a-b8f6-d0d89d4767d0")) {                    Plotly.newPlot(                        "8dcbcb38-801d-4b4a-b8f6-d0d89d4767d0",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"1ShgAPzNJAAaaxkAJigDAHBqGADoPgQAQ5UDAO\u002f3AQA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"xaxis":"x","y":{"dtype":"f8","bdata":"i3IsXVFw3z8d5bun6hDIPxT\u002fllvpnsA\u002fD4twJYGDkD89aWQRKu6\u002fP8gHJNW2NZY\u002f6f41b0m+kj8X\u002forGQJiEPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"pzp6G5IRrAOiIFgHOwG0ABAD","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"lGfB\u002fP4a3D9mW9pd7UHKPzRAds\u002fwIMY\u002f9MIGoCcEhj8MG8+lqQK8P1WO\u002fvfrDZw\u002fgZgRDjpRkT\u002f83t61E8FxPxz7Od3yuYw\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[ ...

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_mode_transit_agg', title="Trip mode choice: transit modes")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="22a2c1d0-4905-45ff-9c44-798fb38359f6" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("22a2c1d0-4905-45ff-9c44-798fb38359f6")) {                    Plotly.newPlot(                        "22a2c1d0-4905-45ff-9c44-798fb38359f6",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"1ShgAPzNJAAaaxkAJigDAHBqGADoPgQAQ5UDAO\u002f3AQA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"xaxis":"x","y":{"dtype":"f8","bdata":"i3IsXVFw3z8d5bun6hDIPxT\u002fllvpnsA\u002fD4twJYGDkD89aWQRKu6\u002fP8gHJNW2NZY\u002f6f41b0m+kj8X\u002forGQJiEPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"pzp6G5IRrAOiIFgHOwG0ABAD","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"lGfB\u002fP4a3D9mW9pd7UHKPzRAds\u002fwIMY\u002f9MIGoCcEhj8MG8+lqQK8P1WO\u002fvfrDZw\u002fgZgRDjpRkT\u002f83t61E8FxPxz7Od3yuYw\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[ ...

# %% [markdown]
# ## Trip mode choice by trip/tour type

# %% [raw]
# ::: {.panel-tabset}
#
# ### trip purpose

# %%
def trip_mode_choice_seg(segment_col, facet_col_wrap=3, height=[1200, 800]):
    """
    faceted bar chart showing trip mode share by segment
    """
    util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_mode_transit_agg", title=f'Trip mode choice by {segment_col}', facet_col=segment_col, facet_col_wrap=facet_col_wrap, height=height[0])
    util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_mode_transit_only", title=f'Trip mode choice by {segment_col}: transit only', facet_col=segment_col, facet_col_wrap=facet_col_wrap, height=height[1])

# %%
trip_mode_choice_seg(segment_col='purpose')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="a490600b-d902-439b-9a21-17eff76fe1c0" class="plotly-graph-div" style="height:1200px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a490600b-d902-439b-9a21-17eff76fe1c0")) {                    Plotly.newPlot(                        "a490600b-d902-439b-9a21-17eff76fe1c0",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"yr4WAPJjAwByzQEAhDEAACUVBAAacwAAz20AAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=work\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"A46uAoP+5T94TEqLRjq6P5LpBrNS46s\u002flR3Mq7Xwdz\u002fedbLnDpW\u002fP7hhJz0\u002f04s\u002f61VN3a6Lij8="},"xaxis":"x10","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"kEYFAI\u002fZAgBJEgEAazYAAN0jAQCUKQAAWBYAAIQRAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=othmaint\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Xec9mn4R3z+ntAZJY8jQP4+QaE0WPbk\u002fUS1c0n8HlD84NIS6KNu6PzKIr5NYm44\u002fhuXd5KZygD8JIoF1mMl5Pw=="},"xaxis":"x11","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"SREIAGGCAwBK2wEAA3EAAO\u002fpAgBJRAAAdxUAAHMoAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=social\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"NuWnt5LZ3T96k10EBfjJP3BFUXNLers\u002fNXUbPk8imj8Lf3bv64\u002fFP7OrC0n7lI8\u002fOVNCEuPacz\u002fMRdTkMrWCPw=="},"xaxis":"x12","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"7MghANsKDgDNvgkAgmEBAJv4BwB3rgEA7mwBAEPIAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=home\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"CtWSV7SI3j8WV3bg5mHJP8C4Ytt9ncE\u002fyfjzeuH3kz8QniU6BNG8P4bVOLy2UJg\u002fyAJc0wudlD+VztVpv5+GPw=="},"xaxis":"x7","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"SKwJAFQFAwBYbgEAASgAAL5NAgAkUwAAzhUAAKgfAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=shopping\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b1944bae-3244-4279-af3b-ca721d8d427a" class="plotly-graph-div" style="height:800px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b1944bae-3244-4279-af3b-ca721d8d427a")) {                    Plotly.newPlot(                        "b1944bae-3244-4279-af3b-ca721d8d427a",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"wjwKJRgNNgIAAg==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=work\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"3RHsJkDk4D8vd0lsSJjUP1LtvmRCH70\u002fyNHz8Gmrkz9uyvbZAMuRPw=="},"xaxis":"x10","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"mB0yCxgAaABKAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=othmaint\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"VP\u002f6I8LG5j+J1oLwjDvRP1Dmru6jeGI\u002fLCTol7EChD9m+KK6\u002fHl8Pw=="},"xaxis":"x11","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"AzG0D70CgQBUAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=social\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"0VxOUdD35j+T\u002fJmFdW\u002fNP5S4pJATiKQ\u002fdCMzfOc5fj8KHTmkoq5zPw=="},"xaxis":"x12","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"jBwBAAN2AABFEQAA2QYAAMoDAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=home\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"0oNoThgn5T+8tt1QqovRP12og9JjiqQ\u002f3Rap+xNKkD\u002fNZMcI6waCPw=="},"xaxis":"x7","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"LzmRGBYAngCwAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=shopping\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"4sX30mcC5j8gKM6rJenSP9FdUtBm71A\u002fFbTZOwRofj\u002fRXVLQZu+APw=="},"xaxis":"x8","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y8" ...

# %% [raw]
# ### tour mode

# %%
trip_mode_choice_seg(segment_col='tour_mode_transit_agg', height=[800, 400])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="439712e3-832d-4d5f-96b8-c42f250898d7" class="plotly-graph-div" style="height:800px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("439712e3-832d-4d5f-96b8-c42f250898d7")) {                    Plotly.newPlot(                        "439712e3-832d-4d5f-96b8-c42f250898d7",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ZndOAI0kAgA1KQAA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=DRIVEALONEFREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"6nn6oFgW7z9o9MEogCqbP\u002f1ydr9dU2A\u002f"},"xaxis":"x7","y":["DRIVEALONEFREE","WALK","SCHBUS"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"kVQNAPn+IADLugAAx7cBAJygAgA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=SHARED2FREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"tcpaygGZ0D+sasQysIrkP3qnXjN3Eo0\u002fRhhRLI4coT9yPbqHwiuqPw=="},"xaxis":"x8","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","WALK","SCHBUS"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"MVEEADtFAgA5PBcARoQAAAgrAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=SHARED3FREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"fRo80QUdwj\u002fap5mXTg2zP\u002f5UxFszX+g\u002fTtL\u002fRc9XkT9harhkcZF2Pw=="},"xaxis":"x9","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","WALK","SCHBUS"],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"5UUCAF0HAAAsBQAA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=BIKE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"M5wR4j9T7z+s3Xw4bV6JP4UVHEOa0YE\u002f"},"xaxis":"x4","y":["BIKE","WALK","SCHBUS"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"9mATAAQ0AAA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=WALK\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"p1Rxiv+q7z9H1qpjHUCFPw=="},"xaxis":"x5","y":["WALK","SCHBUS"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"AiIAAKUNAABAMgAAT\u ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="56af99d0-8361-42ba-9492-08ae0f861e6d" class="plotly-graph-div" style="height:400px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("56af99d0-8361-42ba-9492-08ae0f861e6d")) {                    Plotly.newPlot(                        "56af99d0-8361-42ba-9492-08ae0f861e6d",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"saQBAJsSAQBPIQAAnw8AABUJAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=ALL_TRANSIT\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"CgAt2+Pe4T\u002fgO98kgFTXP\u002ftm2SuIo6Y\u002fjvkpxPw7lT+O8h5h6rCIPw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"pG8SFXEADAA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=TNC\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"+ATuOBvS6j8di+otdD\u002fEPy7m1N61JWs\u002fJdEaxC0QNz8="},"xaxis":"x2","y":["WALK_LOC","WALK_LR","WALK_COM","WALK_FRY"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hQVbADwAEQARAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003etour_mode_transit_agg=ALL_TRANSIT\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"DXYSdExi7D9w5Na\u002fUgyLP59mqjhq+6g\u002fep9QQHsImD9mXyBs+DCcPw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"c ...

# %% [raw]
# ### tour purpose

# %%
trip_mode_choice_seg(segment_col='tour_type', height=[1000, 600])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="aa74f87b-d72b-41f5-bb75-460465d35a63" class="plotly-graph-div" style="height:1000px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("aa74f87b-d72b-41f5-bb75-460465d35a63")) {                    Plotly.newPlot(                        "aa74f87b-d72b-41f5-bb75-460465d35a63",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"57MEAKlnBABPAQEAx1cAAOchAQAtIAAA5QkAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=othmaint\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"zRp0YxKc2T+XYs2G4fzXP8OL75\u002fi5LU\u002f0LzjeB\u002fgnT\u002fJjdTG3aq4P3e\u002fcjED54U\u002fODjVefXwaj8="},"xaxis":"x10","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"Q8UKAFcBAwBF6gAAyi4AACgQAwDCZgAApRoAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=shopping\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"d1MR2T+w4j87mAdSqtvEP6IWdczdZ6k\u002fz7ixa+RLhD9F2Xfxf0LFP7VswVaXSZY\u002f8zpWcbYddz8="},"xaxis":"x11","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"WZ4CALzKBQBppwUASAsAANDdAAALnQAAXQUAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=escort\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"PLZL6P54xT+71ukJX7\u002fXP0je0sKJLtc\u002fZ23cXY4gZz\u002fGJ2tQpGusPwYKOSwlH6Q\u002fmMowzXL9VT8="},"xaxis":"x12","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"AI4QAPYPBwCrbQMAPd0AALu\u002fBQB\u002feQAA1FEAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=social\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"hzcNK5DA3j+2pUKc+zzKPyrbJBd4ebk\u002fF5DQ4ZmvmT\u002fKUPiPz1vFPygmh50qNow\u002flIdawCgAgz8="},"xaxis":"x7","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ZN8tAD4\u002fBgCi\u002fQIArmcAAMBtBAAN1wAAo+wAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=work\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgro ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="cd9bd599-77e9-40f5-86cc-0d21cdeac819" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cd9bd599-77e9-40f5-86cc-0d21cdeac819")) {                    Plotly.newPlot(                        "cd9bd599-77e9-40f5-86cc-0d21cdeac819",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"DBfLCDgAHgA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=othmaint\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"4T29c8Tr5j+BOD6mZ33RP3pOjxHX2Hs\u002fy0GHAAvWbT8="},"xaxis":"x10","y":["WALK_LOC","WALK_LR","WALK_COM","WALK_FRY"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"pEW1H6MAxgA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=shopping\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"lolDstmv5T9cHK+7db\u002fTP0ICDPdLYXk\u002f3xto+2vUfj8="},"xaxis":"x11","y":["WALK_LOC","WALK_LR","WALK_COM","WALK_FRY"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"g2ryLbUC4QE=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=escort\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"ymHpnxW05T+Aq0GFY7nSP+98lFu2ppE\u002fpCNJprqAiD8="},"xaxis":"x12","y":["WALK_LOC","WALK_LR","WALK_COM","WALK_FRY"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"EVYFHS4FvQB+AA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=social\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"29xR2h2r5j8U7YQWsJLOPzvcBcju06U\u002f9W4pqsLjeD9Onxsc15dwPw=="},"xaxis":"x7","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"wW7lRW0ZhwRzBA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_type=work\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"x43DIvx64D\u002fbjjvYB83UP0nK2slrRL4\u002fv0yoW8WOlT+b48GgiS+VPw=="},"xaxis":"x8","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"aBe1Cv8BKAAoAA==","shape":"5 ...

# %% [raw]
# :::

# %% [markdown]
# ## Trip mode choice by segment

# %% [raw]
# ::: {.panel-tabset}

# %% [raw]
# ### person type

# %%
trip_mode_choice_seg(segment_col='ptype_label', facet_col_wrap=2, height=[1000, 700])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="bbab8aa8-fea7-42c3-891d-0cc22cd85fa9" class="plotly-graph-div" style="height:1000px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bbab8aa8-fea7-42c3-891d-0cc22cd85fa9")) {                    Plotly.newPlot(                        "bbab8aa8-fea7-42c3-891d-0cc22cd85fa9",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"xOA7AM1wDQDL7gcARRQBAHyjDABoiAEAeyQBAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"XfnnYYif4z+9t0+4d57BPyV39qY9zLQ\u002fVvQ2wnyihj+FIauyUpHAP0SdtOwrE5A\u002fkiwAA3\u002f2hz8="},"xaxis":"x7","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"zUAKAMoqAwAAzwEAVjwAAGsPAgBpVAAARSgAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"chIhuEA34j\u002fOuA+j1IHGPyI0qTmStLk\u002fqziOOWPMij+OBf4aI0i9PyB0ZPHZvpI\u002fO+guBcbigT8="},"xaxis":"x8","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"0f8DAIYwAQBtfwAA6SIAADRmAQBclQAAwBEAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=3: University Student\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"6v0wRUtA4D9ygws5vlXDP1pfoo9fLrA\u002fi14seHS7kT9X0I6NQb7GPxbRg69k97I\u002fWAiRYCcIgj8="},"xaxis":"x5","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"vCMKAEWeBQD1UwMAA0cAAH2WAgCqYQAA4hsAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=4: Non-Working Adult Age \u003c65\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"8zUrpbDq3D9Nwk39wAXQP68L5jlW+8I\u002fKRelEYNQiT97QUKQUIW9P5tFdy9maJE\u002fvx21Pyjhcz8="},"xaxis":"x6","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"buoJACqdAwDU0gEA30AAANWOAgDvPgAA7hkAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=5: Non-Working Adult Age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="329d0435-b27d-4ce4-8d46-50ffbc2a55f0" class="plotly-graph-div" style="height:700px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("329d0435-b27d-4ce4-8d46-50ffbc2a55f0")) {                    Plotly.newPlot(                        "329d0435-b27d-4ce4-8d46-50ffbc2a55f0",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"OvEAAE93AAByFgAADgUAAF8EAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"ov6Oguyr4z+gfSYgc3XTP+hFR7g1Sa0\u002fmTYypX1hij8zVSHRJtCGPw=="},"xaxis":"x7","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"MTRMGXwEFAFcAQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"n8xIJyzJ4z8fNRy7Hi7TP6i93ypVM6s\u002fB2\u002fEA3Ioij9jZ4ENrH2QPw=="},"xaxis":"x8","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"gUxYRFEBPQL1AA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=3: University Student\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Ejar0Q1k4D9bpNF0+kjdP3nPC5HoDII\u002f\u002fiNAY+qwjj9A+WMN1D56Pw=="},"xaxis":"x5","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"VEEQG88CZgERAQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=4: Non-Working Adult Age \u003c65\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"NAX6k65n5T8Zjb6L+LvRP0Rlc4mocp0\u002fou4PHjRTjT\u002ffVrZYxFyGPw=="},"xaxis":"x6","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hytAEPMBnQCYAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=5: Non-Working Adult Age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"MR1dpOgh5j++ViOwfYbQPxz++NZJt58\u002f2mJ9oyH1gz8Nfd6Sa1KDPw== ...

# %% [raw]
# ### household density

# %%
trip_mode_choice_seg(segment_col='log_hh_1_group', height=[600, 500])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="bfa350fc-d368-43a2-91c2-e38ef4f69f3f" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bfa350fc-d368-43a2-91c2-e38ef4f69f3f")) {                    Plotly.newPlot(                        "bfa350fc-d368-43a2-91c2-e38ef4f69f3f",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"pJAOAAqnBQA24wMAtzQAACN4AQBIFwAA\u002f5EAAN4gAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"FmZ\u002fWKuK4T9u0Cx5FzvLP7qNv2ZqusI\u002f2JlViH++fz+RhN+DIlCsPwYtqjEOCmw\u002f8Ntwk6z6lT9369a0yspzPw=="},"xaxis":"x4","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"owwOAE6vBQBECwQAkVUAADo7AgDtPgAAbpkAACctAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"rReKiMht4D8SXckRIpfKP47UNodq6sI\u002fwy98Db0DiT9ss00ZyN+0PyseNORTZYI\u002fyGcE+Uptlj+ng6A+WWZ6Pw=="},"xaxis":"x5","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ZTgbAK8DCwD0wwcAtb8AAAf6BAD8swAA4yABANFjAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"2Qz5Nngl4D911d4lQCLKP+3SJrTObMI\u002fiU4Qb8xtjD8UHlcFwp23P\u002fj4LhbFsIo\u002fHDD9kIVrlT9mVt+er5p9Pw=="},"xaxis":"x6","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"BvkXAJ4aCQBbPAYABs0AAKHyBQDoBwEAMdsAALNzAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium-high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"hfg+6gqz3z\u002fa73PZlxPIP0g\u002fakfAfcA\u002f9eLWiqvxkD\u002fi2mOAi3W\u002fP8jvJV5zz5U\u002fRjlnymsdkj8zDldArx+DPw=="},"xaxis":"x","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"I1oQAFdZBQBRfAMAIxEBAGvKCQDPLAIAwm0AAGbSAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_ag ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e31996bb-1693-4691-a838-bc220e6b1dc0" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e31996bb-1693-4691-a838-bc220e6b1dc0")) {                    Plotly.newPlot(                        "e31996bb-1693-4691-a838-bc220e6b1dc0",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"iBDlAv0CWACGAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AfUfq9645j9HCZ0fBNS\u002fP85o97D1bcA\u002fGZ8JRCo9jj\u002fFJM1z1wWXPw=="},"xaxis":"x4","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"My0WC14EcQHVAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"bmD880P85j93b8Jp5YzGP+m0qKhXxLE\u002fy5I308l0lz8aIAx5WxSLPw=="},"xaxis":"x5","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"PoAAAPQhAACbCgAA2QQAAFYCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"SKTgfPPM5j\u002fLxJetgyXIP4CN30tWK64\u002f60QdJYaUmz934aF0gJSKPw=="},"xaxis":"x6","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"PrgAAMA6AADZCwAAgQYAAJACAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium-high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"gpRhMR9X5j92uJcvtn7MP9MPrnpF\u002fKY\u002ffmmI3Hk8mT\u002fnRVYKx+KDPw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"gWMBAP68AACDBgAA7QIAAOACAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"tQSeUlJu5D+\u002fc8BHELnVP54Ye01m84c\u002fetH+zcyFdT\u002fXsutXKyZ1Pw=="},"xaxis":"x2","y":["WALK_LOC" ...

# %% [raw]
# ### auto ownership

# %%
trip_mode_choice_seg(segment_col='auto_ownership_4+', height=[600, 500])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="7cbddcf7-4419-4cec-ad0e-083eb0b96f6b" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7cbddcf7-4419-4cec-ad0e-083eb0b96f6b")) {                    Plotly.newPlot(                        "7cbddcf7-4419-4cec-ad0e-083eb0b96f6b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"RMMAAPepAAArYQAAhVgAAJ4pBABOUAEAchcAANV0AAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"YD3XPdDhtz9\u002fblrSo8m0P1zWlGe0xKc\u002foldAqiKnpT\u002f5JwpVl0rgPy27497jkMQ\u002fQsMec6Dwhj8uXc7kE5SsPw=="},"xaxis":"x4","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"PfQWAPotBwDaowQAdPEAAD1CBwAxAwEAApkAAENtAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Zn4Hun1R4D\u002fOMzPYj2rEP\u002fUNGgGrY7o\u002fyg\u002fvgd10lT+pOUzbLaTEP3GYIZ9lCJc\u002fYggRRpwxiz+mxia1O2uDPw=="},"xaxis":"x5","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"hL4sALY4EgCRwwwAwUcBAELjCACiWQEAqNIBAFS0AAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"3YIXFtfl3z+c6Nld4PrJPx5OGifZMsI\u002fSjXVSug0jT92jk31Dli5P4xpW2fFzI4\u002fwl2tJtDKlD+yatRDvxGAPw=="},"xaxis":"x6","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"U78TAO6lBwBPcQUATXAAAGIHAwDpawAA98UAAKFIAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"0EMdc2654D8HfA1uzejJP\u002fpKFLcOcMI\u002fRDmb9P3Ghz9Hf3Tzd4W0P\u002fqimEEC2YY\u002fLU3QQhr1lD8zVjQeWcF+Pw=="},"xaxis":"x","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ffMHAGcXAwA1MQIAHyYAAPETAQDeJQAAMEwAAOIYAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d4dc6c08-bb25-4b37-aab0-0b45d7cbc8a0" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d4dc6c08-bb25-4b37-aab0-0b45d7cbc8a0")) {                    Plotly.newPlot(                        "d4dc6c08-bb25-4b37-aab0-0b45d7cbc8a0",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"VdIAALN1AAA5BAAADQQAAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"JgBBAnMD5D8o9xjWCWbWP+NH+J37tok\u002flMmoDgmriD8="},"xaxis":"x4","y":["WALK_LOC","WALK_LR","WALK_COM","WALK_FRY"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"4KgAANFHAAAqDQAAjwMAAMcBAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"wv9u\u002fnXZ5D\u002fRFH0cqLvRP+ahJcYCAao\u002fmQTYakMejD+T0l2iXBZ8Pw=="},"xaxis":"x5","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"vfgAAPNKAACHDgAARQUAACYCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"QWXGcnUH5z\u002fFKlEln8HLPwylhUgbhaU\u002fNtZVrlA5jz9fMs9R5nV5Pw=="},"xaxis":"x6","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"8kuGFm0GOgLKAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Zt6ZhGOF5j+goBOqd7fKP7jPSesCfa4\u002fSIu6rvEglT8yDmRbavN9Pw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"1BmwCDQCyQBdAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"YdYrXofT5T9nvsWgpF3NP02\u002fxoPPya0\u002fHm3yDms7lT\u002fAqa47yqWDPw=="},"xaxis":"x2","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"ya ...

# %% [raw]
# :::
