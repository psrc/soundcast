# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation4/c$/workspace/sc_asim_040112/output", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached", "survey 2025": "R:/e2projects_two/2023_base_year/2025_survey/activitysim_format/cleaned"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": True, "run_setup_emme_project_folders": True, "run_setup_emme_bank_folders": True, "run_copy_scenario_inputs": True, "run_import_networks": True, "run_skims_and_paths_free_flow": True, "run_skims_and_paths": True, "run_truck_model": True, "run_supplemental_trips": True, "run_abm": True, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# Parameters
# summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["mandatory_tour_frequency"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation3/c$/Workspace/sc_20251118/outputs", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 7, "9to15": 12, "15to18": 17, "18to20": 19, "20to5": 22}, "summer_list": [87], "pollutant_map": {"1": "Total Gaseous HCs", "2": "CO", "3": "NOx", "5": "Methane", "6": "N20", "79": "Non-methane HCs", "87": "VOCs", "90": "Atmospheric CO2", "91": "Total Energy", "98": "CO2 Equivalent", "PM10": "PM10 Total", "PM25": "PM25 Total", "100": "PM10 Exhaust", "106": "PM10 Brakewear", "107": "PM10 Tirewear", "110": "PM25 Exhaust", "112": "Elemental Carbon", "115": "Sulfate Particulate", "116": "PM25 Brakewear", "117": "PM25 Tirewear", "118": "Composite NonECPM", "119": "H20 Aerosol"}, "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
# input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_asim", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Trip Mode Choice
# date: today
# ---

# %% [markdown]
# The trip mode choice models explanatory variables include household and person variables, level-of-service between the trip origin and destination according to the time period for the tour leg, urban form variables, and alternative-specific constants segmented by tour mode.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
# read data
person = util.get_person_data(summary_config)
hh = util.get_hh_data(summary_config)
trip = util.get_trip_data(summary_config)
tour = util.get_tour_data(summary_config)

# %%
per_data = person.merge(hh[['household_id','auto_ownership','auto_ownership_4+','log_hh_1','log_hh_1_group','source']],
                          how='left', on=['household_id','source']) # get auto ownership from hh data

trip_data = trip.\
    merge(tour[['tour_id', 'tour_mode', 'tour_mode_transit_agg', 'tour_type','source']], how = 'left', on=['tour_id', 'source']).\
    merge(per_data, how = 'left', on=['person_id', 'household_id', 'source'])

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_mode_transit_agg', title="Trip mode choice: all modes")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1686f676-4803-4b33-86fb-0356f0a0d4ba" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1686f676-4803-4b33-86fb-0356f0a0d4ba")) {                    Plotly.newPlot(                        "1686f676-4803-4b33-86fb-0356f0a0d4ba",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"29RiAPlbKgC55hwAM2MDAAxsGQDLTwUA9YoEALzIAQA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"xaxis":"x","y":{"dtype":"f8","bdata":"qqOkSvQK3j92J2Sps8DJP1zOX6cgksE\u002fqf7rlMd5kD+m85a7Q+m+PzSUFBqZ1Zk\u002f2nJ8QkAYlj8AhXrf0VqBPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"pzp6G5IRrAOiIFgHOwG0ABAD","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"lGfB\u002fP4a3D9mW9pd7UHKPzRAds\u002fwIMY\u002f9MIGoCcEhj8MG8+lqQK8P1WO\u002fvfrDZw\u002fgZgRDjpRkT\u002f83t61E8FxPxz7Od3yuYw\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hwXYAUUBJQCoAIkA+QAOAFoA","shape":"9, 1"},"hovertemplate":"source=survey 2025\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey 2025","offsetgroup":"survey 2025","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"sZloFsEs4T9DKVz1Pf3GPyl+u8FvOLo\u002fmtS7DDltmT\u002fhZg6D5yOlPze7JAysCqE\u002f0CxrrmRCqj8F+aE0QxaCPzAY1F7jQZY\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333 ...

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_mode_transit_agg', title="Trip mode choice: transit modes")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d95ffa5a-b22b-4907-b520-7a907ce783a4" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d95ffa5a-b22b-4907-b520-7a907ce783a4")) {                    Plotly.newPlot(                        "d95ffa5a-b22b-4907-b520-7a907ce783a4",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"29RiAPlbKgC55hwAM2MDAAxsGQDLTwUA9YoEALzIAQA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"xaxis":"x","y":{"dtype":"f8","bdata":"qqOkSvQK3j92J2Sps8DJP1zOX6cgksE\u002fqf7rlMd5kD+m85a7Q+m+PzSUFBqZ1Zk\u002f2nJ8QkAYlj8AhXrf0VqBPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"pzp6G5IRrAOiIFgHOwG0ABAD","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"lGfB\u002fP4a3D9mW9pd7UHKPzRAds\u002fwIMY\u002f9MIGoCcEhj8MG8+lqQK8P1WO\u002fvfrDZw\u002fgZgRDjpRkT\u002f83t61E8FxPxz7Od3yuYw\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hwXYAUUBJQCoAIkA+QAOAFoA","shape":"9, 1"},"hovertemplate":"source=survey 2025\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey 2025","offsetgroup":"survey 2025","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"sZloFsEs4T9DKVz1Pf3GPyl+u8FvOLo\u002fmtS7DDltmT\u002fhZg6D5yOlPze7JAysCqE\u002f0CxrrmRCqj8F+aE0QxaCPzAY1F7jQZY\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333 ...

# %% [markdown]
# ## Trip mode choice by segment

# %% [raw]
# ::: {.panel-tabset}
#
# ### trip purpose

# %%
def trip_mode_choice_seg(segment_col, facet_col_wrap=3, height=[1200, 800]):
    """
    faceted bar chart showing trip mode share by segment
    """
    util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_mode_transit_agg", title=f'Trip mode choice by {segment_col}', facet_col=segment_col, facet_col_wrap=facet_col_wrap, height=height[0])
    util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_mode_transit_only", title=f'Trip mode choice by {segment_col}: transit only', facet_col=segment_col, facet_col_wrap=facet_col_wrap, height=height[1])

# %%
trip_mode_choice_seg(segment_col='purpose')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="437fdf81-6044-4e49-924f-24ee6eb262c7" class="plotly-graph-div" style="height:1200px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("437fdf81-6044-4e49-924f-24ee6eb262c7")) {                    Plotly.newPlot(                        "437fdf81-6044-4e49-924f-24ee6eb262c7",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"kOQTAAbNAgCMfwEAfjEAAIPmAwDmfQAAY1IAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=work\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"\u002fofE3zPg5T\u002fo9p1i\u002fKO4PxUUOD56XKo\u002f5\u002fZDVn02ez\u002fnQ2seLyjBP394ErNYTpE\u002fAM4SCVqmhj8="},"xaxis":"x10","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"G8kGAA3uAwCcXgEAckkAACFfAQCfOQAArhsAAEUUAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=othmaint\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"fRq9Qpmt3j\u002fudUeBcMTRP6+DDHGJxLg\u002f3V2kjtbAlD9d+W+o7s24P5i2NQQoSJA\u002fVqZgZhlJfz9hHEu1+eh2Pw=="},"xaxis":"x11","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"3HwCAPE0AQDp0QAApB0AAI+9AAC0HAAAABsAAIcMAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=social\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"N\u002fNceUY+3D+C8YSE1WbLP0lwOSU6nsI\u002fRbt0FSsIlT+4OWi1H9DAP3BeqH\u002ffXZQ\u002f7tcw2oAokz+0\u002fVsDJMeBPw=="},"xaxis":"x12","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"os8iAJY\u002fEAB2LAsAK3gBAKB3CAAmHQIAgM8BAAmuAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=home\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Rn\u002ff+94E3T8a4LmX\u002fBbLP2ZQ1+MLocI\u002fR1ZBskSZkz8sKaHt2zu8P889H2PAMZw\u002f+nqDyxYmmD\u002fcpyucgSKCPw=="},"xaxis":"x7","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"TlgNANaiBAD58gEABzkAAMFDAwBZhAAADBwAAHYmAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=shopping\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esam ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c9635206-e741-4074-b6d6-3cbd0a36f0cd" class="plotly-graph-div" style="height:800px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c9635206-e741-4074-b6d6-3cbd0a36f0cd")) {                    Plotly.newPlot(                        "c9635206-e741-4074-b6d6-3cbd0a36f0cd",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"lzjmJnkH9QD7FQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=work\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"oteei2nE3D9hN5awHMbTPx+BwC67Y64\u002fFe9yj94ifz85KmrH7VjGPw=="},"xaxis":"x10","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"CyaIDiwAQwCdBA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=othmaint\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"BYQXK5Mg5T\u002fH7aX50SPQP+30wah8b2g\u002fe9pNRrOacj9xOwGn9360Pw=="},"xaxis":"x11","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"MRQtBmgAJgDIAQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=social\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"TKpirLeC5j\u002fz3z3UYYrLP1fQbRyE\u002fIw\u002fQBjaT68udT9fJMf3BsavPw=="},"xaxis":"x12","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"rEwBAD6LAAA6DgAAzAQAADYyAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=home\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"uz9Mkwus4z9DWynOvnfQP\u002f9EgYWn65o\u002fyel4fGsngj+iJgnc0MC3Pw=="},"xaxis":"x7","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"+lS5JCwAkQDpCQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=shopping\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"KvCvA9iL5D+7ZahZFsLRP4IiUb78RlU\u002fnQadIpOHcT\u002fR0rtWUSuzPw=="},"xaxis":"x8","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y8","typ ...

# %% [raw]
# ### person type

# %%
trip_mode_choice_seg(segment_col='ptype_label', facet_col_wrap=2, height=[1000, 700])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="678b00ed-f77a-444f-aa3c-888c3e11ebca" class="plotly-graph-div" style="height:1000px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("678b00ed-f77a-444f-aa3c-888c3e11ebca")) {                    Plotly.newPlot(                        "678b00ed-f77a-444f-aa3c-888c3e11ebca",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"CmA4AGZnDQBZxQcAVvoAAE\u002fhCwDtzgEAgvQAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"qFX2Ebtc4z8fx7OMGWrCP4KWB777WbU\u002fyUmY4qJ+hT8UbBx2MFLAP8TT\u002faTJ35M\u002fdr2WOIf+hD8="},"xaxis":"x7","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"m7sKAL7kAwDBHQIAYT4AALciAgB5bQAAESIAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"aYhpKhJz4T\u002fOPEO6CFLJPzXqIUJKhrs\u002f7RPq0J5aiT9fdyRw0Ma7P\u002fhnegFmP5Y\u002f0lCwtlKxez8="},"xaxis":"x8","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"yfgDAJZSAQA5tQAAkB0AABldAQA2qgAAXA4AAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=3: University Student\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"JUVtaIb93j\u002fa6TQ5rKPEP1hpP0UAGLY\u002fLXCxQTjVjD8xvweXtUfFPxQCvKBSwLQ\u002fS\u002f7\u002f+YwCfD8="},"xaxis":"x5","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"WXoMANgrBwCjkQQAn1AAAPAVAwAopQAAiRwAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=4: Non-Working Adult Age \u003c65\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"8D9Kdcsk3D\u002fvS6uStizQP3QqkqAwnMQ\u002fZuGdzty6hj9hS6emwta7P2HXO7McSJc\u002fceO3GxMXcD8="},"xaxis":"x6","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"w88MAIqWBABK4gEAA1IAAD7JAgBQVwAAUxcAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=5: Non-Working Adult Age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esam ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="14dbe3ca-1fb4-49f1-a29b-b17d25eff69c" class="plotly-graph-div" style="height:700px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("14dbe3ca-1fb4-49f1-a29b-b17d25eff69c")) {                    Plotly.newPlot(                        "14dbe3ca-1fb4-49f1-a29b-b17d25eff69c",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"Q\u002f8AAGOGAADoDgAAcAIAAO83AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"J0SKvSWl4T9iTGCxQJTSP\u002fppMZmHfKA\u002f8LoOMTKRdT+RDINeeO6+Pw=="},"xaxis":"x7","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"BkFyHkkCrQALCw==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"sVNmrswB4z9aBeb7iMzRP2mOaicNYJU\u002f3BUfHexIeT8VuIiR5NK5Pw=="},"xaxis":"x8","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"qVEZTKQAIQKvCQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=3: University Student\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"5szGS1203j\u002fB7JFH75zcP6kkcKgT1W4\u002fSc1TrIKdiT8sPZ5\u002f6SCtPw=="},"xaxis":"x5","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"2mgtKqQBTAExDw==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=4: Non-Working Adult Age \u003c65\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"ydzK1MtQ5D8Qk1QW91fQP6NgUbAoWIQ\u002fGrqm9uwUgD8jyndLIoy3Pw=="},"xaxis":"x6","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"DTTAFN0BZQBBDA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eptype_label=5: Non-Working Adult Age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"XMU\u002flJsT4z+EKrhnYmvOP18YLyNA2pU\u002fcgrLfBuCcj+shP ...

# %% [raw]
# ### household density

# %%
trip_mode_choice_seg(segment_col='log_hh_1_group', height=[600, 500])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="2289a4cf-75da-4c8c-84e3-629dda529207" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2289a4cf-75da-4c8c-84e3-629dda529207")) {                    Plotly.newPlot(                        "2289a4cf-75da-4c8c-84e3-629dda529207",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"MrgOAIqDBgCncQQAjj0AALGTAQCWNAAAubYAACMaAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"CJKXsZeE4D9U1ENKHT3NP1U+ug6a8sM\u002feJPxw9NEgT\u002f2tPyxOlCsP6AHulxkgX0\u002fukJDgIahmT9xi8k9gVRtPw=="},"xaxis":"x4","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"vGcOAEOaBgALmwQAo14AAOxgAgBMXQAAor4AAEwmAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"ONmPgvwf3z\u002fA9RJCNIjMP5PM4S8N58M\u002f3wMgoVOPiT9YSIgbuY60P0nZchawMok\u002fWWYJQVK+mT9pjqHxzq90Pw=="},"xaxis":"x5","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"uA0cAEu8DAAn4AgAMNAAAIpNBQAU8QAAIWsBAOhWAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"bIbziYuz3j+j9opaA+DLP\u002fuZMMM0bcM\u002fOtd4LcZ6jD\u002fXBu2Qqja3Pz7Gz0FOfZA\u002fko3UzG3WmD8b5lgn9MZ3Pw=="},"xaxis":"x6","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"7u0YADhpCgCYFAcAGeAAAERABgCzVQEA2iABANhoAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium-high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"LdhIzcJv3j8Q2V3X+2vJP+NFh\u002fYGSsE\u002fX82jDaYZkT8tA4XRHoe+P9OSOXTxEpo\u002f+E5\u002fa5YKlj9ck7ERJwCAPw=="},"xaxis":"x","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"R7kQAKkYBgBI5QMAuRYBAKHpCQAidwIAn4kAAI3IAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fae68b6c-6476-4246-a328-af90d1854bfe" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fae68b6c-6476-4246-a328-af90d1854bfe")) {                    Plotly.newPlot(                        "fae68b6c-6476-4246-a328-af90d1854bfe",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"YRRaBbQEQQDmFQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"mY0\u002fy2DN2D8jinCzdg26P4TE08BW5bY\u002fAK7DVfPGcz8FUFgK0KbaPw=="},"xaxis":"x4","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"wjcODr0EGgGlEQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"sj379Nof4z+GPWcIVEjDP6BhGZDFAKo\u002fbuHyxU0uiD8zRUbjKTXIPw=="},"xaxis":"x5","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"E6AAAN4oAAA4CQAAiwMAAGAbAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"eh8rhW4\u002f5T+61G+8x7LFP\u002fmwXrEmlKM\u002fPwhD2B4Zjj86oQ8qxRG9Pw=="},"xaxis":"x6","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"heAAAJ9MAAAuCAAA2QQAAIgbAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium-high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"XXNn6bIG5T8136asv7PMPywiDPpFg5g\u002f6Deb5gYOjT8pNyAAV6C0Pw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"MoIBAJfWAAAnBAAArQEAAIUYAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"3\u002fE6Z8CU4z+IifiCrsLVPzMBtVHI8no\u002fQ\u002fltcFnAZT8cFk\u002fTJuSjPw=="},"xaxis":"x2","y":["WALK_LOC","WAL ...

# %% [raw]
# ### auto ownership

# %%
trip_mode_choice_seg(segment_col='auto_ownership_4+', height=[600, 500])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ed031ea4-b4e5-4257-b774-1400b2466bbb" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ed031ea4-b4e5-4257-b774-1400b2466bbb")) {                    Plotly.newPlot(                        "ed031ea4-b4e5-4257-b774-1400b2466bbb",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"pssAAAKzAADhUwAAylMAABXqAwAjOwEA+R8AAHNzAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"wYAobJffuT+vnTwDKr62P6vx6A5DUKU\u002fogfJ7GpKpT+igx+sFtTfP80G84raBMQ\u002fsaETnZg\u002fkD+zwDFK41WtPw=="},"xaxis":"x4","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"FZgYAIxvCABfjQUAD\u002f4AALCeBwDeZQEAytIAAC5hAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"MfUPnR+c3z9f759DLK\u002fFP01sSj5Yi7w\u002friO144NolD9FfKpXS5bDP0eoyt1Bv5w\u002frplhGLbukD8I5IgGsjl\u002fPw=="},"xaxis":"x5","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"474tACwoFQCWxA4AS28BANioCQDZ5wEAV1wCAOqiAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"CHOXOfb53T9XsgArRLrLPws909+3WsM\u002fBaX4wM0Vjj+CSqkCqlG5PyluARfd+pM\u002fe9CqXjvAmD8wZW68UrB6Pw=="},"xaxis":"x6","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"k80TAGumCADD6gUATngAAHEcAwAglAAABOUAABY9AAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"uIM8CD303z\u002ftlmeyWOrLP62apFNsGMM\u002fCa1Nuu9DiD8Fb9njiBS0PzaVsG1w4I0\u002fFLP0Vp0Ylz+infJFWaR4Pw=="},"xaxis":"x","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"quQHANRqAwAgVgIAwSkAAP4dAQDRMgAA11YAABsUAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003es ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5de6ce80-2b7e-4413-82c7-6bd448f43a57" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5de6ce80-2b7e-4413-82c7-6bd448f43a57")) {                    Plotly.newPlot(                        "5de6ce80-2b7e-4413-82c7-6bd448f43a57",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"CMEAAAFsAABCAgAA2AsAAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"2htdNtyZ4z+DRboxI+\u002fVP62SWwKTWH0\u002f8aMQrBA+oz8="},"xaxis":"x4","y":["WALK_LOC","WALK_LR","WALK_COM","WALK_FRY"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"r9oAAPxiAADrBgAAqQIAAJ8eAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Tv7AleyN4z+ZPKuwvLPRP9xkj5qIy5M\u002fl2BT13Fyfj\u002fnCzJLn+e1Pw=="},"xaxis":"x5","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"hTwBAAFoAAANDQAAOQQAAA0yAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"V7W1SgnD5D9Myq6RyUnLPxLj8ezPZJs\u002fJa3sihK6gT9Eslo6rEO6Pw=="},"xaxis":"x6","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"O1kYHsUHsgFWEw==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Fvkf7NtG4z9p2u3TSwHKP1AvBegO26o\u002f8j\u002fYt41whz9rcRPmd7XAPw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"dh1mCkEDlgAeBw==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"PtYpElWN4j9auOhuPDHKP2KgCqRwZLA\u002fay08rkqdhz+n24ZLYu3BPw=="},"xaxis":"x2","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y2", ...

# %% [raw]
# ### tour mode

# %%
trip_mode_choice_seg(segment_col='tour_mode_transit_agg', height=[800, 400])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c172977a-e04f-499a-b495-6f09bb1195e7" class="plotly-graph-div" style="height:800px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c172977a-e04f-499a-b495-6f09bb1195e7")) {                    Plotly.newPlot(                        "c172977a-e04f-499a-b495-6f09bb1195e7",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"rppQAMQpAgAmMwAA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=DRIVEALONEFREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"+525FLAW7z+dgzo4tLKaPzTojYRJumM\u002f"},"xaxis":"x7","y":["DRIVEALONEFREE","WALK","SCHBUS"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"NPENAHsNJgAw3QAA1u4BAIpUAwA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=SHARED2FREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Dh\u002fkIVK0zj9BJgvHUvPkP9sC4D3OcY4\u002fhvBKpAgHoT+ELvrTDlatPw=="},"xaxis":"x8","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","WALK","SCHBUS"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"izsEAO1vAgDLRhoAw3kAAOA2AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=SHARED3FREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Tl2OS1MbwD9AE8BCloyyPwYlAy+N\u002f+g\u002fWTayBKf1jD+qMjzXTBp6Pw=="},"xaxis":"x9","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","WALK","SCHBUS"],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"5FgCAFkKAADcBgAA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=BIKE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"8moxB\u002fIb7z\u002fh5biLliSRP7R3MxxRuoY\u002f"},"xaxis":"x4","y":["BIKE","WALK","SCHBUS"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"LRAUAMNGAAA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=WALK\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"WjQ97quQ7z9+6bJwBNWLPw=="},"xaxis":"x5","y":["WALK","SCHBUS"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"eTkAAKkgAACpOgAAONg ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="a34f8847-b0ec-418e-84f9-bc1526e9820d" class="plotly-graph-div" style="height:400px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a34f8847-b0ec-418e-84f9-bc1526e9820d")) {                    Plotly.newPlot(                        "a34f8847-b0ec-418e-84f9-bc1526e9820d",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"hPUBADhLAQCFFQAABAsAAPN2AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=ALL_TRANSIT\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"VrFBokpO4D\u002fKKf16s4nVP0PaBD2rY5Y\u002f5SvYu\u002fbrhj8fkkFbc\u002fC+Pw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"cG9EFGgABQA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=TNC\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"\u002fRrSryH96j+iEx464aHDPzAZAJMBMGk\u002fYBMANgFgIz8="},"xaxis":"x2","y":["WALK_LOC","WALK_LR","WALK_COM","WALK_FRY"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hQVbADwAEQARAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003etour_mode_transit_agg=ALL_TRANSIT\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"DXYSdExi7D9w5Na\u002fUgyLP59mqjhq+6g\u002fep9QQHsImD9mXyBs+DCcPw=="},"xaxis":"x","y":["WALK_LOC","WALK_LR","DRIVE_TRN","WALK_COM","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"fQEL","shape":"3, 1"},"hovertemplate":"source=survey 2025\u003cbr\u003etour_mode_transit_agg=ALL_TRANSIT\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey 2025","offsetgroup":"survey 2025","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"ltx8ci0p7T87OfAdSStmP4mZKSM6BbY\u002f"},"xaxis":"x","y":["WALK_LOC","DRIVE_TRN","WALK_FRY"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rg ...

# %% [raw]
# :::
