# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination_choice", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["all_tour_mode", "all_trip_mode", "auto_ownership", "day_pattern", "escort_tour_mode", "escort_trip_mode", "households", "intermediate_stop_generation", "other_home_based_tour_mode", "other_home_based_trip_mode", "persons", "school_location", "school_tour_mode", "school_trip_mode", "telecommute", "time_choice", "tours", "tour_destination", "transit_pass_ownership", "trips", "trip_destination", "workbased_subtour_generation", "workbased_subtour_mode", "work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/cleaned"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}
run_args_dict = {"output_dir": "C:/Workspace/asim_output_6_5_26", "data_dir": "C:/Workspace/asim_data_6_5_26"}

# %%
# Parameters

# summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["mandatory_tour_frequency"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation3/c$/Workspace/sc_20251118/outputs", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 7, "9to15": 12, "15to18": 17, "18to20": 19, "20to5": 22}, "summer_list": [87], "pollutant_map": {"1": "Total Gaseous HCs", "2": "CO", "3": "NOx", "5": "Methane", "6": "N20", "79": "Non-methane HCs", "87": "VOCs", "90": "Atmospheric CO2", "91": "Total Energy", "98": "CO2 Equivalent", "PM10": "PM10 Total", "PM25": "PM25 Total", "100": "PM10 Exhaust", "106": "PM10 Brakewear", "107": "PM10 Tirewear", "110": "PM25 Exhaust", "112": "Elemental Carbon", "115": "Sulfate Particulate", "116": "PM25 Brakewear", "117": "PM25 Tirewear", "118": "Composite NonECPM", "119": "H20 Aerosol"}, "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}

# input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_asim", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml

# from pathlib import Path

# config_path = Path("../../../../configuration/asim_configuration")

# input_config = toml.load(config_path/ "input_configuration.toml")

# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
#
# title: Trip Mode Choice
#
# date: today
#
# ---

# %% [markdown]
# The trip mode choice models explanatory variables include household and person variables, level-of-service between the trip origin and destination according to the time period for the tour leg, urban form variables, and alternative-specific constants segmented by tour mode.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code

sys.path.insert(0, module_path)

import util
import importlib
importlib.reload(util)
# Out:
# <module 'util' from 'C:\\workspace\\sc_6_5_26_pnr_2023\\scripts\\summarize\\validation_activitysim\\nb\\util.py'>

# %%
# read data
person = util.get_person_data(summary_config, run_args_dict)
hh = util.get_hh_data(summary_config, run_args_dict)
trip = util.get_trip_data(summary_config, run_args_dict)
tour = util.get_tour_data(summary_config, run_args_dict)

# %%
per_data = person.merge(hh[['household_id','auto_ownership','auto_ownership_4+','log_hh_1','log_hh_1_group','source']],
                          how='left', on=['household_id','source']) # get auto ownership from hh data



trip_data = trip.\
    merge(tour[['tour_id', 'tour_mode', 'tour_mode_transit_agg', 'tour_type','source']], how = 'left', on=['tour_id', 'source']).\
    merge(per_data, how = 'left', on=['person_id', 'household_id', 'source'])

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_mode_transit_agg', title="Trip mode choice: all modes")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="3ff740c3-7414-4c8a-8d1d-d3ecc030a83b" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3ff740c3-7414-4c8a-8d1d-d3ecc030a83b")) {                    Plotly.newPlot(                        "3ff740c3-7414-4c8a-8d1d-d3ecc030a83b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"xt1kANKFKgAyDh0AkGwDAIYjGQBJiwQA1YkEALf0AQA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"xaxis":"x","y":{"dtype":"f8","bdata":"5Kp3OpJx3j\u002fHbvM9J6vJP\u002fY3KW4EisE\u002ftMI0lQyJkD+t1GyrhVm+P9qz7Mys8ZU\u002fAWWZW6jqlT8h22MYDeSCPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hBs1CtkDrAGeDSsDoQBCAO0A","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"F8Ymv53V4D+mwy8VtuTIP3HzYxSnJ7Y\u002f8UxWl8TQhT9lH9+BtwG8P6kRxtqGc6A\u002fBzb83OhAkD\u002fa\u002fnS7qoxtPwu1+uIuv5U\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111," ...

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_mode_transit_agg', title="Trip mode choice: transit modes")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="90e52d38-040e-43e0-9673-9a1f1fa1d19b" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("90e52d38-040e-43e0-9673-9a1f1fa1d19b")) {                    Plotly.newPlot(                        "90e52d38-040e-43e0-9673-9a1f1fa1d19b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"xt1kANKFKgAyDh0AkGwDAIYjGQBJiwQA1YkEALf0AQA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"xaxis":"x","y":{"dtype":"f8","bdata":"5Kp3OpJx3j\u002fHbvM9J6vJP\u002fY3KW4EisE\u002ftMI0lQyJkD+t1GyrhVm+P9qz7Mys8ZU\u002fAWWZW6jqlT8h22MYDeSCPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hBs1CtkDrAGeDSsDoQBCAO0A","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC","Other"],"xaxis":"x","y":{"dtype":"f8","bdata":"F8Ymv53V4D+mwy8VtuTIP3HzYxSnJ7Y\u002f8UxWl8TQhT9lH9+BtwG8P6kRxtqGc6A\u002fBzb83OhAkD\u002fa\u002fnS7qoxtPwu1+uIuv5U\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111," ...

# %% [markdown]
# ## Trip mode choice by segment

# %% [raw]
# ::: {.panel-tabset}
#
#
#
# ### trip purpose

# %%
def trip_mode_choice_seg(segment_col, facet_col_wrap=3, height=[1200, 800]):
    """
    faceted bar chart showing trip mode share by segment
    """

    util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_mode_transit_agg", title=f'Trip mode choice by {segment_col}', facet_col=segment_col, facet_col_wrap=facet_col_wrap, height=height[0])
    util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_mode_transit_only", title=f'Trip mode choice by {segment_col}: transit only', facet_col=segment_col, facet_col_wrap=facet_col_wrap, height=height[1])

# %%
trip_mode_choice_seg(segment_col='purpose')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="6de7d7bb-d038-4ad0-a1f9-7aedf96397e5" class="plotly-graph-div" style="height:1200px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6de7d7bb-d038-4ad0-a1f9-7aedf96397e5")) {                    Plotly.newPlot(                        "6de7d7bb-d038-4ad0-a1f9-7aedf96397e5",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"qIECAKQ0AQBQ0gAAVB0AACK8AAADGQAAIBsAAMIMAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=social\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"cGu7KJ913D8DNAW022DLP+WHVcrxp8I\u002fq1ODXA3QlD8GOWE5RbDAP01h1JHjv5E\u002fz7CDQc8\u002fkz+TdxwNbxuCPw=="},"xaxis":"x10","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"zWcjAK5IEACaMwsAlHwBAK1wCADBzwEAms4BAGzFAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=home\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Wxg6601Z3T9F06umIf\u002fKP0R0KL8cksI\u002fCRpGIJi3kz\u002fYeHvdPfy7P8FcB2\u002fABpg\u002fAgLv23f3lz+8wyN5zHSEPw=="},"xaxis":"x11","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"bTcGAFrKBAAXhAQAfiIAANgsAQBwhwAAh1IAAOQYAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epurpose=escort\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":
class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bcff53a2-098c-4bb3-96ce-bc706d01aeaf")) {                    Plotly.newPlot(                        "bcff53a2-098c-4bb3-96ce-bc706d01aeaf",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"5BBiAlEA8QJQAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"CDggLCap5z8HMZxmAbS6P73s1ODaXYw\u002fLofasEV7wD8QFpPUMwSMPw=="},"xaxis":"x4","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"mjHcA1wBpwzRAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"VSDwRTw+5z8plT\u002fhke+sP6l5zr5JYpQ\u002fXG2iHiK3xz\u002f7zDWX8XuIPw=="},"xaxis":"x5","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"r5IAANAJAADqBAAANCYAAEUCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"IUbpVSBA5z+lztXSvuKoP9WcudDj7Jg\u002f+xAuNtM4yD\u002fE8wI29AWHPw=="},"xaxis":"x6","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"XM4AAN4KAAArBgAArUMAAIgCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium-high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"0WURHsp95j+J0TgXa\u002fOiP2lfchIcg5U\u002fW3634xeBzT\u002f+oGa+FaiBPw=="},"xaxis":"x","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"XW8BAFkGAAAAAwAAAMUAAPUCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"TuqcmKti5D+ncffRFYuGP2CaxuABT3U\u002fD3H2lxDd1T9\u002fFzkv4AB1Pw=="},"xaxis":"x2","y":["WALK_LOC","DRI ...

# %% [raw]
# ### auto ownership

# %%
trip_mode_choice_seg(segment_col='auto_ownership_4+', height=[600, 500])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="dcdbfdf6-981e-461f-be80-9820f7692d0b" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dcdbfdf6-981e-461f-be80-9820f7692d0b")) {                    Plotly.newPlot(                        "dcdbfdf6-981e-461f-be80-9820f7692d0b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"gM8AAMCyAAAJUgAAMVUAAOXjAwDwMwEArB8AABt4AAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"nVgeRJxwuj86\u002f114ysa2P+oPJDrx56Q\u002fDgu91tq1pT8zDIPveLnfP2MqhGZunsM\u002fYywfp4UkkD8ElG2MopuuPw=="},"xaxis":"x4","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"0S8ZACKBCAAplQUAe\u002f8AAKWBBwBjMQEAENMAAGptAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"zkDkx0YM4D8jdBhltazFPzUZHuXNdLw\u002fWqRvAAFZlD\u002flTyQskCHDP5BbYX+LUpg\u002f9wvNHl3PkD+PqvaMsm2BPw=="},"xaxis":"x5","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"hqMuADw\u002fFQBL3Q4Ak3QBALWSCQBCjAEACVwCAP2xAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"VMWFBAVX3j9iuoCFxaTLP7zP9FXqVsM\u002fufrAMN1Ljj869SPyCOm4P7KekjhxHJA\u002fr3giyBaPmD+lwEfpWfJ8Pw=="},"xaxis":"x6","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"lC8UAF6nCACn8QUA3XgAAKASAwDicgAACOQAAMdFAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"RoWroDcs4D+NDO+3urvLP6cWNXKJDMM\u002fjkUpumk1iD+Wqgot5bGzP1hUA9PBAoc\u002fAMGAgErWlj8sFbJ41vN7Pw=="},"xaxis":"x","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","SCHBUS","TNC"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"WwsIAFZrAwAOWAIAdCoAAKcYAQDSJgAACFcAAG4XAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b9c08477-b0b7-4a63-a8fd-41ab7dd5c630" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b9c08477-b0b7-4a63-a8fd-41ab7dd5c630")) {                    Plotly.newPlot(                        "b9c08477-b0b7-4a63-a8fd-41ab7dd5c630",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"d74AAIkDAADibgAADgMAAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"l5X\u002f9+XK4z\u002faK0w64oKHP85DWTaWC9c\u002frPSl+thQhD8="},"xaxis":"x4","y":["WALK_LOC","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"TMkAAIMMAACNAwAA\u002fFUAAAsCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"TNo9HcoX5T\u002fqrSPQB\u002fqkP\u002fPAHHH7z4c\u002fKMOm+w8F0j\u002fOHgsUvWZ7Pw=="},"xaxis":"x5","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"wR4BAA8NAACTBQAAA1gAANwCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"nUczUC4o5z8Zt+tSc9+gP84iECM9z4w\u002f1fAcWgJuzD86GEDFd459Pw=="},"xaxis":"x6","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"L1GzBSYCLBmuAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"2jnVqP6c5j+Bf6QHWWapP63stQ5jJpM\u002fmjxXvcQLzD800X9yvzt4Pw=="},"xaxis":"x","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"MxsAAvMAbAhAAA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"s7Ng86xr5j+qf4LjwGCqPy\u002ff9BfXCZk\u002fZuGBD9vEyz+qf4LjwGB6Pw=="},"xaxis":"x2","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR", ...

# %% [raw]
# ### tour mode

# %%
trip_mode_choice_seg(segment_col='tour_mode_transit_agg', height=[800, 400])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="06d4b752-7cfa-4ad5-962a-b6226d06e472" class="plotly-graph-div" style="height:800px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("06d4b752-7cfa-4ad5-962a-b6226d06e472")) {                    Plotly.newPlot(                        "06d4b752-7cfa-4ad5-962a-b6226d06e472",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"VV1SAPAnAgAfMwAA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=DRIVEALONEFREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"hKgncTcc7z8i8AByLQ+aP7n6T0gjT2M\u002f"},"xaxis":"x7","y":["DRIVEALONEFREE","WALK","SCHBUS"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"NCcOAN9PJgAW3wAA8+8BALRaAwA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=SHARED2FREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"JOhqVFzmzj8xZY6iQunkPzd2riLXcI4\u002fLQ2YOCDroD+qYSqEDkutPw=="},"xaxis":"x8","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","WALK","SCHBUS"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"30oEAFh1AgCOfhoAUngAACI2AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=SHARED3FREE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"2qYY1t4xwD8xqcU\u002f1YyyPy\u002f8o9Fh\u002feg\u002fDNeezzJfjD9GzFTPgod5Pw=="},"xaxis":"x9","y":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","WALK","SCHBUS"],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"M1kCAEEKAAAZBwAA","shape":"3, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=BIKE\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"kVsFxjIa7z84uC8\u002fpPmQP0KrSQAGgIc\u002f"},"xaxis":"x4","y":["BIKE","WALK","SCHBUS"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"Mc8TAMhGAAA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=WALK\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"aVx04zuP7z+i5egiBzGMPw=="},"xaxis":"x5","y":["WALK","SCHBUS"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"1yIAAIUUAAD8NQAAJSw ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1ec16cfe-1c10-401a-8c94-f007b2511d31" class="plotly-graph-div" style="height:400px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1ec16cfe-1c10-401a-8c94-f007b2511d31")) {                    Plotly.newPlot(                        "1ec16cfe-1c10-401a-8c94-f007b2511d31",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"0MsBABcdAAB\u002fDwAA4ioBAN0IAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=ALL_TRANSIT\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"UYkzLRIe4j93TKJGz1aiP6v6zjPUiZM\u002fX\u002fvvPJaN1z+uGPeSx1mGPw=="},"xaxis":"x","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"hG1DAJcTBgA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003etour_mode_transit_agg=TNC\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"eqBhuqsV6z9JrLMs6pFgP6zh3O8ZYcM\u002fN+82p\u002fe9Jz8="},"xaxis":"x2","y":["WALK_LOC","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"3gIfAAkAGgALAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003etour_mode_transit_agg=ALL_TRANSIT\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_only=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"EcpVrGoo7D+\u002f1ECOuF+pPy2HPNN3Ipw\u002f21v4hUERjj88X4zCIAidPw=="},"xaxis":"x","y":["WALK_LOC","DRIVE_TRN","WALK_COM","WALK_LR","WALK_FRY"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"c ...

# %% [raw]
# :::
