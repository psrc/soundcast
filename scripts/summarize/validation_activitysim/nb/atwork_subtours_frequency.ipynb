# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination_choice", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["all_tour_mode", "all_trip_mode", "auto_ownership", "day_pattern", "escort_tour_mode", "escort_trip_mode", "households", "intermediate_stop_generation", "other_home_based_tour_mode", "other_home_based_trip_mode", "persons", "school_location", "school_tour_mode", "school_trip_mode", "telecommute", "time_choice", "tours", "tour_destination", "transit_pass_ownership", "trips", "trip_destination", "workbased_subtour_generation", "workbased_subtour_mode", "work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/cleaned"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}
run_args_dict = {"output_dir": "C:/Workspace/asim_output_6_5_26", "data_dir": "C:/Workspace/asim_data_6_5_26"}

# %%
# Parameters

# summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["mandatory_tour_frequency"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation3/c$/Workspace/sc_20251118/outputs", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 7, "9to15": 12, "15to18": 17, "18to20": 19, "20to5": 22}, "summer_list": [87], "pollutant_map": {"1": "Total Gaseous HCs", "2": "CO", "3": "NOx", "5": "Methane", "6": "N20", "79": "Non-methane HCs", "87": "VOCs", "90": "Atmospheric CO2", "91": "Total Energy", "98": "CO2 Equivalent", "PM10": "PM10 Total", "PM25": "PM25 Total", "100": "PM10 Exhaust", "106": "PM10 Brakewear", "107": "PM10 Tirewear", "110": "PM25 Exhaust", "112": "Elemental Carbon", "115": "Sulfate Particulate", "116": "PM25 Brakewear", "117": "PM25 Tirewear", "118": "Composite NonECPM", "119": "H20 Aerosol"}, "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}

# input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_asim", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": False, "run_setup_emme_project_folders": False, "run_setup_emme_bank_folders": False, "run_copy_scenario_inputs": False, "run_import_networks": False, "run_skims_and_paths_free_flow": False, "run_skims_and_paths": False, "run_truck_model": False, "run_supplemental_trips": False, "run_abm": False, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml

# from pathlib import Path

# config_path = Path("../../../../configuration/asim_configuration")

# input_config = toml.load(config_path/ "input_configuration.toml")

# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
#
# title: At-work Subtours Frequency
#
# date: today
#
# ---

# %% [markdown]
# The at-work subtour frequency model selects the number of at-work subtours made for each work tour.
#
#
#
# - work tours Alternatives: none, 1 eating out tour, 1 business tour, 1 maintenance tour, 2 business tours, 1 eating out tour + 1 business tour
#
# - Explanatory variables include employment status, income, auto ownership, the frequency of other tours, characteristics of the parent work tour, and characteristics of the workplace zone.

# %%
import pandas as pd
import polars as pl
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code

sys.path.insert(0, module_path)

import util
import importlib
importlib.reload(util)
# Out:
# <module 'util' from 'C:\\workspace\\sc_6_5_26_pnr_2023\\scripts\\summarize\\validation_activitysim\\nb\\util.py'>

# %%
# read data

hh = util.get_hh_data(summary_config, run_args_dict, uncloned=True)
person = util.get_person_data(summary_config, run_args_dict, uncloned=True)
tour = util.get_tour_data(summary_config, run_args_dict)

# %%
per_data = person.merge(hh[['household_id','income_group','auto_ownership_4+','log_hh_1','log_hh_1_group',
                            'auto_available_driver','auto_available_worker','source']],
                          how='left', on=['household_id','source']) # get auto ownership from hh data

tour_data = tour.merge(per_data, how='left', on=['person_id','household_id','source'])

# %%
atwork_subtour = tour_data.loc[tour_data['tour_category']=="atwork"].copy()
# select all work tours that could make atwork subtours
work_tour = tour_data.loc[tour_data['tour_type']=="work"].copy()

# calculate atwork_subtour_frequency

# count number of subtours by type
tour_type_count = atwork_subtour.groupby(['source',"parent_tour_id","tour_type"],observed=True, as_index=False).size()
df_wide = tour_type_count.pivot(index=['source','parent_tour_id'], columns='tour_type', values='size').reset_index()
df_wide = df_wide.fillna(0)
df_wide['subtour_count'] = df_wide['eat'] + df_wide['business'] + df_wide['maint']

# assign atwork_subtour_frequency for parent tour id
df_wide['atwork_subtour_frequency_reassign'] = ""
df_wide.loc[df_wide['maint']>=1.0,'atwork_subtour_frequency_reassign'] = 'maint'
df_wide.loc[df_wide['eat']>=1.0,'atwork_subtour_frequency_reassign'] = 'eat'
df_wide.loc[df_wide['business']==1.0,'atwork_subtour_frequency_reassign'] = 'business1'
df_wide.loc[df_wide['business']>1.0,'atwork_subtour_frequency_reassign'] = 'business2'
df_wide.loc[(df_wide['eat']==1.0) & (df_wide['business']==1.0),'atwork_subtour_frequency_reassign'] = 'eat_business'

# merge to parent work tour (replace missing only: survey records)
work_tour = work_tour.merge(df_wide, left_on=['source','tour_id'],right_on=['source','parent_tour_id'], how='left')
work_tour.loc[work_tour['atwork_subtour_frequency'].isna(),'atwork_subtour_frequency'] = work_tour.loc[work_tour['atwork_subtour_frequency'].isna(),'atwork_subtour_frequency_reassign']
work_tour['atwork_subtour_frequency'] = work_tour['atwork_subtour_frequency'].fillna('no_subtours')

# max number of subtours at 2

work_tour['subtour_count'] = work_tour['subtour_count'].fillna(0)
work_tour.loc[work_tour['subtour_count']>2,'subtour_count'] = 2

# %%
util.plot_share_barchart(work_tour, 'tour_weight', 'atwork_subtour_frequency', title="atwork subtours frequency")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5dc08ee5-4e1a-4cf7-a482-eae2bb8f7c84" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5dc08ee5-4e1a-4cf7-a482-eae2bb8f7c84")) {                    Plotly.newPlot(                        "5dc08ee5-4e1a-4cf7-a482-eae2bb8f7c84",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"nGcEAD0zDgDStQAACAkAAPLtAAD1DwAA","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","no_subtours","maint","business2","business1","eat_business"],"xaxis":"x","y":{"dtype":"f8","bdata":"x3VzOU23yz+GjvTziVbmP7QHVwtN4KE\u002fniO78\u002fFpXD\u002foe7tp7mSnPxU9jmMNGmk\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"RgBzBSwA","shape":"3, 1"},"hovertemplate":"source=survey\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","no_subtours","maint"],"xaxis":"x","y":{"dtype":"f8","bdata":"S6igSTbApz8LrbQLH5XtPxUOKfax250\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b ...

# %% [markdown]
# ## Atwork subtour frequency by segment

# %% [raw]
# :::{.panel-tabset}
#
#
#
# ### employment

# %%
util.plot_share_facetbar(work_tour, 'tour_weight', share_col="pemploy_label", title="atwork subtours frequency by employment", 
                             facet_col='atwork_subtour_frequency', facet_col_wrap=3, height=500, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="df36933c-382a-476e-a095-731d7120c9b5" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("df36933c-382a-476e-a095-731d7120c9b5")) {                    Plotly.newPlot(                        "df36933c-382a-476e-a095-731d7120c9b5",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"rDgEAPAuAAA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=eat\u003cbr\u003epemploy_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["1: Full-time worker","2: Part-time worker"],"xaxis":"x4","y":{"dtype":"f8","bdata":"voCNogCr7j8c9CfX9U+lPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"KZsLABSYAgA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=no_subtours\u003cbr\u003epemploy_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["1: Full-time worker","2: Part-time worker"],"xaxis":"x5","y":{"dtype":"f8","bdata":"BJvAbYAn6j\u002fwk\u002f1I\u002fmHHPw=="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"7KAAAOYUAAA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=maint\u003cbr\u003epemploy_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["1: Full-time worker","2: Part-time worker"],"xaxis":"x6","y":{"dtype":"f8","bdata":"yVKKOWlS7D+4aa0ztmy9Pw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"0gc2AQ==","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=business2\u003cbr\u003epemploy_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["1: Full-time worker","2: Part-time worker"],"xaxis":"x","y":{"dtype":"f8","bdata":"Hz1beZe16z+EC5MaoinBPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"Nt8AALwOAAA=","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=business1\u003cbr\u003epemploy_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["1: Full-time worker","2: Part-time worker"],"xaxis":"x2","y":{"dtype":"f8","bdata":"uSZJSbkE7j9ulG1ra7SvPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"sg1DAg==","shape":"2, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=eat_business\u003cbr\u003epemploy_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\ ...

# %% [raw]
# ### income

# %%
util.plot_share_facetbar(work_tour, 'tour_weight', share_col="income_group", title="atwork subtours frequency by income", 
                             facet_col='atwork_subtour_frequency', facet_col_wrap=3, height=500, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f0a77ed9-9d53-49aa-9c68-15bbb86ffbc5" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f0a77ed9-9d53-49aa-9c68-15bbb86ffbc5")) {                    Plotly.newPlot(                        "f0a77ed9-9d53-49aa-9c68-15bbb86ffbc5",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"Z2UAADcdAQAYZAEA5oABAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=eat\u003cbr\u003eincome_group=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["low","medium","medium-high","high"],"xaxis":"x4","y":{"dtype":"f8","bdata":"1yQ59XEFtz91RgZRITDQPyGWIob9NdQ\u002fNNqIq4TY1T8="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"AQoCAOBkAwBUJgQACJ4EAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=no_subtours\u003cbr\u003eincome_group=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["low","medium","medium-high","high"],"xaxis":"x5","y":{"dtype":"f8","bdata":"efFQeFZhwj+VUyK7B5jOP\u002fr2ikbos9I\u002ff2a7n2jP1D8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"3BcWLpk2Rzk=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=maint\u003cbr\u003eincome_group=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["low","medium","medium-high","high"],"xaxis":"x6","y":{"dtype":"f8","bdata":"sSDESvvLwD8Dh97q2DjQPxsdGqrYN9M\u002fiUulxVAp1D8="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"YgBfAikDHgM=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=business2\u003cbr\u003eincome_group=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["low","medium","medium-high","high"],"xaxis":"x","y":{"dtype":"f8","bdata":"SiwO8NGzpT9VoOs2gs3QP1a\u002fKJL7ZNY\u002fzNrp+AcX1j8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"sxDVPFdNE1M=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=business1\u003cbr\u003eincome_group=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["low","medium","medium-high","high"],"xaxis":"x2","y":{"dtype":"f8","bdata":"RwGoTGD3sT8nL0byqFzQP+RDyxFTzdQ\u002fo4zE6CtY1j8="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"5QB1BBkFggU=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003e ...

# %% [raw]
# ### work tour mode

# %%
util.plot_share_facetbar(work_tour, 'tour_weight', share_col="tour_mode_transit_agg", title="atwork subtours frequency by work tour mode", 
                             facet_col='atwork_subtour_frequency', facet_col_wrap=3, height=500, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e28c3b31-a60e-4290-9422-3e8c2b225c9d" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e28c3b31-a60e-4290-9422-3e8c2b225c9d")) {                    Plotly.newPlot(                        "e28c3b31-a60e-4290-9422-3e8c2b225c9d",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"KPYCALCgAABLcAAAWggAAOs3AACzDQAAgRIAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=eat\u003cbr\u003etour_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"xaxis":"x4","y":{"dtype":"f8","bdata":"EajiL\u002fOD5T+RRKktiD3CP6lKz+Rmfrk\u002fDCpVCDVWfj9JlQTs1mOpP4+cVmCG4Yg\u002fYOvZuL7NkD8="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"1BIIAI22AgD62gEA+CMAAMrpAAAOOwAAEkYAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=no_subtours\u003cbr\u003etour_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"xaxis":"x5","y":{"dtype":"f8","bdata":"3jcHgJcx4j80yPhqrHTIPxDwpAxvucA\u002ftxKtDo1DhD8qVpmNvnawP5ASx\u002fSLopA\u002fiE2oj+e8kz8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"0ZAAAEIQAADHCgAAxQAAALcFAACzAQAAyQEAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=maint\u003cbr\u003etour_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"xaxis":"x6","y":{"dtype":"f8","bdata":"r+KAg8V86T+ve\u002fT+BuS2P+sEmcFAWa4\u002fOTs4yPZVcT8Ezxx9whegP4P8NFfII4M\u002f0Qz7cZYbhD8="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"FAhpAEkABQAoAAgADQA=","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=business2\u003cbr\u003etour_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","BIKE","WALK","ALL_TRANSIT","TNC"],"xaxis":"x","y":{"dtype":"f8","bdata":"vuoXRXKf7D9Q5nwTqkCnP+6TOd+EKqA\u002f9E2oAl23YT\u002f0TagCXbeRP4ZJDdGUWGw\u002fvcva6fgHdz8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"XLoAACMXAABnEAAAFAEAAAwHAACYAQAAVAIAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eatwork_subtour_frequency=business1\u003cbr\u003etour_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u ...

# %% [raw]
# :::
