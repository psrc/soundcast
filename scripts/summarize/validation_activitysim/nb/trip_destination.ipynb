# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit"], "activitysim-validation-notebook": ["configs", "cdap", "trip_destination", "non_mandatory_tour_destination", "atwork_subtour_frequency", "atwork_subtour_destination", "atwork_subtour_scheduling", "tour_mode_choice", "trip_mode_choice"], "daysim-validation-notebook": ["all_tour_mode", "all_trip_mode", "auto_ownership", "day_pattern", "escort_tour_mode", "escort_trip_mode", "households", "intermediate_stop_generation", "other_home_based_tour_mode", "other_home_based_trip_mode", "persons", "school_location", "school_tour_mode", "school_trip_mode", "telecommute", "time_choice", "tours", "tour_destination", "transit_pass_ownership", "trips", "trip_destination", "workbased_subtour_generation", "workbased_subtour_mode", "work_location", "work_tour_mode", "work_trip_mode"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "../../../../", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}, "output_dir": "P:/workspace/sc_6_22_26_asim_output", "data_dir": "P:/workspace/sc_6_22_26_asim_data"}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": True, "run_setup_emme_project_folders": True, "run_setup_emme_bank_folders": True, "run_copy_scenario_inputs": True, "run_import_networks": True, "run_skims_and_paths_free_flow": True, "run_skims_and_paths": True, "run_truck_model": True, "run_supplemental_trips": True, "run_abm": True, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Trip destination
# date: today
# ---

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
# read data
trip_data = util.get_trip_data(summary_config)

# %% [markdown]
# ## trip distance

# %% [raw]
# :::{.panel-tabset}
#
# ### distance bins

# %%
util.plot_share_barchart(trip_data, 'trip_weight', 'trip_distance_bin', title="Trip distance")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [raw]
# ### 0 to 60-mile bins

# %%
df_plot = trip_data.loc[trip_data['trip_distance_bin_60mi'].notna()].groupby(['source','trip_distance_bin_60mi'])['trip_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['trip_weight']. \
    apply(lambda x: x / float(x.sum()))

fig2 = px.line(df_plot, x='trip_distance_bin_60mi', y="percentage", color="source", title="Trip distance")
fig2.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig2.update_layout(height=400, width=700, font=dict(size=11), yaxis=dict(tickformat=".1%"))
fig2.show()
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_25080\699490682.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [raw]
# :::

# %% [markdown]
# ## trip destination by mode

# %%
util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_distance_bin", title="Trip distance by trip mode", 
                            facet_col="trip_mode_transit_agg", facet_col_wrap=3, height=700, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
util.plot_share_facetbar(trip_data, 'trip_weight', share_col="trip_distance_bin", title="Trip distance by trip mode: transit only", 
                            facet_col="trip_mode_transit_only", facet_col_wrap=3, height=500, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## district flow
#
# - \(model trips - survey trips\) / survey trips

# %%
# get district names for home and work locations
dist_name = {1: '1: Suburban Snohomish',
             2: '2: Everett-Lynwood-Edmonds',
             3: '3: North Seattle-Shoreline',
             4: '4: Seattle CBD',
             5: '5: West-South Seattle',
             6: '6: East Side',
             7: '7: Renton-FedWay-Kent',
             8: '8: Tacoma',
             9: '9: Kitsap',
             10: '10: South Pierce'}
# get maz to district lookup
geog_lookup_maz_district = util.read_sqlite_db(input_config, summary_config, "SELECT * FROM parcel_2023_geography").\
    drop_duplicates(subset=['maz_id'], keep='first').\
    sort_values(by=['maz_id'])
maz_district_lookup = dict(zip(geog_lookup_maz_district['maz_id'], geog_lookup_maz_district['District']))

trip_data_dist = trip_data.copy()
trip_data_dist['origin_district'] = trip_data_dist['origin'].map(maz_district_lookup)
trip_data_dist['dest_district'] = trip_data_dist['destination'].map(maz_district_lookup)

trip_data_dist['origin_dist_name'] = trip_data_dist['origin_district'].map(dist_name)
trip_data_dist['dest_dist_name'] = trip_data_dist['dest_district'].map(dist_name)

# %%
from pandas.api.types import CategoricalDtype

# model district flow
df_model = trip_data_dist.\
    groupby(['source','origin_dist_name','dest_dist_name'], observed=True)['trip_weight'].sum().\
    reset_index()

df_cols = ['origin_dist_name','dest_dist_name','person_weight','source']

dist_type = CategoricalDtype(categories=dist_name.values(), ordered=True)

df_model['origin_dist_name'] = df_model['origin_dist_name'].astype(dist_type)
df_model['dest_dist_name'] = df_model['dest_dist_name'].astype(dist_type)

# %%
import numpy as np
import matplotlib
import matplotlib.cm as cm

# get percent difference between model and LEHD
df_plot = pd.pivot_table(df_model, values='trip_weight', index=['origin_dist_name','dest_dist_name'],
                        columns=['source']).reset_index()
df_plot['pct_diff'] = (df_plot['model'] - df_plot['survey']) / df_plot['survey']

df_plot2 = pd.pivot_table(df_plot, values='pct_diff', index=['origin_dist_name'],
                        columns=['dest_dist_name']).reset_index()

# Build a symmetric color range around zero, with a safe fallback when all values
# are 0/NaN/inf so TwoSlopeNorm still has a strictly increasing range.
finite_values = df_plot2.set_index('origin_dist_name').to_numpy(dtype=float)
finite_values = finite_values[np.isfinite(finite_values)]
abs_max = float(np.max(np.abs(finite_values))) if finite_values.size else 1.0
if abs_max == 0:
    abs_max = 1.0
abs_min = -abs_max

def make_pretty(styler):

    def background_with_norm(s):
        cmap = matplotlib.colormaps['RdBu_r'].resampled(9)
        norm = matplotlib.colors.TwoSlopeNorm(vmin=abs_min, vcenter=0, vmax=abs_max)
        return [
            '' if not np.isfinite(v) else 'background-color: {:s}'.format(matplotlib.colors.to_hex(cmap(norm(v))))
            for v in s.values
        ]

    styler.set_caption("District distribution")
    styler.format("{:.2%}")
    styler.apply(background_with_norm)
    styler.set_properties(**{'color': 'black'})
    return styler


df_plot2.set_index('origin_dist_name').style.pipe(make_pretty)
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_25080\3248556144.py:6: FutureWarning:
#
# The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_25080\3248556144.py:10: FutureWarning:
#
# The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
# <style type="text/css">
# ...
