# %%
# Parameters
summary_config = {"run_run_comparison": False, "run_RTP_summary": False, "run_validation": True, "run_network_validation": False, "summary_list": {"RTP-summary-notebook": ["RTP_index", "RTP_congestion", "RTP_topsheet", "RTP_MIC", "RTP_person", "RTP_household", "RTP_access", "RTP_costs", "RTP_walk_bike", "RTP_emissions", "RTP_mode_share", "RTP_freight", "RTP_transit", "RTP_conformity_analysis"], "activitysim-validation-notebook": ["work_from_home", "auto_ownership", "telecommute_frequency", "free_parking", "cdap", "intermediate_stop_frequency", "trip_purpose", "trip_destination_choice", "school_location", "work_location", "mandatory_tour_frequency", "mandatory_tour_scheduling", "non_mandatory_tour_frequency", "non_mandatory_tour_destination_choice", "non_mandatory_tour_scheduling", "joint_tour_frequency", "joint_tour_composition", "atwork_subtours_frequency", "atwork_subtours_destination_choice", "atwork_subtours_scheduling", "atwork_subtour_mode", "tour_mode_choice", "trip_mode_choice"], "network-validation-notebook": ["JBLM", "supplementals", "transit_validation", "traffic_validation", "bike_validation", "link_analysis"], "run-comparison-notebook": ["topsheet", "population", "parking", "vmt", "transit"]}, "p_output_dir": "outputs/summary", "output_folder": "outputs", "survey_folder": "inputs/base_year/survey", "uncloned_folder": "uncloned", "sc_run_name": "current run", "sc_run_path": "//modelstation4/c$/workspace/sc_asim_040112/output", "survey_directories": {"survey": "R:/e2projects_two/2023_base_year/2023_survey/activitysim_format/skims_attached", "survey 2025": "R:/e2projects_two/2023_base_year/2025_survey/activitysim_format/cleaned"}, "comparison_runs_list": {"2050 new transit, old network": "\\\\modelstation3\\c$\\Workspace\\sc_new_2050_transit\\soundcast", "2050 urbansim": "\\\\modelstation2\\c$\\Workspace\\sc_2050_urbansim2_07_30_25"}, "county_map": {"33": "King", "35": "Kitsap", "53": "Pierce", "61": "Snohomish"}, "uc_list": ["@sov_inc1", "@sov_inc2", "@sov_inc3", "@hov2_inc1", "@hov2_inc2", "@hov2_inc3", "@hov3_inc1", "@hov3_inc2", "@hov3_inc3", "@av_sov_inc1", "@av_sov_inc2", "@av_sov_inc3", "@av_hov2_inc1", "@av_hov2_inc2", "@av_hov2_inc3", "@av_hov3_inc1", "@av_hov3_inc2", "@av_hov3_inc3", "@tnc_inc1", "@tnc_inc2", "@tnc_inc3", "@mveh", "@hveh", "@bveh"], "agency_lookup": {"1": "King County Metro", "2": "Pierce Transit", "3": "Community Transit", "4": "Kitsap Transit", "5": "Washington Ferries", "6": "Sound Transit", "7": "Everett Transit"}, "emissions_scenario": "standard", "tot_veh_model_base_year": 3185281, "speed_bins": [-999999.0, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 999999.0], "fac_type_lookup": {"0": 0, "1": 4, "2": 4, "3": 5, "4": 5, "5": 5, "6": 3, "7": 5, "8": 0}, "tod_lookup": {"5to9": 5, "9to15": 9, "15to18": 15, "18to20": 18, "20to5": 20}, "summer_list": [87], "special_route_lookup": {"1671": "A-Line Rapid Ride", "1672": "B-Line Rapid Ride", "1673": "C-Line Rapid Ride", "1674": "D-Line Rapid Ride", "1675": "E-Line Rapid Ride", "1677": "H-Line Rapid Ride", "4950": "Central Link", "6995": "Tacoma Link", "6998": "Sounder South", "6999": "Sounder North", "3701": "Swift Blue Line", "3702": "Swift Green Line"}}
input_config = {"debug_skims_and_paths": False, "model_year": "2023", "base_year": "2023", "landuse_inputs": "23_on_23_v3", "network_inputs": "network_2023_v9_time_period_fix", "db_name": "soundcast_inputs_2023.db", "soundcast_inputs_dir": "R:/e2projects_two/SoundCast/Inputs/activitysim", "abm_model": "activitysim", "run_accessibility_calcs": True, "run_setup_emme_project_folders": True, "run_setup_emme_bank_folders": True, "run_copy_scenario_inputs": True, "run_import_networks": True, "run_skims_and_paths_free_flow": True, "run_skims_and_paths": True, "run_truck_model": True, "run_supplemental_trips": True, "run_abm": True, "run_summaries": True, "include_av": False, "include_tnc": True, "tnc_av": False, "include_tnc_to_transit": False, "include_knr_to_transit": False, "include_delivery": False, "include_telecommute": True, "run_integrated": False, "should_build_shadow_price": False, "delete_banks": False, "include_tnc_emissions": False, "add_distance_pricing": False, "distance_rate_dict": {"am": 13.5, "md": 8.5, "pm": 13.5, "ev": 8.5, "ni": 8.5}}

# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Auto Ownership
# date: today
# ---

# %%
import pandas as pd
import polars as pl
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %% [markdown]
# ## Household data
#
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# read data
hh_data = util.get_hh_data(summary_config, uncloned=True)

# %% [markdown]
# ## Auto ownership across all households

# %%
util.plot_share_barchart(hh_data, 'hh_weight', 'auto_ownership_4+', title="Auto ownership")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="23e8b7bc-a936-4863-8d0d-0e9671df75f2" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("23e8b7bc-a936-4863-8d0d-0e9671df75f2")) {                    Plotly.newPlot(                        "23e8b7bc-a936-4863-8d0d-0e9671df75f2",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"d1sCAEFGCADxYQoAUAwEAL9qAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"Ytfdbz3Ktj\u002fZHbrIxP\u002fTP0fibS0uGNk\u002fpt2dFnyRwz+o2YwU\u002fWWrPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"fwKeBloEIQGGAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"mOH1ORdUtT+LD7xzyzbVP4YTjZvcCtg\u002fxHOdSmmnwD+TqqrzdVa0Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"yACKA04DJgF8AA==","shape":"5, 1"},"hovertemplate":"source=survey 2025\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey 2025","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey 2025","offsetgroup":"survey 2025","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"XrSiogqttz+9XdkmL2XUP5xUKuNqztg\u002fIEAbuUm0wz\u002f3AzCG8zeoPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.33333333 ...

# %% [markdown]
# ## Auto ownership by segments

# %% [raw]
# ::: {.panel-tabset}

# %% [raw]
# ### Income

# %%
util.plot_share_facetbar(hh_data, 'hh_weight', share_col="auto_ownership_4+", title="Auto ownership by income group", 
                            facet_col="income_group", facet_col_wrap=4, height=400, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="963b0572-5e4a-4c64-8193-7b0513ae3811" class="plotly-graph-div" style="height:400px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("963b0572-5e4a-4c64-8193-7b0513ae3811")) {                    Plotly.newPlot(                        "963b0572-5e4a-4c64-8193-7b0513ae3811",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"wJMBANTNAgBupwEA3HEAAF4jAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=low\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"6yNOWeKAzj+7DTietx3bPzcoKsCB\u002fc8\u002fXU0AgEg0sT\u002fCjbtQQ2CVPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"s2QAAPGcAgCUeAIAJ8sAAFZXAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=medium\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"nY33sXp1rj9sCNZFzErZP5Ts2N\u002fU6tc\u002f0OtFfGK5vj\u002fD8gQot2qqPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"dTkAABKhAQCnCAMAfUgBAAh0AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=medium-high\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"uAegjz1ZoT+x81fkinvPP6ihbeYVUN0\u002ftx7Ja8TLyD+zUDf+aoSxPw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"jykAAGo6AQBIOQMA0IYBAAN8AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eincome_group=high\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"25tfVEAXmT8v5ibqb7rHP7of5DspJN8\u002fm71k1HF+zT+QUkB+x7eyPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"SQGWAWIAGwAJAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003eincome_group=low\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"ESgaNVIg0T+4P97dN2jfP+ucqVbzjcM\u002f7zMncGDsrj8zNN46Ay+dPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"fwDWAe8ANQAaAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003e ...

# %% [raw]
# ### Household size

# %%
util.plot_share_facetbar(hh_data, 'hh_weight', share_col="auto_ownership_4+", title="Auto ownership by household size", 
                            facet_col="hhsize_4+", facet_col_wrap=4, height=400, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e8741a9d-6f5a-46f3-a983-3ad481d4aee4" class="plotly-graph-div" style="height:400px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e8741a9d-6f5a-46f3-a983-3ad481d4aee4")) {                    Plotly.newPlot(                        "e8741a9d-6f5a-46f3-a983-3ad481d4aee4",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"DccBABUlBADOxwAA6oEAANQnAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"0+XweIzjzj8Lt4ShrgHiP9eByZ0gILs\u002ffsdDuRujsT+0yqyr1qCVPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"xGkAAD5\u002fAgDcigQACyoBAKNGAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=2\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"XOLhe3LJpz\u002f0h8shivjRP0fFjoh4WOA\u002fMuWHK\u002fPBwD+d6Wt9zsWfPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"iBcAAKLPAACVFQIAzOkAAD1BAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=3\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"xiSW27mmlj\u002fc51n1x\u002fvIP4LnwHUGDeA\u002fLRLHobghzD9ejaJZOWavPw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"HhMAAEzSAACy+QIAj3YBAAu7AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=4+\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"0eeH2xo3iT\u002f+LAqsDFbBP6sJatdOZd8\u002fHcYJ1JXgzj8k9r5GnNa+Pw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"9wG3A3QAGAANAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=1\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"WeMMuomryz8kbyu1OBDlP3a3DUH4j7U\u002f\u002fgYYp6bQnD+sN7i9JxiLPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"cQAOAmQCggA0AA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=2\u003cbr\u ...

# %% [raw]
# ### Number of workers

# %%
util.plot_share_facetbar(hh_data, 'hh_weight', share_col="auto_ownership_4+", title="Auto ownership by number of workers", 
                            facet_col="num_workers_4+", facet_col_wrap=3, height=500, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c569eef3-3929-4fa9-b2d4-045334ee9322" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c569eef3-3929-4fa9-b2d4-045334ee9322")) {                    Plotly.newPlot(                        "c569eef3-3929-4fa9-b2d4-045334ee9322",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"KxQBAD9sAgBbkgEAPXsAAEAkAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_4+=0\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"f92kcKw9yD\u002f20kePqjjbP9jVDyaYqNE\u002fB+K8CH2itT8F\u002f2oCfXSZPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"KhcBADAnBAAIdwMAEzwBAPRkAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_4+=1\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":{"dtype":"f8","bdata":"KiFzGEABuz9fnQ9NObbZPyMQFLGic9U\u002fxardMkyTvj8R\u002fEB4B4ijPw=="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"DCwAAJWTAQC5mwQAJ6cBAJ5\u002fAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_4+=2\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x6","y":{"dtype":"f8","bdata":"3Awmfi+1lD8ne21fjbfHPx4MGNr7VOE\u002f9kH2m\u002fjdyD9CQ92xkv+tPw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"dQHqEC9i\u002fljKJw==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_4+=3\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"6Qgxg2lTeD\u002frQT6BNqaxPzvKSw3jnNk\u002ftL7dPRE31z\u002fnRPTcYMLEPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"oQJTDqZa21QjOg==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_4+=4+\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"2c3wMyd8hT8p2zXTOEStP7QlsQGpJtc\u002fzGPOZemr1T9aafSICrLNPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"7ACmAfMATQAbAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003enum_ ...

# %% [raw]
# ### Number of drivers

# %%
util.plot_share_facetbar(hh_data.loc[hh_data['num_drivers_4+']!="0"], 'hh_weight', share_col="auto_ownership_4+", title="Auto ownership by number of drivers", 
                            facet_col="num_drivers_4+", facet_col_wrap=4, height=400, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1daa1fa5-62f1-42cb-a394-73d835e63e69" class="plotly-graph-div" style="height:400px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1daa1fa5-62f1-42cb-a394-73d835e63e69")) {                    Plotly.newPlot(                        "1daa1fa5-62f1-42cb-a394-73d835e63e69",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"aN4BAPqEBACQ4AAAApAAABssAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_4+=1\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"lR058EfmzT+EjewaxhPiP4+uol7LEbw\u002fakjHPx4Asj\u002flhv2mVg2WPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"HmoAAIE6AwBZTgcAu7EBAD5lAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_4+=2\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"m4YT6O9GoD9N8Z7DpbHPP7qm7oQ47uE\u002fJQetm9uhwD\u002fwV6SXBA+fPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"UwsAAOFhAADTZwEApQkBAAhNAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_4+=3\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"AU0OEnCSjD+F2zYUot6+P0FO2HLzXtw\u002fVI292\u002fXx1D+G7C+vaku4Pw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ngcAAOUkAAA1ywAA7sAAAF6MAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_4+=4+\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"Ek60MnvZij9dfg1YikGwP+qqhtc2YtY\u002f6Kv2imdA1T9MTtNbZuzOPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"\u002fwHiA30AGQAOAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003enum_drivers_4+=1\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"vawfhp5lyz8rs8aYw9XkP74UQejGpLY\u002fhaiwgFVcoT9XIY0npJ2JPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"cgByAmQDoQA5AA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003enum_drivers ...

# %% [raw]
# ### Household density

# %%
util.plot_share_facetbar(hh_data.dropna(subset=['log_hh_1_group']), 'hh_weight', share_col="auto_ownership_4+", title="Auto ownership by household density", 
                            facet_col="log_hh_1_group", facet_col_wrap=3, height=500, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b7298822-6682-40c9-af24-f218bd12214d" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b7298822-6682-40c9-af24-f218bd12214d")) {                    Plotly.newPlot(                        "b7298822-6682-40c9-af24-f218bd12214d",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"DwUAAMdYAABlaQEAohgBAF5vAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=very low\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"BNabmcZ0eD9zq0iANtO6P6vZ4NTBTNs\u002fl7i7Z\u002fYy1T8Rp9URTtPAPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"0Q4AACOgAADTkwEAVcYAAExGAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=low\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":{"dtype":"f8","bdata":"Ncd\u002fhW\u002fnkT\u002fAfdicQjDIP7L5i8mnf94\u002fdcOgBzj1zT8DpX2vjzy1Pw=="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"DTUAAOa4AQCCGAMA7i4BAFRpAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x6","y":{"dtype":"f8","bdata":"VNMVnAgHoD\u002f7u\u002f6meabQP25+TfK67d0\u002f7r5pwUThxj+uXeGTP9KvPw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"qn4AABOCAgBfqgIA3rgAAGQ6AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=medium-high\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"hUv7DTUjsz8nLxsWqEDYPyBGQZNQxtk\u002fNCYOY27uuz9UcgnT86ShPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"4JMBAF4SAwDYoQEAjUUAAF0RAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_hh_1_group=high\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"YPznAMZ\u002fzj9eEVPmFbHdPx3duMjRjc8\u002fPyTw9kMCpT9sq8+\u002ftvqEPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"BQBXAKAARgAnAA==","shape":"5, 1" ...

# %% [raw]
# ### Employment density

# %%
util.plot_share_facetbar(hh_data.dropna(subset=['log_emptot_1_group']), 'hh_weight', share_col="auto_ownership_4+", title="Auto ownership by employment density", 
                            facet_col="log_emptot_1_group", facet_col_wrap=3, height=500, orientation='v')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="52c120f2-e81e-4d6f-9a6f-65b443e78f1f" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("52c120f2-e81e-4d6f-9a6f-65b443e78f1f")) {                    Plotly.newPlot(                        "52c120f2-e81e-4d6f-9a6f-65b443e78f1f",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"xgMAAMpsAABLfAEAJPsAAPhmAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_emptot_1_group=very low\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"w00kPKo\u002fcj9i3JJS6XDAP2ZVgf2GvNw\u002fFtjhIij60j9wTIs1dh+\u002fPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"4QcAAH+OAACSjQEAbdoAAD9RAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_emptot_1_group=low\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":{"dtype":"f8","bdata":"+pNJ\u002f3EJgz\u002fSGkY\u002fwITFP71V8ODTBN4\u002f9LRhkQ5+0D8cbUJ4x4m4Pw=="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"iDAAANHGAQD+EQMA4C0BAH5mAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_emptot_1_group=medium\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x6","y":{"dtype":"f8","bdata":"CMm1OXBXnT+vg9F4pS\u002fRP+48DrlCs90\u002fRImhUVnQxj+E8aANofuuPw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"qoAAAH+BAgA1qQIA\u002fLsAAGQ4AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_emptot_1_group=medium-high\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"xvxPi4dssz8DVh5ZCTbYPxEz4qy3tdk\u002fhJLjuBphvD\u002fNmJRHswahPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"np4BAKgCAwDhnAEA40wAAKYTAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003elog_emptot_1_group=high\u003cbr\u003eauto_ownership_4+=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample_size=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"E8IczutQzz\u002fLGfyWmBrdPyY8F2lPL88\u002fF8urxKM6pz+kto2aqr6HPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"BQBfAKA ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data
#
# - TO-DO:
#     1. get auto ownership values [0,1,2,3,4+] from ACS data.
#     2. check block_group_id values: not matching ACS block group IDs
#
# - household counts in ACS data

# %%
print(f"n=\n"
      f"{hh_data.loc[hh_data['source']=='model','auto_ownership_2+'].value_counts()[hh_data['auto_ownership_2+'].sort_values().unique()]}")
      
df = hh_data.groupby(['source','block_group_id','auto_ownership_2+'])['hh_weight'].sum().reset_index()
# df_plot = df_plot.loc[df_plot['auto_ownership_2+']!="-1"]

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hh_weight'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_csv("R:/e2projects_two/activitysim/estimation/2017_2019_data/validation_data/auto_ownership/bg_auto_ownership.csv")[['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id']]

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2+',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2+','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# bg_auto_ownership
# Out:
# n=
# auto_ownership_2+
# 0      154487
# 1      542273
# 2+    1038592
# Name: count, dtype: int64

# %% [markdown]
# - scatterplot

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2+'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2+', height=400, width=1000,
                 title="Auto ownership model validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=360, width=800, font=dict(size=11))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="81e47c70-8113-4eee-a939-51ca6e23f265" class="plotly-graph-div" style="height:360px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("81e47c70-8113-4eee-a939-51ca6e23f265")) {                    Plotly.newPlot(                        "81e47c70-8113-4eee-a939-51ca6e23f265",                        [{"hovertemplate":"auto_ownership_2+=0\u003cbr\u003eacs data=%{x}\u003cbr\u003emodel=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"UscDRMgUMkAvuuiiiy4yQMVbrjGrKzJApnEDo840MkBfEQKx\u002fBcyQJOVrGQlKxlAZeDp1vywGECTlaxkJSsZQKL0gqDl3RhASpMmTZo0GUAAAAAAAAAZQD1pG1hkeRhATHxf1PJvGEDO24qJI8I5QMcw2QKI3jlA7aNoGWu4OUAHN\u002fuFWFEyQNgeclkxUDJAPPb0bYcTMkCXPZZL2zkyQMAf8Af8Af8\u002foRYwJnHw\u002fj\u002fAIkrAIkoAQHCpbO86oCFADdIgDdKgIUBELisGSnghQJZ7GmG5pyFAa6211lprIUAhBSyPN7IhQJrTLnT+gChAMEU+6wZTKEAmS7cc+1coQPwI7iO4jyhAKK+hvIby+j\u002f7RZHcJ3P+P8JyTyMs9wJAyiDywFW0A0De9XylsRsVQMog8sBVtBNAFLQDOC8KGkBCGqRBGqQZQJ3dwq\u002fGRDVAvoT2EtpLNUDB2NdcgTg1QJjmLvirODVAAAAAAABANUBzwy4WkSorQCAYki2iOStAKcYPcOE2K0DAH\u002fAH\u002fAEfQMfFAkktUx5AT+zETuzEHkBpz8sTdO4eQCVJkiRJkgxAS8oBkeFeDUDPepBAl1cSQNSvF9ZdgRJA0UQTTTTREkDGp0w7B2syQLIuGJFmZzJACqVQCqVQMkD1mL\u002fXRqwrQJh4P3KarytAJbzR1Pm1K0AgGJItojkrQPJUxlMZTxVAo6nzaw+5FED6GJyPwfkUQF4pMQrN\u002filA0WAm+PXkKUALRn4ASTQqQLqD\u002fVYbQyBA7l\u002fd\u002ftXtH0B2gynyWTcgQE\u002fsxE7sxA5AYOsKze1UDkBZU9aUNWUPQAxXYamhaxFALSkHRIZ7EUCE3ZKaVXsQQOj9Y5kjXBBA3xWZL00cBkCP7BmISkcGQMamk8WmkwVAoVSYeD9yGkC\u002fupAWyyMaQC8eARNDdBhARCG5gNfbGEDHhVSR\u002fbMYQAGRAkQKEBlAx\\u002fhu4yVAT+zETuzEHkBjhjQFuQ0fQD7x+MTjEx9A+N577733HkDdFSj0FFEfQBV2TXIJqhRAYwjZeN0JFEBVVVVVVdUUQNu2bdu2bSVAgtaiUB9oJUA22WSTTTYlQPiQolTS7i5AyRCso837LkCN3y71ZPwuQArXo3A9Ci9AT31R7vLUH0CcqVdyBMMfQJUG79rYmhtAsGk\u002fWQKbGkBNd7DfamMkQJtssskmmyRA1Xyf7AsgBkCOAQ5+buIFQKjioDVnIgZAj10NSy\u002fiBEAg0QqbA4kGQPQxOB+D8wVAJ5xwwgknDECytzZMcxcMQLbUVbsD\u002fQtA1NfRc\u002fcLDEBhpq4U\u002f0kLQBtXjhpXjipAq6qqqqqqKkADLdACLdAqQOA96j+EK0hA8bV4V+YzSEALz4\u002fpYeA+QCYh3\u002flZyz5Ao6nzaw+5PkBx5nUqXdY+QG\u002fV1NfIEyVAPc\u002fzPM\u002fzJEAZ8MnhMuADQHLDvIyD4QRAxBzmMIc5BEDYBsGpTNgwQNFuk\u002fkj0DBAWN6SUEPaMEBsjLbTrOAwQDIN283yJBJA032uQVYqE0DCck8jLPcSQP7z9HoAwxJAXBq+JKTlKUDHMNkCiN4pQHBMm4BS1ClA0LrBFPmsKUAaSI0MCcUpQAouIqH3sypAObjZL8SKKkANmd6B\u002fa0qQJcBnxwuAyJAy+pd8mDAIUCmpaWlpaUhQPdVkUpZDEBALVcy7vzkP0BnBYcvpAhAQEXm0MNd2z9Aep7neZ7nP0A4velNb3pMQFkgkq51Z0xAwHQireB5TECJ5+yfRGFMQAAAAAAAAE5AAAAAAAAATkAAAAAAAAD4\u002f3FH3BF3xCNALMKWz5e7I0B8vMd7vMcjQH5Xi5swvyNAFm2slD3+BUAW\u002fBfNN2oFQAAAAAAA4AVA9IftS+RxBkAermUO4H4GQJAGaZAGaQBAgbKOqyFfAkCQwfkYnI8BQD\u002fiXdMMPQNAD+jGPH20AkDT0tLS0tICQLaErxmmuiJAbbLJJptsIkDmqS\u002fKXZ4iQIyHuBeNSiJA0Q9Q5Qj9IECBHyP1iUEhQEyRz7rBFCFAigdNKQolG0CzMRuzMRsbQDaU11BeQxlAMpEeqJzdGkAbV44aV44aQAAAAAAAQBVAEvLob3vDFUDfz1PG0mQVQDOs1ltQhhVA4qz8hDgrH0BP7MRO7MQeQM6\u002f5OebHR9Aot9sHfrNHkCZjThtE+MCQMxQeKICNgNAcucnX0UvA0AGWsWHiXMWQGZI+Z5NKBZAy2ksp7GcFkBoPOMZz3gWQD744IMPPhhAZjwIpK2XF0A4velNb3oXQKV9kAyoZzJAk3cS8DB8MkDqxXzqxXwyQOgAfyduIDFAVNhy6f0gMUAT17mHn1owQMYhCoNaTjBAqXRkz0BUMED6pV\u002f6pV8wQCELWchCFipADJTbmuEzKkBfypjdScMTQJybm5ubmxNAg\u002fMxOB+DE0Cn8UBuGg8UQAZ9QV\u002fQVzxABdOUxBYzPEASd8QdcUc8QCvUD2y1TDxAwGRiyn0xPEAZJlsA0Ts8QM4A3AqakjtAmO3thnOWO0C2PBUUBUJFQAUvp+DlREVALUyh2s09RUDQBv+2nOlEQEz5Oizh6ERA8MEuTWPoREBSBSce3apBQM1JIC7UnEFAKvJZN5iiQUBiIx020qFBQ ...
