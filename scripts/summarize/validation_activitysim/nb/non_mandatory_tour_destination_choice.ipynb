# %%
# import toml
# from pathlib import Path
# config_path = Path("../../../../configuration/asim_configuration")
# input_config = toml.load(config_path/ "input_configuration.toml")
# summary_config = toml.load(config_path/ "summary_configuration.toml")

# %% [raw]
# ---
# title: Non-mandatory tour destination choice
# date: today
# ---

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os, sys

module_path = os.path.abspath(os.path.join('../../../..')) # or the path to your source code
sys.path.insert(0, module_path)
import util

# %%
# read data
tour = util.get_tour_data(summary_config)

non_m_tour_data = tour.loc[tour['tour_category']=="non_mandatory"]

# %% [markdown]
# ## non-mandatory tour distance

# %% [raw]
# :::{.panel-tabset}
#
# ### distance bins

# %%
# plot1
df_plot = non_m_tour_data.loc[non_m_tour_data['tour_distance_bin'] != float('nan')].groupby(['source','tour_distance_bin'])['tour_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))
# df_plot
fig1 = px.bar(df_plot, x='tour_distance_bin', y="percentage", color="source", barmode="group",
              title="share of non-mandatory tours by distance bin")
fig1.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig1.update_layout(height=400, width=700, font=dict(size=11), yaxis=dict(tickformat=".1%"))
fig1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [raw]
# ### 0 to 60-mile bins

# %%
df_plot = non_m_tour_data.loc[non_m_tour_data['tour_distance_bin_60mi'].notna()].groupby(['source','tour_distance_bin_60mi'])['tour_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))

fig2 = px.line(df_plot, x='tour_distance_bin_60mi', y="percentage", color="source", title="tour distance")
fig2.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig2.update_layout(height=400, width=700, font=dict(size=11), yaxis=dict(tickformat=".1%"))
fig2.show()
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_40896\1249835661.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [raw]
# :::

# %% [markdown]
# ## non-mantatory tour distance by purpose

# %%
df_plot = non_m_tour_data.loc[non_m_tour_data['tour_distance_bin'] != float('nan')].groupby(['source','tour_type','tour_distance_bin'], observed=True)['tour_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source','tour_type'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))
# df_plot
fig1 = px.bar(df_plot, x='tour_distance_bin', y="percentage", color="source", barmode="group",
              facet_row='tour_type',
              title="tour distance bin by tour purpose")
fig1.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig1.update_layout(height=1000, width=700, font=dict(size=11), yaxis=dict(tickformat=".1%"))
fig1.show()
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_40896\376550004.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
